# %% [markdown]
# <a href="https://colab.research.google.com/github/analyticsariel/projects/blob/master/BatchData_SkipTracing_MockData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Batch Data Skip Tracing Mock Data
#
# ## Overview
# | Detail Tag            | Information                                                                                        |
# |-----------------------|----------------------------------------------------------------------------------------------------|
# | Originally Created By | Ariel Herrera arielherrera@analyticsariel.com |
# | External References   | API |
# | Input Datasets        | Source name |
# | Output Datasets       | Source name |
# | Input Data Source     | Pandas DataFrame |
# | Output Data Source    | Pandas DataFrame |
#
# ## History
# | Date         | Developed By  | Reason                                                |
# |--------------|---------------|-------------------------------------------------------|
# | 1st Jun 2022 | Ariel Herrera | Create notebook. |
#
# ## Getting Started
# 1. Copy this notebook -> File -> Save a Copy in Drive
# 2. Directions
#   - Signup for BatchData
#   - Create mock api key and live api key
#
# ## Useful Resources
# - [Google Colab Cheat Sheet](https://towardsdatascience.com/cheat-sheet-for-google-colab-63853778c093)
# - [BatchData API docs](https://developer.batchdata.com/docs/batchdata/a45e094c668b1-property-skip-trace)
# - [Curl Convertor](https://curlconverter.com/#)

# %% [markdown]
# ## <font color="blue">Install Packages</font>

# %% [markdown]
# ## <font color="blue">Imports</font>

# %%
from google.colab import drive, files # google colab specific
import pandas as pd
import requests
import os
import warnings

pd.set_option('display.max_columns', None) # show all columns

# %% [markdown]
# ## <font color="blue">Functions</font>

# %% [markdown]
# ## <font color="blue">Locals & Constants</font>

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# set working directory
os.chdir('/content/drive/MyDrive/Colab Data/')
dir = os.getcwd()
print('Current working directory:', dir)

# remove pandas warnings
warnings.filterwarnings('ignore')
# Out:
# Current working directory: /content/drive/MyDrive/Colab Data

# %% [markdown]
# ## <font color="blue">Data</font>

# %%
# read in api keys
df_api_keys = pd.read_csv(dir + '/input/api_keys.csv')
# extract api key
batchdata_mock_api_key = df_api_keys.loc[df_api_keys['API'] == 'batchdata_mock']['KEY'].iloc[0]

# %% [markdown]
# ## <font color="blue">Transformations</font>

# %% [markdown]
# ### <font color="green">1) Single Property - Skip Trace Search</font>

# %%
url = 'https://stoplight.io/mocks/batchdata/batchdata/20349728/property/skip-trace'

json_data = {
  'requests': [
    {
      'propertyAddress': {
        "city": "Franklin Square",
        "street": "1011 Rosegold St",
        "state": "NY",
        "zip": "11010"
      },
    },
  ],
}

headers = {
  'Content-Type': "application/json",
  'Authorization': 'Bearer ' + batchdata_mock_api_key
}

response = requests.post(url, headers=headers, json=json_data)
response.text
# Out:
# '{"status":{"code":200,"text":"OK"},"results":{"persons":[{"_id":"tOdljN72SozLw","bankruptcy":{},"death":{},"dnc":{},"emails":[{"email":"john@example.net"}],"mailingAddress":{},"name":{"first":"john","last":"dow"},"phoneNumbers":[{"number":"123123123","carrier":"test carries","type":"Mobile","tested":true,"reachable":true,"score":100},{"number":"123123","carrier":"test carries","type":"Land Line","tested":false,"reachable":false,"score":95},{"number":"123123","carrier":"test carries.","type":"Land Line","tested":true,"reachable":true,"score":90},{"number":"123123","carrier":"test carries","type":"Land Line","tested":true,"reachable":true,"score":85}],"litigator":false,"propertyAddress":{"houseNumber":"1011","street":"1011 Rosegold St","city":"Franklin Square","county":"Nassau","state":"NY","zip":"11010","zipPlus4":"2507","formattedStreet":"Rosegold St","streetNoUnit":"1011 Rosegold St","hash":"b7bd4cea51b26af459febfbf822c99e2"},"involuntaryLien":[],"property":{"address":{"houseNumber":"1011","street":"1011 Rosegold St","city":"Franklin Square","county":"Nassau","state":"NY","zip":"11010","zipPlus4":"2507","localities":["franklin square"],"hash":"b7bd4cea51b26af459febfbf822c99e2","latitude":40.704661,"longitude":-73.6776615,"countyFipsCode":"36059","formattedStreet":"Rosegold St","streetNoUnit":"1011 Rosegold St","geoStatus":"Rooftop"},"owner":{"name":{"first":"john","last":"doe"},"mailingAddress":{"houseNumber":"161","street":"161 Sheridan Blvd","city":"Mineola","county":"Nassau","state":"NY","zip":"11501","formattedStreet":"Sheridan Blvd","streetNoUnit":"161 Sheridan Blvd","hash":"8659e28750aff33159bdc0dbc484bf6f"}},"equity":171469,"equityPercent":30.2,"absenteeOwner":true,"vacant":false,"uspsDeliverable":true},"meta":{"matched":true,"error":false}}],"meta":{"apiVersion":"2.10.2","performance":{"totalRequestTime":948,"startTime":"2022-04-20T11:25:00.231Z","endTime":"2022-04-20T11:25:01.179Z"},"results":{"requestCount":1,"matchCount":1,"noMatchCount":0,"errorCount":0},"requestId":"1gKSoy00kQLgmyQ"}}}'

# %%
response.json()['results']
# Out:
# {'meta': {'apiVersion': '2.10.2',
#   'performance': {'endTime': '2022-04-20T11:25:01.179Z',
#    'startTime': '2022-04-20T11:25:00.231Z',
#    'totalRequestTime': 948},
#   'requestId': '1gKSoy00kQLgmyQ',
#   'results': {'errorCount': 0,
#    'matchCount': 1,
#    'noMatchCount': 0,
#    'requestCount': 1}},
#  'persons': [{'_id': 'tOdljN72SozLw',
#    'bankruptcy': {},
#    'death': {},
#    'dnc': {},
#    'emails': [{'email': 'john@example.net'}],
#    'involuntaryLien': [],
#    'litigator': False,
#    'mailingAddress': {},
#    'meta': {'error': False, 'matched': True},
#    'name': {'first': 'john', 'last': 'dow'},
#    'phoneNumbers': [{'carrier': 'test carries',
#      'number': '123123123',
#      'reachable': True,
#      'score': 100,
#      'tested': True,
#      'type': 'Mobile'},
#     {'carrier': 'test carries',
#      'number': '123123',
#      'reachable': False,
#      'score': 95,
#      'tested': False,
#      'type': 'Land Line'},
#     {'carrier': 'test carries.',
#      'number': '123123',
#      'reachable': True,
#      'score': 90,
#      'tested': True,
#      'type': 'Land Line'},
#     {'carrier': 'test carries',
#      'number': '123123',
#      'reachable': True,
#      'score': 85,
#      'tested': True,
#      'type': 'Land Line'}],
#    'property': {'absenteeOwner': True,
#     'address': {'city': 'Franklin Square',
#      'county': 'Nassau',
#      'countyFipsCode': '36059',
#      'formattedStreet': 'Rosegold St',
#      'geoStatus': 'Rooftop',
#      'hash': 'b7bd4cea51b26af459febfbf822c99e2',
#      'houseNumber': '1011',
#      'latitude': 40.704661,
#      'localities': ['franklin square'],
#      'longitude': -73.6776615,
#      'state': 'NY',
#      'street': '1011 Rosegold St',
#      'streetNoUnit': '1011 Rosegold St',
#      'zip': '11010',
#      'zipPlus4': '2507'},
#     'equity': 171469,
#     'equityPercent': 30.2,
#     'owner': {'mailingAddress': {'city': 'Mineola',
#       'county': 'Nassau',
#       'formattedStreet': 'Sheridan Blvd',
#       'hash': '8659e28750aff33159bdc0dbc484bf6f',
#       'houseNumber': '161',
#       'state': 'NY',
#       'street': '161 Sheridan Blvd',
#       'streetNoUnit': '161 Sheridan Blvd',
#       'zip': '11501'},
#      'name': {'first': 'john', 'last': 'doe'}},
#     'uspsDeliverable': True,
#     'vacant': False},
#    'propertyAddress': {'city': 'Franklin Square',
#     'county': 'Nassau',
#     'formattedStreet': 'Rosegold St',
#     'hash': 'b7bd4cea51b26af459febfbf822c99e2',
#     'houseNumber': '1011',
#     'state': 'NY',
#     'street': '1011 Rosegold St',
#     'streetNoUnit': '1011 Rosegold St',
#     'zip': '11010',
#     'zipPlus4': '2507'}}]}

# %%
_df = pd.json_normalize(response.json()['results']['persons'])
print('No of columns:', len(_df.columns))
_df
# Out:
# No of columns: 50
#              _id                           emails  \
# 0  tOdljN72SozLw  [{'email': 'john@example.net'}]
#
#                                         phoneNumbers  litigator  \
# 0  [{'number': '123123123', 'carrier': 'test carr...      False
#
#   involuntaryLien name.first name.last propertyAddress.houseNumber  \
# 0              []       john       dow                        1011
#
#   propertyAddress.street propertyAddress.city propertyAddress.county  \
# 0       1011 Rosegold St      Franklin Square                 Nassau
#
#   propertyAddress.state propertyAddress.zip propertyAddress.zipPlus4  \
# 0                    NY               11010                     2507
#
#   propertyAddress.formattedStreet propertyAddress.streetNoUnit  \
# 0                     Rosegold St             1011 Rosegold St
#
#                propertyAddress.hash property.address.houseNumber  \
# 0  b7bd4cea51b26af459febfbf822c99e2                         1011
#
#   property.address.street property.address.city property.address.county  \
# 0        1011 Rosegold St       Franklin Square                  Nassau
#
#   property.address.state property.address.zip property.address.zipPlus4  \
# 0                     NY                11010                      2507
#
#   property.address.localities             property.address.hash  \
# 0           [franklin square]  b7bd4cea51b26af459febfbf822c99e2
#
#    property.address.latitude  property.address.longitude  \
# 0                  40.704661                  -73.677661
#
#   property.address.countyFipsCode property.address.formattedStreet  \
# 0                           36059                      Rosegold St
#
#   property.address.streetNoUnit property.address.geoStatus  \
# 0              1011 Rosegold St                    Rooftop
#
#   property.owner.name.first property.owner.name.last  \
# 0                      john                      doe
#
#   property.owner.mailingAddress.houseNumber  \
# 0                                       161
#
#   property.owner.mailingAddress.street property.owner.mailingAddress.city  \
# 0                    161 Sheridan Blvd                            Mineola
#
#   property.owner.mailingAddress.county property.owner.mailingAddress.state  \
# 0                               Nassau                                  NY
#
#   property.owner.mailingAddress.zip  \
# 0                             11501
#
#   property.owner.mailingAddress.formattedStreet  \
# 0                                 Sheridan Blvd
#
#   property.owner.mailingAddress.streetNoUnit  \
# 0                          161 Sheridan Blvd
#
#   property.owner.mailingAddress.hash  property.equity  property.equityPercent  \
# 0   8659e28750aff33159bdc0dbc484bf6f           171469                    30.2
#
#    property.absenteeOwner  property.vacant  property.uspsDeliverable  \
# 0                    True            False                      True
#
#    meta.matched  meta.error
# 0          True       False

# %%
df_phone_num = pd.DataFrame(_df["phoneNumbers"].iloc[0])
df_phone_num
# Out:
#       number        carrier       type  tested  reachable  score
# 0  123123123   test carries     Mobile    True       True    100
# 1     123123   test carries  Land Line   False      False     95
# 2     123123  test carries.  Land Line    True       True     90
# 3     123123   test carries  Land Line    True       True     85

# %%
# filter on valid phone numbers
df_ph_valid = df_phone_num.loc[
  (df_phone_num['reachable'] == True) & (df_phone_num['score'] >= 90)]
# change phone numbers for testing purposes only
df_ph_valid['number'] = [6027828692, 5633574823] # mock dnc phone numbers
df_ph_valid['number'] = df_ph_valid['number'].astype(str)
df_ph_valid
# Out:
#        number        carrier       type  tested  reachable  score
# 0  6027828692   test carries     Mobile    True       True    100
# 2  5633574823  test carries.  Land Line    True       True     90

# %%
url = "https://stoplight.io/mocks/batchdata/batchdata/20349728/phone/dnc"

json_data = {
  'requests': df_ph_valid['number'].tolist(), # pass all valid numbers
}

headers = {
  'Content-Type': "application/json",
  'Authorization': 'Bearer ' + batchdata_mock_api_key
}

dnc_response = requests.post(url, headers=headers, json=json_data)
dnc_response.json()
# Out:
# {'results': {'meta': {'apiVersion': '2.0',
#    'performance': {'endTime': '2021-10-05T21:18:51.009Z',
#     'startTime': '2021-10-05T21:18:50.576Z',
#     'totalRequestTime': 433},
#    'requestId': 'qTmKWCL3mDLIpmX',
#    'results': {'errorCount': 0,
#     'matchCount': 3,
#     'noMatchCount': 0,
#     'requestCount': 3}},
#   'phoneNumbers': [{'dnc': False,
#     'meta': {'error': False, 'matched': True},
#     'number': '6027828692'},
#    {'dnc': True,
#     'meta': {'error': False, 'matched': True},
#     'number': '5633574823'},
#    {'dnc': True,
#     'meta': {'error': False, 'matched': True},
#     'number': '4808602153'}]},
#  'status': {'code': 200, 'text': 'OK'}}

# %%
# transform JSON object to a DataFrame and select relevant columns
df_dnc = pd.json_normalize(dnc_response.json()['results']['phoneNumbers'])[['number', 'dnc']]
df_dnc
# Out:
#        number    dnc
# 0  6027828692  False
# 1  5633574823   True
# 2  4808602153   True

# %%
# convert numbers to string type
df_ph_valid['number'] = df_ph_valid['number'].astype(str)
df_dnc['number'] = df_dnc['number'].astype(str)
# merge valid and dnc tables
df_ph_valid_dnc = pd.merge(df_ph_valid, df_dnc, how='left', on=['number'])
df_ph_valid_dnc
# Out:
#        number        carrier       type  tested  reachable  score    dnc
# 0  6027828692   test carries     Mobile    True       True    100  False
# 1  5633574823  test carries.  Land Line    True       True     90   True

# %%
# filter on phone numbers that are NOT on DNC (Do Not Call) list
df_ph_valid_dnc_fltr = df_ph_valid_dnc.loc[df_ph_valid_dnc['dnc'] == False]
df_ph_valid_dnc_fltr
# Out:
#        number       carrier    type  tested  reachable  score    dnc
# 0  6027828692  test carries  Mobile    True       True    100  False

# %%
# create copy of df
df = _df.copy()

# create phone numbers columns
i = 1
# itereate through list of valid numbers
for num in df_ph_valid_dnc_fltr['number'].tolist():
  df['phone' + str(i)] = [num] # create column

# create email column
df['emails'] = df.apply(lambda x: x['emails'][0], axis=1)
df = pd.concat([df, df["emails"].apply(pd.Series)], axis=1)
df
# Out:
#              _id                         emails  \
# 0  tOdljN72SozLw  {'email': 'john@example.net'}
#
#                                         phoneNumbers  litigator  \
# 0  [{'number': '123123123', 'carrier': 'test carr...      False
#
#   involuntaryLien name.first name.last propertyAddress.houseNumber  \
# 0              []       john       dow                        1011
#
#   propertyAddress.street propertyAddress.city propertyAddress.county  \
# 0       1011 Rosegold St      Franklin Square                 Nassau
#
#   propertyAddress.state propertyAddress.zip propertyAddress.zipPlus4  \
# 0                    NY               11010                     2507
#
#   propertyAddress.formattedStreet propertyAddress.streetNoUnit  \
# 0                     Rosegold St             1011 Rosegold St
#
#                propertyAddress.hash property.address.houseNumber  \
# 0  b7bd4cea51b26af459febfbf822c99e2                         1011
#
#   property.address.street property.address.city property.address.county  \
# 0        1011 Rosegold St       Franklin Square                  Nassau
#
#   property.address.state property.address.zip property.address.zipPlus4  \
# 0                     NY                11010                      2507
#
#   property.address.localities             property.address.hash  \
# 0           [franklin square]  b7bd4cea51b26af459febfbf822c99e2
#
#    property.address.latitude  property.address.longitude  \
# 0                  40.704661                  -73.677661
#
#   property.address.countyFipsCode property.address.formattedStreet  \
# 0                           36059                      Rosegold St
#
#   property.address.streetNoUnit property.address.geoStatus  \
# 0              1011 Rosegold St                    Rooftop
#
#   property.owner.name.first property.owner.name.last  \
# 0                      john                      doe
#
#   property.owner.mailingAddress.houseNumber  \
# 0                                       161
#
#   property.owner.mailingAddress.street property.owner.mailingAddress.city  \
# 0                    161 Sheridan Blvd                            Mineola
#
#   property.owner.mailingAddress.county property.owner.mailingAddress.state  \
# 0                               Nassau                                  NY
#
#   property.owner.mailingAddress.zip  \
# 0                             11501
#
#   property.owner.mailingAddress.formattedStreet  \
# 0                                 Sheridan Blvd
#
#   property.owner.mailingAddress.streetNoUnit  \
# 0                          161 Sheridan Blvd
#
#   property.owner.mailingAddress.hash  property.equity  property.equityPercent  \
# 0   8659e28750aff33159bdc0dbc484bf6f           171469                    30.2
#
#    property.absenteeOwner  property.vacant  property.uspsDeliverable  \
# 0                    True            False                      True
#
#    meta.matched  meta.error      phone1             email
# 0          True       False  6027828692  john@example.net

# %%
output_cols = ['name.first', 'name.last',
       'propertyAddress.street', 'propertyAddress.city',
       'propertyAddress.county', 'propertyAddress.state',
       'propertyAddress.zip', 'property.equity',
       'property.equityPercent', 'property.absenteeOwner', 'property.vacant',
       'property.uspsDeliverable', 'phone1', 'email']

df_output = df[output_cols]
df_output
# Out:
#   name.first name.last propertyAddress.street propertyAddress.city  \
# 0       john       dow       1011 Rosegold St      Franklin Square
#
#   propertyAddress.county propertyAddress.state propertyAddress.zip  \
# 0                 Nassau                    NY               11010
#
#    property.equity  property.equityPercent  property.absenteeOwner  \
# 0           171469                    30.2                    True
#
#    property.vacant  property.uspsDeliverable      phone1             email
# 0            False                      True  6027828692  john@example.net

# %% [markdown]
# ### <font color="green">2) Multi Property - Skip Trace Search</font>

# %% [markdown]
# ## <font color="blue">Output</font>

# %%
# download file
df_output.to_csv('output.csv', index=False)
files.download('output.csv')

# %% [markdown]
# # End Notebook
