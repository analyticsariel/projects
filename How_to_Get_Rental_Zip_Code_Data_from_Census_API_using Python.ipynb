# %% [markdown]
# <a href="https://colab.research.google.com/github/analyticsariel/projects/blob/master/How_to_Get_Rental_Zip_Code_Data_from_Census_API_using%C2%A0Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to Get Rental Zip Code Data from Census API using Python
#
# ## Overview
# | Detail Tag            | Information                                                                                        |
# |-----------------------|----------------------------------------------------------------------------------------------------|
# | Originally Created By | Ariel Herrera arielherrera@analyticsariel.com |
# | External References   | API |
# | Input Datasets        | Source name |
# | Output Datasets       | Source name |
# | Input Data Source     | Pandas DataFrame |
# | Output Data Source    | Pandas DataFrame |
#
# ## History
# | Date         | Developed By  | Reason                                                |
# |--------------|---------------|-------------------------------------------------------|
# | 1st Sep 2022 | Ariel Herrera | Create notebook. |
#
# ## Getting Started
# 1. Copy this notebook -> File -> Save a Copy in Drive
# 2. Directions
#
# ## Useful Resources
# - [American Community Survey 5-Year Data API](https://www.census.gov/data/developers/data-sets/acs-5year.html)
# - [Request Census API Key](https://api.census.gov/data/key_signup.html)
# - [Google Colab Cheat Sheet](https://towardsdatascience.com/cheat-sheet-for-google-colab-63853778c093)

# %% [markdown]
# ## <font color="blue">Install Packages</font>

# %% [markdown]
# ## <font color="blue">Imports</font>

# %%
from google.colab import output, drive, files # specific to Google Colab
import pandas as pd
import numpy as np
import plotly.express as px
import requests
import warnings

# settings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## <font color="blue">Functions</font>

# %%
def zip_code_to_str(x):
  x_str = str(x).split('.')[0]
  if len(x_str) == 5:
    return x_str
  elif len(x_str) == 4:
    return '0' + x_str
  elif len(x_str) == 3:
    return '00' + x_str

# %% [markdown]
# ## <font color="blue">Locals & Constants</font>

# %%
############
# OPTIONAL #
############

# mount drive
drive.mount('/content/drive', force_remount=False)

# data location
file_dir = '/content/drive/My Drive/Colab Data/input/' # optional
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# read in api key file
df_api_keys = pd.read_csv(file_dir + 'api_keys.csv')

# get keys
census_api_key = df_api_keys.loc[df_api_keys['API'] =='census']['KEY'].iloc[0] # replace this with your own key
rapid_api_key = df_api_keys.loc[df_api_keys['API'] =='rapid']['KEY'].iloc[0] # replace this with your own key

# %% [markdown]
# ## <font color="blue">Data</font>

# %% [markdown]
# ### <font color="green">Section #1 - API Requests</font> 💻
# This section will cover how to make API requests to the [American Community Survey 5-Year Data API](https://www.census.gov/data/developers/data-sets/acs-5year.html) It demonstrates how to modify your search based on different parameters.

# %%
variable = 'B25031_001E' # median rent all beds
year = '2020'

# %% [markdown]
# #### <font color="purple">1. National Region</font> 👨‍👩‍👧‍👦

# %%
# get data by nation
url = 'https://api.census.gov/data/{0}/acs/acs5?get=NAME,{1}&for=us:*&key={2}'\
  .format(year, variable, census_api_key)
# request data
response = requests.request("GET", url)
# view status code
response.status_code
# Out:
# 200

# %%
# view data
response.text
# Out:
# '[["NAME","B25031_001E","us"],\n["United States","1096","1"]]'

# %%
# transform to JSON object
response.json()
# Out:
# [['NAME', 'B25031_001E', 'us'], ['United States', '1096', '1']]

# %%
# read median rent data as a dataframe
df_national = pd.DataFrame(response.json()[1:], columns=response.json()[0])
df_national
# Out:
#             NAME B25031_001E us
# 0  United States        1096  1

# %%
# rename columns
df_national = df_national.rename(columns={'B25031_001E': 'median_rent_all_bds'})
df_national
# Out:
#             NAME median_rent_all_bds us
# 0  United States                1096  1

# %% [markdown]
# #### <font color="purple">2. Zip Code</font> 👨‍👩‍👧‍👦

# %% [markdown]
# ##### <font color="orange">Get HUD Tract Data</font>

# %%
# read zip to tract data from HUD
hud_tract_url = 'https://raw.githubusercontent.com/analyticsariel/market-research-data/main/ZIP_TRACT_122021.csv'
_df_hud_tract = pd.read_csv(hud_tract_url)

# dataframe detail
print('Num of rows:', len(_df_hud_tract))
print('Num of columns:', len(_df_hud_tract.columns))
_df_hud_tract.head()
# Out:
# Num of rows: 172177
# Num of columns: 8
#    zip        tract usps_zip_pref_city usps_zip_pref_state  res_ratio  \
# 0  683  72023830102         SAN GERMAN                  PR   0.000791
# 1  683  72125840700         SAN GERMAN                  PR   0.186219
# 2  683  72125840400         SAN GERMAN                  PR   0.300451
# 3  683  72125840600         SAN GERMAN                  PR   0.095325
# 4  683  72121960300         SAN GERMAN                  PR   0.042402
#
#    bus_ratio  oth_ratio  tot_ratio
# 0   0.001116   0.000000   0.000800
# 1   0.370536   0.381643   0.201179
# 2   0.187500   0.115942   0.290308
# 3   0.007812   0.000000   0.088184
# 4   0.002232   0.019324   0.039435

# %%
# clean zip / tract (issue with cut off IDs, data read as [int] type)
df_hud_tract = _df_hud_tract.copy()
df_hud_tract['zip'] = df_hud_tract.apply(lambda x: zip_code_to_str(x['zip']), axis=1)
df_hud_tract['tract'] = df_hud_tract.apply(lambda x: 
  '0' + str(x['tract']) if len(str(x['tract'])) == 10 else str(x['tract']), axis=1)
df_hud_tract['state_code'] = df_hud_tract.apply(lambda x: x['tract'][:2], axis=1)
df_hud_tract['county_code'] = df_hud_tract.apply(lambda x: x['tract'][2:5], axis=1)
df_hud_tract['tract_code'] = df_hud_tract.apply(lambda x: x['tract'][5:], axis=1)
df_hud_tract.head()
# Out:
#      zip        tract usps_zip_pref_city usps_zip_pref_state  res_ratio  \
# 0  00683  72023830102         SAN GERMAN                  PR   0.000791
# 1  00683  72125840700         SAN GERMAN                  PR   0.186219
# 2  00683  72125840400         SAN GERMAN                  PR   0.300451
# 3  00683  72125840600         SAN GERMAN                  PR   0.095325
# 4  00683  72121960300         SAN GERMAN                  PR   0.042402
#
#    bus_ratio  oth_ratio  tot_ratio state_code county_code tract_code
# 0   0.001116   0.000000   0.000800         72         023     830102
# 1   0.370536   0.381643   0.201179         72         125     840700
# 2   0.187500   0.115942   0.290308         72         125     840400
# 3   0.007812   0.000000   0.088184         72         125     840600
# 4   0.002232   0.019324   0.039435         72         121     960300

# %%
# view sample zipcode
zipcode = '33606' # Hyde Park / Davis Island, Tampa, FL
df_zip_sample = df_hud_tract.loc[df_hud_tract['zip'] == zipcode]
df_zip_sample
# Out:
#          zip        tract usps_zip_pref_city usps_zip_pref_state  res_ratio  \
# 93377  33606  12057005500              TAMPA                  FL   0.164003
# 93378  33606  12057006103              TAMPA                  FL   0.006683
# 93379  33606  12057005401              TAMPA                  FL   0.251603
# 93380  33606  12057005000              TAMPA                  FL   0.182606
# 93381  33606  12057006000              TAMPA                  FL   0.035853
# 93382  33606  12057006101              TAMPA                  FL   0.156687
# 93383  33606  12057004900              TAMPA                  FL   0.202565
#
#        bus_ratio  oth_ratio  tot_ratio state_code county_code tract_code
# 93377   0.248222   0.217361   0.178734         12         057     005500
# 93378   0.025210   0.006944   0.008748         12         057     006103
# 93379   0.122172   0.208333   0.232930         12         057     005401
# 93380   0.188106   0.103472   0.175107         12         057     005000
# 93381   0.040078   0.013889   0.034068         12         057     006000
# 93382   0.085326   0.145139   0.147653         12         057     006101
# 93383   0.290886   0.304861   0.222760         12         057     004900

# %% [markdown]
# ##### <font color="orange">Get Census Data</font>

# %%
# prepare parameters
tract_str = ','.join(df_zip_sample['tract_code'].tolist())
state = df_zip_sample['state_code'].iloc[0]
county = df_zip_sample['county_code'].iloc[0]
print('Year:', year)
print('Variable:', variable)
print('Tracts:',  tract_str)
print('State:', state)
print('County:', county)
# Out:
# Year: 2020
# Variable: B25031_001E
# Tracts: 005500,006103,005401,005000,006000,006101,004900
# State: 12
# County: 057

# %%
# get data from census
url = 'https://api.census.gov/data/{0}/acs/acs5?get=NAME,{1}&for=tract:{2}&in=state:{3}%20county:{4}&key={5}'\
  .format(year, variable, tract_str, state, county, census_api_key)
response = requests.request("GET", url)
response.status_code
# Out:
# 200

# %%
# read rent data
df_zip = pd.DataFrame(response.json()[1:], columns=response.json()[0])\
  .rename(columns={'B25031_001E': 'median_rent_all_bds'})
print('Num of rows:', len(df_zip))
df_zip.sort_values(by=['median_rent_all_bds'])
# Out:
# Num of rows: 6
#                                                NAME median_rent_all_bds state  \
# 5  Census Tract 61.03, Hillsborough County, Florida                1192    12
# 0     Census Tract 50, Hillsborough County, Florida                1215    12
# 1  Census Tract 54.01, Hillsborough County, Florida                1234    12
# 4  Census Tract 61.01, Hillsborough County, Florida                1700    12
# 3     Census Tract 60, Hillsborough County, Florida                1754    12
# 2     Census Tract 55, Hillsborough County, Florida                1807    12
#
#   county   tract
# 5    057  006103
# 0    057  005000
# 1    057  005401
# 4    057  006101
# 3    057  006000
# 2    057  005500

# %%
print('For zipcode:{0} median rent in {1} is ${2}'.format(zipcode, year, df_zip['median_rent_all_bds'].median()))
# Out:
# For zipcode:33606 median rent in 2020 is $1467.0

# %% [markdown]
# ### <font color="green">Section #2 - Loops</font> 🏙
# Get data for multiple years for a given region

# %%
# list of years for Census API
year_list = ['2015', '2016', '2017', '2018', '2019', '2020']

# %% [markdown]
# #### <font color="purple">1. Census API</font>

# %%
# iterate through list of years
df_list = []
for year in year_list:
  # get median rent for the sample zipcode
  url = 'https://api.census.gov/data/{0}/acs/acs5?get=NAME,{1}&for=tract:{2}&in=state:{3}%20county:{4}&key={5}'\
    .format(year, variable, tract_str, state, county, census_api_key)
  response = requests.request("GET", url)
  _df = pd.DataFrame(response.json()[1:], columns=response.json()[0])
  _df['year'] = year
  df_list.append(_df)

# combine responses into a single dataframe
df_census = pd.concat(df_list)\
  .rename(columns={'B25031_001E': 'median_rent_all_bds'})
df_census['median_rent_all_bds'] = df_census['median_rent_all_bds'].astype(int)
print('Num of rows:', len(df_census))
df_census.head()
# Out:
# Num of rows: 41
#                                                NAME  median_rent_all_bds  \
# 0     Census Tract 50, Hillsborough County, Florida                 1054
# 1  Census Tract 61.01, Hillsborough County, Florida                 1195
# 2  Census Tract 54.01, Hillsborough County, Florida                 1045
# 3  Census Tract 61.03, Hillsborough County, Florida                  921
# 4     Census Tract 60, Hillsborough County, Florida                 1039
#
#   state county   tract  year
# 0    12    057  005000  2015
# 1    12    057  006101  2015
# 2    12    057  005401  2015
# 3    12    057  006103  2015
# 4    12    057  006000  2015

# %%
# group by year
df_census_grp = df_census.groupby(['year'])['median_rent_all_bds'].median().reset_index()
df_census_grp
# Out:
#    year  median_rent_all_bds
# 0  2015               1054.0
# 1  2016               1160.0
# 2  2017               1205.0
# 3  2018               1314.0
# 4  2019               1416.0
# 5  2020               1467.0

# %% [markdown]
# #### <font color="purple">2. US Housing Market Data API</font> 🏘
# Get enriched housing and economic datasets by signing up for the [US Housing Market Data API](https://bit.ly/3AHH7sY).

# %%
# get enriched dataset of housing and economic data
url = "https://us-housing-market-data.p.rapidapi.com/getZipcodeEnriched"

querystring = {"zipcode":zipcode}

headers = {
	"X-RapidAPI-Key": rapid_api_key,
	"X-RapidAPI-Host": "us-housing-market-data.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
df_zip_e = pd.DataFrame.from_dict(response.json(), orient='index')
print('Num of rows: {}'.format(len(df_zip_e)))
print('Num of columns: {}'.format(len(df_zip_e.columns)))
df_zip_e.tail()
# Out:
# Num of rows: 72
# Num of columns: 71
#     census.year  census.state  census.zipcode  census.median_household_income  \
# 67         2020            12           33606                        115096.0
# 68         2020            12           33606                        115096.0
# 69         2020            12           33606                        115096.0
# 70         2020            12           33606                        115096.0
# 71         2020            12           33606                        115096.0
#
#     census.median_rent_all_bds  census.median_rent_0_beds  \
# 67                      1467.0                     1205.0
# 68                      1467.0                     1205.0
# 69                      1467.0                     1205.0
# 70                      1467.0                     1205.0
# 71                      1467.0                     1205.0
#
#     census.median_rent_1_beds  census.median_rent_2_beds  \
# 67                     1179.0                     1743.0
# 68                     1179.0                     1743.0
# 69                     1179.0                     1743.0
# 70                     1179.0                     1743.0
# 71                     1179.0                     1743.0
#
#     census.median_rent_3_beds  census.median_rent_4_beds  \
# 67                     2054.0                     1742.0
# 68                     2054.0                     1742.0
# 69                     2054.0                     1742.0
# 70                     2054.0                     1742.0
# 71                     2054.0                     1742.0
#
#    census.median_rent_5+_beds redfin.period_begin redfin.period_end  \
# 67                       None          2020-11-01        2021-01-31
# 68                       None          2020-04-01        2020-06-30
# 69                       None          2020-07-01        2020-09-30
# 70                       None          2020-02-01        2020-04-30
# 71                       None          2020-01-01        2020-03-31
#
#     redfin.period_duration redfin.region_type  redfin.region_type_id  \
# 67                      90           zip code                      2
# 68                      90           zip code                      2
# 69                      90           zip code                      2
# 70                      90           zip code                      2
# 71                      90           zip code                      2
#
#     redfin.table_id redfin.is_seasonally_adjusted    redfin.region  \
# 67            14272                             f  Zip Code: 33606
# 68            14272                             f  Zip Code: 33606
# 69            14272                             f  Zip Code: 33606
# 70            14272                             f  Zip Code: 33606
# 71            14272                             f  Zip Code: 33606
#
#    redfin.city redfin.state redfin.state_code       redfin.property_type  \
# 67        None      Florida                FL  Single Family Residential
# 68        None      Florida                FL  Single Family Residential
# 69        None      Florida                FL  Single Family Residential
# 70        None      Florida                FL  Single Family Residential
# 71        None      Florida                FL  Single Family Residential
#
#     redfin.property_type_id  redfin.median_sale_price  \
# 67                        6                  910000.0
# 68                        6                  928750.0
# 69                        6                  849000.0
# 70                        6                  773062.5
# 71                        6                  775000.0
#
#     redfin.median_sale_price_mom  redfin.median_sale_price_yoy  \
# 67                     -0.018815                      0.116564
# 68                      0.218033                      0.077436
# 69                     -0.094400                      0.078095
# 70                     -0.002500                      0.023924
# 71                     -0.060606                      0.152416
#
#     redfin.median_list_price  redfin.median_list_price_mom  \
# 67                  914850.0                     -0.005598
# 68                  950000.0                      0.279462
# 69                  948250.0                     -0.196398
# 70                  778062.5                     -0.056322
# 71                  824500.0                     -0.173434
#
#     redfin.median_list_price_yoy  redfin.median_ppsf  redfin.median_ppsf_mom  \
# 67                     -0.010973          388.565085                0.036721
# 68                      0.131087          353.477081                0.068033
# 69                      0.355611          368.117798               -0.013694
# 70                     -0.180986          344.006492               -0.026953
# 71                     -0.096438          353.535354               -0.057537
#
#     redfin.median_ppsf_yoy  redfin.median_list_ppsf  \
# 67                0.040327               398.890736
# 68                0.043833               368.117798
# 69                0.044758               389.404494
# 70                0.047434               355.293759
# 71                0.099539               377.393228
#
#     redfin.median_list_ppsf_mom  redfin.median_list_ppsf_yoy  \
# 67                    -0.032381                     0.056684
# 68                     0.036848                     0.031853
# 69                    -0.001999                     0.072374
# 70                    -0.058558                    -0.043659
# 71                    -0.032475                     0.034347
#
#     redfin.homes_sold  redfin.homes_sold_mom  redfin.homes_sold_yoy  \
# 67               47.0               0.021739               0.468750
# 68               44.0               0.100000              -0.137255
# 69               53.0               0.000000               0.261905
# 70               42.0               0.200000               0.135135
# 71               35.0               0.060606               0.250000
#
#     redfin.pending_sales  redfin.pending_sales_mom  redfin.pending_sales_yoy  \
# 67                   8.0                 -0.600000                 -0.333333
# 68                  19.0                  0.727273                  0.000000
# 69                  12.0                  0.000000                 -0.076923
# 70                  12.0                  0.200000                  0.090909
# 71                  10.0                 -0.375000                 -0.090909
#
#     redfin.new_listings  redfin.new_listings_mom  redfin.new_listings_yoy  \
# 67                 39.0                -0.093023                 0.083333
# 68                 55.0                -0.083333                 0.018519
# 69                 54.0                 0.000000                -0.018182
# 70                 56.0                -0.034483                 0.056604
# 71                 58.0                 0.348837                 0.074074
#
#     redfin.inventory  redfin.inventory_mom  redfin.inventory_yoy  \
# 67              21.0              0.050000             -0.475000
# 68              40.0             -0.130435              0.025641
# 69              30.0              0.000000             -0.400000
# 70              43.0              0.023810             -0.104167
# 71              42.0              0.312500             -0.086957
#
#    redfin.months_of_supply redfin.months_of_supply_mom  \
# 67                    None                        None
# 68                    None                        None
# 69                    None                        None
# 70                    None                        None
# 71                    None                        None
#
#    redfin.months_of_supply_yoy  redfin.median_dom  redfin.median_dom_mom  \
# 67                        None               43.5                    2.5
# 68                        None               21.5                  -34.5
# 69                        None               34.5                   17.0
# 70                        None               30.0                  -63.0
# 71                        None               93.0                   16.5
#
#     redfin.median_dom_yoy  redfin.avg_sale_to_list  \
# 67                  -40.0                 0.984205
# 68                  -20.5                 0.966180
# 69                   -7.5                 0.978935
# 70                  -31.5                 0.991364
# 71                   42.0                 0.993425
#
#     redfin.avg_sale_to_list_mom  redfin.avg_sale_to_list_yoy  \
# 67                    -0.001095                     0.024032
# 68                     0.002929                     0.006690
# 69                    -0.000202                     0.009629
# 70                    -0.002061                     0.029502
# 71                     0.005691                     0.036320
#
#     redfin.sold_above_list  redfin.sold_above_list_mom  \
# 67                0.170213                    0.039778
# 68                0.068182                    0.018182
# 69                0.150943                    0.000000
# 70                0.142857                    0.000000
# 71                0.142857                    0.021645
#
#     redfin.sold_above_list_yoy redfin.price_drops redfin.price_drops_mom  \
# 67                    0.076463               None                   None
# 68                    0.009358               None                   None
# 69                    0.055705               None                   None
# 70                    0.088803               None                   None
# 71                    0.071429               None                   None
#
#    redfin.price_drops_yoy  redfin.off_market_in_two_weeks  \
# 67                   None                        0.625000
# 68                   None                        0.526316
# 69                   None                        0.666667
# 70                   None                        0.583333
# 71                   None                        0.600000
#
#     redfin.off_market_in_two_weeks_mom  redfin.off_market_in_two_weeks_yoy  \
# 67                           -0.025000                            0.041667
# 68                           -0.110048                            0.052632
# 69                            0.083333                            0.205128
# 70                           -0.016667                            0.128788
# 71                           -0.150000                           -0.036364
#
#    redfin.parent_metro_region  redfin.parent_metro_region_metro_code  \
# 67                  Tampa, FL                                  45300
# 68                  Tampa, FL                                  45300
# 69                  Tampa, FL                                  45300
# 70                  Tampa, FL                                  45300
# 71                  Tampa, FL                                  45300
#
#     redfin.last_updated  redfin.zipcode  redfin.year
# 67  2022-08-14 14:44:22           33606         2020
# 68  2022-08-14 14:44:22           33606         2020
# 69  2022-08-14 14:44:22           33606         2020
# 70  2022-08-14 14:44:22           33606         2020
# 71  2022-08-14 14:44:22           33606         2020

# %% [markdown]
# ### <font color="green">Section #3 - Visualization</font> 📈
# Visualize housing and economic data trends over time

# %% [markdown]
# Source [US Census Bureau Median Gross Rent by Bedrooms](https://api.census.gov/data/2020/acs/acs5/variables/B25031_001E.json)

# %%
fig = px.line(df_census_grp, x='year', y='median_rent_all_bds', title='Median Rent by Year for {}'.format(zipcode))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9dc12f97-e5bf-43f0-8f91-1559f4c9bed4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9dc12f97-e5bf-43f0-8f91-1559f4c9bed4")) {                    Plotly.newPlot(                        "9dc12f97-e5bf-43f0-8f91-1559f4c9bed4",                        [{"hovertemplate":"year=%{x}<br>median_rent_all_bds=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2015","2016","2017","2018","2019","2020"],"xaxis":"x","y":[1054.0,1160.0,1205.0,1314.0,1416.0,1467.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"lin ...

# %% [markdown]
# Source [US Census Bureau Median Gross Rent by Bedrooms](https://api.census.gov/data/2020/acs/acs5/variables/B25031_001E.json)

# %%
rent_cols = ['census.median_rent_all_bds',	'census.median_rent_0_beds',	
             'census.median_rent_1_beds',	'census.median_rent_2_beds',	'census.median_rent_3_beds']

# select relevant cols
df_plot = df_zip_e[['redfin.year'] + rent_cols].drop_duplicates()

# melt df
df_plot = pd.melt(df_plot, id_vars=['redfin.year'], value_vars=rent_cols, 
                  var_name='num_bds', value_name='median_rent')
df_plot.head(6)
# Out:
#    redfin.year                     num_bds  median_rent
# 0         2015  census.median_rent_all_bds       1054.0
# 1         2016  census.median_rent_all_bds       1160.0
# 2         2017  census.median_rent_all_bds       1312.0
# 3         2018  census.median_rent_all_bds       1314.0
# 4         2019  census.median_rent_all_bds       1444.0
# 5         2020  census.median_rent_all_bds       1467.0

# %%
fig = px.line(df_plot, x='redfin.year', y='median_rent', 
              color='num_bds', title='Population by Year for {}'.format(zipcode))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="169e775c-2026-4af1-90fc-e01bf68e46f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("169e775c-2026-4af1-90fc-e01bf68e46f1")) {                    Plotly.newPlot(                        "169e775c-2026-4af1-90fc-e01bf68e46f1",                        [{"hovertemplate":"num_bds=census.median_rent_all_bds<br>redfin.year=%{x}<br>median_rent=%{y}<extra></extra>","legendgroup":"census.median_rent_all_bds","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"census.median_rent_all_bds","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[1054.0,1160.0,1312.0,1314.0,1444.0,1467.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"num_bds=census.median_rent_0_beds<br>redfin.year=%{x}<br>median_rent=%{y}<extra></extra>","legendgroup":"census.median_rent_0_beds","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"census.median_rent_0_beds","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[1008.0,1020.0,947.0,1029.0,1104.5,1205.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"num_bds=census.median_rent_1_beds<br>redfin.year=%{x}<br>median_rent=%{y}<extra></extra>","legendgroup":"census.median_rent_1_beds","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"census.median_rent_1_beds","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[940.5,1013.5,1073.0,1112.5,1263.0,1179.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"num_bds=census.median_rent_2_beds<br>redfin.year=%{x}<br>median_rent=%{y}<extra></extra>","legendgroup":"census.median_rent_2_beds","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"census.median_rent_2_beds","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[1456.0,1334.0,1444.0,1516.0,1626.0,1743.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"num_bds=census.median_rent_3_beds<br>redfin.year=%{x}<br>median_rent=%{y}<extra></extra>","legendgroup":"census.median_rent_3_beds","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"census.median_rent_3_beds","orientation":"v","showlegend":true,"x":[2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[1940.0,1911.0,1995.0,2375.0,1992.5,2054.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111111111 ...

# %% [markdown]
# ## <font color="blue">Output</font>

# %%
# # download file
# df.to_csv('output.csv', index=False)
# files.download('output.csv')

# %% [markdown]
# # End Notebook
