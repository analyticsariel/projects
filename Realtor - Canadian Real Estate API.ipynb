# %% [markdown]
# # Canadian Real Estate API - Get Statistics
# ## Overview
# | Detail Tag            | Information                                                                                        |
# |-----------------------|----------------------------------------------------------------------------------------------------|
# | Originally Created By | Ariel Herrera, arielherrera@analyticsariel.com                                                      |
# | External References   | <a href="https://rapidapi.com/apidojo/api/realtor-canadian-real-estate" target="_blank">Realtor API</a>|
# | Input Datasets        | List for Sale |
# | Output Datasets       | Table    |
# | Input Data Source     | API |
# | Output Data Source    | Pandas Dataframe |
#
# ## History
# | Date         | Developed By  | Reason                                                |
# |--------------|---------------|-------------------------------------------------------|
# | 1st September 2020 | Ariel Herrera | Notebook created to get canadian demographic data. |
# | 20th October 2020 | Ariel Herrera | Created prototype dashboard. |
#
# ## Other Details
# This Notebook is a prototype.

# %% [markdown]
# ## Widgets

# %%
# remove widgets
dbutils.widgets.removeAll()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.widgets.text("selectedCity", "Montreal", "01) City")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
selectedCity = dbutils.widgets.get("selectedCity")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
displayHTML("""Get GEO statistic information of surrounded area for <b><font color="blue">""" + selectedCity + "</font></b>")
# Out:
# Get GEO statistic information of surrounded area for <b><font color="blue">Montreal</font></b>

# %% [markdown]
# ## Imports

# %%
from datetime import datetime
import pandas as pd
import requests
import json
import plotly.express as px
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Functions

# %%
def save_pandas_df(df, file_name, file_path='dbfs:/FileStore/tables/'):
  # Create a Spark DataFrame from a pandas DataFrame using Arrow
  df_spark = spark.createDataFrame(df)
  df_spark.write.format("com.databricks.spark.csv").mode('overwrite').option("header", "true").save(file_path + file_name)
  print('Saved file!')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def get_lat_lon(location, google_api_key):
  """
  Get latitude and longitude for a city.

  Parameters
  ----------
  @location [string]: Locatin entered by user from widget
  @google_api_key [string]: Api Key

  Returns
  -------
  [string]: Latitude and longitude

  """
  # api-endpoint 
  URL = "https://maps.googleapis.com/maps/api/geocode/json"

  # defining a params dict for the parameters to be sent to the API 
  PARAMS = {'address':location, 'key':google_api_key} 

  # sending get request and saving the response as response object 
  r = requests.get(url = URL, params = PARAMS) 
  
  # get data from response
  data = r.json()
  
  # location
  location_dict = data['results'][0]['geometry']['location']
  lattitude = location_dict['lat']
  longitude = location_dict['lng']
  
  return lattitude, longitude
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def get_api_key(api_key_id = "Realtor"):
  """
  Get the api key for website accessing.

  Table of key type and key value for privacy.

  Parameters
  ----------
  @api_key_id [string]: Key value in dataframe

  Returns
  -------
  [string]: API Key

  """
  # load api keys file
  df_api_keys = spark.read.format('csv').options(header='true', inferSchema='true').load('/FileStore/tables/api_keys.csv').toPandas()
  
  # return api key if in dataset
  try:
    # get api key from id
    api_key = df_api_keys.loc[df_api_keys['Id'] == api_key_id]['Key'].iloc[0] # get key by id
    # return api key
    return api_key
  except IndexError:
    # get api key id list
    api_key_id_list = df_api_keys['Id'].unique().tolist()
    # print error message
    print('Cannot map key. Api key id must be one of the following options {0}'.format(api_key_id_list))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def api_get_city_statistics(api_key, lat, lon):
  """
  Get city statistics from canadian realtor api.

  Parameters
  ----------
  @api_key_id [string]: Key API realtor id
  @lat [float]: Lattitude
  @lon [float]: Longitude

  Returns
  -------
  [json]: Dictionary of city statistics

  """
  # url for api
  url = "https://realtor-canadian-real-estate.p.rapidapi.com/properties/get-statistics"

  # enter parameters
  querystring = {
    "CultureId":"1", # return in english
    "Latitude": str(lat),
    "Longitude": str(lon)
  }

  # header
  headers = {
    'x-rapidapi-host': "realtor-canadian-real-estate.p.rapidapi.com",
    'x-rapidapi-key': api_key
  }

  # response
  response = requests.request("GET", url, headers=headers, params=querystring)
  return response.json() # json format
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Local Constants

# %%
df_api_keys = spark.read.format('csv').options(header='true', inferSchema='true').load('/FileStore/tables/api_keys.csv').toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_api_keys)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Id</th><th>Key</th></tr></thead><tbody><tr><td>Google</td><td>AIzaSyCLyzv_J7GLkfuDLrmbU_hZtDtxX7phM24</td></tr><tr><td>Plotly</td><td>pk.eyJ1IjoiaGVycmVyYS11cy1yZWkiLCJhIjoiY2pyejJtd3kxMTRvcDQ0bHZiM3BzdWVkMCJ9.bo7U4hgixCPZwdIyPeRqiA</td></tr><tr><td>Realtor</td><td>606b269419msh0ecb93ce6f56330p117eebjsn2d8e244b9945</td></tr></tbody></table></div>

# %%
google_api_key = get_api_key(api_key_id = "Google")
realtor_api_key = get_api_key(api_key_id = "Realtor")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Data Exploration

# %%
# get latitude and longitude based on city entered
latitude, longitude = get_lat_lon(selectedCity, google_api_key)

# get city statistics
stats_response = api_get_city_statistics(api_key=realtor_api_key, lat=latitude, lon=longitude)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# view stats response
stats_response
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[40]: {&#39;ErrorCode&#39;: {&#39;Id&#39;: 200,
#   &#39;Description&#39;: &#39;Success - OK&#39;,
#   &#39;ProductName&#39;: &#39;! Push to PR-Stage - Realtor API (Maintenance)^29583 + Casing issue on serialize [Wednesday, October 28, 2020 8:42:08 AM]&#39;,
#   &#39;Version&#39;: &#39;1.0.7606.15704&#39;},
#  &#39;Data&#39;: [{&#39;key&#39;: &#39;&#39;,
#    &#39;value&#39;: [{&#39;key&#39;: &#39;Daytime Population&#39;, &#39;value&#39;: &#39;143546&#39;},
#     {&#39;key&#39;: &#39;Number of Businesses&#39;, &#39;value&#39;: &#39;3218&#39;},
#     {&#39;key&#39;: &#39;Population size&#39;, &#39;value&#39;: &#39;2741&#39;},
#     {&#39;key&#39;: &#39;Median age&#39;, &#39;value&#39;: &#39;32.1&#39;},
#     {&#39;key&#39;: &#39;Average Household Size&#39;, &#39;value&#39;: &#39;1.6&#39;},
#     {&#39;key&#39;: &#39;Average Household Income&#39;, &#39;value&#39;: &#39;$88,926.81&#39;},
#     {&#39;key&#39;: &#39;Households with Children (%)&#39;, &#39;value&#39;: &#39;38&#39;},
#     {&#39;key&#39;: &#39;Households without Children (%)&#39;, &#39;value&#39;: &#39;62&#39;},
#     {&#39;key&#39;: &#39;Number of Households&#39;, &#39;value&#39;: &#39;1715&#39;}]},
#   {&#39;key&#39;: &#39;Retail Sales&#39;,
#    &#39;value&#39;: [{&#39;key&#39;: &#39;Unknown&#39;, &#39;value&#39;: &#39;570&#39;},
#     {&#39;key&#39;: &#39;&lt; 1&#39;, &#39;value&#39;: &#39;1475&#39;},
#     {&#39;key&#39;: &#39;1 - 4.9&#39;, &#39;value&#39;: &#39;797&#39;},
#     {&#39;key&#39;: &#39;5 - 19.9&#39;, &#39;value&#39;: &#39;234&#39;},
#     {&#39;key&#39;: &#39;20 - 99.9&#39;, &#39;value&#39;: &#39;116&#39;},
#     {&#39;key&#39;: &#39;100+ &#39;, &#39;value&#39;: &#39;26&#39;}]},
#   {&#39;key&#39;: &#39;Population by Age Group&#39;,
#    &#39;value&#39;: [{&#39;key&#39;: &#39;0 - 4 years old&#39;, &#39;value&#39;: &#39;90&#39;},
#     {&#39;key&#39;: &#39;5 - 9 years old&#39;, &#39;value&#39;: &#39;23&#39;},
#     {&#39;key&#39;: &#39;10 - 19 years old&#39;, &#39;value&#39;: &#39;185&#39;},
#     {&#39;key&#39;: &#39;20 - 34 years old&#39;, &#39;value&#39;: &#39;1330&#39;},
#     {&#39;key&#39;: &#39;35 - 49 years old&#39;, &#39;value&#39;: &#39;623&#39;},
#     {&#39;key&#39;: &#39;50 - 54 years old&#39;, &#39;value&#39;: &#39;149&#39;},
#     {&#39;key&#39;: &#39;55 - 64 years old&#39;, &#39;value&#39;: &#39;243&#39;},
#     {&#39;key&#39;: &#39;65 - 69 years old&#39;, &#39;value&#39;: &#39;98&#39;},
#     {&#39;key&#39;: &#39;70 - 79 years old&#39;, &#39;value&#39;: &#39;69&#39;},
#     {&#39;key&#39;: &#39;80 - 84 years old&#39;, &#39;value&#39;: &#39;13&#39;},
#     {&#39;key&#39;: &#39;85+ years old&#39;, &#39;value&#39;: &#39;9&#39;}]},
#   {&#39;key&#39;: &#39;Population Growth/Projection&#39;,
#    &#39;value&#39;: [{&#39;key&#39;: &#39;2013&#39;, &#39;value&#39;: &#39;2248&#39;},
#     {&#39;key&#39;: &#39;2018&#39;, &#39;value&#39;: &#39;2741&#39;},
#     {&#39;key&#39;: &#39;2021&#39;, &#39;value&#39;: &#39;2899&#39;},
#     {&#39;key&#39;: &#39;2023&#39;, &#39;value&#39;: &#39;3000&#39;},
#     {&#39;key&#39;: &#39;2028&#39;, &#39;value&#39;: &#39;3256&#39;}]},
#   {&#39;key&#39;: &#39;Education&#39;,
#    &#39;value&#39;: [{&#39;key&#39;: &#39;No cert. / Diploma / Degree&#39;, &#39;value&#39;: &#39;63&#39;},
#     {&#39;key&#39;: &#39;High school&#39;, &#39;value&#39;: &#39;490&#39;},
#     {&#39;key&#39;: &#39;Apprenticeship / Trade cert. / Diploma&#39;, &#39;value&#39;: &#39;48&#39;},
#     {&#39;key&#39;: &#39;Non-university cert. / Diploma&#39;, &#39;value&#39;: &#39;250&#39;},
#     {&#39;key&#39;: &#39;University cert. / Diploma below bachelor&#39;, &#39;value&#39;: &#39;118&#39;},
#     {&#39;key&#39;: &#39;University degree&#39;, &#39;value&#39;: &#39;1642&#39;}]},
#   {&#39;key&#39;: &#39;Marital Status&#39;,
#    &#39;value&#39;: [{&#39;key&#39;: &#39;Married&#39;, &#39;value&#39;: &#39;768&#39;},
#     {&#39;key&#39;: &#39;Common law&#39;, &#39;value&#39;: &#39;309&#39;},
#     {&#39;key&#39;: &#39;Single&#39;, &#39;value&#39;: &#39;1357&#39;},
#     {&#39;key&#39;: &#39;Separated&#39;, &#39;value&#39;: &#39;42&#39;},
#     {&#39;key&#39;: &#39;Divorced&#39;, &#39;value&#39;: &#39;102&#39;},
#     {&#39;key&#39;: &#39;Widowed&#39;, &#39;value&#39;: &#39;33&#39;}]},
#   {&#39;key&#39;: &#39;Languages&#39;,
#    &#39;value&#39;: [{&#39;key&#39;: &#39;English&#39;, &#39;value&#39;: &#39;580&#39;},
#     {&#39;key&#39;: &#39;French&#39;, &#39;value&#39;: &#39;1086&#39;},
#     {&#39;key&#39;: &#39;Italian&#39;, &#39;value&#39;: &#39;45&#39;},
#     {&#39;key&#39;: &#39;German&#39;, &#39;value&#39;: &#39;5&#39;},
#     {&#39;key&#39;: &#39;Cantonese&#39;, &#39;value&#39;: &#39;38&#39;},
#     {&#39;key&#39;: &#39;Spanish&#39;, &#39;value&#39;: &#39;109&#39;},
#     {&#39;key&#39;: &#39;Arabic&#39;, &#39;value&#39;: &#39;258&#39;},
#     {&#39;key&#39;: &#39;Tagalog&#39;, &#39;value&#39;: &#39;8&#39;},
#     {&#39;key&#39;: &#39;Portuguese&#39;, &#39;value&#39;: &#39;26&#39;},
#     {&#39;key&#39;: &#39;Polish&#39;, &#39;value&#39;: &#39;5&#39;},
#     {&#39;key&#39;: &#39;Mandarin&#39;, &#39;value&#39;: &#39;32&#39;},
#     {&#39;key&#39;: &#39;Chinese n.o.s&#39;, &#39;value&#39;: &#39;97&#39;},
#     {&#39;key&#39;: &#39;Urdu&#39;, &#39;value&#39;: &#39;12&#39;},
#     {&#39;key&#39;: &#39;Vietnamese&#39;, &#39;value&#39;: &#39;18&#39;},
#     {&#39;key&#39;: &#39;Ukrainian&#39;, &#39;value&#39;: &#39;4&#39;},
#     {&#39;key&#39;: &#39;Persian&#39;, &#39;value&#39;: &#39;99&#39;},
#     {&#39;key&#39;: &#39;Russian&#39;, &#39;value&#39;: &#39;33&#39;},
#     {&#39;key&#39;: &#39;Dutch&#39;, &#39;value&#39;: &#39;9&#39;},
#     {&#39;key&#39;: &#39;Korean&#39;, &#39;value&#39;: &#39;29&#39;},
#     {&#39;key&#39;: &#39;Greek&#39;, &#39;value&#39;: &#39;6&#39;},
#     {&#39;key&#39;: &#39;Tamil&#39;, &#39;value&#39;: &#39;5&#39;},
#     {&#39;key&#39;: &#39;Gujarati&#39;, &#39;value&#39;: &#39;7&#39;},
#     {&#39;key&#39;: &#39;Romanian&#39;, &#39;value&#39;: &#39;10&#39;},
#     {&#39;key&#39;: &#39;Hindi&#39;, &#39;value&#39;: &#39;7&#39;},
#     {&#39;key&#39;: &#39;Croatian&#39;, &#39;value&#39;: &#39;5&#39;},
#     {&#39;key&#39;: &#39;Serbian&#39;, &#39;value&#39;: &#39;7&#39;},
#     {&#39;key&#39;: &#39;Japanese&#39;, &#39;value&#39;: &#39;5&#39;},
#     {&#39;key&#39;: &#39;Turkish&#39;, &#39;value&#39;: &#39;56&#39;},
#     {&#39;key&#39;: &#39;Other Languages&#39;, &#39;value&#39;: &#39;56&#39;},
#     {&#39;key&#39;: &#39;English &amp; French&#39;, &#39;value&#39;: &#39;31&#39;},
#     {&#39;key&#39;: &#39;English &amp; Non-Official&#39;, &#39;value&#39;: &#39;29&#39;},
#     {&#39;key&#39;: &#39;French &amp; Non-Official&#39;, &#39;value&#39;: &#39;15&#39;},
#     {&#39;key&#39;: &#39;English &amp; French &amp; Non-Official&#39;, &#39;value&#39;: &#39;9&#39;}]},
#   {&#39;key&#39;: &#39;Household income&#39;,
#    &#39;value&#39;: [{&#39;key&#39;: &#39;$0 - $29,999&#39;, &#39;value&#39;: &#39;568&#39;},
#     {&#39;key&#39;: &#39;$30,000 - $59,999&#39;, &#39;value&#39;: &#39;407&#39;},
#     {&#39;key&#39;: &#39;$60,000 - $79,999&#39;, &#39;value&#39;: &#39;182&#39;},
#     {&#39;key&#39;: &#39;$80,000 - $99,999&#39;, &#39;value&#39;: &#39;127&#39;},
#     {&#39;key&#39;: &#39;$100,000 - $149,999&#39;, &#39;value&#39;: &#39;246&#39;},
#     {&#39;key&#39;: &#39;$150,000 - $199,999&#39;, &#39;value&#39;: &#39;93&#39;},
#     {&#39;key&#39;: &#39;$200,000+&#39;, &#39;value&#39;: &#39;92&#39;}]},
#   {&#39;key&#39;: &#39;Children at Home&#39;,
#    &#39;value&#39;: [{&#39;key&#39;: &#39;0 - 4 years old&#39;, &#39;value&#39;: &#39;88&#39;},
#     {&#39;key&#39;: &#39;5 - 9 years old&#39;, &#39;value&#39;: &#39;23&#39;},
#     {&#39;key&#39;: &#39;10 - 14 years old&#39;, &#39;value&#39;: &#39;16&#39;},
#     {&#39;key&#39;: &#39;15 - 19 years old&#39;, &#39;value&#39;: &#39;46&#39;},
#     {&#39;key&#39;: &#39;20

# %%
# get file name
stats_date_str = stats_response['ErrorCode']['ProductName'].split("[")[-1].replace("]", "")
stats_date = datetime.strptime(stats_date_str, '%A, %B %d, %Y %I:%M:%S %p')
stats_data_concat_str = stats_date.strftime('%Y-%m-%d')
stats_file_name = selectedCity + "_stats-data_" + stats_data_concat_str

# save file path
file_dir = '/dbfs/FileStore/tables/canadian_stats/'
stats_file_path = file_dir + stats_file_name

print(stats_file_path)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/dbfs/FileStore/tables/canadian_stats/Montreal_stats-data_2020-10-28
# </div>

# %%
# view all contents in the table
i = 1
for data_table in stats_response['Data']:
  print("Table {0}:".format(i), data_table['key'])
  i += 1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Table 1:
# Table 2: Retail Sales
# Table 3: Population by Age Group
# Table 4: Population Growth/Projection
# Table 5: Education
# Table 6: Marital Status
# Table 7: Languages
# Table 8: Household income
# Table 9: Children at Home
# Table 10: Ownership
# Table 11: Construction Date
# Table 12: Occupations
# </div>

# %% [markdown]
# ## Data Exploration

# %%
# notes:
# assumptions - (1) amount is in canadian dollar, (2) daytime population is an abreviation by 1K, (3) population is an abreviation by 1K
# daytime population = commuter adjusted
df_table_1 = pd.DataFrame(stats_response['Data'][0]['value'])
df_table_1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Daytime Population</td>
#       <td>143546</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Number of Businesses</td>
#       <td>3218</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Population size</td>
#       <td>2741</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Median age</td>
#       <td>32.1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Average Household Size</td>
#       <td>1.6</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Average Household Income</td>
#       <td>$88,926.81</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Households with Children (%)</td>
#       <td>38</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Households without Children (%)</td>
#       <td>62</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Number of Households</td>
#       <td>1715</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# notes:
# https://tradingeconomics.com/canada/retail-sales
# questions - (1) what industry are the retail sales? (2) what do the values mean?
df_table_2 = pd.DataFrame(stats_response['Data'][1]['value'])
df_table_2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Unknown</td>
#       <td>570</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>&lt; 1</td>
#       <td>1475</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1 - 4.9</td>
#       <td>797</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>5 - 19.9</td>
#       <td>234</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>20 - 99.9</td>
#       <td>116</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>100+</td>
#       <td>26</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# notes:
# questions - (1) total does not equal population in table 1, why?
df_table_3 = pd.DataFrame(stats_response['Data'][2]['value'])
df_table_3['value'] = df_table_3.apply(lambda x: int(x['value']), axis = 1)
print('sum of total population:', df_table_3['value'].sum())
print('population from table 1:', df_table_1.loc[df_table_1['key'] == "Population size"]['value'].iloc[0])
df_table_3
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0 - 4 years old</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5 - 9 years old</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>10 - 19 years old</td>
#       <td>185</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>20 - 34 years old</td>
#       <td>1330</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>35 - 49 years old</td>
#       <td>623</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>50 - 54 years old</td>
#       <td>149</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>55 - 64 years old</td>
#       <td>243</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>65 - 69 years old</td>
#       <td>98</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>70 - 79 years old</td>
#       <td>69</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>80 - 84 years old</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>85+ years old</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# notes:
# good for forecasting
df_table_4 = pd.DataFrame(stats_response['Data'][3]['value'])
df_table_4
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2013</td>
#       <td>2248</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2018</td>
#       <td>2741</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2021</td>
#       <td>2899</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2023</td>
#       <td>3000</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2028</td>
#       <td>3256</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# notes:
df_table_5 = pd.DataFrame(stats_response['Data'][4]['value'])
df_table_5
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>No cert. / Diploma / Degree</td>
#       <td>63</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>High school</td>
#       <td>490</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Apprenticeship / Trade cert. / Diploma</td>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Non-university cert. / Diploma</td>
#       <td>250</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>University cert. / Diploma below bachelor</td>
#       <td>118</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>University degree</td>
#       <td>1642</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# notes:
df_table_6 = pd.DataFrame(stats_response['Data'][5]['value'])
df_table_6
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Married</td>
#       <td>768</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Common law</td>
#       <td>309</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Single</td>
#       <td>1357</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Separated</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Divorced</td>
#       <td>102</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Widowed</td>
#       <td>33</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# notes:
# questions - (1) what could this be used for? trends over year? focus on marketing?
df_table_7 = pd.DataFrame(stats_response['Data'][6]['value'])
df_table_7['value'] = df_table_7.apply(lambda x: int(x['value']), axis = 1)
df_table_7 = df_table_7.sort_values(by=['value'], ascending=False)
print('Length of table:', len(df_table_7))
df_table_7.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>French</td>
#       <td>1086</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>English</td>
#       <td>580</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Arabic</td>
#       <td>258</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Spanish</td>
#       <td>109</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Persian</td>
#       <td>99</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Chinese n.o.s</td>
#       <td>97</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>Other Languages</td>
#       <td>56</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>Turkish</td>
#       <td>56</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Italian</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Cantonese</td>
#       <td>38</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# notes:
# assumptions - (1) in canadian dollars
df_table_8 = pd.DataFrame(stats_response['Data'][7]['value'])
df_table_8
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>$0 - $29,999</td>
#       <td>568</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>$30,000 - $59,999</td>
#       <td>407</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>$60,000 - $79,999</td>
#       <td>182</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>$80,000 - $99,999</td>
#       <td>127</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>$100,000 - $149,999</td>
#       <td>246</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>$150,000 - $199,999</td>
#       <td>93</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>$200,000+</td>
#       <td>92</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# notes:
# if 25+ starts to decline we could see more renters or home buyers in market
# questions - (1) not in prct, what is the base value?
df_table_9 = pd.DataFrame(stats_response['Data'][8]['value'])
df_table_9
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0 - 4 years old</td>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5 - 9 years old</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>10 - 14 years old</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>15 - 19 years old</td>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>20 - 24 years old</td>
#       <td>57</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>25+ years old</td>
#       <td>60</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# notes:
df_table_10 = pd.DataFrame(stats_response['Data'][9]['value'])
df_table_10
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Own</td>
#       <td>733</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Rent</td>
#       <td>982</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# notes:
df_table_11 = pd.DataFrame(stats_response['Data'][10]['value'])
df_table_11
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Before 1960</td>
#       <td>343</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1961 - 1980</td>
#       <td>83</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1981 - 1990</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1991 - 2000</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2001 - 2005</td>
#       <td>129</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2006 - 2010</td>
#       <td>479</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2011 - 2016</td>
#       <td>526</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>After 2016</td>
#       <td>100</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# notes:
# diversity in occupations
df_table_12 = pd.DataFrame(stats_response['Data'][11]['value'])
df_table_12['value'] = df_table_12.apply(lambda x: int(x['value']), axis = 1)
df_table_12 = df_table_12.sort_values(by=['value'], ascending=False)
df_table_12
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>key</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>Business, Finance, Admin</td>
#       <td>196</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Management</td>
#       <td>130</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Sales and service</td>
#       <td>114</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Social Sciences, Education, Government, Religion</td>
#       <td>91</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Sciences</td>
#       <td>86</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Health</td>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Art, Culture, Recreation, Sport</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>Not Applicable</td>
#       <td>25</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Visualization

# %%
selectedCity = dbutils.widgets.get("selectedCity") # get widget for auto update
# generate plot
plot_1 = pd.DataFrame(stats_response['Data'][0]['value'])
plot_1 = plot_1.iloc[3:]
plot_1 = plot_1.rename(columns={"key": "City Stat", "value": "Value"})
display(plot_1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>City Stat</th><th>Value</th></tr></thead><tbody><tr><td>Median age</td><td>32.1</td></tr><tr><td>Average Household Size</td><td>1.6</td></tr><tr><td>Average Household Income</td><td>$88,926.81</td></tr><tr><td>Households with Children (%)</td><td>38</td></tr><tr><td>Households without Children (%)</td><td>62</td></tr><tr><td>Number of Households</td><td>1715</td></tr></tbody></table></div>

# %%
selectedCity = dbutils.widgets.get("selectedCity") # get widget for auto update
# generate plot
plot_2 = pd.DataFrame(stats_response['Data'][2]['value'])
plot_2['key'] = plot_2.apply(lambda x: x['key'].split(" "), axis = 1)
plot_2['key'] = plot_2.apply(lambda x: x['key'][0] + x['key'][1] + x['key'][2], axis = 1)
plot_2['key'] = plot_2.apply(lambda x: "85+" if (x['key'] == "85+yearsold") else x['key'], axis = 1)
plot_2['value'] = plot_2.apply(lambda x: int(x['value']), axis = 1)
plot_2 = plot_2.rename(columns={"key": "Years Old", "value": "Value"})
fig = px.bar(plot_2, x='Years Old', y='Value')
fig.update_xaxes(title="")
fig
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="bbc0656f-98f8-415e-86dc-5b008dbf3a0b" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbc0656f-98f8-415e-86dc-5b008dbf3a0b")) {                    Plotly.newPlot(                        "bbc0656f-98f8-415e-86dc-5b008dbf3a0b",                        [{"alignmentgroup": "True", "hovertemplate": "Years Old=%{x}<br>Value=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["0-4", "5-9", "10-19", "20-34", "35-49", "50-54", "55-64", "65-69", "70-79", "80-84", "85+"], "xaxis": "x", "y": [90, 23, 185, 1330, 623, 149, 243, 98, 69, 13, 9], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %%
selectedCity = dbutils.widgets.get("selectedCity") # get widget for auto update
# generate plot
plot_3 = pd.DataFrame(stats_response['Data'][3]['value'])
plot_3['value'] = plot_3.apply(lambda x: int(x['value']), axis = 1)
plot_3 = plot_3.rename(columns={"key": "Year", "value": "Value"})
fig = px.line(plot_3, x="Year", y="Value")
fig.update_xaxes(title="", tickmode='linear')
fig
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="20e9767b-c87f-4a70-a901-bd3fff55c4cb" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20e9767b-c87f-4a70-a901-bd3fff55c4cb")) {                    Plotly.newPlot(                        "20e9767b-c87f-4a70-a901-bd3fff55c4cb",                        [{"hovertemplate": "Year=%{x}<br>Value=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["2013", "2018", "2021", "2023", "2028"], "xaxis": "x", "y": [2248, 2741, 2899, 3000, 3256], "yaxis": "y"}],                        {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automar ...

# %%
selectedCity = dbutils.widgets.get("selectedCity") # get widget for auto update
# generate plot
plot_4 = pd.DataFrame(stats_response['Data'][4]['value'])
plot_4['value'] = plot_4.apply(lambda x: int(x['value']), axis = 1)
plot_4 = plot_4.rename(columns={"key": "Education Level", "value": "Value"})
display(spark.createDataFrame(plot_4))
# px.pie(plot_4, values='Value', names='Education Level')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Education Level</th><th>Value</th></tr></thead><tbody><tr><td>No cert. / Diploma / Degree</td><td>63</td></tr><tr><td>High school</td><td>490</td></tr><tr><td>Apprenticeship / Trade cert. / Diploma</td><td>48</td></tr><tr><td>Non-university cert. / Diploma</td><td>250</td></tr><tr><td>University cert. / Diploma below bachelor</td><td>118</td></tr><tr><td>University degree</td><td>1642</td></tr></tbody></table></div>

# %%
selectedCity = dbutils.widgets.get("selectedCity") # get widget for auto update
# generate plot
plot_5 = pd.DataFrame(stats_response['Data'][9]['value'])
plot_5['value'] = plot_5.apply(lambda x: int(x['value']), axis = 1)
plot_5 = plot_5.rename(columns={"key": "Status", "value": "Value"})
display(spark.createDataFrame(plot_5))
# px.pie(plot_5, values='Value', names='Status')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Status</th><th>Value</th></tr></thead><tbody><tr><td>Own</td><td>733</td></tr><tr><td>Rent</td><td>982</td></tr></tbody></table></div>

# %%
selectedCity = dbutils.widgets.get("selectedCity") # get widget for auto update
# generate plot
plot_6 = pd.DataFrame(stats_response['Data'][10]['value'])
plot_6['value'] = plot_6.apply(lambda x: int(x['value']), axis = 1)
home_built_sum = plot_6['value'].sum()
plot_6['Prct'] = plot_6.apply(lambda x: str(int(round((x['value'] / home_built_sum) * 100))) + "%", axis = 1)
plot_6 = plot_6.rename(columns={"key": "Time Frame", "value": "Value"})
display(spark.createDataFrame(plot_6))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Time Frame</th><th>Value</th><th>Prct</th></tr></thead><tbody><tr><td>Before 1960</td><td>343</td><td>20%</td></tr><tr><td>1961 - 1980</td><td>83</td><td>5%</td></tr><tr><td>1981 - 1990</td><td>21</td><td>1%</td></tr><tr><td>1991 - 2000</td><td>34</td><td>2%</td></tr><tr><td>2001 - 2005</td><td>129</td><td>8%</td></tr><tr><td>2006 - 2010</td><td>479</td><td>28%</td></tr><tr><td>2011 - 2016</td><td>526</td><td>31%</td></tr><tr><td>After 2016</td><td>100</td><td>6%</td></tr></tbody></table></div>

# %%
selectedCity = dbutils.widgets.get("selectedCity") # get widget for auto update
# generate plot
plot_7 = pd.DataFrame(stats_response['Data'][7]['value'])
plot_7['value'] = plot_7.apply(lambda x: int(x['value']), axis = 1)
plot_7 = plot_7.rename(columns={"key": "Income Bracket", "value": "Value"})
fig = px.bar(plot_7, x='Income Bracket', y='Value')
fig.update_xaxes(title="")
fig
# Out:
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>                <div id="486e07d1-1bc0-4dd2-bf5c-9a66c8903715" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("486e07d1-1bc0-4dd2-bf5c-9a66c8903715")) {                    Plotly.newPlot(                        "486e07d1-1bc0-4dd2-bf5c-9a66c8903715",                        [{"alignmentgroup": "True", "hovertemplate": "Income Bracket=%{x}<br>Value=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["$0 - $29,999", "$30,000 - $59,999", "$60,000 - $79,999", "$80,000 - $99,999", "$100,000 - $149,999", "$150,000 - $199,999", "$200,000+"], "xaxis": "x", "y": [568, 407, 182, 127, 246, 93, 92], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar" ...

# %% [markdown]
# ## Write Output

# %% [markdown]
# # End Notebook
