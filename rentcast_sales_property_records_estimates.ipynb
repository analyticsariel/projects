# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1SM0iggcJnitFe8T7Ay3ymaoijtxF89Pj?usp=sharing)
# # Rent Cast | Property Records, Estimates, & Market Stats
#
# ## Overview
# | Detail Tag            | Information                                                                                        |
# |-----------------------|----------------------------------------------------------------------------------------------------|
# | Originally Created By | Ariel Herrera arielherrera@analyticsariel.com |
# | External References   | API |
# | Input Datasets        | Source name |
# | Output Datasets       | Source name |
# | Input Data Source     | Pandas DataFrame |
# | Output Data Source    | Pandas DataFrame |
#
# ## History
# | Date         | Developed By  | Reason                                                |
# |--------------|---------------|-------------------------------------------------------|
# | 1st Sep 2023 | Ariel Herrera | Create notebook. |
#
# ## Getting Started
# 1. Copy this notebook -> File -> Save a Copy in Drive
# 2. Directions
#
# ## Useful Resources
# - [Google Colab Cheat Sheet](https://towardsdatascience.com/cheat-sheet-for-google-colab-63853778c093)

# %% [markdown]
# ## <font color="blue">Imports</font>

# %%
import requests
import pandas as pd
from getpass import getpass
from google.colab import files
import plotly.express as px # visualization

pd.set_option('display.max_columns', None)

# %% [markdown]
# ## <font color="blue">Locals & Constants</font>

# %%
rent_cast_api_key = getpass('Enter the rent cast api key: ')
mapbox_api_key = getpass('Enter the mapbox api key: ')
px.set_mapbox_access_token(mapbox_api_key)
# Out:
# Enter the rent cast api key: ··········
# Enter the mapbox api key: ··········

# %% [markdown]
# ## <font color="blue">API Endpoints</font>

# %% [markdown]
# ### 1) Property Records 🏠
# [Api Docs](https://developers.rentcast.io/reference/property-records) | Search for property records in a geographical area, or by a specific address.

# %% [markdown]
# #### <font color="green">Single Property Search</font>

# %%
# enter property address - streetAddress, city, state, zipCode
address = '5430 Brownell St, Orlando, FL 32810'

# %%
# get data from rent cast
url = "https://api.rentcast.io/v1/properties"
querystring = {
    "address": address
}
headers = {
    "accept": "application/json",
    "X-Api-Key": rent_cast_api_key # your secret key
}
response = requests.get(url, headers=headers, params=querystring)
print(response.text)
# Out:
# [{"addressLine1":"5430 Brownell St","city":"Orlando","state":"FL","zipCode":"32810","formattedAddress":"5430 Brownell St, Orlando, FL 32810","assessorID":"29-21-29-0356-02-050","bedrooms":3,"county":"Orange","legalDescription":"AVONDALE PARK FIRST ADDITION J/86 LOT 5 BLK B","ownerOccupied":true,"squareFootage":1092,"subdivision":"AVONDALE PARK 1ST ADD","yearBuilt":1989,"zoning":"R-2","bathrooms":2,"lotSize":6781,"propertyType":"Single Family","lastSalePrice":161000,"lastSaleDate":"2019-12-26T00:00:00.000Z","features":{"cooling":true,"coolingType":"Central","exteriorType":"Concrete Block","floorCount":1,"garage":true,"garageSpaces":1,"garageType":"Garage","heating":true,"heatingType":"Forced Air","roofType":"Composition Shingle","unitCount":1},"taxAssessments":{"2019":{"value":130442,"land":40000,"improvements":90442},"2020":{"value":137987,"land":40000,"improvements":97987},"2021":{"value":147223,"land":40000,"improvements":107223},"2022":{"value":183721,"land":50000,"improvements":133721}},"propertyTaxes":{"2020":{"total":2445},"2022":{"total":2914}},"owner":{"names":["HOWARD RUSSELL COHEN"],"mailingAddress":{"id":"1101-Shady-Lane-Dr,-Orlando,-FL-32804","addressLine1":"1101 Shady Lane Dr","city":"Orlando","state":"FL","zipCode":"32804"}},"id":"5430-Brownell-St,-Orlando,-FL-32810","longitude":-81.442822,"latitude":28.628838}]

# %%
# view json object
response.json()
# Out:
# [{'addressLine1': '5430 Brownell St',
#   'city': 'Orlando',
#   'state': 'FL',
#   'zipCode': '32810',
#   'formattedAddress': '5430 Brownell St, Orlando, FL 32810',
#   'assessorID': '29-21-29-0356-02-050',
#   'bedrooms': 3,
#   'county': 'Orange',
#   'legalDescription': 'AVONDALE PARK FIRST ADDITION J/86 LOT 5 BLK B',
#   'ownerOccupied': True,
#   'squareFootage': 1092,
#   'subdivision': 'AVONDALE PARK 1ST ADD',
#   'yearBuilt': 1989,
#   'zoning': 'R-2',
#   'bathrooms': 2,
#   'lotSize': 6781,
#   'propertyType': 'Single Family',
#   'lastSalePrice': 161000,
#   'lastSaleDate': '2019-12-26T00:00:00.000Z',
#   'features': {'cooling': True,
#    'coolingType': 'Central',
#    'exteriorType': 'Concrete Block',
#    'floorCount': 1,
#    'garage': True,
#    'garageSpaces': 1,
#    'garageType': 'Garage',
#    'heating': True,
#    'heatingType': 'Forced Air',
#    'roofType': 'Composition Shingle',
#    'unitCount': 1},
#   'taxAssessments': {'2019': {'value': 130442,
#     'land': 40000,
#     'improvements': 90442},
#    '2020': {'value': 137987, 'land': 40000, 'improvements': 97987},
#    '2021': {'value': 147223, 'land': 40000, 'improvements': 107223},
#    '2022': {'value': 183721, 'land': 50000, 'improvements': 133721}},
#   'propertyTaxes': {'2020': {'total': 2445}, '2022': {'total': 2914}},
#   'owner': {'names': ['HOWARD RUSSELL COHEN'],
#    'mailingAddress': {'id': '1101-Shady-Lane-Dr,-Orlando,-FL-32804',
#     'addressLine1': '1101 Shady Lane Dr',
#     'city': 'Orlando',
#     'state': 'FL',
#     'zipCode': '32804'}},
#   'id': '5430-Brownell-St,-Orlando,-FL-32810',
#   'longitude': -81.442822,
#   'latitude': 28.628838}]

# %%
# view all keys
response.json()[0].keys()
# Out:
# dict_keys(['addressLine1', 'city', 'state', 'zipCode', 'formattedAddress', 'assessorID', 'bedrooms', 'county', 'legalDescription', 'ownerOccupied', 'squareFootage', 'subdivision', 'yearBuilt', 'zoning', 'bathrooms', 'lotSize', 'propertyType', 'lastSalePrice', 'lastSaleDate', 'features', 'taxAssessments', 'propertyTaxes', 'owner', 'id', 'longitude', 'latitude'])

# %%
# transform into a dataframe with columns and rows
df_prop = pd.json_normalize(response.json())
df_prop
# Out:
#        addressLine1     city state zipCode  \
# 0  5430 Brownell St  Orlando    FL   32810
#
#                       formattedAddress            assessorID  bedrooms  \
# 0  5430 Brownell St, Orlando, FL 32810  29-21-29-0356-02-050         3
#
#    county                               legalDescription  ownerOccupied  \
# 0  Orange  AVONDALE PARK FIRST ADDITION J/86 LOT 5 BLK B           True
#
#    squareFootage            subdivision  yearBuilt zoning  bathrooms  lotSize  \
# 0           1092  AVONDALE PARK 1ST ADD       1989    R-2          2     6781
#
#     propertyType  lastSalePrice              lastSaleDate  \
# 0  Single Family         161000  2019-12-26T00:00:00.000Z
#
#                                     id  longitude   latitude  \
# 0  5430-Brownell-St,-Orlando,-FL-32810 -81.442822  28.628838
#
#    features.cooling features.coolingType features.exteriorType  \
# 0              True              Central        Concrete Block
#
#    features.floorCount  features.garage  features.garageSpaces  \
# 0                    1             True                      1
#
#   features.garageType  features.heating features.heatingType  \
# 0              Garage              True           Forced Air
#
#      features.roofType  features.unitCount  taxAssessments.2019.value  \
# 0  Composition Shingle                   1                     130442
#
#    taxAssessments.2019.land  taxAssessments.2019.improvements  \
# 0                     40000                             90442
#
#    taxAssessments.2020.value  taxAssessments.2020.land  \
# 0                     137987                     40000
#
#    taxAssessments.2020.improvements  taxAssessments.2021.value  \
# 0                             97987                     147223
#
#    taxAssessments.2021.land  taxAssessments.2021.improvements  \
# 0                     40000                            107223
#
#    taxAssessments.2022.value  taxAssessments.2022.land  \
# 0                     183721                     50000
#
#    taxAssessments.2022.improvements  propertyTaxes.2020.total  \
# 0                            133721                      2445
#
#    propertyTaxes.2022.total             owner.names  \
# 0                      2914  [HOWARD RUSSELL COHEN]
#
#                  owner.mailingAddress.id owner.mailingAddress.addressLine1  \
# 0  1101-Shady-Lane-Dr,-Orlando,-FL-32804                1101 Shady Lane Dr
#
#   owner.mailingAddress.city owner.mailingAddress.state  \
# 0                   Orlando                         FL
#
#   owner.mailingAddress.zipCode
# 0                        32804

# %%
# [OPTIONAL] export into a csv file
file_name = 'ariel_is_my_fav_datascientist.csv' # 'rent_cast_single_prop_output.csv'
df_prop.to_csv(file_name, index=False)
files.download(file_name)

# %% [markdown]
# #### <font color="green">Get List of Properties</font>

# %%
def get_property_records(rent_cast_api_key, address):
  # get data from rent cast
  url = "https://api.rentcast.io/v1/properties"
  querystring = {
      "address": address
  }
  headers = {
      "accept": "application/json",
      "X-Api-Key": rent_cast_api_key # your secret key
  }
  response = requests.get(url, headers=headers, params=querystring)
  return response.json()

# %%
# create list of property addresses
property_address_list = [
    '4616 Westgrove Way, Orlando, FL 32808',
    '3402 Hillmont Cir, Orlando, FL 32817'
]
property_address_list
# Out:
# ['4616 Westgrove Way, Orlando, FL 32808',
#  '3402 Hillmont Cir, Orlando, FL 32817']

# %%
# %%time
# get property records for each property address
prop_records_resp_list = []

# iterate through list
print(f'Retrieving data for {len(property_address_list)} records')
for prop_address in property_address_list:
  print(f'  Getting data for {prop_address}...')
  response_json = get_property_records(rent_cast_api_key, prop_address)
  prop_records_resp_list.append(response_json[0])
print('Loop complete!')
# Out:
# Retrieving data for 2 records
#   Getting data for 4616 Westgrove Way, Orlando, FL 32808...
#   Getting data for 3402 Hillmont Cir, Orlando, FL 32817...
# Loop complete!
# CPU times: user 191 ms, sys: 2.85 ms, total: 194 ms
# Wall time: 574 ms

# %%
# transform into dataframe
df_mulit_prop = pd.json_normalize(prop_records_resp_list)
df_mulit_prop
# Out:
#          addressLine1     city state zipCode  \
# 0  4616 Westgrove Way  Orlando    FL   32808
# 1   3402 Hillmont Cir  Orlando    FL   32817
#
#                         formattedAddress            assessorID  bedrooms  \
# 0  4616 Westgrove Way, Orlando, FL 32808  06-22-29-1848-00-950         3
# 1   3402 Hillmont Cir, Orlando, FL 32817  08-22-31-8389-00-470         4
#
#    county           legalDescription ownerOccupied  squareFootage  \
# 0  Orange  CRYSTAL COVE 36/32 LOT 95          True           1641
# 1  Orange  SUMMER WOODS 17/70 LOT 47           NaN           1661
#
#     subdivision  yearBuilt     zoning  bathrooms  lotSize   propertyType  \
# 0  CRYSTAL COVE       1997  R-3A/W/RP          2     5735  Single Family
# 1  SUMMER WOODS       1987       R-1A          2     7499  Single Family
#
#    lastSalePrice              lastSaleDate  \
# 0         140000  2016-09-22T00:00:00.000Z
# 1          79700  1987-06-01T00:00:00.000Z
#
#                                       id  longitude   latitude  \
# 0  4616-Westgrove-Way,-Orlando,-FL-32808 -81.446604  28.598854
# 1   3402-Hillmont-Cir,-Orlando,-FL-32817 -81.227434  28.595553
#
#    features.cooling features.coolingType features.exteriorType  \
# 0              True              Central                Stucco
# 1              True              Central                Stucco
#
#    features.floorCount  features.garage  features.garageSpaces  \
# 0                    1             True                    2.0
# 1                    1             True                    NaN
#
#   features.garageType  features.heating features.heatingType  \
# 0              Garage              True           Forced Air
# 1              Garage              True           Forced Air
#
#      features.roofType  features.unitCount  taxAssessments.2020.value  \
# 0  Composition Shingle                   1                   190412.0
# 1  Composition Shingle                   1                        NaN
#
#    taxAssessments.2020.land  taxAssessments.2020.improvements  \
# 0                   34000.0                          156412.0
# 1                       NaN                               NaN
#
#    taxAssessments.2021.value  taxAssessments.2021.land  \
# 0                   189118.0                   34000.0
# 1                        NaN                       NaN
#
#    taxAssessments.2021.improvements  taxAssessments.2022.value  \
# 0                          155118.0                     194792
# 1                               NaN                     278853
#
#    propertyTaxes.2020.total  propertyTaxes.2021.total  \
# 0                    2913.0                    2868.0
# 1                       NaN                       NaN
#
#    propertyTaxes.2022.total                           owner.names  \
# 0                      2923                        [CORWIN RUISE]
# 1                      4480  [RONALD L BLOSSOM, BRENDA G BLOSSOM]
#
#                  owner.mailingAddress.id owner.mailingAddress.addressLine1  \
# 0  4616-Westgrove-Way,-Orlando,-FL-32808                4616 Westgrove Way
# 1     14839-Oldham-Dr,-Orlando,-FL-32826                   14839 Oldham Dr
#
#   owner.mailingAddress.city owner.mailingAddress.state  \
# 0                   Orlando                         FL
# 1                   Orlando                         FL
#
#   owner.mailingAddress.zipCode  taxAssessments.2022.land  \
# 0                        32808                       NaN
# 1                        32826                   55000.0
#
#    taxAssessments.2022.improvements
# 0                               NaN
# 1                          223853.0

# %%
# # [OPTIONAL] export into a csv file
# file_name = 'rent_cast_multiple_prop_output.csv'
# df_prop.to_csv(file_name, index=False)
# files.download(file_name)

# %% [markdown]
# #### <font color="green">Get Properties for a Zip Code</font>

# %%
# get data from rent cast
url = "https://api.rentcast.io/v1/properties"
querystring = {
    "zipCode": "32810",
    "propertyType": "Single Family",
    "bedrooms": 3,
    "bathrooms": 2,
    "limit": 250
}
headers = {
    "accept": "application/json",
    "X-Api-Key": rent_cast_api_key # your secret key
}
response_zip = requests.get(url, headers=headers, params=querystring)

# %%
# transform into df
df_props_zip = pd.json_normalize(response_zip.json())
print(f'Num of records: {len(df_props_zip)}')
print(f'Num of columns: {len(df_props_zip.columns)}')
df_props_zip.head()
# Out:
# Num of records: 250
# Num of columns: 65
#                              formattedAddress             addressLine1  \
# 0        3349 Sassafras Ct, Orlando, FL 32810        3349 Sassafras Ct
# 1          3214 Needles Dr, Orlando, FL 32810          3214 Needles Dr
# 2          1502 Leeway Ave, Orlando, FL 32810          1502 Leeway Ave
# 3  4245 Plantation Cove Dr, Orlando, FL 32810  4245 Plantation Cove Dr
# 4            2924 Drake Dr, Orlando, FL 32810            2924 Drake Dr
#
#       city state zipCode  bathrooms  bedrooms  squareFootage  county  \
# 0  Orlando    FL   32810          2         3         1718.0  Orange
# 1  Orlando    FL   32810          2         3         1494.0  Orange
# 2  Orlando    FL   32810          2         3         1535.0  Orange
# 3  Orlando    FL   32810          2         3         1184.0  Orange
# 4  Orlando    FL   32810          2         3         1447.0  Orange
#
#     propertyType            assessorID  \
# 0  Single Family  28-21-29-7500-00-560
# 1  Single Family  28-21-29-5430-03-120
# 2  Single Family  34-21-29-4204-00-310
# 3  Single Family  32-21-29-5426-00-480
# 4  Single Family  28-21-29-7460-02-080
#
#                                   legalDescription               subdivision  \
# 0                     RIVERSIDE WOODS 13/26 LOT 56           RIVERSIDE WOODS
# 1              MAGNOLIA ESTATES W/134 LOT 12 BLK C             MAGNOLIA ESTS
# 2       KINGSWOOD MANOR FIFTH ADDITION Z/22 LOT 31   KINGSWOOD MANOR 5TH ADD
# 3           MAGNOLIA BAY AT MAITLAND 50/73 UNIT 48  MAGNOLIA BAY AT MAITLAND
# 4  RIVERSIDE ACRES U/137 LOT 8 BLK B SEE 3879/2087           RIVERSIDE ACRES
#
#    yearBuilt zoning  lotSize  lastSalePrice              lastSaleDate  \
# 0     1984.0    P-D   9314.0       165000.0  2018-04-03T00:00:00.000Z
# 1     1969.0    R-1  10195.0        75000.0  2014-09-23T00:00:00.000Z
# 2     1963.0    R-1  10483.0       112500.0  2003-04-10T00:00:00.000Z
# 3     2004.0    R-3    721.0        45000.0  2012-07-12T00:00:00.000Z
# 4     1956.0    R-1   8655.0       285000.0  2021-12-22T00:00:00.000Z
#
#                                            id  longitude   latitude  \
# 0        3349-Sassafras-Ct,-Orlando,-FL-32810 -81.421262  28.630100
# 1          3214-Needles-Dr,-Orlando,-FL-32810 -81.419975  28.632066
# 2          1502-Leeway-Ave,-Orlando,-FL-32810 -81.403146  28.614237
# 3  4245-Plantation-Cove-Dr,-Orlando,-FL-32810 -81.430654  28.625240
# 4            2924-Drake-Dr,-Orlando,-FL-32810 -81.417206  28.633832
#
#   features.cooling features.coolingType features.exteriorType  \
# 0             True              Central        Concrete Block
# 1             True              Central        Concrete Block
# 2             True              Central        Concrete Block
# 3             True              Central                Stucco
# 4             True              Central        Concrete Block
#
#    features.floorCount features.garage  features.garageSpaces  \
# 0                  1.0            True                    2.0
# 1                  1.0             NaN                    NaN
# 2                  1.0            True                    2.0
# 3                  2.0             NaN                    NaN
# 4                  1.0            True                    1.0
#
#   features.garageType features.heating features.heatingType  \
# 0              Garage             True           Forced Air
# 1                 NaN             True           Forced Air
# 2              Garage             True           Forced Air
# 3                 NaN             True           Forced Air
# 4             Carport             True           Forced Air
#
#      features.roofType  features.unitCount  taxAssessments.2019.value  \
# 0  Composition Shingle                 1.0                   160403.0
# 1  Composition Shingle                 1.0                   135587.0
# 2  Composition Shingle                 1.0                   176372.0
# 3  Composition Shingle                 1.0                        NaN
# 4  Composition Shingle                 1.0                   147092.0
#
#    taxAssessments.2019.land  taxAssessments.2019.improvements  \
# 0                   40000.0                          120403.0
# 1                   40000.0                           95587.0
# 2                   42000.0                          134372.0
# 3                       NaN                               NaN
# 4                   40000.0                          107092.0
#
#    taxAssessments.2021.value  taxAssessments.2021.land  \
# 0                   198921.0                   40000.0
# 1                   161068.0                   40000.0
# 2                   197700.0                   50000.0
# 3                        NaN                       NaN
# 4                   141866.0                   40000.0
#
#    taxAssessments.2021.improvements  propertyTaxes.2020.total  \
# 0                          158921.0                    3235.0
# 1                          121068.0                    2498.0
# 2                          147700.0                    3456.0
# 3                               NaN                    1697.0
# 4                          101866.0                    2466.0
#
#    propertyTaxes.2021.total  propertyTaxes.2022.total  \
# 0                    3470.0                    3905.0
# 1                    2662.0                    3003.0
# 2                       NaN                    4082.0
# 3                       NaN                    2084.0
# 4                    2532.0                    2343.0
#
#                                owner.names  \
# 0          [HUNG NGUYEN, THUYNGA THI TRAN]
# 1                  [IH BORROWER L P 20191]
# 2                        [REYES DORA ARES]
# 3                           [JI YUE ZHANG]
# 4  [ANGELA ELIZABETH KNASE, MATTHEW MOORE]
#
#                     owner.mailingAddress.id owner.mailingAddress.addressLine1  \
# 0         313-Cortona-Dr,-Orlando,-FL-32828                    313 Cortona Dr
# 1  1717-Main-St,-STE-2000,-Dallas,-TX-75201                      1717 Main St
# 2        1502-Leeway-Ave,-Orlando,-FL-32810                   1502 Leeway Ave
# 3    1682-Barnswallow-Rd,-Yardley,-PA-19067               1682 Barnswallow Rd
# 4          2924-Drake-Dr,-Orlando,-FL-32810                     2924 Drake Dr
#
#   owner.mailingAddress.city owner.mailingAddress.state  \
# 0                   Orlando                         FL
# 1                    Dallas                         TX
# 2                   Orlando                         FL
# 3                   Yardley                         PA
# 4                   Orlando                         FL
#
#   owner.mailingAddress.zipCode features.fireplace  \
# 0                        32828                NaN
# 1                        75201               True
# 2                        32810                NaN
# 3                        19067                NaN
# 4                        32810               True
#
#   owner.mailingAddress.addressLine2 ownerOccupied features.pool  \
# 0                               NaN           NaN           NaN
# 1                          STE 2000           NaN           NaN
# 2                               NaN          True          True
# 3                               NaN           NaN           NaN
# 4                               NaN          True          True
#
#    taxAssessments.2022.value  taxAssessments.2022.land  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                   230641.0                   70000.0
# 3                   156795.0                   24000.0
# 4                   171881.0                   50000.0
#
#    taxAssessments.2022.improvements  taxAssessments.2020.value  \
# 0                               NaN                        NaN
# 1                               NaN                        NaN
# 2                          160641.0                        NaN
# 3                          132795.0                   117935.0
# 4                          121881.0                        NaN
#
#    taxAssessments.2020.land  taxAssessments.2020.improvements addressLine2  \
# 0                       NaN                               NaN          NaN
# 1                       NaN                               NaN          NaN
# 2                       NaN                               NaN          NaN
# 3                   20000.0                           97935.0          NaN
# 4                       NaN                               NaN          NaN
#
#   features.architectureType  propertyTaxes.2018.total  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    taxAssessments.2018.value  taxAssessments.2018.land  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
#
#    taxAssessments.2018.improvements  propertyTaxes.2019.total  \
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               NaN                       NaN
#
#   features.poolType
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
# view distribution of properties based on year built
fig = px.histogram(df_props_zip, x="yearBuilt")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="67a2a023-6d3a-4a76-ac70-0b1a9c31e8c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67a2a023-6d3a-4a76-ac70-0b1a9c31e8c6")) {                    Plotly.newPlot(                        "67a2a023-6d3a-4a76-ac70-0b1a9c31e8c6",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"yearBuilt=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[1984.0,1969.0,1963.0,2004.0,1956.0,1975.0,1972.0,1958.0,1958.0,1991.0,1995.0,1988.0,2003.0,1984.0,2002.0,1988.0,1988.0,1980.0,1995.0,2006.0,1996.0,2002.0,1960.0,1970.0,1958.0,1963.0,1959.0,1995.0,1986.0,1962.0,1995.0,1989.0,1987.0,1984.0,null,1989.0,2001.0,null,1998.0,2001.0,1995.0,2000.0,null,1986.0,1995.0,2006.0,1995.0,2003.0,1995.0,1995.0,1971.0,1995.0,1995.0,1986.0,1995.0,1995.0,2008.0,1995.0,1995.0,2006.0,1982.0,2003.0,1959.0,1959.0,1959.0,1956.0,1959.0,1959.0,1960.0,1959.0,1983.0,1995.0,2001.0,1981.0,1960.0,1995.0,2000.0,1996.0,2002.0,2002.0,1996.0,1995.0,1955.0,1994.0,1995.0,1994.0,1959.0,1995.0,1995.0,1995.0,2000.0,1992.0,1994.0,1996.0,1996.0,1995.0,1995.0,2000.0,1995.0,2001.0,2001.0,2001.0,1996.0,1959.0,1995.0,1959.0,1955.0,1959.0,1958.0,1995.0,2002.0,2001.0,1996.0,1995.0,1981.0,1996.0,1996.0,2002.0,1996.0,1996.0,1995.0,2008.0,1995.0,1995.0,1959.0,1995.0,1998.0,1995.0,1982.0,1959.0,1972.0,2002.0,1995.0,1995.0,2001.0,1996.0,2002.0,1955.0,1995.0,1955.0,1995.0,1995.0,1959.0,1955.0,2000.0,2000.0,1996.0,2000.0,1996.0,1996.0,2002.0,1996.0,1996.0,1960.0,1996.0,1996.0,2011.0,1995.0,2007.0,1983.0,1995.0,null,1986.0,2006.0,1976.0,1984.0,1970.0,1981.0,2002.0,1995.0,1989.0,1998.0,1970.0,1940.0,1980.0,1993.0,1988.0,1984.0,1982.0,1956.0,2022.0,1988.0,1950.0,1979.0,null,1973.0,1962.0,1978.0,null,1993.0,1982.0,1984.0,1964.0,1999.0,1981.0,1963.0,1981.0,1972.0,1990.0,2005.0,1957.0,2004.0,1987.0,1999.0,1972.0,1959.0,1971.0,1988.0,null,null,1981.0,1957.0,1963.0,1982.0,1990.0,null,2000.0,2012.0,1986.0,2020.0,1985.0,1959.0,1950.0,1987.0,null,1981.0,1959.0,1958.0,1982.0,1962.0,1962.0,2017.0,1999.0,null,1990.0,1999.0,2005.0,1972.0,null,1950.0,1992.0,1985.0,1985.0,null,2000.0,1979.0,1978.0,1978.0,1978.0,1978.0],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0 ...

# %%
# view distribution of properties based on last sale price
fig = px.box(df_props_zip, y="lastSalePrice")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="04562c7d-a34b-40ae-abc8-2eee0614fa1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04562c7d-a34b-40ae-abc8-2eee0614fa1e")) {                    Plotly.newPlot(                        "04562c7d-a34b-40ae-abc8-2eee0614fa1e",                        [{"alignmentgroup":"True","hovertemplate":"lastSalePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[165000.0,75000.0,112500.0,45000.0,285000.0,null,null,102000.0,null,68000.0,10345900.0,null,197700.0,6109200.0,380000.0,100000.0,110000.0,30000.0,10345900.0,96000.0,76000.0,254000.0,155300.0,155000.0,170000.0,215800.0,100000.0,10345900.0,77000.0,77500.0,10345900.0,80000.0,146500.0,67300.0,209500.0,80800.0,145000.0,103000.0,135000.0,143000.0,10345900.0,128000.0,null,249000.0,6109200.0,87000.0,10345900.0,117300.0,10345900.0,10345900.0,130000.0,10345900.0,10345900.0,215000.0,10345900.0,10345900.0,94000.0,10345900.0,10345900.0,86500.0,71900.0,201100.0,107300.0,null,null,85000.0,null,67500.0,179900.0,125000.0,125000.0,93000.0,345000.0,null,48000.0,98900.0,135000.0,74100.0,54354.0,94900.0,null,null,37800.0,70700.0,83100.0,115000.0,52000.0,178000.0,234900.0,38000.0,127000.0,62000.0,1224800.0,1022900.0,null,77100.0,156000.0,66000.0,null,67000.0,232000.0,106900.0,77000.0,null,97500.0,27000.0,null,74000.0,null,71700.0,58000.0,175100.0,1550.0,77500.0,65500.0,74800.0,155000.0,96900.0,278000.0,26717300.0,72000.0,235000.0,100000.0,50000.0,null,76500.0,26000.0,62700.0,136000.0,null,null,235000.0,60800.0,null,120000.0,84600.0,116900.0,192400.0,93500.0,null,60000.0,76900.0,140000.0,134500.0,118000.0,null,171000.0,315000.0,95000.0,128900.0,121000.0,99200.0,74000.0,69500.0,79500.0,205200.0,113000.0,10345900.0,59300.0,94100.0,10345900.0,null,124000.0,90000.0,118100.0,48300.0,127700.0,75000.0,175400.0,10345900.0,220000.0,115500.0,158400.0,46000.0,null,201000.0,325000.0,92200.0,195800.0,271000.0,null,140000.0,28000.0,320000.0,null,290500.0,169900.0,195000.0,null,180000.0,215000.0,218000.0,229900.0,225000.0,215000.0,224500.0,215000.0,260000.0,240000.0,245000.0,242000.0,245000.0,87000.0,240000.0,300000.0,245000.0,251000.0,255000.0,null,null,264000.0,259900.0,269000.0,280000.0,291100.0,null,125000.0,384000.0,165000.0,332000.0,96000.0,180000.0,40000.0,245000.0,null,305000.0,211529.0,248000.0,269900.0,255000.0,6846600.0,235000.0,230000.0,null,305000.0,230000.0,109000.0,227500.0,null,110000.0,275000.0,153000.0,245000.0,null,245000.0,255000.0,237000.0,217000.0,null,347500.0],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333333333 ...

# %% [markdown]
# ### 2) Property Estimates 🏙️
# [Api Docs](https://developers.rentcast.io/reference/value-estimate) | Returns a property value estimate and comparable properties.

# %%
# get sales estimate data from rent cast
url = "https://api.rentcast.io/v1/avm/value"
querystring = {
    "address":address,
}
headers = {
    "accept": "application/json",
    "X-Api-Key": rent_cast_api_key
}
response_prop_estimate = requests.get(url, headers=headers, params=querystring)
response_prop_estimate.text
# Out:
# '{"price":323000,"priceRangeLow":226000,"priceRangeHigh":420000,"longitude":-81.442822,"latitude":28.628838,"comparables":[{"id":"5430-Brownell-St,-Orlando,-FL-32810","addressLine1":"5430 Brownell St","city":"Orlando","state":"FL","zipCode":"32810","formattedAddress":"5430 Brownell St, Orlando, FL 32810","latitude":28.628838,"longitude":-81.442822,"price":274900,"listedDate":"2023-06-09T00:00:00.000Z","lastSeenDate":"2023-08-23T00:00:00.000Z","daysOld":1,"distance":0,"correlation":1,"county":"Orange","propertyType":"Single Family","bedrooms":3,"bathrooms":2,"squareFootage":1092,"lotSize":6781,"yearBuilt":1989},{"id":"8001-Rose-Ave,-Orlando,-FL-32810","addressLine1":"8001 Rose Ave","city":"Orlando","state":"FL","zipCode":"32810","formattedAddress":"8001 Rose Ave, Orlando, FL 32810","latitude":28.629439,"longitude":-81.443367,"price":289500,"listedDate":"2023-02-17T00:00:00.000Z","lastSeenDate":"2023-04-03T00:00:00.000Z","daysOld":143,"distance":0.0531,"correlation":0.9959,"county":"Orange","propertyType":"Single Family","bedrooms":2,"bathrooms":2,"squareFootage":1208,"lotSize":6499,"yearBuilt":1948},{"id":"5429-Vanderlin-St,-Orlando,-FL-32810","addressLine1":"5429 Vanderlin St","city":"Orlando","state":"FL","zipCode":"32810","formattedAddress":"5429 Vanderlin St, Orlando, FL 32810","latitude":28.627584,"longitude":-81.442979,"price":230000,"listedDate":"2022-06-22T00:00:00.000Z","lastSeenDate":"2023-08-23T00:00:00.000Z","daysOld":1,"distance":0.0873,"correlation":0.9956,"county":"Orange","propertyType":"Single Family","bedrooms":2,"bathrooms":1,"squareFootage":1024,"lotSize":6758,"yearBuilt":1946},{"id":"7814-Empire-Ave,-Orlando,-FL-32810","addressLine1":"7814 Empire Ave","city":"Orlando","state":"FL","zipCode":"32810","formattedAddress":"7814 Empire Ave, Orlando, FL 32810","latitude":28.627923,"longitude":-81.444931,"price":135000,"listedDate":"2023-02-23T00:00:00.000Z","lastSeenDate":"2023-06-05T00:00:00.000Z","daysOld":80,"distance":0.1428,"correlation":0.9921,"county":"Orange","propertyType":"Single Family","bedrooms":2,"bathrooms":1,"squareFootage":740,"lotSize":6735,"yearBuilt":1952},{"id":"7720-Eastridge-Ct,-Orlando,-FL-32810","addressLine1":"7720 Eastridge Ct","city":"Orlando","state":"FL","zipCode":"32810","formattedAddress":"7720 Eastridge Ct, Orlando, FL 32810","latitude":28.626627,"longitude":-81.441428,"price":345000,"listedDate":"2023-06-15T00:00:00.000Z","lastSeenDate":"2023-08-23T00:00:00.000Z","daysOld":1,"distance":0.1748,"correlation":0.9913,"county":"Orange","propertyType":"Single Family","bedrooms":3,"bathrooms":2,"squareFootage":1532,"lotSize":9708,"yearBuilt":1980},{"id":"7734-Groveridge-Ct,-Orlando,-FL-32810","addressLine1":"7734 Groveridge Ct","city":"Orlando","state":"FL","zipCode":"32810","formattedAddress":"7734 Groveridge Ct, Orlando, FL 32810","latitude":28.627029,"longitude":-81.440552,"price":285000,"listedDate":"2023-07-11T00:00:00.000Z","lastSeenDate":"2023-08-23T00:00:00.000Z","daysOld":1,"distance":0.1862,"correlation":0.9907,"county":"Orange","propertyType":"Single Family","bedrooms":2,"bathrooms":2,"squareFootage":988,"lotSize":12197,"yearBuilt":1981},{"id":"8250-Baywood-Vista-Dr,-Orlando,-FL-32810","addressLine1":"8250 Baywood Vista Dr","city":"Orlando","state":"FL","zipCode":"32810","formattedAddress":"8250 Baywood Vista Dr, Orlando, FL 32810","latitude":28.630458,"longitude":-81.445638,"price":470000,"listedDate":"2023-04-30T00:00:00.000Z","lastSeenDate":"2023-05-11T00:00:00.000Z","daysOld":105,"distance":0.2044,"correlation":0.9887,"county":"Orange","propertyType":"Single Family","bedrooms":4,"bathrooms":2,"squareFootage":2200,"lotSize":5275,"yearBuilt":2003},{"id":"5337-Windridge-Ln,-Orlando,-FL-32810","addressLine1":"5337 Windridge Ln","city":"Orlando","state":"FL","zipCode":"32810","formattedAddress":"5337 Windridge Ln, Orlando, FL 32810","latitude":28.62622,"longitude":-81.439718,"price":344990,"listedDate":"2023-06-01T00:00:00.000Z","lastSeenDate":"2023-08-04T00:00:00.000Z","daysOl ...

# %%
# view keys
response_prop_estimate.json().keys()
# Out:
# dict_keys(['price', 'priceRangeLow', 'priceRangeHigh', 'longitude', 'latitude', 'comparables'])

# %%
# get sales comparables into a dataframe
df_prop_sales_comps = pd.json_normalize(response_prop_estimate.json()['comparables'])
print('Estimated price: ${:,}'.format(response_prop_estimate.json()['price']))
print(f'Num of records: {len(df_prop_sales_comps)}')
print(f'Num of columns: {len(df_prop_sales_comps.columns)}')
df_prop_sales_comps.head()
# Out:
# Estimated price: $323,000
# Num of records: 10
# Num of columns: 21
#                                      id       addressLine1     city state  \
# 0   5430-Brownell-St,-Orlando,-FL-32810   5430 Brownell St  Orlando    FL
# 1      8001-Rose-Ave,-Orlando,-FL-32810      8001 Rose Ave  Orlando    FL
# 2  5429-Vanderlin-St,-Orlando,-FL-32810  5429 Vanderlin St  Orlando    FL
# 3    7814-Empire-Ave,-Orlando,-FL-32810    7814 Empire Ave  Orlando    FL
# 4  7720-Eastridge-Ct,-Orlando,-FL-32810  7720 Eastridge Ct  Orlando    FL
#
#   zipCode                      formattedAddress   latitude  longitude   price  \
# 0   32810   5430 Brownell St, Orlando, FL 32810  28.628838 -81.442822  274900
# 1   32810      8001 Rose Ave, Orlando, FL 32810  28.629439 -81.443367  289500
# 2   32810  5429 Vanderlin St, Orlando, FL 32810  28.627584 -81.442979  230000
# 3   32810    7814 Empire Ave, Orlando, FL 32810  28.627923 -81.444931  135000
# 4   32810  7720 Eastridge Ct, Orlando, FL 32810  28.626627 -81.441428  345000
#
#                  listedDate              lastSeenDate  daysOld  distance  \
# 0  2023-06-09T00:00:00.000Z  2023-08-23T00:00:00.000Z        1    0.0000
# 1  2023-02-17T00:00:00.000Z  2023-04-03T00:00:00.000Z      143    0.0531
# 2  2022-06-22T00:00:00.000Z  2023-08-23T00:00:00.000Z        1    0.0873
# 3  2023-02-23T00:00:00.000Z  2023-06-05T00:00:00.000Z       80    0.1428
# 4  2023-06-15T00:00:00.000Z  2023-08-23T00:00:00.000Z        1    0.1748
#
#    correlation  county   propertyType  bedrooms  bathrooms  squareFootage  \
# 0       1.0000  Orange  Single Family         3          2           1092
# 1       0.9959  Orange  Single Family         2          2           1208
# 2       0.9956  Orange  Single Family         2          1           1024
# 3       0.9921  Orange  Single Family         2          1            740
# 4       0.9913  Orange  Single Family         3          2           1532
#
#    lotSize  yearBuilt
# 0     6781       1989
# 1     6499       1948
# 2     6758       1946
# 3     6735       1952
# 4     9708       1980

# %%
# get subject property attributes into a dataframe
comp_cols = ['price', 'latitude', 'longitude']
d_sales_comps = {}
for c in comp_cols:
  d_sales_comps[c] = [response_prop_estimate.json()[c]]
df_sales_comp_subj = pd.DataFrame(data=d_sales_comps)
df_sales_comp_subj['type'] = 'subject property'
df_sales_comp_subj
# Out:
#     price   latitude  longitude              type
# 0  323000  28.628838 -81.442822  subject property

# %%
# get saels comp attributes into a dataframe
df_sales_comp = df_prop_sales_comps[['price', 'latitude', 'longitude']]
df_sales_comp['type'] = 'comparables'
df_sales_comp
# Out:
# <ipython-input-24-8e90c2ce9232>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     price   latitude  longitude         type
# 0  274900  28.628838 -81.442822  comparables
# 1  289500  28.629439 -81.443367  comparables
# 2  230000  28.627584 -81.442979  comparables
# 3  135000  28.627923 -81.444931  comparables
# 4  345000  28.626627 -81.441428  comparables
# 5  285000  28.627029 -81.440552  comparables
# 6  470000  28.630458 -81.445638  comparables
# 7  344990  28.626220 -81.439718  comparables
# 8  495500  28.632090 -81.444665  comparables
# 9  365000  28.631804 -81.445597  comparables

# %%
# concatenate subj & comps dataframe
df_sales_comps_fig = pd.concat([df_sales_comp_subj, df_sales_comp])
# plot coordinates in map
fig = px.scatter_mapbox(df_sales_comps_fig, lat="latitude", lon="longitude", size="price", color="type", zoom=15, title=f"<b>{address}</b><br>Property Sales Comparables")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="12317bdb-c1a5-4624-bbd9-d3f20ee993af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12317bdb-c1a5-4624-bbd9-d3f20ee993af")) {                    Plotly.newPlot(                        "12317bdb-c1a5-4624-bbd9-d3f20ee993af",                        [{"hovertemplate":"type=subject property\u003cbr\u003eprice=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[28.628838],"legendgroup":"subject property","lon":[-81.442822],"marker":{"color":"#636efa","size":[323000],"sizemode":"area","sizeref":1238.75},"mode":"markers","name":"subject property","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"type=comparables\u003cbr\u003eprice=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[28.628838,28.629439,28.627584,28.627923,28.626627,28.627029,28.630458,28.62622,28.63209,28.631804],"legendgroup":"comparables","lon":[-81.442822,-81.443367,-81.442979,-81.444931,-81.441428,-81.440552,-81.445638,-81.439718,-81.444665,-81.445597],"marker":{"color":"#EF553B","size":[274900,289500,230000,135000,345000,285000,470000,344990,495500,365000],"sizemode":"area","sizeref":1238.75},"mode":"markers","name":"comparables","showlegend":true,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666 ...

# %% [markdown]
# ### 3) Rent Estimates 🤑
# [Api Docs](https://developers.rentcast.io/reference/rent-estimate-long-term) | Returns a property rent estimate and comparable properties.

# %%
# get rental estimate data from rent cast
url = "https://api.rentcast.io/v1/avm/rent/long-term"
querystring = {
    "address":address,
}
headers = {
    "accept": "application/json",
    "X-Api-Key": rent_cast_api_key
}
response_prop_rent_estimate = requests.get(url, headers=headers, params=querystring)
response_prop_rent_estimate.text
# Out:
# '{"rent":2090,"rentRangeLow":1810,"rentRangeHigh":2370,"longitude":-81.442822,"latitude":28.628838,"comparables":[{"id":"5458-Windridge-Ln,-Lockhart,-FL-32810","addressLine1":"5458 Windridge Ln","city":"Lockhart","state":"FL","zipCode":"32810","formattedAddress":"5458 Windridge Ln, Lockhart, FL 32810","latitude":28.626034,"longitude":-81.443057,"price":1695,"listedDate":"2023-03-17T00:00:00.000Z","lastSeenDate":"2023-05-03T00:00:00.000Z","daysOld":113,"distance":0.1945,"correlation":0.9893,"county":"Orange","propertyType":"Single Family","bedrooms":4,"squareFootage":1108},{"id":"5458-Windridge-Ln,-Orlando,-FL-32810","addressLine1":"5458 Windridge Ln","city":"Orlando","state":"FL","zipCode":"32810","formattedAddress":"5458 Windridge Ln, Orlando, FL 32810","latitude":28.626034,"longitude":-81.443057,"price":1695,"listedDate":"2023-03-16T00:00:00.000Z","lastSeenDate":"2023-05-01T00:00:00.000Z","daysOld":115,"distance":0.1945,"correlation":0.9893,"county":"Orange","propertyType":"Single Family","bedrooms":4,"bathrooms":2,"squareFootage":1108,"lotSize":8212,"yearBuilt":1980},{"id":"5541-New-Cambridge-Rd,-Orlando,-FL-32810","addressLine1":"5541 New Cambridge Rd","city":"Orlando","state":"FL","zipCode":"32810","formattedAddress":"5541 New Cambridge Rd, Orlando, FL 32810","latitude":28.631799,"longitude":-81.445176,"price":2235,"listedDate":"2023-07-16T00:00:00.000Z","lastSeenDate":"2023-08-22T00:00:00.000Z","daysOld":2,"distance":0.2497,"correlation":0.9877,"county":"Orange","propertyType":"Single Family","bedrooms":3,"bathrooms":2,"squareFootage":1292},{"id":"8507-Baywood-Vista-Dr,-Orlando,-FL-32810","addressLine1":"8507 Baywood Vista Dr","city":"Orlando","state":"FL","zipCode":"32810","formattedAddress":"8507 Baywood Vista Dr, Orlando, FL 32810","latitude":28.632086,"longitude":-81.444345,"price":2495,"listedDate":"2023-07-07T00:00:00.000Z","lastSeenDate":"2023-07-16T00:00:00.000Z","daysOld":39,"distance":0.2429,"correlation":0.9876,"county":"Orange","propertyType":"Single Family","bedrooms":3,"bathrooms":2,"squareFootage":2044,"lotSize":6352,"yearBuilt":2004},{"id":"5541-New-Cambridge-Rd,-Lockhart,-FL-32810","addressLine1":"5541 New Cambridge Rd","city":"Lockhart","state":"FL","zipCode":"32810","formattedAddress":"5541 New Cambridge Rd, Lockhart, FL 32810","latitude":28.631799,"longitude":-81.445176,"price":2550,"listedDate":"2023-05-16T00:00:00.000Z","lastSeenDate":"2023-07-06T00:00:00.000Z","daysOld":49,"distance":0.2497,"correlation":0.9872,"county":"Orange","propertyType":"Single Family","bedrooms":3,"bathrooms":2,"squareFootage":1292},{"id":"5550-New-Cambridge-Rd,-Lockhart,-FL-32810","addressLine1":"5550 New Cambridge Rd","city":"Lockhart","state":"FL","zipCode":"32810","formattedAddress":"5550 New Cambridge Rd, Lockhart, FL 32810","latitude":28.631388,"longitude":-81.445411,"price":1875,"listedDate":"2023-03-02T00:00:00.000Z","lastSeenDate":"2023-03-23T00:00:00.000Z","daysOld":154,"distance":0.2363,"correlation":0.9868,"county":"Orange","propertyType":"Single Family","bedrooms":3,"bathrooms":2,"squareFootage":1292},{"id":"5550-New-Cambridge-Rd,-Orlando,-FL-32810","addressLine1":"5550 New Cambridge Rd","city":"Orlando","state":"FL","zipCode":"32810","formattedAddress":"5550 New Cambridge Rd, Orlando, FL 32810","latitude":28.631388,"longitude":-81.445411,"price":1875,"listedDate":"2022-11-10T20:06:33.000Z","lastSeenDate":"2023-03-22T00:00:00.000Z","daysOld":155,"distance":0.2363,"correlation":0.9868,"county":"Orange","propertyType":"Single Family","bedrooms":3,"bathrooms":2,"squareFootage":1292,"lotSize":4499,"yearBuilt":1998},{"id":"5337R-Windridge-Ln,-Orlando,-FL-32810","addressLine1":"5337R Windridge Ln","city":"Orlando","state":"FL","zipCode":"32810","formattedAddress":"5337R Windridge Ln, Orlando, FL 32810","latitude":28.626165,"longitude":-81.439713,"price":2200,"listedDate":"2023-03-31T00:00:00.000Z","lastSeenDate":"2023-04-02T00:00:00.000Z","daysOld":144,"distance":0.2642,"correlation":0.9855,"county":"Orange","propert ...

# %%
# view keys
response_prop_rent_estimate.json().keys()
# Out:
# dict_keys(['rent', 'rentRangeLow', 'rentRangeHigh', 'longitude', 'latitude', 'comparables'])

# %%
# get rental comparables into a dataframe
df_prop_rent_comps = pd.json_normalize(response_prop_rent_estimate.json()['comparables'])
print('Estimated rent: ${:,}'.format(response_prop_rent_estimate.json()['rent']))
print(f'Num of records: {len(df_prop_rent_comps)}')
print(f'Num of columns: {len(df_prop_rent_comps.columns)}')
df_prop_rent_comps.head()
# Out:
# Estimated rent: $2,090
# Num of records: 10
# Num of columns: 21
#                                           id           addressLine1      city  \
# 0      5458-Windridge-Ln,-Lockhart,-FL-32810      5458 Windridge Ln  Lockhart
# 1       5458-Windridge-Ln,-Orlando,-FL-32810      5458 Windridge Ln   Orlando
# 2   5541-New-Cambridge-Rd,-Orlando,-FL-32810  5541 New Cambridge Rd   Orlando
# 3   8507-Baywood-Vista-Dr,-Orlando,-FL-32810  8507 Baywood Vista Dr   Orlando
# 4  5541-New-Cambridge-Rd,-Lockhart,-FL-32810  5541 New Cambridge Rd  Lockhart
#
#   state zipCode                           formattedAddress   latitude  \
# 0    FL   32810      5458 Windridge Ln, Lockhart, FL 32810  28.626034
# 1    FL   32810       5458 Windridge Ln, Orlando, FL 32810  28.626034
# 2    FL   32810   5541 New Cambridge Rd, Orlando, FL 32810  28.631799
# 3    FL   32810   8507 Baywood Vista Dr, Orlando, FL 32810  28.632086
# 4    FL   32810  5541 New Cambridge Rd, Lockhart, FL 32810  28.631799
#
#    longitude  price                listedDate              lastSeenDate  \
# 0 -81.443057   1695  2023-03-17T00:00:00.000Z  2023-05-03T00:00:00.000Z
# 1 -81.443057   1695  2023-03-16T00:00:00.000Z  2023-05-01T00:00:00.000Z
# 2 -81.445176   2235  2023-07-16T00:00:00.000Z  2023-08-22T00:00:00.000Z
# 3 -81.444345   2495  2023-07-07T00:00:00.000Z  2023-07-16T00:00:00.000Z
# 4 -81.445176   2550  2023-05-16T00:00:00.000Z  2023-07-06T00:00:00.000Z
#
#    daysOld  distance  correlation  county   propertyType  bedrooms  \
# 0      113    0.1945       0.9893  Orange  Single Family         4
# 1      115    0.1945       0.9893  Orange  Single Family         4
# 2        2    0.2497       0.9877  Orange  Single Family         3
# 3       39    0.2429       0.9876  Orange  Single Family         3
# 4       49    0.2497       0.9872  Orange  Single Family         3
#
#    squareFootage  bathrooms  lotSize  yearBuilt
# 0           1108        NaN      NaN        NaN
# 1           1108        2.0   8212.0     1980.0
# 2           1292        2.0      NaN        NaN
# 3           2044        2.0   6352.0     2004.0
# 4           1292        2.0      NaN        NaN

# %%
# get subject property attributes into a dataframe
rent_comp_cols = ['rent', 'latitude', 'longitude']
d_rent_comps = {}
for c in rent_comp_cols:
  d_rent_comps[c] = [response_prop_rent_estimate.json()[c]]
df_rent_comp_subj = pd.DataFrame(data=d_rent_comps).rename(columns={'rent': 'price'})
df_rent_comp_subj['type'] = 'subject property'
df_rent_comp_subj
# Out:
#    price   latitude  longitude              type
# 0   2090  28.628838 -81.442822  subject property

# %%
# get saels comp attributes into a dataframe
df_rent_comp = df_prop_rent_comps[['price', 'latitude', 'longitude']]
df_rent_comp['type'] = 'comparables'
df_rent_comp
# Out:
# <ipython-input-32-6f7925050543>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    price   latitude  longitude         type
# 0   1695  28.626034 -81.443057  comparables
# 1   1695  28.626034 -81.443057  comparables
# 2   2235  28.631799 -81.445176  comparables
# 3   2495  28.632086 -81.444345  comparables
# 4   2550  28.631799 -81.445176  comparables
# 5   1875  28.631388 -81.445411  comparables
# 6   1875  28.631388 -81.445411  comparables
# 7   2200  28.626165 -81.439713  comparables
# 8   2295  28.631118 -81.446695  comparables
# 9   1960  28.633249 -81.443056  comparables

# %%
# concatenate subj & comps dataframe
df_rent_comps_fig = pd.concat([df_rent_comp_subj, df_rent_comp])
# plot coordinates in map
fig = px.scatter_mapbox(df_rent_comps_fig, lat="latitude", lon="longitude", size="price", color="type", zoom=14, title=f"<b>{address}</b><br>Property Rental Comparables")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f64efe1b-8d9f-4d5c-b8dc-4a55d22a7ca2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f64efe1b-8d9f-4d5c-b8dc-4a55d22a7ca2")) {                    Plotly.newPlot(                        "f64efe1b-8d9f-4d5c-b8dc-4a55d22a7ca2",                        [{"hovertemplate":"type=subject property\u003cbr\u003eprice=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[28.628838],"legendgroup":"subject property","lon":[-81.442822],"marker":{"color":"#636efa","size":[2090],"sizemode":"area","sizeref":6.375},"mode":"markers","name":"subject property","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"type=comparables\u003cbr\u003eprice=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[28.626034,28.626034,28.631799,28.632086,28.631799,28.631388,28.631388,28.626165,28.631118,28.633249],"legendgroup":"comparables","lon":[-81.443057,-81.443057,-81.445176,-81.444345,-81.445176,-81.445411,-81.445411,-81.439713,-81.446695,-81.443056],"marker":{"color":"#EF553B","size":[1695,1695,2235,2495,2550,1875,1875,2200,2295,1960],"sizemode":"area","sizeref":6.375},"mode":"markers","name":"comparables","showlegend":true,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7 ...

# %% [markdown]
# ### 4) Market Statistics 📊
# [Api Docs](https://developers.rentcast.io/reference/rent-estimate-long-term) | Returns aggregate rental statistics and listing trends for a single US zip code.

# %%
# get zip code from address
zip_code = address.split(' ')[-1]
zip_code
# Out:
# '32810'

# %%
# get market data from rent cast
url = "https://api.rentcast.io/v1/markets"
querystring = {
    "zipCode": zip_code,
    "historyRange": 24 # number of months
}
headers = {
    "accept": "application/json",
    "X-Api-Key": rent_cast_api_key
}
response_market_stats = requests.get(url, headers=headers, params=querystring)
response_market_stats.text
# Out:
# '{"id":"32810","zipCode":"32810","rentalData":{"averageRent":1991,"minRent":850,"maxRent":10000,"totalListings":501,"dataByBedrooms":[{"bedrooms":1,"averageRent":1676,"minRent":850,"maxRent":2118,"totalListings":140},{"bedrooms":2,"averageRent":1982,"minRent":1350,"maxRent":2743,"totalListings":161},{"bedrooms":3,"averageRent":2205,"minRent":1065,"maxRent":10000,"totalListings":163},{"bedrooms":4,"averageRent":2302,"minRent":1595,"maxRent":3250,"totalListings":34},{"bedrooms":5,"averageRent":2023,"minRent":1925,"maxRent":2150,"totalListings":3}],"history":{"2021-11":{"averageRent":1922.5,"minRent":783,"maxRent":3154,"totalListings":198,"dataByBedrooms":[{"bedrooms":0,"averageRent":1471.29,"minRent":1200,"maxRent":1680,"totalListings":7},{"bedrooms":1,"averageRent":1696.78,"minRent":995,"maxRent":2085,"totalListings":63},{"bedrooms":2,"averageRent":1850,"minRent":1025,"maxRent":2515,"totalListings":65},{"bedrooms":3,"averageRent":1777.59,"minRent":783,"maxRent":3154,"totalListings":49},{"bedrooms":4,"averageRent":1999.5,"minRent":1400,"maxRent":2500,"totalListings":10},{"bedrooms":5,"averageRent":1813.33,"minRent":1750,"maxRent":1895,"totalListings":3},{"bedrooms":6,"averageRent":2849,"minRent":2849,"maxRent":2849,"totalListings":1}]},"2021-12":{"averageRent":1934.73,"minRent":783,"maxRent":3154,"totalListings":260,"dataByBedrooms":[{"bedrooms":0,"averageRent":1399.67,"minRent":1200,"maxRent":1553,"totalListings":6},{"bedrooms":1,"averageRent":1661.54,"minRent":995,"maxRent":2056,"totalListings":84},{"bedrooms":2,"averageRent":1907.8,"minRent":950,"maxRent":2695,"totalListings":93},{"bedrooms":3,"averageRent":1891.48,"minRent":783,"maxRent":3154,"totalListings":56},{"bedrooms":4,"averageRent":2020.29,"minRent":1400,"maxRent":2500,"totalListings":17},{"bedrooms":5,"averageRent":1813.33,"minRent":1750,"maxRent":1895,"totalListings":3},{"bedrooms":6,"averageRent":2849,"minRent":2849,"maxRent":2849,"totalListings":1}]},"2021-10":{"averageRent":1914.8,"minRent":783,"maxRent":3154,"totalListings":280,"dataByBedrooms":[{"bedrooms":0,"averageRent":1398,"minRent":1200,"maxRent":1545,"totalListings":6},{"bedrooms":1,"averageRent":1649.23,"minRent":915,"maxRent":2056,"totalListings":83},{"bedrooms":2,"averageRent":1884.68,"minRent":950,"maxRent":2730,"totalListings":93},{"bedrooms":3,"averageRent":1777.42,"minRent":783,"maxRent":3154,"totalListings":81},{"bedrooms":4,"averageRent":2031.92,"minRent":1400,"maxRent":2500,"totalListings":13},{"bedrooms":5,"averageRent":1813.33,"minRent":1750,"maxRent":1895,"totalListings":3},{"bedrooms":6,"averageRent":2849,"minRent":2849,"maxRent":2849,"totalListings":1}]},"2021-09":{"averageRent":1909.51,"minRent":783,"maxRent":3154,"totalListings":287,"dataByBedrooms":[{"bedrooms":0,"averageRent":1398,"minRent":1200,"maxRent":1545,"totalListings":6},{"bedrooms":1,"averageRent":1643.94,"minRent":915,"maxRent":2056,"totalListings":84},{"bedrooms":2,"averageRent":1857.73,"minRent":950,"maxRent":2730,"totalListings":97},{"bedrooms":3,"averageRent":1772.66,"minRent":783,"maxRent":3154,"totalListings":83},{"bedrooms":4,"averageRent":2031.92,"minRent":1400,"maxRent":2500,"totalListings":13},{"bedrooms":5,"averageRent":1813.33,"minRent":1750,"maxRent":1895,"totalListings":3},{"bedrooms":6,"averageRent":2849,"minRent":2849,"maxRent":2849,"totalListings":1}]},"2022-01":{"averageRent":1940.37,"minRent":783,"maxRent":3154,"totalListings":291,"dataByBedrooms":[{"bedrooms":0,"averageRent":1450.67,"minRent":1200,"maxRent":1698,"totalListings":6},{"bedrooms":1,"averageRent":1658.42,"minRent":1000,"maxRent":2056,"totalListings":95},{"bedrooms":2,"averageRent":1912.07,"minRent":900,"maxRent":2680,"totalListings":109},{"bedrooms":3,"averageRent":1936.84,"minRent":783,"maxRent":3154,"totalListings":62},{"bedrooms":4,"averageRent":1953.13,"minRent":1400,"maxRent":2405,"totalListings":16},{"bedrooms":5,"averageRent":1822.5,"minRent":1750,"maxRent":1895,"totalListings":2},{"bedrooms":6,"averageRent":2849,"minRent":2849,"maxRent" ...

# %%
# get all dates for market stats to a list
market_date_list = list(response_market_stats.json()['rentalData']['history'].keys())
market_date_list
# Out:
# ['2021-11',
#  '2021-12',
#  '2021-10',
#  '2021-09',
#  '2022-01',
#  '2022-02',
#  '2022-03',
#  '2022-04',
#  '2022-05',
#  '2022-06',
#  '2022-07',
#  '2022-08',
#  '2022-09',
#  '2022-10',
#  '2022-11',
#  '2022-12',
#  '2023-01',
#  '2023-02',
#  '2023-03',
#  '2023-04',
#  '2023-05',
#  '2023-06',
#  '2023-07',
#  '2023-08']

# %%
# get rental details for latest date
response_market_stats.json()['rentalData']['history'][market_date_list[-1]]
# Out:
# {'averageRent': 1991,
#  'minRent': 850,
#  'maxRent': 10000,
#  'totalListings': 501,
#  'dataByBedrooms': [{'bedrooms': 1,
#    'averageRent': 1676,
#    'minRent': 850,
#    'maxRent': 2118,
#    'totalListings': 140},
#   {'bedrooms': 2,
#    'averageRent': 1982,
#    'minRent': 1350,
#    'maxRent': 2743,
#    'totalListings': 161},
#   {'bedrooms': 3,
#    'averageRent': 2205,
#    'minRent': 1065,
#    'maxRent': 10000,
#    'totalListings': 163},
#   {'bedrooms': 4,
#    'averageRent': 2302,
#    'minRent': 1595,
#    'maxRent': 3250,
#    'totalListings': 34},
#   {'bedrooms': 5,
#    'averageRent': 2023,
#    'minRent': 1925,
#    'maxRent': 2150,
#    'totalListings': 3}]}

# %%
# get market rental history to a dataframe
df_market_list = [] # create empty list

# iterate through all dates
for dt in market_date_list:
  # transform month/year rental history to a single dataframe
  _df_market = pd.DataFrame(response_market_stats.json()['rentalData']['history'][dt]['dataByBedrooms'])
  _df_market['date'] = dt # add date
  _df_market.insert(0, 'date', _df_market.pop('date')) # move date to be first column
  df_market_list.append(_df_market) # append to list

# merge all rental history dates
df_market_by_dt = pd.concat(df_market_list)
df_market_by_dt
# Out:
#        date  bedrooms  averageRent  minRent  maxRent  totalListings
# 0   2021-11         0      1471.29     1200     1680              7
# 1   2021-11         1      1696.78      995     2085             63
# 2   2021-11         2      1850.00     1025     2515             65
# 3   2021-11         3      1777.59      783     3154             49
# 4   2021-11         4      1999.50     1400     2500             10
# ..      ...       ...          ...      ...      ...            ...
# 0   2023-08         1      1676.00      850     2118            140
# 1   2023-08         2      1982.00     1350     2743            161
# 2   2023-08         3      2205.00     1065    10000            163
# 3   2023-08         4      2302.00     1595     3250             34
# 4   2023-08         5      2023.00     1925     2150              3
#
# [157 rows x 6 columns]

# %%
# filter on number of bedrooms
df_market_by_dt_fig = df_market_by_dt.loc[df_market_by_dt["bedrooms"].isin([1,2,3,4])]
df_market_by_dt_fig = df_market_by_dt_fig.sort_values(by=["date"]) # sort before plotting
# create figure
fig = px.line(df_market_by_dt_fig, x="date", y="averageRent", color='bedrooms', title=f"Average Rent by Bedroom for <b>{zip_code}</b>")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="69c37d7c-6c45-44c7-aed6-7558f9d60410" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69c37d7c-6c45-44c7-aed6-7558f9d60410")) {                    Plotly.newPlot(                        "69c37d7c-6c45-44c7-aed6-7558f9d60410",                        [{"hovertemplate":"bedrooms=4\u003cbr\u003edate=%{x}\u003cbr\u003eaverageRent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"4","orientation":"v","showlegend":true,"x":["2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06","2022-07","2022-08","2022-09","2022-10","2022-11","2022-12","2023-01","2023-02","2023-03","2023-04","2023-05","2023-06","2023-07","2023-08"],"xaxis":"x","y":[2031.92,2031.92,1999.5,2020.29,1953.13,2028.06,2023.1,2047.06,2054.23,2162.14,2140.45,2219.87,2208.1,2325.65,2371.68,2377.46,2435.0,2184.0,2120.0,2153.0,2130.0,2195.0,2221.0,2302.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"bedrooms=3\u003cbr\u003edate=%{x}\u003cbr\u003eaverageRent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"3","orientation":"v","showlegend":true,"x":["2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06","2022-07","2022-08","2022-09","2022-10","2022-11","2022-12","2023-01","2023-02","2023-03","2023-04","2023-05","2023-06","2023-07","2023-08"],"xaxis":"x","y":[1772.66,1777.42,1777.59,1891.48,1936.84,2119.42,2084.24,2125.85,2155.14,2189.32,2207.06,2251.24,2223.81,2154.23,2162.01,2161.4,2139.0,2167.0,2168.0,2193.0,2220.0,2162.0,2213.0,2205.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"bedrooms=2\u003cbr\u003edate=%{x}\u003cbr\u003eaverageRent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2","orientation":"v","showlegend":true,"x":["2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06","2022-07","2022-08","2022-09","2022-10","2022-11","2022-12","2023-01","2023-02","2023-03","2023-04","2023-05","2023-06","2023-07","2023-08"],"xaxis":"x","y":[1857.73,1884.68,1850.0,1907.8,1912.07,1915.63,1932.11,1915.24,1915.52,1927.38,1941.92,1941.47,1959.31,1930.82,1924.5,1886.76,1915.0,1944.0,1970.0,2046.0,2061.0,2022.0,1992.0,1982.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"bedrooms=1\u003cbr\u003edate=%{x}\u003cbr\u003eaverageRent=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"1","orientation":"v","showlegend":true,"x":["2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06","2022-07","2022-08","2022-09","2022-10","2022-11","2022-12","2023-01","2023-02","2023-03","2023-04","2023-05","2023-06","2023-07","2023-08"],"xaxis":"x","y":[1643.94,1649.23,1696.78,1661.54,1658.42,1702.75,1706.3,1668.4,1669.0,1716.77,1704.39,1709.49,1654.43,1604.21,1606.24,1618.95,1623.0,1671.0,1700.0,1688.0,1684.0,1678.0,1673.0,1676.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"ch ...

# %%
# get yoy change for average rent
df_market_by_dt_yoy_fig = df_market_by_dt_fig.copy()
df_market_by_dt_yoy_fig['rent_pct_yoy'] = df_market_by_dt_yoy_fig['averageRent'].pct_change(12)
# create figure
fig = px.line(df_market_by_dt_yoy_fig, x="date", y="rent_pct_yoy", color='bedrooms', title=f"YoY Average Rent by Bedroom for <b>{zip_code}</b>")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b26542b7-79e7-466d-ae53-c5ca8fe46063" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b26542b7-79e7-466d-ae53-c5ca8fe46063")) {                    Plotly.newPlot(                        "b26542b7-79e7-466d-ae53-c5ca8fe46063",                        [{"hovertemplate":"bedrooms=4\u003cbr\u003edate=%{x}\u003cbr\u003erent_pct_yoy=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"4","orientation":"v","showlegend":true,"x":["2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06","2022-07","2022-08","2022-09","2022-10","2022-11","2022-12","2023-01","2023-02","2023-03","2023-04","2023-05","2023-06","2023-07","2023-08"],"xaxis":"x","y":[null,null,null,0.22893171283623492,0.09885676992494741,0.19524039651575342,0.0013908894267653515,0.04809203688438557,0.012903957476603223,0.2671511457539706,0.2829357468233036,0.030035171728982846,0.008578005956187296,0.19760340281782973,0.05349940477248105,0.07669942484488934,0.04701911293616834,-0.0791337785873304,-0.1082920427683326,-0.11581108829568787,-0.02472527472527475,0.03537735849056611,0.0315838365071992,0.11693352741387675],"yaxis":"y","type":"scatter"},{"hovertemplate":"bedrooms=3\u003cbr\u003edate=%{x}\u003cbr\u003erent_pct_yoy=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"3","orientation":"v","showlegend":true,"x":["2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06","2022-07","2022-08","2022-09","2022-10","2022-11","2022-12","2023-01","2023-02","2023-03","2023-04","2023-05","2023-06","2023-07","2023-08"],"xaxis":"x","y":[null,null,null,-0.06911689436591995,0.17439047312988487,0.05997499374843707,0.25440254221986813,0.0975867908552075,0.016853667512809922,0.08216103998813717,0.07816087462018695,0.0959045481762022,0.15379945833203612,0.263930203767917,-0.026064589367845725,-0.0280644479519383,-0.007069811487167121,0.0023080374281339022,0.003053576385675827,0.02524544179523147,0.02445777572681118,-0.002767527675276771,0.00911992704058373,0.035211267605633756],"yaxis":"y","type":"scatter"},{"hovertemplate":"bedrooms=2\u003cbr\u003edate=%{x}\u003cbr\u003erent_pct_yoy=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2","orientation":"v","showlegend":true,"x":["2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06","2022-07","2022-08","2022-09","2022-10","2022-11","2022-12","2023-01","2023-02","2023-03","2023-04","2023-05","2023-06","2023-07","2023-08"],"xaxis":"x","y":[null,null,null,0.07623571356041192,0.014532971114459725,0.03547567567567578,0.012742425830799764,0.0016578890940186497,0.12495668771105573,-0.07526004682762044,-0.08652068584330963,0.16325344517675267,0.14127693284481913,-0.09793734962274281,-0.008740799497288121,-0.037028341610056525,-0.008193410053759509,0.010132501948558081,0.0441179588288918,0.06840731070496076,0.06018518518518512,0.02639593908629445,-0.02639296187683282,0.1769596199524941],"yaxis":"y","type":"scatter"},{"hovertemplate":"bedrooms=1\u003cbr\u003edate=%{x}\u003cbr\u003erent_pct_yoy=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"1","orientation":"v","showlegend":true,"x":["2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03","2022-04","2022-05","2022-06","2022-07","2022-08" ...

# %% [markdown]
# # End Notebook
