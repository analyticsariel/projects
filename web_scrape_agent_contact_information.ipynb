# %% [markdown]
# # Web Scrape Agent Contact Information
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1pmgaYBVoi5H-AkTbHC8po6moWZ5sgfva?usp=sharing)
#
# ## Overview
# | Detail Tag            | Information                                                                                        |
# |-----------------------|----------------------------------------------------------------------------------------------------|
# | Originally Created By | Ariel Herrera arielherrera@analyticsariel.com |
# | External References   | API |
# | Input Datasets        | Source name |
# | Output Datasets       | Source name |
# | Input Data Source     | Pandas DataFrame |
# | Output Data Source    | Pandas DataFrame |
#
# ## History
# | Date         | Developed By  | Reason                                                |
# |--------------|---------------|-------------------------------------------------------|
# | 15th Jun 2024 | Ariel Herrera | Create notebook. |
#
# ## Getting Started
# 1. Copy this notebook -> File -> Save a Copy in Drive
# 2. Directions
#
# ## Useful Resources
# - [Google Colab Cheat Sheet](https://towardsdatascience.com/cheat-sheet-for-google-colab-63853778c093)
# - [Redfin Housing Market Overview](https://www.redfin.com/city/13655/FL/Orlando/housing-market)

# %% [markdown]
# ## Why Agents are Valuable Leads for Real Estate Products 🤔
# Skip the Cold Calls 📱: Target Real Estate Agents 👩‍💼 for Success
#
# Forget cold calling - real estate agents are the key to unlocking a network of qualified leads. Here's why:
#
# - <b>Trusted referrals</b> 🤝: Agents recommend products and services to their clients, turning them into brand advocates for your business.
# - <b>Industry insights</b> 📊: Partnering with agents gives you access to their market knowledge, helping you tailor your offerings for maximum impact.
# - <b>High-quality leads</b> 🙋: Agents work with pre-qualified clients actively seeking solutions, saving you time and resources.
#
# From mortgage lenders to home improvement companies, marketing to real estate agents benefits businesses across the industry.
#
# <b>BONUS TIP</b> 🙌: If you are a student or new to the the real estate indusry, then reach out to agents to provide free work. This will help you build your network building and experience.

# %% [markdown]
# ## <font color="blue">Install Packages</font>

# %% [markdown]
# ## <font color="blue">Imports</font>

# %%
import requests
from getpass import getpass
import pandas as pd
import numpy as np
import decimal
import json

# %% [markdown]
# ## <font color="blue">Functions</font>

# %%
def isvalid(val):
    try:
        if val is None or np.isnan(val):
            return False
        else:
            return True
    except:
        try:
            if type(val) == str:
                return True
            elif type(val) == dict:
                return True
            elif type(val) == list:
                return True
            elif type(val) == bool:
                return True
            elif isinstance(val, decimal.Decimal) == True:
                return True
        except:
            return False

# %%
def normalize_phone_number(x):
  phone_num = str(x)
  phone_num = phone_num.replace('(','')
  phone_num = phone_num.replace(')','')
  phone_num = phone_num.replace(' ','')
  phone_num = phone_num.replace('-','')
  return phone_num

# %% [markdown]
# ## <font color="blue">Locals & Constants</font>

# %%
# api key - https://rapidapi.com/apimaker/api/us-real-estate-listings/playground/apiendpoint_f6ae6980-74c8-40db-9d63-51ecfdeb6e6e
rapid_api_key = getpass('Enter the api key: ')
# Out:
# Enter the api key: ··········

# %% [markdown]
# ## <font color="blue">Data</font>

# %%
url = "https://us-real-estate-listings.p.rapidapi.com/agent/find"

querystring = {
    "zip": "33610", # zipcode
    "limit": "20", # number of records returned (max 20)
    "offset": "0", # page number
    "sort": "RECENT_ACTIVITY_HIGH", # sorting
    "types": "agent", # agent
    "agent_type": "BUYER" # type of agent buyer / seller
}

headers = {
	"x-rapidapi-key": rapid_api_key,
	"x-rapidapi-host": "us-real-estate-listings.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'totalResultCount': 675, 'agents': [{'types': 'agent', 'nar_only': 1, 'role': 'agent', 'marketing_area_cities': [{'name': 'Brandon', 'state_code': 'FL', 'city_state': 'Brandon_FL'}, {'name': 'Bloomingdale', 'state_code': 'FL', 'city_state': 'Bloomingdale_FL'}, {'name': 'Gibsonton', 'state_code': 'FL', 'city_state': 'Gibsonton_FL'}, {'name': 'Riverview', 'state_code': 'FL', 'city_state': 'Riverview_FL'}, {'name': 'Zephyrhills', 'state_code': 'FL', 'city_state': 'Zephyrhills_FL'}, {'name': 'Zephyrhills West', 'state_code': 'FL', 'city_state': 'Zephyrhills West_FL'}, {'name': 'Pasadena Hills', 'state_code': 'FL', 'city_state': 'Pasadena Hills_FL'}, {'name': 'Zephyrhills South', 'state_code': 'FL', 'city_state': 'Zephyrhills South_FL'}, {'name': 'Wesley Chapel', 'state_code': 'FL', 'city_state': 'Wesley Chapel_FL'}, {'name': 'University', 'state_code': 'FL', 'city_state': 'University_FL'}, {'name': 'Lake Magdalene', 'state_code': 'FL', 'city_state': 'Lake Magdalene_FL'}, {'name': 'Lutz', 'state_code': 'FL', 'city_state': 'Lutz_FL'}, {'name': "Land O' Lakes", 'state_code': 'FL', 'city_state': "Land O' Lakes_FL"}, {'name': 'Apollo Beach', 'state_code': 'FL', 'city_state': 'Apollo Beach_FL'}, {'name': 'Valrico', 'state_code': 'FL', 'city_state': 'Valrico_FL'}, {'name': 'Tampa', 'state_code': 'FL', 'city_state': 'Tampa_FL'}, {'name': 'Ybor City', 'state_code': 'FL', 'city_state': 'Ybor City_FL'}, {'name': 'Rocky Point', 'state_code': 'FL', 'city_state': 'Rocky Point_FL'}, {'name': "Town 'n' Country", 'state_code': 'FL', 'city_state': "Town 'n' Country_FL"}, {'name': 'East Lake-Orient Park', 'state_code': 'FL', 'city_state': 'East Lake-Orient Park_FL'}, {'name': 'Mango', 'state_code': 'FL', 'city_state': 'Mango_FL'}, {'name': 'Carrollwood', 'state_code': 'FL', 'city_state': 'Carrollwood_FL'}, {'name': 'Egypt Lake-Leto', 'state_code': 'FL', 'city_state': 'Egypt Lake-Leto_FL'}, {'name': 'Temple Terrace', 'state_code': 'FL', 'city_state': 'Temple Terrace_FL'}, {'name': 'Progress Village', 'state_code': 'FL', 'city_state': 'Progress Village_FL'}, {'name': 'Palm River-Clair Mel', 'state_code': 'FL', 'city_state': 'Palm River-Clair Mel_FL'}, {'name': 'Clair Mel', 'state_code': 'FL', 'city_state': 'Clair Mel_FL'}, {'name': 'Citrus Park', 'state_code': 'FL', 'city_state': 'Citrus Park_FL'}, {'name': 'Northdale', 'state_code': 'FL', 'city_state': 'Northdale_FL'}, {'name': 'Westchase', 'state_code': 'FL', 'city_state': 'Westchase_FL'}, {'name': 'Oldsmar', 'state_code': 'FL', 'city_state': 'Oldsmar_FL'}, {'name': 'Keystone', 'state_code': 'FL', 'city_state': 'Keystone_FL'}, {'name': 'Pebble Creek', 'state_code': 'FL', 'city_state': 'Pebble Creek_FL'}, {'name': 'Connerton', 'state_code': 'FL', 'city_state': 'Connerton_FL'}], 'background_photo': {'href': 'https://ap.rdcpix.com/e7092b5a77b29e8b08f72b82055ca962g-c2215664681s.jpg'}, 'address': {'postal_code': '', 'city': '', 'country': 'US', 'line2': '', 'state': '', 'line': '2234 Lithia Center Lane', 'state_code': 'FL'}, 'is_realtor': True, 'social_media': {'facebook': {'href': 'https://www.facebook.com/SignatureRealtyAssociatesTeamBarone/', 'type': 'facebook'}}, 'href': 'http://www.teambarone.com', 'office': {'slogan': 'In The Neighborhood ... At Your Service !!', 'website': 'WWW.SIGNATUREFL.COM', 'feed_licenses': {}, 'video': None, 'name': 'Signature Realty Associates', 'photo': {'href': 'http://p.rdcpix.com/v01/o33be0900-c0l.gif'}, 'email': 'kevin@signaturerealtyassociates.com', 'phones': [{'type': 'Office', 'number': '(888) 270-7653', 'ext': ''}, {'type': 'Fax', 'number': '(813) 643-5776', 'ext': ''}, {'type': 'Toll Free', 'number': '(888) 270-7653', 'ext': ''}], 'address': {'postal_code': '', 'city': '', 'country': 'US', 'line2': '', 'state': '', 'line': '2234 Lithia Center Lane', 'state_code': 'FL'}, 'nrds_id': '261500917', 'licenses': {}, 'phone_list': {'phone_1': {'ext': '', 'number': '8882707653', 'type': 'Office'}, 'phone_3': {'ext': '', 'number': '8882707653', 'type': 'Toll Free'}, 'phone ...

# %%
print('Number of results:', response.json()['totalResultCount'])
# Out:
# Number of results: 675

# %% [markdown]
# ## <font color="blue">Explore</font>

# %%
# review keys
print('Num of keys:', len(response.json()))
print(response.json().keys())
# Out:
# Num of keys: 2
# dict_keys(['totalResultCount', 'agents'])

# %%
print('Num of agent records:', len(response.json()['agents']))
# Out:
# Num of agent records: 20

# %% [markdown]
# Review first element

# %%
response.json()['agents'][0].keys()
# Out:
# dict_keys(['types', 'nar_only', 'role', 'marketing_area_cities', 'background_photo', 'address', 'is_realtor', 'social_media', 'href', 'office', 'zips', 'party_id', 'first_year', 'name', 'has_photo', 'review_count', 'for_sale_price', 'agent_team_details', 'recently_sold', 'slogan', 'feed_licenses', 'languages', 'id', 'nick_name', 'full_name', 'photo', 'email', 'first_name', 'settings', 'web_url', 'description', 'mls', 'mls_history', 'recommendations_count', 'designations', 'last_name', 'broker', 'last_updated', 'specializations', 'video', 'served_areas', 'person_name', 'user_languages', 'advertiser_id', 'title', 'mls_monetization', 'agent_type', 'nrds_id', 'first_month', 'agent_rating', 'phones'])

# %%
# review single example
response.json()['agents'][0]
# Out:
# {'types': 'agent',
#  'nar_only': 1,
#  'role': 'agent',
#  'marketing_area_cities': [{'name': 'Brandon',
#    'state_code': 'FL',
#    'city_state': 'Brandon_FL'},
#   {'name': 'Bloomingdale',
#    'state_code': 'FL',
#    'city_state': 'Bloomingdale_FL'},
#   {'name': 'Gibsonton', 'state_code': 'FL', 'city_state': 'Gibsonton_FL'},
#   {'name': 'Riverview', 'state_code': 'FL', 'city_state': 'Riverview_FL'},
#   {'name': 'Zephyrhills', 'state_code': 'FL', 'city_state': 'Zephyrhills_FL'},
#   {'name': 'Zephyrhills West',
#    'state_code': 'FL',
#    'city_state': 'Zephyrhills West_FL'},
#   {'name': 'Pasadena Hills',
#    'state_code': 'FL',
#    'city_state': 'Pasadena Hills_FL'},
#   {'name': 'Zephyrhills South',
#    'state_code': 'FL',
#    'city_state': 'Zephyrhills South_FL'},
#   {'name': 'Wesley Chapel',
#    'state_code': 'FL',
#    'city_state': 'Wesley Chapel_FL'},
#   {'name': 'University', 'state_code': 'FL', 'city_state': 'University_FL'},
#   {'name': 'Lake Magdalene',
#    'state_code': 'FL',
#    'city_state': 'Lake Magdalene_FL'},
#   {'name': 'Lutz', 'state_code': 'FL', 'city_state': 'Lutz_FL'},
#   {'name': "Land O' Lakes",
#    'state_code': 'FL',
#    'city_state': "Land O' Lakes_FL"},
#   {'name': 'Apollo Beach',
#    'state_code': 'FL',
#    'city_state': 'Apollo Beach_FL'},
#   {'name': 'Valrico', 'state_code': 'FL', 'city_state': 'Valrico_FL'},
#   {'name': 'Tampa', 'state_code': 'FL', 'city_state': 'Tampa_FL'},
#   {'name': 'Ybor City', 'state_code': 'FL', 'city_state': 'Ybor City_FL'},
#   {'name': 'Rocky Point', 'state_code': 'FL', 'city_state': 'Rocky Point_FL'},
#   {'name': "Town 'n' Country",
#    'state_code': 'FL',
#    'city_state': "Town 'n' Country_FL"},
#   {'name': 'East Lake-Orient Park',
#    'state_code': 'FL',
#    'city_state': 'East Lake-Orient Park_FL'},
#   {'name': 'Mango', 'state_code': 'FL', 'city_state': 'Mango_FL'},
#   {'name': 'Carrollwood', 'state_code': 'FL', 'city_state': 'Carrollwood_FL'},
#   {'name': 'Egypt Lake-Leto',
#    'state_code': 'FL',
#    'city_state': 'Egypt Lake-Leto_FL'},
#   {'name': 'Temple Terrace',
#    'state_code': 'FL',
#    'city_state': 'Temple Terrace_FL'},
#   {'name': 'Progress Village',
#    'state_code': 'FL',
#    'city_state': 'Progress Village_FL'},
#   {'name': 'Palm River-Clair Mel',
#    'state_code': 'FL',
#    'city_state': 'Palm River-Clair Mel_FL'},
#   {'name': 'Clair Mel', 'state_code': 'FL', 'city_state': 'Clair Mel_FL'},
#   {'name': 'Citrus Park', 'state_code': 'FL', 'city_state': 'Citrus Park_FL'},
#   {'name': 'Northdale', 'state_code': 'FL', 'city_state': 'Northdale_FL'},
#   {'name': 'Westchase', 'state_code': 'FL', 'city_state': 'Westchase_FL'},
#   {'name': 'Oldsmar', 'state_code': 'FL', 'city_state': 'Oldsmar_FL'},
#   {'name': 'Keystone', 'state_code': 'FL', 'city_state': 'Keystone_FL'},
#   {'name': 'Pebble Creek',
#    'state_code': 'FL',
#    'city_state': 'Pebble Creek_FL'},
#   {'name': 'Connerton', 'state_code': 'FL', 'city_state': 'Connerton_FL'}],
#  'background_photo': {'href': 'https://ap.rdcpix.com/e7092b5a77b29e8b08f72b82055ca962g-c2215664681s.jpg'},
#  'address': {'postal_code': '',
#   'city': '',
#   'country': 'US',
#   'line2': '',
#   'state': '',
#   'line': '2234 Lithia Center Lane',
#   'state_code': 'FL'},
#  'is_realtor': True,
#  'social_media': {'facebook': {'href': 'https://www.facebook.com/SignatureRealtyAssociatesTeamBarone/',
#    'type': 'facebook'}},
#  'href': 'http://www.teambarone.com',
#  'office': {'slogan': 'In The Neighborhood ... At Your Service !!',
#   'website': 'WWW.SIGNATUREFL.COM',
#   'feed_licenses': {},
#   'video': None,
#   'name': 'Signature Realty Associates',
#   'photo': {'href': 'http://p.rdcpix.com/v01/o33be0900-c0l.gif'},
#   'email': 'kevin@signaturerealtyassociates.com',
#   'phones': [{'type': 'Office', 'number': '(888) 270-7653', 'ext': ''},
#    {'type': 'Fax', 'number': '(813) 643-5776', 'ext': ''},
#    {'type': 'Toll Free', 'number': '(888) 270-7653', 'ext': ''}],
#   'address': {'postal_code': '',
#    'city': '',
#    'country': 'US',
#    'line2': '',
#    'state': '',
#    'line': '2234 Lithia Center Lane',
#    'state_code': 'FL'},
#   'nrds_id': '261500917',
#   'licenses': {},
#   'phone_list': {'phone_1': {'ext': '',
#     'number': '8882707653',
#     'type': 'Office'},
#    'phone_3': {'ext': '', 'number': '8882707653', 'type': 'Toll Free'},
#    'phone_2': {'ext': '', 'number': '8136435776', 'type': 'Fax'}},
#   'mls': [{'abbreviation': 'BEFL',
#     'member': {'id': '261500917'},
#     'license_number': '',
#     'primary': False,
#     'type': 'O'},
#    {'abbreviation': 'BEFL',
#     'member': {'id': 'SEFSGNT01'},
#     'license_number': '',
#     'primary': False,
#     'type': 'O'},
#    {'abbreviation': 'FLFL',
#     'member': {'id': 'SGNT01'},
#     'license_number': '',
#     'primary': False,
#     'type': 'O'},
#    {'abbreviation': 'FTFL',
#     'member': {'id': '261500917'},
#     'license_number': '',
#     'primary': False,
#     'type': 'O'},
#    {'abbreviation': 'HCFL',
#     'member': {'id': '2320'},
#     'license_number': '',
#     'primary': False,
#     'type': 'O'},
#    {'abbreviation': 'JAFL',
#     'member': {'id': 'RSIG'},
#     'license_number': '',
#     'primary': False,
#     'type': 'O'},
#    {'abbreviation': 'ORFL',
#     'member': {'id': '261500917'},
#     'license_number': '',
#     'primary': False,
#     'type': 'O'},
#    {'abbreviation': 'ORFL',
#     'member': {'id': '673900'},
#     'license_number': '',
#     'primary': True,
#     'type': 'O'},
#    {'abbreviation': 'STNY',
#     'member': {'id': '22585'},
#     'license_number': '',
#     'primary': False,
#     'type': 'O'}],
#   'fulfillment_id': 638515},
#  'zips': ['33510',
#   '33511',
#   '33534',
#   '33541',
#   '33543',
#   '33544',
#   '33545',
#   '33549',
#   '33569',
#   '33572',
#   '33594',
#   '33601',
#   '33602',
#   '33603',
#   '33604',
#   '33605',
#   '33606',
#   '33607',
#   '33608',
#   '33609',
#   '33610',
#   '33611',
#   '33612',
#   '33613',
#   '33614',
#   '33615',
#   '33616',
#   '33617',
#   '33618',
#   '33619',
#   '33620',
#   '33621',
#   '33622',
#   '33625',
#   '33626',
#   '33629',
#   '33647',
#   '34637',
#   '34639'],
#  'party_id': 4511422,
#  'first_year': 1992,
#  'name': 'CHRISTINA BARONE, President',
#  'has_photo': True,
#  'review_count': 0,
#  'for_sale_price': {'max': 850000,
#   'last_listing_date': '2024-06-18T00:29:12Z',
#   'count': 7,
#   'min': 439900},
#  'agent_team_details': {'is_team_member': False},
#  'recently_sold': {'max': 14100000,
#   'last_sold_date': '2024-05-31',
#   'count': 71,
#   'min': 149900},
#  'slogan': 'WE CLOSED OVER 1/2 BILLION IN SALES!',
#  'feed_licenses': {},
#  'languages': {},
#  'id': '56b37a830fa417010074e51f',
#  'nick_name': '',
#  'full_name': 'CHRISTINA BARONE',
#  'photo': {'is_zoomed': False,
#   'href': 'https://ap.rdcpix.com/b444f79cafd29467912b137816e1066aa-e2534519818s.jpg'},
#  'email': 'vinchris7@aol.com',
#  'first_name': 'CHRISTINA',
#  'settings': {'share_contacts': False,
#   'reviews_opt_out': {'rdc': False, 'rs': False},
#   'display_listings': True,
#   'display_ratings': True,
#   'show_stream': True,
#   'display_price_range': False,
#   'display_sold_listings': True,
#   'unsubscribe': {'autorecs': False,
#    'account_notify': False,
#    'recapprove': False},
#   'new_feature_popup_closed': {'agent_left_nav_avatar_to_profile': False},
#   'broker_data_feed_opt_out': False,
#   'loaded_from_sb': True,
#   'full_access': False,
#   'profile_wizard': {'realsatisfied_opt_out': False, 'tt_opt_out': False},
#   'cfb_wizard_step': 'account_integration',
#   'has_dotrealtor': False,
#   'terms_of_use': True,
#   'far_override': False},
#  'web_url': 'https://www.realtor.com/realestateagents/CHRISTINA-BARONE__FL_296705_740964837',
#  'description': "We have been doing Real Estate for over 29 years. We are Top 1% Nationwide in sales out of 1.3 million Realtors! \n\nWE CLOSED OVER 1/2 BILLION IN SALES\n\nTop producers in the Tampa area with 29 years experience! We have a staff helping us to selling your home for top dollar. There are a lot of moving pieces for every transaction, so you need an experienced Realtors like us that works well with various vendors, inspectors, title companies, appraises and lenders to make sure you don't have to worry about a thing. With every home we sell, our main priority is our client's bottom line and net proceeds. With our many years of experience & high grossing sales performance, I guarantee you'll be satisfied with your selling price and net proceeds. You will be treated like family not a number like most firms!\n\nOur philosophy is simple take care of our clients as we would take care of ourselves. No games, no lies, no tricks, no bait & switch just the honest truth. With these principals that is why after 29 years we are top 1% nationwide & over 1,500 homes sold!",
#  'mls': [{'primary': True,
#    'type': 'A',
#    'abbreviation': 'ORFL',
#    'member': {'id': '261530952'}}],
#  'mls_history': {},
#  'recommendations_count': 1,
#  'designations': {},
#  'last_name': 'BARONE',
#  'broker': {'accent_color': '',
#   'designations': {},
#   'video': '',
#   'name': 'Signature Realty Associates -  Broker',
#   'photo': {'href': ''},
#   'fulfillment_id': 4298600},
#  'last_updated': 'Wed, 22 May 2024 05:07:35 GMT',
#  'specializations': [{'name': 'Expert Knowledge Of The New Tampa'},
#   {'name': 'Tampa'},
#   {'name': 'Land O Lakes Market'},
#   {'name': 'Lutz'},
#   {'name': 'Wesley Chapel'},
#   {'name': '29 years experience!'}],
#  'video': 'https://www.youtube.com/embed/6ZZJqkNRUk4?modestbranding=1&rel=0',
#  'served_areas': [{'state_code': 'FL', 'name': 'Brandon'},
#   {'state_code': 'FL', 'name': 'Gibsonton'},
#   {'state_code': 'FL', 'name': 'Zephyrhills'},
#   {'state_code': 'FL', 'name': 'Wesley Chapel'},
#   {'state_code': 'FL', 'name': 'Lutz'},
#   {'state_code': 'FL', 'name': 'Riverview'},
#   {'state_code': 'FL', 'name': 'Apollo Beach'},
#   {'state_code': 'FL', 'name': 'Valrico'},
#   {'state_code': 'FL', 'name': 'Tampa'},
#   {'state_code': 'FL', 'name': "Land O' Lakes"}],
#  'person_name': 'CHRISTINA BARONE',
#  'user_languages': {},
#  'advertiser_id': 296705,
#  'title': 'President',
#  'mls_monetization': False,
#  'agent_type': ['buyer', 'seller'],
#  'nrds_id': '261530952',
#  'first_month': 7,
#  'agent_rating': 0,
#  'phones': [{'type': 'Mobile', 'number': '(813) 294-4464', 'ext': ''},
#   {'type': 'Other', 'number': '(813) 294-4904', 'ext': ''}]}

# %%
# write example
with open("sample_agents.json", "w") as outfile:
    json.dump(response.json()['agents'][0], outfile)

# %% [markdown]
# ## <font color="blue">Data Manipulation</font>

# %% [markdown]
# First Name

# %%
response.json()['agents'][0]['first_name']
# Out:
# 'CHRISTINA'

# %%
agent_list = []

# iterate through list of agents
for x in response.json()['agents']:

  if 'first_name' in list(x.keys()):
    first_name = x['first_name']
  else:
    first_name = x['name'].replace(', ', '').split(' ')[0]

  d = {
      'first_name': first_name.capitalize()
  }

  # append to agent list
  agent_list.append(d)

# %%
x['name'].replace(', ', '').split(' ')[0]
# Out:
# 'Tyler'

# %%
df = pd.DataFrame(agent_list)
print(df.shape)
df
# Out:
# (20, 1)
#     first_name
# 0    Christina
# 1        Tyler
# 2        Henry
# 3       Coleen
# 4         Tony
# 5        Linda
# 6       Jordan
# 7        James
# 8    Anastasia
# 9       Romana
# 10       Nancy
# 11  The duncan
# 12         Kim
# 13   Christine
# 14         Amy
# 15        Wade
# 16    Jennifer
# 17      Ramone
# 18      Leslie
# 19   Elizabeth

# %% [markdown]
# ## <font color="blue">Transformations</font>

# %%
agent_list = []

# iterate through list of agents
for x in response.json()['agents']:
  #|----------PERSONAL CONTACT INFO------------|
  if ('first_name' in x.keys()) and ('last_name' in x.keys()): # test key exists
    if isvalid(x['first_name']) == True: # test key is not null
      first_name = x['first_name']
      last_name = x['last_name']
  else:
    if 'full_name' in x.keys(): # test key exists
      if isvalid(x['full_name']) == True: # test key is not null
        name_split_list = x['full_name'].split(' ')
        first_name = x['full_name'].split(' ')[0]
        last_name = x['full_name'].split(' ')[-1]

  # get all mobile phones to a list
  mobile_phone_num_list = [x for x in x['phones'] if x['type'] == 'Mobile']

  # get valid address
  address = None
  if (isvalid(x['address']['line']) == True) and (isvalid(x['address']['city']) == True) and (isvalid(x['address']['state']) == True) and (isvalid(x['address']['postal_code']) == True):
    if len(x['address']['line']) > 0:
      address = (x['address']['line'] + ', ' + x['address']['city'] + ', ' + x['address']['state'] + ' ' + x['address']['postal_code']).title()

  d = {
    #|----------PERSONAL CONTACT INFO------------|
    'first_name': first_name.capitalize(),
    'last_name': last_name.capitalize(),
    'email': x['email'],
    'phone': normalize_phone_number(mobile_phone_num_list[0]['number']) if len(mobile_phone_num_list) > 0 else None,
    'address': address,
    #|------------AGENT RELATED INFO-------------|
    'nrds_id': x['nrds_id'],
    'role': x['role'],
    'office': x['office']['name'].title(),
    'photo': x['has_photo'],
    'review_count': x['review_count'],
    'agent_rating': x['agent_rating'],
    'recommendations_count': x['recommendations_count'],
    #|---------------LISTINGS INFO---------------|
    'num_active_listings': x['for_sale_price']['count'],
    'active_listings_price_min': x['for_sale_price']['min'],
    'active_listings_price_max': x['for_sale_price']['max'],
    'active_listings_latest_dt': x['for_sale_price']['last_listing_date'],
    #|---------------RELEVANT LINKS--------------|
    'realtor_url': x['web_url'],
    'personal_url': x['href'] if 'href' in list(x.keys()) else None,
  }
  agent_list.append(d)

# %%
df = pd.DataFrame(agent_list)
print(df.shape)
df
# Out:
# (20, 18)
#     first_name              last_name                                  email  \
# 0    Christina                 Barone                      vinchris7@aol.com
# 1        Tyler              Carpenter       tylercarpenterventures@gmail.com
# 2        Henry                 Linder             henry@xpertrealtygroup.com
# 3       Coleen                 Garner         coleen.garner@teamgarner21.com
# 4         Tony                 Baroni                    lead@tonybaroni.com
# 5        Linda                 Durham          linda.durham@floridamoves.com
# 6       Jordan                 Rogers                    jordan@bhhsflpg.com
# 7        James                    Roy                      Info@JamesRoy.net
# 8    Anastasia               Bizzarri            dolcevita.realtor@gmail.com
# 9       Romana                  Group      romana.simplice@engelvoelkers.com
# 10       Nancy                 Pruitt                 NancyPruitt1@gmail.com
# 11  The duncan                    Duo           realtor.com@theduncanduo.com
# 12         Kim                  Adams               kimadams.adams@gmail.com
# 13   Christine                   P.a.        christine.vinson@SuncoastRS.com
# 14         Amy             Greenfield               Greenfield.Amy@gmail.com
# 15        Wade                 Cleary                   wadecleary@yahoo.com
# 16    Jennifer  And anthony sparacino            SparacinoRealtors@gmail.com
# 17      Ramone                 Harris                ramonepharris@gmail.com
# 18      Leslie                Sibbitt            RealEstateRefined@gmail.com
# 19   Elizabeth               Martinez  elizabethmartinezrealestate@gmail.com
#
#          phone                                            address    nrds_id  \
# 0   8132944464                       2234 Lithia Center Lane, ,    261530952
# 1   8133624586           2502 Madrid Way S, St Petersburg,  33712  271514876
# 2   8636519759           4725 Us Hwy 92 E Ste A, Lakeland,  33081  255002273
# 3   8133407069  11406 N Dale Mabry Hwy, Tampa, Florida 33618-3879  261522310
# 4   8668639005         2350 E State Rd 60, Valrico, Florida 33594  261536272
# 5   8138925903                                               None  261533443
# 6   7023338915            2300 4Th St N, Saint Petersburg,  33704  260052398
# 7         None             1526 Bloomingdale Ave, Valrico,  33596  261545714
# 8   7273449315                                               None  260037174
# 9   8133977137      102 2Nd Ave Ne, #101B, St. Petersburg,  33701  261546862
# 10  3525527574         16903 Lakeside Dr # 6, Montverde, Fl 34756  261203477
# 11  8135149750               6320 S Dale Mabry Hwy, Tampa,  33611  261535729
# 12  7273006560             34650 Us Hwy 19 N, Palm Harbor,  34684  260041019
# 13        None             7772 Bishopwood Rd, Lake Worth,  33467   89246418
# 14  8137776104               1208 E. Kennedy Blvd., Tampa,  33602  261096949
# 15  8137655085                       5016 Gunn Hwy, Tampa,  33624  261555838
# 16        None          130 E Bloomingdale Ave, Brandon, Fl 33511  278027527
# 17  8137857497       1400 International Pkwy S, Lake Mary,  32746  265579478
# 18  8138154738          3615 Bromley Grand Avenue , Tampa,  33607  260015713
# 19        None  260 1St Avenue South, Suite 200, Saint Petersb...  261567990
#
#      role                                             office  photo  \
# 0   agent                        Signature Realty Associates   True
# 1   agent                         Carpenter Realty Group Inc   True
# 2   agent                                 Xpert Realty Group   True
# 3   agent                    Century 21 Elite Locations, Inc   True
# 4   agent                             Keller Williams Realty   True
# 5   agent                                                      True
# 6   agent  Berkshire Hathaway Home Services Florida Prope...   True
# 7   agent                                    Re/Max All Pros   True
# 8   agent                     Real Estate With An Accent Llc   True
# 9   agent                           Engel & Volkers St. Pete   True
# 10  agent   Olympus Executive Realty, Home Of Top Producers®   True
# 11  agent                                     Lpt Realty Llc   True
# 12  agent                                Re Max Elite Realty   True
# 13  agent                            Christine Vinson Realty   True
# 14  agent               Keller Williams Realty Tampa Central   True
# 15  agent                          Century 21 Executive Team   True
# 16  agent                           Florida Executive Realty   True
# 17  agent                                     Lpt Realty Llc   True
# 18  agent                                            Compass   True
# 19  agent                                    Dalton Wade Inc   True
#
#     review_count  agent_rating  recommendations_count  num_active_listings  \
# 0              0           0.0                      1                    7
# 1              0           0.0                     11                    6
# 2              2           5.0                      1                    2
# 3            129           4.9                      0                    7
# 4            170           5.0                    297                   57
# 5              9           5.0                      1                    5
# 6              0           0.0                      7                    3
# 7              0           0.0                      1                    7
# 8             45           5.0                      0                    7
# 9              5           5.0                      0                    7
# 10            25           4.9                      2                  711
# 11           217           4.9                    367                   64
# 12             3           5.0                      0                   11
# 13             0           0.0                      0                    1
# 14            76           4.9                    143                    5
# 15           133           5.0                      0                    5
# 16            10           5.0                     14                   10
# 17             5           5.0                      2                    6
# 18             4           5.0                      1                    3
# 19             3           5.0                      0                    1
#
#     active_listings_price_min  active_listings_price_max  \
# 0                      439900                     850000
# 1                      295000                     650000
# 2                      245000                     380000
# 3                      115000                     425000
# 4                        9000                     750000
# 5                      440000                     699000
# 6                      245000                     485000
# 7                      319000                    1045000
# 8                      195000                     950000
# 9                       95000                    6250000
# 10                      19990                    1351648
# 11                      80000                    2699000
# 12                     175000                    1269900
# 13                     895900                     895900
# 14                     219900                     830000
# 15                     325000                     485000
# 16                     214000                     810000
# 17                      15000                     449900
# 18                     595000                     775000
# 19                    1100000                    1100000
#
#    active_listings_latest_dt  \
# 0       2024-06-18T00:29:12Z
# 1       2024-06-17T21:50:17Z
# 2       2024-06-17T21:18:19Z
# 3       2024-06-17T20:53:40Z
# 4       2024-06-17T20:42:17Z
# 5       2024-06-17T20:10:54Z
# 6       2024-06-17T18:54:41Z
# 7       2024-06-17T18:29:37Z
# 8       2024-06-17T18:13:07Z
# 9       2024-06-17T16:30:04Z
# 10      2024-06-17T15:41:18Z
# 11      2024-06-17T15:12:13Z
# 12      2024-06-17T14:53:45Z
# 13      2024-06-17T12:22:52Z
# 14      2024-06-17T01:40:49Z
# 15      2024-05-24T01:11:16Z
# 16      2024-06-14T17:11:18Z
# 17      2024-05-15T14:11:14Z
# 18      2024-05-18T23:16:56Z
# 19      2024-01-07T00:34:52Z
#
#                                           realtor_url  \
# 0   https://www.realtor.com/realestateagents/CHRIS...
# 1   https://www.realtor.com/realestateagents/Tyler...
# 2   https://www.realtor.com/realestateagents/HENRY...
# 3   https://www.realtor.com/realestateagents/Colee...
# 4   https://www.realtor.com/realestateagents/Tony-...
# 5   https://www.realtor.com/realestateagents/Linda...
# 6   https://www.realtor.com/realestateagents/Jorda...
# 7   https://www.realtor.com/realestateagents/James...
# 8   https://www.realtor.com/realestateagents/ANAST...
# 9   https://www.realtor.com/realestateagents/Roman...
# 10  https://www.realtor.com/realestateagents/Nancy...
# 11  https://www.realtor.com/realestateagents/The-D...
# 12  https://www.realtor.com/realestateagents/Kim-A...
# 13  https://www.realtor.com/realestateagents/Chris...
# 14  https://www.realtor.com/realestateagents/AMY-G...
# 15  https://www.realtor.com/realestateagents/Wade-...
# 16  https://www.realtor.com/realestateagents/Team-...
# 17  https://www.realtor.com/realestateagents/Ramon...
# 18  https://www.realtor.com/realestateagents/Lesli...
# 19  https://www.realtor.com/realestateagents/Eliza...
#
#                                          personal_url
# 0                           http://www.teambarone.com
# 1
# 2           https://henrylinder.xpertrealtygroup.com/
# 3                             http://coleengarner.com
# 4                           http://www.tonybaroni.com
# 5               https://www.lindadurhamrealestate.com
# 6                                                None
# 7                       https://www.JamesRoyREMAX.com
# 8                   http://www.anastasiabizzarri.com/
# 9       https://romanasimplicegroup.evrealestate.com/
# 10                         http://www.NancyPruitt.com
# 11                        http://www.TheDuncanDuo.com
# 12                www.facebook.com/kimadamsrealestate
# 13  http://christinevinson.suncoastrealtysolutions...
# 14                 http://www.AmyMakesHomesHappen.com
# 15                     http://www.wadesworldtampa.com
# 16                  https://www.sparacinorealtors.com
# 17                               WWW.RENTING2HOME.COM
# 18                         http://www.sibbittteam.com
# 19           https://elizabethmartinez.daltonwade.com

# %% [markdown]
# ## <font color="blue">CTA: How to Get Your Agent Leads List 👇</font>
# Contact me at arielherrera@analyticsariel.com with the subject line "WANT TO BUY AGENT LEADS FOR <font color="red">XYZ</font> COUNTY"
#
# | Record Count            | Cost      |
# |-----------------------|------------------------------|
# | 250 or less | \$35 |
# | 250-500 | \$35-\$60 |
# | 500-750 | \$60-\$85 |
# | 750-1,000 | \$85-\$110 |
# | 1,000+     | Contact me |
#
# [Sample Output](https://docs.google.com/spreadsheets/d/1v2FW9Kk7Wg46Oc6AG2Iqj16BcVlDvCZ24yIbukMyN9I/edit?usp=sharing)

# %% [markdown]
# # End Notebook
