# %% [markdown]
# <a href="https://colab.research.google.com/github/analyticsariel/projects/blob/master/Get_Zip_Code_Rental_Data_by_County.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Get Zip Code Rental Data by County
#
# ## Overview
# | Detail Tag            | Information                                                                                        |
# |-----------------------|----------------------------------------------------------------------------------------------------|
# | Originally Created By | Ariel Herrera arielherrera@analyticsariel.com |
# | External References   | API |
# | Input Datasets        | Source name |
# | Output Datasets       | Source name |
# | Input Data Source     | Pandas DataFrame |
# | Output Data Source    | Pandas DataFrame |
#
# ## History
# | Date         | Developed By  | Reason                                                |
# |--------------|---------------|-------------------------------------------------------|
# | 22nd Jun 2022 | Ariel Herrera | Create notebook. |
#
# ## Getting Started
# 1. Copy this notebook -> File -> Save a Copy in Drive
# 2. Directions
#
# ## Useful Resources
# - [Google Colab Cheat Sheet](https://towardsdatascience.com/cheat-sheet-for-google-colab-63853778c093)

# %% [markdown]
# ## <font color="blue">Install Packages</font>

# %% [markdown]
# ## <font color="blue">Imports</font>

# %%
from google.colab import drive, files # specific to Google Colab
import pandas as pd
from scipy.stats import zscore
import requests
import warnings
from datetime import datetime
from dateutil.relativedelta import relativedelta
import time

warnings.filterwarnings('ignore')

# %% [markdown]
# ## <font color="blue">Functions</font>

# %%
def get_rental_market_data(rapid_api_key, zip_code):

  if len(str(zip_code)) != 5:
    return "Invalid Zip Code"

  url = "https://realty-mole-property-api.p.rapidapi.com/zipCodes/{}".format(str(zip_code))

  headers = {
    "X-RapidAPI-Key": rapid_api_key,
    "X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
  }

  return requests.request("GET", url, headers=headers)

# %%
def move_col_to_front(df, col_name):
  front_col = df[col_name]
  df.drop(labels=[col_name], axis=1,inplace = True)
  df.insert(0, col_name, front_col)
  return df

# %%
def get_latest_rental_data(response):
  # transform data to pandas dataframe
  df = pd.json_normalize(data=response.json())
  # relevant cols
  rent_cols = ['id', 'rentalData.averageRent', 'rentalData.minRent', 'rentalData.maxRent', 'rentalData.totalRentals', 'rentalData.detailed']
  df = df[rent_cols]
  return df.rename(columns={'id': 'zip_code'})

def get_historical_rental_data(response):
  # transform data to pandas dataframe
  df_rent = pd.json_normalize(data=response.json())

  """ get historical data to single dataframe """
  df_list = [] # create empty list
  # get all "detailed" columns
  rent_detail_hist_cols = [x for x in df_rent.columns if 'detailed' and 'history' in x]
  # iterate through "detailed" columns
  for x in rent_detail_hist_cols:
    # get column date
    date_str = x.split('.')[2]
    # get column name
    detail_col = 'rentalData.history.' + date_str + '.detailed'
    # convert historical data to a dataframe
    _df = pd.DataFrame(df_rent[detail_col].iloc[0])
    # create columns
    _df['date_str'] = date_str
    _df['zip_code'] = zip_code
    # append to list
    df_list.append(_df)

  """ combine """
  # comine sub date dataframes
  df_detail = pd.concat(df_list)
  # move date column to front
  df_detail = move_col_to_front(df=df_detail, col_name='date_str')
  df_detail = move_col_to_front(df=df_detail, col_name='zip_code')
  # add feature for previous year
  df_detail['prev_yr_dt'] = df_detail.apply(lambda x: (datetime.strptime(x['date_str'], '%Y-%m') - relativedelta(years=1)).strftime('%Y-%m'), axis=1)

  """ merge """
  df_detail_prev = df_detail.copy()
  df_detail_prev.columns = [x + '_prev_yr' for x in df_detail_prev.columns]
  # merge
  df_merge = pd.merge(df_detail, df_detail_prev, how='left', left_on=['prev_yr_dt', 'bedrooms'], right_on=['date_str_prev_yr', 'bedrooms_prev_yr']).drop_duplicates()
  # identify outliers
  df_merge['averageRent_zscore'] = df_merge[['averageRent']].apply(zscore)

  """ filter """
  # filter
  df_filter = df_merge.copy()
  df_filter = df_filter.loc[(df_filter['bedrooms'] <= 4) & (df_filter['averageRent_zscore'] <= 2)]
  df_filter = df_filter.drop(columns=['prev_yr_dt', 'date_str_prev_yr', 'prev_yr_dt_prev_yr', 'zip_code_prev_yr'])
  # add features
  df_filter['YoY_avg_rent'] = \
    (df_filter['averageRent'] - df_filter['averageRent_prev_yr']) / df_filter['averageRent_prev_yr']
  df_filter['YoY_total_rentals'] = \
    (df_filter['totalRentals'] - df_filter['totalRentals_prev_yr']) / df_filter['totalRentals_prev_yr']
  return df_filter

# %% [markdown]
# ## <font color="blue">Locals & Constants</font>

# %%
############
# OPTIONAL #
############

# mount drive
drive.mount('/content/drive', force_remount=False)

# data location
file_dir = '/content/drive/My Drive/Colab Data/input/' # optional
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# read in api key file
df_api_keys = pd.read_csv(file_dir + 'api_keys.csv')

# get keys
rapid_api_key = df_api_keys.loc[df_api_keys['API'] =='rapid']['KEY'].iloc[0] # replace this with your own key

# %% [markdown]
# ## <font color="blue">Data</font>

# %% [markdown]
# ## <font color="blue">Transformations</font>

# %% [markdown]
# ### <font color="green">1. Single Zip Code</font>

# %%
zip_code = '33610' # Ybor, Tampa, FL
url = "https://realty-mole-property-api.p.rapidapi.com/zipCodes/{}".format(str(zip_code))

headers = {
  "X-RapidAPI-Key": rapid_api_key,
  "X-RapidAPI-Host": "realty-mole-property-api.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

# %%
response.json()
# Out:
# {'id': '33610',
#  'rentalData': {'averageRent': 21264.16,
#   'detailed': [{'averageRent': 118059.5,
#     'bedrooms': 0,
#     'maxRent': 469000,
#     'minRent': 769,
#     'totalRentals': 4},
#    {'averageRent': 1590.2,
#     'bedrooms': 1,
#     'maxRent': 1897,
#     'minRent': 850,
#     'totalRentals': 64},
#    {'averageRent': 1825.64,
#     'bedrooms': 2,
#     'maxRent': 3000,
#     'minRent': 985,
#     'totalRentals': 70},
#    {'averageRent': 2002.55,
#     'bedrooms': 3,
#     'maxRent': 3500,
#     'minRent': 1350,
#     'totalRentals': 96},
#    {'averageRent': 2060.08,
#     'bedrooms': 4,
#     'maxRent': 2975,
#     'minRent': 1200,
#     'totalRentals': 26},
#    {'averageRent': 2047,
#     'bedrooms': 5,
#     'maxRent': 2099,
#     'minRent': 1995,
#     'totalRentals': 2}],
#   'history': {'2020-04': {'averageRent': 1367.13,
#     'detailed': [{'averageRent': 826,
#       'bedrooms': 0,
#       'maxRent': 959,
#       'minRent': 744,
#       'totalRentals': 3},
#      {'averageRent': 920,
#       'bedrooms': 1,
#       'maxRent': 1040,
#       'minRent': 800,
#       'totalRentals': 2},
#      {'averageRent': 1121.51,
#       'bedrooms': 2,
#       'maxRent': 1450,
#       'minRent': 842,
#       'totalRentals': 35},
#      {'averageRent': 2103.31,
#       'bedrooms': 3,
#       'maxRent': 49900,
#       'minRent': 950,
#       'totalRentals': 124},
#      {'averageRent': 1445.26,
#       'bedrooms': 4,
#       'maxRent': 2150,
#       'minRent': 1100,
#       'totalRentals': 19},
#      {'averageRent': 1786.67,
#       'bedrooms': 5,
#       'maxRent': 2500,
#       'minRent': 1365,
#       'totalRentals': 3}],
#     'maxRent': 49900,
#     'minRent': 744,
#     'totalRentals': 186},
#    '2020-05': {'averageRent': 1247.24,
#     'detailed': [{'averageRent': 820.33,
#       'bedrooms': 0,
#       'maxRent': 908,
#       'minRent': 775,
#       'totalRentals': 3},
#      {'averageRent': 905,
#       'bedrooms': 1,
#       'maxRent': 1040,
#       'minRent': 800,
#       'totalRentals': 3},
#      {'averageRent': 1199.73,
#       'bedrooms': 2,
#       'maxRent': 2200,
#       'minRent': 842,
#       'totalRentals': 33},
#      {'averageRent': 1356.61,
#       'bedrooms': 3,
#       'maxRent': 3400,
#       'minRent': 950,
#       'totalRentals': 180},
#      {'averageRent': 1436.75,
#       'bedrooms': 4,
#       'maxRent': 2100,
#       'minRent': 1030,
#       'totalRentals': 20},
#      {'averageRent': 1765,
#       'bedrooms': 5,
#       'maxRent': 2500,
#       'minRent': 1365,
#       'totalRentals': 4}],
#     'maxRent': 3400,
#     'minRent': 775,
#     'totalRentals': 243},
#    '2020-06': {'averageRent': 1251.74,
#     'detailed': [{'averageRent': 810.67,
#       'bedrooms': 0,
#       'maxRent': 879,
#       'minRent': 775,
#       'totalRentals': 3},
#      {'averageRent': 941.25,
#       'bedrooms': 1,
#       'maxRent': 1050,
#       'minRent': 800,
#       'totalRentals': 4},
#      {'averageRent': 1226.43,
#       'bedrooms': 2,
#       'maxRent': 2200,
#       'minRent': 842,
#       'totalRentals': 42},
#      {'averageRent': 1366.33,
#       'bedrooms': 3,
#       'maxRent': 3400,
#       'minRent': 950,
#       'totalRentals': 186},
#      {'averageRent': 1454.76,
#       'bedrooms': 4,
#       'maxRent': 2100,
#       'minRent': 1030,
#       'totalRentals': 21},
#      {'averageRent': 1711,
#       'bedrooms': 5,
#       'maxRent': 2500,
#       'minRent': 1365,
#       'totalRentals': 5}],
#     'maxRent': 3400,
#     'minRent': 775,
#     'totalRentals': 261},
#    '2020-07': {'averageRent': 1259.99,
#     'detailed': [{'averageRent': 832,
#       'bedrooms': 0,
#       'maxRent': 943,
#       'minRent': 775,
#       'totalRentals': 3},
#      {'averageRent': 941.25,
#       'bedrooms': 1,
#       'maxRent': 1050,
#       'minRent': 800,
#       'totalRentals': 4},
#      {'averageRent': 1241.95,
#       'bedrooms': 2,
#       'maxRent': 2200,
#       'minRent': 842,
#       'totalRentals': 41},
#      {'averageRent': 1366.01,
#       'bedrooms': 3,
#       'maxRent': 3400,
#       'minRent': 950,
#       'totalRentals': 191},
#      {'averageRent': 1467.75,
#       'bedrooms': 4,
#       'maxRent': 2100,
#       'minRent': 1030,
#       'totalRentals': 20},
#      {'averageRent': 1711,
#       'bedrooms': 5,
#       'maxRent': 2500,
#       'minRent': 1365,
#       'totalRentals': 5}],
#     'maxRent': 3400,
#     'minRent': 775,
#     'totalRentals': 264},
#    '2020-08': {'averageRent': 1214.77,
#     'detailed': [{'averageRent': 838.33,
#       'bedrooms': 0,
#       'maxRent': 962,
#       'minRent': 775,
#       'totalRentals': 3},
#      {'averageRent': 808.71,
#       'bedrooms': 1,
#       'maxRent': 1050,
#       'minRent': 250,
#       'totalRentals': 7},
#      {'averageRent': 1281.26,
#       'bedrooms': 2,
#       'maxRent': 2000,
#       'minRent': 900,
#       'totalRentals': 43},
#      {'averageRent': 1368.11,
#       'bedrooms': 3,
#       'maxRent': 2150,
#       'minRent': 1000,
#       'totalRentals': 187},
#      {'averageRent': 1510.53,
#       'bedrooms': 4,
#       'maxRent': 2100,
#       'minRent': 1030,
#       'totalRentals': 17},
#      {'averageRent': 1481.67,
#       'bedrooms': 5,
#       'maxRent': 1700,
#       'minRent': 1250,
#       'totalRentals': 3}],
#     'maxRent': 2150,
#     'minRent': 250,
#     'totalRentals': 260},
#    '2020-09': {'averageRent': 1236.16,
#     'detailed': [{'averageRent': 860.33,
#       'bedrooms': 0,
#       'maxRent': 1003,
#       'minRent': 778,
#       'totalRentals': 3},
#      {'averageRent': 797.67,
#       'bedrooms': 1,
#       'maxRent': 1050,
#       'minRent': 250,
#       'totalRentals': 6},
#      {'averageRent': 1299.26,
#       'bedrooms': 2,
#       'maxRent': 2000,
#       'minRent': 900,
#       'totalRentals': 35},
#      {'averageRent': 1406.21,
#       'bedrooms': 3,
#       'maxRent': 2150,
#       'minRent': 1000,
#       'totalRentals': 101},
#      {'averageRent': 1571.81,
#       'bedrooms': 4,
#       'maxRent': 2000,
#       'minRent': 1150,
#       'totalRentals': 16},
#      {'averageRent': 1481.67,
#       'bedrooms': 5,
#       'maxRent': 1700,
#       'minRent': 1250,
#       'totalRentals': 3}],
#     'maxRent': 2150,
#     'minRent': 250,
#     'totalRentals': 164},
#    '2020-10': {'averageRent': 1199.54,
#     'detailed': [{'averageRent': 859.67,
#       'bedrooms': 0,
#       'maxRent': 1001,
#       'minRent': 778,
#       'totalRentals': 3},
#      {'averageRent': 871.5,
#       'bedrooms': 1,
#       'maxRent': 1040,
#       'minRent': 800,
#       'totalRentals': 4},
#      {'averageRent': 1265.76,
#       'bedrooms': 2,
#       'maxRent': 2000,
#       'minRent': 850,
#       'totalRentals': 33},
#      {'averageRent': 1403.61,
#       'bedrooms': 3,
#       'maxRent': 2150,
#       'minRent': 1000,
#       'totalRentals': 85},
#      {'averageRent': 1546.71,
#       'bedrooms': 4,
#       'maxRent': 2000,
#       'minRent': 1195,
#       'totalRentals': 14},
#      {'averageRent': 1250,
#       'bedrooms': 5,
#       'maxRent': 1250,
#       'minRent': 1250,
#       'totalRentals': 1}],
#     'maxRent': 2150,
#     'minRent': 778,
#     'totalRentals': 140},
#    '2020-11': {'averageRent': 1216.43,
#     'detailed': [{'averageRent': 868,
#       'bedrooms': 0,
#       'maxRent': 1026,
#       'minRent': 778,
#       'totalRentals': 3},
#      {'averageRent': 907.2,
#       'bedrooms': 1,
#       'maxRent': 1050,
#       'minRent': 800,
#       'totalRentals': 5},
#      {'averageRent': 1247.78,
#       'bedrooms': 2,
#       'maxRent': 2000,
#       'minRent': 850,
#       'totalRentals': 32},
#      {'averageRent': 1458.18,
#       'bedrooms': 3,
#       'maxRent': 2500,
#       'minRent': 1025,
#       'totalRentals': 91},
#      {'averageRent': 1567.42,
#       'bedrooms': 4,
#       'maxRent': 2100,
#       'minRent': 1300,
#       'totalRentals': 12},
#      {'averageRent': 1250,
#       'bedrooms': 5,
#       'maxRent': 1250,
#       'minRent': 1250,
#       'totalRentals': 1}],
#     'maxRent': 2500,
#     'minRent': 778,
#     'totalRentals': 144},
#    '2020-12': {'averageRent': 1178.75,
#     'detailed': [{'averageRent': 866.33,
#       'bedrooms': 0,
#       'maxRent': 1021,
#       'minRent': 778,
#       'totalRentals': 3},
#      {'averageRent': 825,
#       'bedrooms': 1,
#       'maxRent': 1050,
#       'minRent': 600,
#       'totalRentals': 2},
#      {'averageRent': 1245.14,
#       'bedrooms': 2,
#       'maxRent': 2000,
#       'minRent': 850,
#       'totalRentals': 29},
#      {'averageRent': 1449.51,
#       'bedrooms': 3,
#       'maxRent': 2500,
#       'minRent': 1025,
#       'totalRentals': 73},
#      {'averageRent': 1507.75,
#       'bedrooms': 4,
#       'maxRent': 2100,
#       'minRent': 1295,
#       'totalRentals': 16}],
#     'maxRent': 2500,
#     'minRent': 600,
#     'totalRentals': 123},
#    '2021-01': {'averageRent': 1166.08,
#     'detailed': [{'averageRent': 866.33,
#       'bedrooms': 0,
#       'maxRent': 1021,
#       'minRent': 778,
#       'totalRentals': 3},
#      {'averageRent': 825,
#       'bedrooms': 1,
#       'maxRent': 1050,
#       'minRent': 600,
#       'totalRentals': 2},
#      {'averageRent': 1175.95,
#       'bedrooms': 2,
#       'maxRent': 1600,
#       'minRent': 850,
#       'totalRentals': 20},
#      {'averageRent': 1449.54,
#       'bedrooms': 3,
#       'maxRent': 2500,
#       'minRent': 1025,
#       'totalRentals': 68},
#      {'averageRent': 1513.57,
#       'bedrooms': 4,
#       'maxRent': 2100,
#       'minRent': 1295,
#       'totalRentals': 14}],
#     'maxRent': 2500,
#     'minRent': 600,
#     'totalRentals': 107},
#    '2021-02': {'averageRent': 1248.09,
#     'detailed': [{'averageRent': 860.33,
#       'bedrooms': 0,
#       'maxRent': 959,
#       'minRent': 800,
#       'totalRentals': 3},
#      {'averageRent': 750,
#       'bedrooms': 1,
#       'maxRent': 1050,
#       'minRent': 600,
#       'totalRentals': 3},
#      {'averageRent': 1205.29,
#       'bedrooms': 2,
#       'maxRent': 1600,
#       'minRent': 800,
#       'totalRentals': 28},
#      {'averageRent': 1464.12,
#       'bedrooms': 3,
#       'maxRent': 2500,
#       'minRent': 1025,
#       'totalRentals': 76},
#      {'averageRent': 1513.82,
#       'bedrooms': 4,
#       'maxRent': 2100,
#       'minRent': 1295,
#       'totalRentals': 17},
#      {'averageRent': 1695,
#       'bedrooms': 5,
#       'maxRent': 1695,
#       'minRent': 1695,
#       'totalRentals': 1}],
#     'maxRent': 2500,
#     'minRent': 600,
#     'totalRentals': 128},
#    '2021-03': {'averageRent': 1218.55,
#     'detailed': [{'averageRent': 888,
#       'bedrooms': 0,
#       'maxRent': 954,
#       'minRent': 822,
#       'totalRentals': 2},
#      {'averageRent': 600,
#       'bedrooms': 1,
#       'maxRent': 600,
#       'minRent': 600,
#       'totalRentals': 2},
#      {'averageRent': 1195.72,
#       'bedrooms': 2,
#       'maxRent': 1600,
#       'minRent': 800,
#       'totalRentals': 25},
#      {'averageRent': 1486.07,
#       'bedrooms': 3,
#       'maxRent': 2700,
#       'minRent': 1025,
#       'totalRentals': 58},
#      {'averageRent': 1446.54,
#       'bedrooms': 4,
#       'maxRent': 1695,
#       'minRent': 1295,
#       'totalRentals': 13},
#      {'averageRent': 1695,
#       'bedrooms': 5,
#       'maxRent': 1695,
#       'minRent': 1695,
#       'totalRentals': 1}],
#     'maxRent': 2700,
#     'minRent': 600,
#     'totalRentals': 101},
#    '2021-04': {'averageRent': 1357.01,
#     'detailed': [{'averageRent': 1024.5,
#       'bedrooms': 0,
#       'maxRent': 1227,
#       'minRent': 822,
#       'totalRentals': 2},
#      {'averageRent': 600,
#       'bedrooms': 1,
#       'maxRent': 600,
#       'minRent': 600,
#       'totalRentals': 1},
#      {'averageRent': 1185.78,
#       'bedrooms': 2,
#       'maxRent': 1600,
#       'minRent': 800,
#       'totalRentals': 18},
#      {'averageRent': 1474.38,
#       'bedrooms': 3,
#       'maxRent': 2700,
#       'minRent': 1025,
#       'totalRentals': 45},
#      {'averageRent': 1534.89,
#       'bedrooms': 4,
#       'maxRent': 1699,
#       'minRent': 1395,
#       'totalRentals': 9},
#      {'averageRent': 2322.5,
#       'bedrooms': 5,
#       'maxRent': 2950,
#       'minRent': 1695,
#       'totalRentals': 2}],
#     'maxRent': 2950,
#     'minRent': 600,
#     'totalRentals': 77},
#    '2021-05': {'averageRent': 1364.92,
#     'detailed': [{'averageRent': 1027.5,
#       'bedrooms': 0,
#       'maxRent': 1233,
#       'minRent': 822,
#       'totalRentals': 2},
#      {'averageRent': 600,
#       'bedrooms': 1,
#       'maxRent': 600,
#       'minRent': 600,
#       'totalRentals': 1},
#      {'averageRent': 1219.7,
#       'bedrooms': 2,
#       'maxRent': 1700,
#       'minRent': 800,
#       'totalRentals': 20},
#      {'averageRent': 1479.4,
#       'bedrooms': 3,
#       'maxRent': 2700,
#       'minRent': 1025,
#       'totalRentals': 45},
#      {'averageRent': 1540.44,
#       'bedrooms': 4,
#       'maxRent': 1699,
#       'minRent': 1395,
#       'totalRentals': 9},
#      {'averageRent': 2322.5,
#       'bedrooms': 5,
#       'maxRent': 2950,
#       'minRent': 1695,
#       'totalRentals': 2}],
#     'maxRent': 2950,
#     'minRent': 600,
#     'totalRentals': 79},
#    '2021-06': {'averageRent': 1520.16,
#     'detailed': [{'averageRent': 1018,
#       'bedrooms': 0,
#       'maxRent': 1214,
#       'minRent': 822,
#       'totalRentals': 2},
#      {'averageRent': 1202.78,
#       'bedrooms': 2,
#       'maxRent': 1700,
#       'minRent': 800,
#       'totalRentals': 18},
#      {'averageRent': 1494.5,
#       'bedrooms': 3,
#       'maxRent': 2700,
#       'minRent': 1025,
#       'totalRentals': 44},
#      {'averageRent': 1563,
#       'bedrooms': 4,
#       'maxRent': 1699,
#       'minRent': 1395,
#       'totalRentals': 8},
#      {'averageRent': 2322.5,
#       'bedrooms': 5,
#       'maxRent': 2950,
#       'minRent': 1695,
#       'totalRentals': 2}],
#     'maxRent': 2950,
#     'minRent': 800,
#     'totalRentals': 74},
#    '2021-07': {'averageRent': 21822.66,
#     'detailed': [{'averageRent': 121367.29,
#       'bedrooms': 0,
#       'maxRent': 469000,
#       'minRent': 769,
#       'totalRentals': 7},
#      {'averageRent': 1446.77,
#       'bedrooms': 1,
#       'maxRent': 1791,
#       'minRent': 500,
#       'totalRentals': 39},
#      {'averageRent': 1597.62,
#       'bedrooms': 2,
#       'maxRent': 2198,
#       'minRent': 850,
#       'totalRentals': 52},
#      {'averageRent': 1772.61,
#       'bedrooms': 3,
#       'maxRent': 2800,
#       'minRent': 1025,
#       'totalRentals': 84},
#      {'averageRent': 1801.67,
#       'bedrooms': 4,
#       'maxRent': 2295,
#       'minRent': 1200,
#       'totalRentals': 27},
#      {'averageRent': 2950,
#       'bedrooms': 5,
#       'maxRent': 2950,
#       'minRent': 2950,
#       'totalRentals': 1}],
#     'maxRent': 469000,
#     'minRent': 500,
#     'totalRentals': 210},
#    '2021-08': {'averageRent': 25603.46,
#     'detailed': [{'averageRent': 121367.29,
#       'bedrooms': 0,
#       'maxRent': 469000,
#       'minRent': 769,
#       'totalRentals': 7},
#      {'averageRent': 1446.77,
#       'bedrooms': 1,
#       'maxRent': 1791,
#       'minRent': 500,
#       'totalRentals': 39},
#      {'averageRent': 1611.29,
#       'bedrooms': 2,
#       'maxRent': 2198,
#       'minRent': 850,
#       'totalRentals': 51},
#      {'averageRent': 1786.35,
#       'bedrooms': 3,
#       'maxRent': 2800,
#       'minRent': 1100,
#       'totalRentals': 81},
#      {'averageRent': 1805.62,
#       'bedrooms': 4,
#       'maxRent': 2295,
#       'minRent': 1200,
#       'totalRentals': 26}],
#     'maxRent': 469000,
#     'minRent': 500,
#     'totalRentals': 204},
#    '2021-09': {'averageRent': 25608.82,
#     'detailed': [{'averageRent': 121367.29,
#       'bedrooms': 0,
#       'maxRent': 469000,
#       'minRent': 769,
#       'totalRentals': 7},
#      {'averageRent': 1446.77,
#       'bedrooms': 1,
#       'maxRent': 1791,
#       'minRent': 500,
#       'totalRentals': 39},
#      {'averageRent': 1629.28,
#       'bedrooms': 2,
#       'maxRent': 2198,
#       'minRent': 850,
#       'totalRentals': 47},
#      {'averageRent': 1795.18,
#       'bedrooms': 3,
#       'maxRent': 2800,
#       'minRent': 1100,
#       'totalRentals': 79},
#      {'averageRent': 1805.62,
#       'bedrooms': 4,
#       'maxRent': 2295,
#       'minRent': 1200,
#       'totalRentals': 26}],
#     'maxRent': 469000,
#     'minRent': 500,
#     'totalRentals': 198},
#    '2021-10': {'averageRent': 25614.98,
#     'detailed': [{'averageRent': 121367.29,
#       'bedrooms': 0,
#       'maxRent': 469000,
#       'minRent': 769,
#       'totalRentals': 7},
#      {'averageRent': 1446.77,
#       'bedrooms': 1,
#       'maxRent': 1791,
#       'minRent': 500,
#       'totalRentals': 39},
#      {'averageRent': 1629.28,
#       'bedrooms': 2,
#       'maxRent': 2198,
#       'minRent': 850,
#       'totalRentals': 47},
#      {'averageRent': 1809.53,
#       'bedrooms': 3,
#       'maxRent': 2800,
#       'minRent': 1100,
#       'totalRentals': 76},
#      {'averageRent': 1822.04,
#       'bedrooms': 4,
#       'maxRent': 2295,
#       'minRent': 1200,
#       'totalRentals': 25}],
#     'maxRent': 469000,
#     'minRent': 500,
#     'totalRentals': 194},
#    '2021-11': {'averageRent': 43665.04,
#     'detailed': [{'averageRent': 211509,
#       'bedrooms': 0,
#       'maxRent': 469000,
#       'minRent': 769,
#       'totalRentals': 4},
#      {'averageRent': 1424.9,
#       'bedrooms': 1,
#       'maxRent': 1791,
#       'minRent': 500,
#       'totalRentals': 31},
#      {'averageRent': 1635.94,
#       'bedrooms': 2,
#       'maxRent': 2140,
#       'minRent': 850,
#       'totalRentals': 33},
#      {'averageRent': 1856.87,
#       'bedrooms': 3,
#       'maxRent': 2800,
#       'minRent': 1200,
#       'totalRentals': 54},
#      {'averageRent': 1898.5,
#       'bedrooms': 4,
#       'maxRent': 2383,
#       'minRent': 1200,
#       'totalRentals': 16}],
#     'maxRent': 469000,
#     'minRent': 500,
#     'totalRentals': 138},
#    '2021-12': {'averageRent': 25629.94,
#     'detailed': [{'averageRent': 121289.14,
#       'bedrooms': 0,
#       'maxRent': 469000,
#       'minRent': 769,
#       'totalRentals': 7},
#      {'averageRent': 1459.78,
#       'bedrooms': 1,
#       'maxRent': 1791,
#       'minRent': 500,
#       'totalRentals': 36},
#      {'averageRent': 1625.02,
#       'bedrooms': 2,
#       'maxRent': 2198,
#       'minRent': 850,
#       'totalRentals': 43},
#      {'averageRent': 1883.46,
#       'bedrooms': 3,
#       'maxRent': 2800,
#       'minRent': 1200,
#       'totalRentals': 59},
#      {'averageRent': 1892.28,
#       'bedrooms': 4,
#       'maxRent': 2295,
#       'minRent': 1200,
#       'totalRentals': 18}],
#     'maxRent': 469000,
#     'minRent': 500,
#     'totalRentals': 163},
#    '2022-01': {'averageRent': 25672.71,
#     'detailed': [{'averageRent': 121306.71,
#       'bedrooms': 0,
#       'maxRent': 469000,
#       'minRent': 769,
#       'totalRentals': 7},
#      {'averageRent': 1498.75,
#       'bedrooms': 1,
#       'maxRent': 2104,
#       'minRent': 500,
#       'totalRentals': 44},
#      {'averageRent': 1648.42,
#       'bedrooms': 2,
#       'maxRent': 2166,
#       'minRent': 850,
#       'totalRentals': 55},
#      {'averageRent': 1889.61,
#       'bedrooms': 3,
#       'maxRent': 2800,
#       'minRent': 1100,
#       'totalRentals': 69},
#      {'averageRent': 2020.05,
#       'bedrooms': 4,
#       'maxRent': 3495,
#       'minRent': 1200,
#       'totalRentals': 19}],
#     'maxRent': 469000,
#     'minRent': 500,
#     'totalRentals': 194},
#    '2022-02': {'averageRent': 21732.99,
#     'detailed': [{'averageRent': 121292.29,
#       'bedrooms': 0,
#       'maxRent': 469000,
#       'minRent': 769,
#       'totalRentals': 7},
#      {'averageRent': 1524.38,
#       'bedrooms': 1,
#       'maxRent': 2075,
#       'minRent': 500,
#       'totalRentals': 55},
#      {'averageRent': 1670.28,
#       'bedrooms': 2,
#       'maxRent': 2120,
#       'minRent': 850,
#       'totalRentals': 67},
#      {'averageRent': 1918.12,
#       'bedrooms': 3,
#       'maxRent': 2800,
#       'minRent': 1100,
#       'totalRentals': 77},
#      {'averageRent': 1997.89,
#       'bedrooms': 4,
#       'maxRent': 2975,
#       'minRent': 1200,
#       'totalRentals': 18},
#      {'averageRent': 1995,
#       'bedrooms': 5,
#       'maxRent': 1995,
#       'minRent': 1995,
#       'totalRentals': 1}],
#     'maxRent': 469000,
#     'minRent': 500,
#     'totalRentals': 225},
#    '2022-03': {'averageRent': 21750.35,
#     'detailed': [{'averageRent': 121288.57,
#       'bedrooms': 0,
#       'maxRent': 469000,
#       'minRent': 769,
#       'totalRentals': 7},
#      {'averageRent': 1497.25,
#       'bedrooms': 1,
#       'maxRent': 2035,
#       'minRent': 500,
#       'totalRentals': 53},
#      {'averageRent': 1719.06,
#       'bedrooms': 2,
#       'maxRent': 2400,
#       'minRent': 850,
#       'totalRentals': 67},
#      {'averageRent': 1916.44,
#       'bedrooms': 3,
#       'maxRent': 2800,
#       'minRent': 1100,
#       'totalRentals': 77},
#      {'averageRent': 2085.8,
#       'bedrooms': 4,
#       'maxRent': 2975,
#       'minRent': 1200,
#       'totalRentals': 15},
#      {'averageRent': 1995,
#       'bedrooms': 5,
#       'maxRent': 1995,
#       'minRent': 1995,
#       'totalRentals': 1}],
#     'maxRent': 469000,
#     'minRent': 500,
#     'totalRentals': 220},
#    '2022-04': {'averageRent': 21771.82,
#     'detailed': [{'averageRent': 121285.86,
#       'bedrooms': 0,
#       'maxRent': 469000,
#       'minRent': 769,
#       'totalRentals': 7},
#      {'averageRent': 1559.8,
#       'bedrooms': 1,
#       'maxRent': 2035,
#       'minRent': 850,
#       'totalRentals': 55},
#      {'averageRent': 1734.15,
#       'bedrooms': 2,
#       'maxRent': 2400,
#       'minRent': 875,
#       'totalRentals': 67},
#      {'averageRent': 1961.48,
#       'bedrooms': 3,
#       'maxRent': 2950,
#       'minRent': 1100,
#       'totalRentals': 91},
#      {'averageRent': 2094.61,
#       'bedrooms': 4,
#       'maxRent': 2975,
#       'minRent': 1200,
#       'totalRentals': 18},
#      {'averageRent': 1995,
#       'bedrooms': 5,
#       'maxRent': 1995,
#       'minRent': 1995,
#       'totalRentals': 1}],
#     'maxRent': 469000,
#     'minRent': 769,
#     'totalRentals': 239},
#    '2022-05': {'averageRent': 25126.24,
#     'detailed': [{'averageRent': 141359.17,
#       'bedrooms': 0,
#       'maxRent': 469000,
#       'minRent': 769,
#       'totalRentals': 6},
#      {'averageRent': 1613.31,
#       'bedrooms': 1,
#       'maxRent': 2035,
#       'minRent': 850,
#       'totalRentals': 64},
#      {'averageRent': 1796.96,
#       'bedrooms': 2,
#       'maxRent': 3000,
#       'minRent': 975,
#       'totalRentals': 69},
#      {'averageRent': 1943.76,
#       'bedrooms': 3,
#       'maxRent': 2950,
#       'minRent': 1350,
#       'totalRentals': 94},
#      {'averageRent': 2049.23,
#       'bedrooms': 4,
#       'maxRent': 2975,
#       'minRent': 1200,
#       'totalRentals': 22},
#      {'averageRent': 1995,
#       'bedrooms': 5,
#       'maxRent': 1995,
#       'minRent': 1995,
#       'totalRentals': 1}],
#     'maxRent': 469000,
#     'minRent': 769,
#     'totalRentals': 256},
#    '2022-06': {'averageRent': 21264.16,
#     'detailed': [{'averageRent': 118059.5,
#       'bedrooms': 0,
#       'maxRent': 469000,
#       'minRent': 769,
#       'totalRentals': 4},
#      {'averageRent': 1590.2,
#       'bedrooms': 1,
#       'maxRent': 1897,
#       'minRent': 850,
#       'totalRentals': 64},
#      {'averageRent': 1825.64,
#       'bedrooms': 2,
#       'maxRent': 3000,
#       'minRent': 985,
#       'totalRentals': 70},
#      {'averageRent': 2002.55,
#       'bedrooms': 3,
#       'maxRent': 3500,
#       'minRent': 1350,
#       'totalRentals': 96},
#      {'averageRent': 2060.08,
#       'bedrooms': 4,
#       'maxRent': 2975,
#       'minRent': 1200,
#       'totalRentals': 26},
#      {'averageRent': 2047,
#       'bedrooms': 5,
#       'maxRent': 2099,
#       'minRent': 1995,
#       'totalRentals': 2}],
#     'maxRent': 469000,
#     'minRent': 769,
#     'totalRentals': 262}},
#   'maxRent': 469000,
#   'minRent': 769,
#   'totalRentals': 262}}

# %%
# transform data to pandas dataframe
df_rent = pd.json_normalize(data=response.json())
print('Num of rows:', len(df_rent))
print('Num of cols:', len(df_rent.columns))
df_rent.head()
# Out:
# Num of rows: 1
# Num of cols: 141
#       id  rentalData.averageRent  rentalData.minRent  rentalData.maxRent  \
# 0  33610                21264.16                 769              469000
#
#    rentalData.totalRentals                                rentalData.detailed  \
# 0                      262  [{'bedrooms': 0, 'averageRent': 118059.5, 'min...
#
#    rentalData.history.2020-04.averageRent  rentalData.history.2020-04.minRent  \
# 0                                 1367.13                                 744
#
#    rentalData.history.2020-04.maxRent  \
# 0                               49900
#
#    rentalData.history.2020-04.totalRentals  ...  \
# 0                                      186  ...
#
#   rentalData.history.2022-05.averageRent  rentalData.history.2022-05.minRent  \
# 0                               25126.24                                 769
#
#    rentalData.history.2022-05.maxRent  \
# 0                              469000
#
#    rentalData.history.2022-05.totalRentals  \
# 0                                      256
#
#                  rentalData.history.2022-05.detailed  \
# 0  [{'bedrooms': 0, 'averageRent': 141359.17, 'mi...
#
#   rentalData.history.2022-06.averageRent  rentalData.history.2022-06.minRent  \
# 0                               21264.16                                 769
#
#    rentalData.history.2022-06.maxRent  \
# 0                              469000
#
#    rentalData.history.2022-06.totalRentals  \
# 0                                      262
#
#                  rentalData.history.2022-06.detailed
# 0  [{'bedrooms': 0, 'averageRent': 118059.5, 'min...
#
# [1 rows x 141 columns]

# %% [markdown]
# #### Get historical rental data

# %%
df_list = [] # create empty list
# get all "detailed" columns
rent_detail_hist_cols = [x for x in df_rent.columns if 'detailed' and 'history' in x]
# iterate through "detailed" columns
for x in rent_detail_hist_cols:
  # get column date
  date_str = x.split('.')[2]
  # get column name
  detail_col = 'rentalData.history.' + date_str + '.detailed'
  # convert historical data to a dataframe
  _df = pd.DataFrame(df_rent[detail_col].iloc[0])
  # create columns
  _df['date_str'] = date_str
  _df['zip_code'] = zip_code
  # append to list
  df_list.append(_df)

# %%
# comine sub date dataframes
df_detail = pd.concat(df_list)
# move date column to front
df_detail = move_col_to_front(df=df_detail, col_name='date_str')
df_detail = move_col_to_front(df=df_detail, col_name='zip_code')
# add feature for previous year
df_detail['prev_yr_dt'] = df_detail.apply(lambda x: (datetime.strptime(x['date_str'], '%Y-%m') - relativedelta(years=1)).strftime('%Y-%m'), axis=1)
df_detail.head()
# Out:
#   zip_code date_str  bedrooms  averageRent  minRent  maxRent  totalRentals  \
# 0    33610  2020-04         0       826.00      744      959             3
# 1    33610  2020-04         1       920.00      800     1040             2
# 2    33610  2020-04         2      1121.51      842     1450            35
# 3    33610  2020-04         3      2103.31      950    49900           124
# 4    33610  2020-04         4      1445.26     1100     2150            19
#
#   prev_yr_dt
# 0    2019-04
# 1    2019-04
# 2    2019-04
# 3    2019-04
# 4    2019-04

# %% [markdown]
# #### Filter and add features

# %%
df_detail_prev = df_detail.copy()
df_detail_prev.columns = [x + '_prev_yr' for x in df_detail_prev.columns]
# merge
df_merge = pd.merge(df_detail, df_detail_prev, how='left', left_on=['prev_yr_dt', 'bedrooms'], right_on=['date_str_prev_yr', 'bedrooms_prev_yr']).drop_duplicates()
# identify outliers
df_merge['averageRent_zscore'] = df_merge[['averageRent']].apply(zscore)
# view latest two months
df_merge.tail(10)
# Out:
#      zip_code date_str  bedrooms  averageRent  minRent  maxRent  totalRentals  \
# 2135    33610  2022-05         2      1796.96      975     3000            69
# 2140    33610  2022-05         3      1943.76     1350     2950            94
# 2145    33610  2022-05         4      2049.23     1200     2975            22
# 2150    33610  2022-05         5      1995.00     1995     1995             1
# 2275    33610  2022-06         0    118059.50      769   469000             4
# 2280    33610  2022-06         1      1590.20      850     1897            64
# 2281    33610  2022-06         2      1825.64      985     3000            70
# 2286    33610  2022-06         3      2002.55     1350     3500            96
# 2291    33610  2022-06         4      2060.08     1200     2975            26
# 2296    33610  2022-06         5      2047.00     1995     2099             2
#
#      prev_yr_dt zip_code_prev_yr date_str_prev_yr  bedrooms_prev_yr  \
# 2135    2021-05            33610          2021-05               2.0
# 2140    2021-05            33610          2021-05               3.0
# 2145    2021-05            33610          2021-05               4.0
# 2150    2021-05            33610          2021-05               5.0
# 2275    2021-06            33610          2021-06               0.0
# 2280    2021-06              NaN              NaN               NaN
# 2281    2021-06            33610          2021-06               2.0
# 2286    2021-06            33610          2021-06               3.0
# 2291    2021-06            33610          2021-06               4.0
# 2296    2021-06            33610          2021-06               5.0
#
#       averageRent_prev_yr  minRent_prev_yr  maxRent_prev_yr  \
# 2135              1219.70            800.0           1700.0
# 2140              1479.40           1025.0           2700.0
# 2145              1540.44           1395.0           1699.0
# 2150              2322.50           1695.0           2950.0
# 2275              1018.00            822.0           1214.0
# 2280                  NaN              NaN              NaN
# 2281              1202.78            800.0           1700.0
# 2286              1494.50           1025.0           2700.0
# 2291              1563.00           1395.0           1699.0
# 2296              2322.50           1695.0           2950.0
#
#       totalRentals_prev_yr prev_yr_dt_prev_yr  averageRent_zscore
# 2135                  20.0            2020-05           -0.276613
# 2140                  45.0            2020-05           -0.272458
# 2145                   9.0            2020-05           -0.269473
# 2150                   2.0            2020-05           -0.271008
# 2275                   2.0            2020-06            3.014071
# 2280                   NaN                NaN           -0.282465
# 2281                  18.0            2020-06           -0.275801
# 2286                  44.0            2020-06           -0.270794
# 2291                   8.0            2020-06           -0.269166
# 2296                   2.0            2020-06           -0.269536

# %%
# filter
df_filter = df_merge.copy()
df_filter = df_filter.loc[(df_filter['bedrooms'] <= 4) & (df_filter['averageRent_zscore'] <= 2)]
df_filter = df_filter.drop(columns=['prev_yr_dt', 'date_str_prev_yr', 'prev_yr_dt_prev_yr', 'zip_code_prev_yr'])
# add features
df_filter['YoY_avg_rent'] = \
  (df_filter['averageRent'] - df_filter['averageRent_prev_yr']) / df_filter['averageRent_prev_yr']
df_filter['YoY_total_rentals'] = \
  (df_filter['totalRentals'] - df_filter['totalRentals_prev_yr']) / df_filter['totalRentals_prev_yr']
# view latest two months
df_filter.tail(10)
# Out:
#      zip_code date_str  bedrooms  averageRent  minRent  maxRent  totalRentals  \
# 1990    33610  2022-04         3      1961.48     1100     2950            91
# 1995    33610  2022-04         4      2094.61     1200     2975            18
# 2130    33610  2022-05         1      1613.31      850     2035            64
# 2135    33610  2022-05         2      1796.96      975     3000            69
# 2140    33610  2022-05         3      1943.76     1350     2950            94
# 2145    33610  2022-05         4      2049.23     1200     2975            22
# 2280    33610  2022-06         1      1590.20      850     1897            64
# 2281    33610  2022-06         2      1825.64      985     3000            70
# 2286    33610  2022-06         3      2002.55     1350     3500            96
# 2291    33610  2022-06         4      2060.08     1200     2975            26
#
#       bedrooms_prev_yr  averageRent_prev_yr  minRent_prev_yr  maxRent_prev_yr  \
# 1990               3.0              1474.38           1025.0           2700.0
# 1995               4.0              1534.89           1395.0           1699.0
# 2130               1.0               600.00            600.0            600.0
# 2135               2.0              1219.70            800.0           1700.0
# 2140               3.0              1479.40           1025.0           2700.0
# 2145               4.0              1540.44           1395.0           1699.0
# 2280               NaN                  NaN              NaN              NaN
# 2281               2.0              1202.78            800.0           1700.0
# 2286               3.0              1494.50           1025.0           2700.0
# 2291               4.0              1563.00           1395.0           1699.0
#
#       totalRentals_prev_yr  averageRent_zscore  YoY_avg_rent  \
# 1990                  45.0           -0.271957      0.330376
# 1995                   9.0           -0.268188      0.364665
# 2130                   1.0           -0.281811      1.688850
# 2135                  20.0           -0.276613      0.473280
# 2140                  45.0           -0.272458      0.313884
# 2145                   9.0           -0.269473      0.330289
# 2280                   NaN           -0.282465           NaN
# 2281                  18.0           -0.275801      0.517850
# 2286                  44.0           -0.270794      0.339946
# 2291                   8.0           -0.269166      0.318029
#
#       YoY_total_rentals
# 1990           1.022222
# 1995           1.000000
# 2130          63.000000
# 2135           2.450000
# 2140           1.088889
# 2145           1.444444
# 2280                NaN
# 2281           2.888889
# 2286           1.181818
# 2291           2.250000

# %% [markdown]
# ### <font color="green">2. Multiple Zip Codes - All for a county</font>

# %% [markdown]
# #### Get county, zip data

# %%
geo_data_url = 'https://raw.githubusercontent.com/scpike/us-state-county-zip/master/geo-data.csv'
df_geo = pd.read_csv(geo_data_url)
print('Num of rows:', len(df_geo))
print('Num of columns:', len(df_geo.columns))
df_geo.head()
# Out:
# Num of rows: 33103
# Num of columns: 6
#    state_fips    state state_abbr zipcode      county        city
# 0           1  Alabama         AL   35004   St. Clair       Acmar
# 1           1  Alabama         AL   35005   Jefferson  Adamsville
# 2           1  Alabama         AL   35006   Jefferson       Adger
# 3           1  Alabama         AL   35007      Shelby    Keystone
# 4           1  Alabama         AL   35010  Tallapoosa    New site

# %%
# filter on single county
df_geo_county = df_geo.loc[(df_geo['state_abbr'] == 'FL') &
                           (df_geo['county'] == 'Hillsborough')]
# create feature to check if zip code is valid
df_geo_county['valid_zip_code'] = df_geo_county.apply(lambda x: x['zipcode'].isnumeric(), axis=1)
print('Dataset:')
print(df_geo_county.groupby(['valid_zip_code'])['zipcode'].count())
print(' ')
print('Invalid zip codes:', df_geo_county.loc[df_geo_county['valid_zip_code'] == False]['zipcode'].unique())
# Out:
# Dataset:
# valid_zip_code
# False     2
# True     45
# Name: zipcode, dtype: int64
#
# Invalid zip codes: ['335HH' '336HH']

# %%
# filter on only valid zip codes
df_geo_county_valid = df_geo_county.loc[df_geo_county['valid_zip_code'] == True]
print('Num of VALID zip codes:', len(df_geo_county_valid))
df_geo_county_valid.head()
# Out:
# Num of VALID zip codes: 45
#       state_fips    state state_abbr zipcode        county       city  \
# 5129          12  Florida         FL   33510  Hillsborough    Brandon
# 5130          12  Florida         FL   33511  Hillsborough    Brandon
# 5136          12  Florida         FL   33527  Hillsborough      Dover
# 5137          12  Florida         FL   33534  Hillsborough  Gibsonton
# 5143          12  Florida         FL   33547  Hillsborough     Lithia
#
#       valid_zip_code
# 5129            True
# 5130            True
# 5136            True
# 5137            True
# 5143            True

# %% [markdown]
# #### Get data for each zip code

# %%
_df_latest_list = []
_df_historical_list = []

# iterate through each zip code in the list
for zip_code in df_geo_county_valid['zipcode'].tolist():
  print('Getting data for zipcode:', zip_code)
  
  # for each zip code get rental data
  response = get_rental_market_data(rapid_api_key, zip_code)

  try:

    # transform response
    # 1) latest rental data
    _df_latest = get_latest_rental_data(response)
    _df_latest_list.append(_df_latest)

    # 2) historical rental data
    _df_historical = get_historical_rental_data(response)
    _df_historical_list.append(_df_historical)

  except:

    print('**Error in retrieving data for:', zip_code)

  time.sleep(1) # pause for 2 seconds (max 2 requests per second)
# Out:
# Getting data for zipcode: 33510
# Getting data for zipcode: 33511
# Getting data for zipcode: 33527
# Getting data for zipcode: 33534
# Getting data for zipcode: 33547
# Getting data for zipcode: 33549
# Getting data for zipcode: 33556
# Getting data for zipcode: 33565
# Getting data for zipcode: 33566
# Getting data for zipcode: 33567
# Getting data for zipcode: 33569
# Getting data for zipcode: 33570
# Getting data for zipcode: 33572
# Getting data for zipcode: 33573
# Getting data for zipcode: 33584
# Getting data for zipcode: 33592
# Getting data for zipcode: 33594
# Getting data for zipcode: 33598
# Getting data for zipcode: 33602
# Getting data for zipcode: 33603
# Getting data for zipcode: 33604
# Getting data for zipcode: 33605
# Getting data for zipcode: 33606
# Getting data for zipcode: 33607
# Getting data for zipcode: 33609
# Getting data for zipcode: 33610
# Getting data for zipcode: 33611
# Getting data for zipcode: 33612
# Getting data for zipcode: 33613
# Getting data for zipcode: 33614
# Getting data for zipcode: 33615
# Getting data for zipcode: 33616
# Getting data for zipcode: 33617
# Getting data for zipcode: 33618
# Getting data for zipcode: 33619
# Getting data for zipcode: 33620
# **Error in retrieving data for: 33620
# Getting data for zipcode: 33621
# Getting data for zipcode: 33624
# Getting data for zipcode: 33625
# Getting data for zipcode: 33626
# Getting data for zipcode: 33629
# Getting data for zipcode: 33634
# Getting data for zipcode: 33635
# Getting data for zipcode: 33637
# Getting data for zipcode: 33647

# %%
# concat
df_latest = pd.concat(_df_latest_list)
df_latest.head()
# Out:
#   zip_code  rentalData.averageRent  rentalData.minRent  rentalData.maxRent  \
# 0    33510                 2253.22                 650                4300
# 0    33511                 2148.86                1100                4090
# 0    33527                 3901.67                2495                4950
# 0    33534                 1785.64                 800                2965
# 0    33547                 2222.97                1200                3645
#
#    rentalData.totalRentals                                rentalData.detailed
# 0                      243  [{'bedrooms': 0, 'averageRent': 1597.33, 'minR...
# 0                      946  [{'bedrooms': 0, 'averageRent': 1573.63, 'minR...
# 0                       10  [{'bedrooms': 3, 'averageRent': 4950, 'minRent...
# 0                      120  [{'bedrooms': 0, 'averageRent': 1443.33, 'minR...
# 0                      176  [{'bedrooms': 0, 'averageRent': 1624.46, 'minR...

# %%
# concat
df_historical = pd.concat(_df_historical_list)
df_historical.groupby(['zip_code'])['bedrooms'].count().reset_index().rename(columns={'bedrooms': 'num_records'})
# Out:
#    zip_code  num_records
# 0     33510          135
# 1     33511          135
# 2     33527           72
# 3     33534          125
# 4     33547          120
# 5     33549          129
# 6     33556          126
# 7     33565           68
# 8     33566          107
# 9     33567           78
# 10    33569           79
# 11    33570          121
# 12    33572          106
# 13    33573          130
# 14    33584          122
# 15    33592          101
# 16    33594          132
# 17    33598          102
# 18    33602          135
# 19    33603          135
# 20    33604          128
# 21    33605          132
# 22    33606          130
# 23    33607          134
# 24    33609          135
# 25    33610          122
# 26    33611          135
# 27    33612          135
# 28    33613          135
# 29    33614          134
# 30    33615          123
# 31    33616          133
# 32    33617          135
# 33    33618          135
# 34    33619          135
# 35    33624          135
# 36    33625          124
# 37    33626          134
# 38    33629          132
# 39    33634          135
# 40    33635          119
# 41    33637          135
# 42    33647          135

# %% [markdown]
# ## <font color="blue">Output</font>

# %%
latest_dt_str = df_historical['date_str'].max()
print('Latest date:', latest_dt_str)
# Out:
# Latest date: 2022-06

# %%
# download file
df_latest.to_csv('zip_rent_analysis_latest_{}.csv'.format(latest_dt_str), index=False)
files.download('zip_rent_analysis_latest_{}.csv'.format(latest_dt_str))

# %%
df_historical_context = pd.merge(df_historical, df_geo_county_valid.rename(columns={'zipcode': 'zip_code'}), how='left', on='zip_code')
df_historical_context.head(1)
# Out:
#   zip_code date_str  bedrooms  averageRent  minRent  maxRent  totalRentals  \
# 0    33510  2020-04         0       979.25      730     1281             4
#
#    bedrooms_prev_yr  averageRent_prev_yr  minRent_prev_yr  ...  \
# 0               NaN                  NaN              NaN  ...
#
#    totalRentals_prev_yr  averageRent_zscore  YoY_avg_rent  YoY_total_rentals  \
# 0                   NaN           -1.217757           NaN                NaN
#
#    state_fips    state state_abbr        county     city valid_zip_code
# 0          12  Florida         FL  Hillsborough  Brandon           True
#
# [1 rows x 21 columns]

# %%
# download file
df_historical_context.to_csv('zip_rent_analysis_historical_{}.csv'.format(latest_dt_str), index=False)
files.download('zip_rent_analysis_historical_{}.csv'.format(latest_dt_str))

# %% [markdown]
# # End Notebook
