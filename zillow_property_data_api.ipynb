# %% [markdown]
# <a href="https://colab.research.google.com/github/analyticsariel/projects/blob/master/zillow_property_data_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to Get Zillow Property Data in Python [2022]
# <i>Python tutorial to get property data for on and off-market deals</i>
#
# ## Overview
# | Detail Tag            | Information                                                                                        |
# |-----------------------|----------------------------------------------------------------------------------------------------|
# | Originally Created By | Ariel Herrera arielherrera@analyticsariel.com |
# | External References   | API |
# | Input Datasets        | Source name |
# | Output Datasets       | Source name |
# | Input Data Source     | Pandas DataFrame |
# | Output Data Source    | Pandas DataFrame |
#
# ## History
# | Date         | Developed By  | Reason                                                |
# |--------------|---------------|-------------------------------------------------------|
# | 20th May 2022 | Ariel Herrera | Create notebook. |
#
# ## Getting Started
# 1. Copy this notebook -> File -> Save a Copy in Drive
# 2. Directions
#   - Get Free [Rapid API Key by creating an account](https://rapidapi.com/marketplace)
#   - Store each key in a central and private location.
#   - Subscribe to [Zillow on Rapid API](https://rapidapi.com/apimaker/api/zillow-com1/)
#
# ## Useful Resources
# - [Google Colab Cheat Sheet](https://towardsdatascience.com/cheat-sheet-for-google-colab-63853778c093)

# %% [markdown]
# ## <font color="blue">Install Packages</font>

# %%
# !pip install googlesearch-python -q

# %% [markdown]
# ## <font color="blue">Imports</font>

# %%
from google.colab import drive, files # specific to Google Colab
from googlesearch import search # get zpid
import pandas as pd
import requests
import json
import time
import io
import plotly.express as px


# show all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## <font color="blue">Functions</font>

# %%
def get_zpid(street=None, city=None, state=None, zip_code=None, full_address=None):
  # get search query string
  if full_address == None:
    try:
      query = '{0}, {1}, {2} {3} zillow home details'.format(street, city, state, str(zip_code))
    except:
      return 'Please enter a query string or address details'
  else:
    query = full_address + ' zillow home details'

  # get google search results
  search_results = search(query, tld='com', lang='en', num=3, start=0, stop=1, pause=0)
  search_results_list = [u for u in search_results]
  url = search_results_list[0] # extract first returned result
  
  # return zpid
  try:
    return [x for x in url.split('/') if 'zpid' in x][0].split('_')[0]
  except:
    return None

# %%
def get_property_detail(rapid_api_key, zpid):
  # get property details from API
  url = "https://zillow-com1.p.rapidapi.com/property"

  querystring = {"zpid":zpid} # zpid

  headers = {
    "X-RapidAPI-Host": "zillow-com1.p.rapidapi.com",
    "X-RapidAPI-Key": rapid_api_key # your key here
  }

  # request data
  return requests.request("GET", url, headers=headers, params=querystring)

# %% [markdown]
# ## <font color="blue">Locals & Constants</font>

# %%
############
# OPTIONAL #
############

# mount drive
drive.mount('/content/drive', force_remount=False)

# data location
file_dir = '/content/drive/My Drive/Colab Data/input/' # optional
# Out:
# Mounted at /content/drive

# %%
# read in api key file
df_api_keys = pd.read_csv(file_dir + 'api_keys.csv')

# get keys
rapid_api_key = df_api_keys.loc[df_api_keys['API'] =='rapid']['KEY'].iloc[0] # replace this with your own key

# %% [markdown]
# ## <font color="blue">Data</font>

# %% [markdown]
# ### 1) Single Property
#
#
# *   Get ZPID *(unique identifier for each property stored in the URL)*
# *   Get Property Details Data

# %%
# property address
property_address = "11622 Pure Pebble Dr, RIVERVIEW, FL 33569" # https://www.zillow.com/homedetails/11622-Pure-Pebble-Dr-Riverview-FL-33569/66718658_zpid/

# search query
query = property_address + ' zillow home details'
print('Search this phrase in Google Search:', query)
# Out:
# Search this phrase in Google Search: 11622 Pure Pebble Dr, RIVERVIEW, FL 33569 zillow home details

# %%
# google search results
search_results = search(query, tld='com', lang='en', num=3, start=0, stop=3, pause=0)
search_results_list = [u for u in search_results] # get all results
search_results_list
# Out:
# ['https://www.zillow.com/homedetails/11622-Pure-Pebble-Dr-Riverview-FL-33569/66718658_zpid/',
#  'https://www.trulia.com/p/fl/riverview/11622-pure-pebble-dr-riverview-fl-33569--2035606137',
#  'https://www.coldwellbankerhomes.com/fl/riverview/11622-pure-pebble-dr/pid_47199068/']

# %%
# get the first search result
url = search_results_list[0] # extract first returned result
url
# Out:
# 'https://www.zillow.com/homedetails/11622-Pure-Pebble-Dr-Riverview-FL-33569/66718658_zpid/'

# %%
# extract the zpid
zpid = [x for x in url.split('/') if 'zpid' in x][0].split('_')[0]
print('Zpid of the property is:', zpid )
# Out:
# Zpid of the property is: 66718658

# %%
# get property details from API
url = "https://zillow-com1.p.rapidapi.com/property"

querystring = {"zpid":zpid} # zpid

headers = {
	"X-RapidAPI-Host": "zillow-com1.p.rapidapi.com",
	"X-RapidAPI-Key": rapid_api_key # your key here
}

# request data
response = requests.request("GET", url, headers=headers, params=querystring)
# show success
response.status_code # 200 is success!
# Out:
# 200

# %%
response.json()
# Out:
# {'address': {'city': 'Riverview',
#   'neighborhood': None,
#   'state': 'FL',
#   'streetAddress': '11622 Pure Pebble Dr',
#   'zipcode': '33569'},
#  'annualHomeownersInsurance': 2016,
#  'bathrooms': 2,
#  'bedrooms': 4,
#  'brokerId': None,
#  'brokerageName': 'Keller Williams Tampa Prop.',
#  'building': None,
#  'buildingPermits': None,
#  'city': 'Riverview',
#  'cityId': 6790,
#  'comingSoonOnMarketDate': None,
#  'contact_recipients': [{'agent_reason': 1,
#    'badge_type': 'Premier Agent',
#    'display_name': 'Steve Scott',
#    'image_url': 'https://photos.zillowstatic.com/h_n/ISfo3zws3l499v1000000000.jpg',
#    'phone': {'areacode': '813', 'number': '3633', 'prefix': '902'},
#    'rating_average': 5,
#    'recent_sales': 1,
#    'review_count': 17,
#    'zpro': None,
#    'zuid': 'X1-ZU14g8dp89dtyix_9tzap'}],
#  'contingentListingType': None,
#  'country': 'USA',
#  'county': None,
#  'countyFIPS': '12057',
#  'countyId': 3165,
#  'currency': 'USD',
#  'datePosted': '2022-05-20',
#  'dateSold': '2018-01-22',
#  'description': 'This 4 bedroom/2 bath pool home with a great yard can be yours!  This lovely home features 4 bedrooms, 2 baths, a formal living and dining space as well as a family room, a large kitchen with breakfast nook, large owners suite and 3 other bedrooms.  Split floor plan.  The backyard is complete with a pool and screened lanai as well as a large yard with plenty of space to play, entertain, garden or for your pets.  The location is near Riverview High School, the Alafia River Hiking Trail, Restaurants, Movie theaters and shopping as well as hospitals.  The location could not be better. The neighborhood offers low HOA fees and No CDD fee.  Boyette Farms is convenient to Hwy 301, I75 and the Crosstown Expressway.',
#  'favoriteCount': 18,
#  'homeFacts': None,
#  'homeStatus': 'FOR_SALE',
#  'homeType': 'SINGLE_FAMILY',
#  'imgSrc': 'https://photos.zillowstatic.com/fp/f42d9a19a27488f4bc03b1c062442efd-p_d.jpg',
#  'isListedByOwner': False,
#  'latitude': 27.856653,
#  'listed_by': {'agent_reason': 3,
#   'badge_type': 'Listing Agent',
#   'business_name': 'Keller Williams Tampa Prop.',
#   'display_name': 'Melissa De Maria',
#   'image_url': 'https://photos.zillowstatic.com/h_n/ISnygmm26i8b201000000000.jpg',
#   'phone': {'areacode': '813', 'number': '8675', 'prefix': '390'},
#   'rating_average': 5,
#   'recent_sales': 0,
#   'review_count': 8,
#   'zpro': True,
#   'zuid': 'X1-ZUyb6yrkeebkzt_64j9u'},
#  'listingProvider': None,
#  'livingArea': 2079,
#  'livingAreaUnits': 'sqft',
#  'livingAreaValue': 2079,
#  'longitude': -82.305725,
#  'mlsid': 'T3374663',
#  'monthlyHoaFee': 48,
#  'mortgageRates': {'arm5Rate': 4.452,
#   'fifteenYearFixedRate': 4.021,
#   'thirtyYearFixedRate': 4.882},
#  'nearbyHomes': [{'address': {'city': 'Riverview',
#     'state': 'FL',
#     'streetAddress': '11620 Pure Pebble Dr',
#     'zipcode': '33569'},
#    'currency': 'USD',
#    'homeStatus': 'RECENTLY_SOLD',
#    'homeType': 'SINGLE_FAMILY',
#    'latitude': 27.856646,
#    'longitude': -82.30591,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/1d913fe3d0f2317b4d505889f25970c2-p_c.jpg'}],
#    'price': 365000,
#    'zpid': 66716625},
#   {'address': {'city': 'Riverview',
#     'state': 'FL',
#     'streetAddress': '11624 Pure Pebble Dr',
#     'zipcode': '33569'},
#    'currency': 'USD',
#    'homeStatus': 'OTHER',
#    'homeType': 'SINGLE_FAMILY',
#    'latitude': 27.856688,
#    'longitude': -82.30551,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/86e14e3be2b5075aa0e14a6e9ed87c42-p_c.jpg'}],
#    'price': 362700,
#    'zpid': 59917553},
#   {'address': {'city': 'Riverview',
#     'state': 'FL',
#     'streetAddress': '11626 Pure Pebble Dr',
#     'zipcode': '33569'},
#    'currency': 'USD',
#    'homeStatus': 'OTHER',
#    'homeType': 'SINGLE_FAMILY',
#    'latitude': 27.856678,
#    'longitude': -82.3054,
#    'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/streetview?location=11626+Pure+Pebble+Dr%2C+Riverview%2C+FL+33569&size=316x234&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=ybAFuAamuoOeCe96Ln-vxLMOiYc='}],
#    'price': 399600,
#    'zpid': 59915263},
#   {'address': {'city': 'Riverview',
#     'state': 'FL',
#     'streetAddress': '9804 Laurel Ledge Dr',
#     'zipcode': '33569'},
#    'currency': 'USD',
#    'homeStatus': 'OTHER',
#    'homeType': 'SINGLE_FAMILY',
#    'latitude': 27.85694,
#    'longitude': -82.30555,
#    'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/streetview?location=9804+Laurel+Ledge+Dr%2C+Riverview%2C+FL+33569&size=316x234&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=n9O4tqeQLnuRooWWTRu99O0CDZ4='}],
#    'price': 389800,
#    'zpid': 66718657},
#   {'address': {'city': 'Riverview',
#     'state': 'FL',
#     'streetAddress': '9806 Laurel Ledge Dr',
#     'zipcode': '33569'},
#    'currency': 'USD',
#    'homeStatus': 'OTHER',
#    'homeType': 'SINGLE_FAMILY',
#    'latitude': 27.85699,
#    'longitude': -82.30567,
#    'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/streetview?location=9806+Laurel+Ledge+Dr%2C+Riverview%2C+FL+33569&size=316x234&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=-U8KM_kPEBCZy6qUhPJURC-zhpY='}],
#    'price': 358200,
#    'zpid': 66718656},
#   {'address': {'city': 'Riverview',
#     'state': 'FL',
#     'streetAddress': '9808 Laurel Ledge Dr',
#     'zipcode': '33569'},
#    'currency': 'USD',
#    'homeStatus': 'OTHER',
#    'homeType': 'SINGLE_FAMILY',
#    'latitude': 27.856989,
#    'longitude': -82.305824,
#    'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/streetview?location=9808+Laurel+Ledge+Dr%2C+Riverview%2C+FL+33569&size=316x234&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=a86Oh9S2E2T8HpZqanNSnN73jcA='}],
#    'price': 390400,
#    'zpid': 66718655},
#   {'address': {'city': 'Riverview',
#     'state': 'FL',
#     'streetAddress': '11618 Pure Pebble Dr',
#     'zipcode': '33569'},
#    'currency': 'USD',
#    'homeStatus': 'PENDING',
#    'homeType': 'SINGLE_FAMILY',
#    'latitude': 27.856428,
#    'longitude': -82.306076,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/90f9d17dba28db99b2cf6588aa1ce389-p_c.jpg'}],
#    'price': 499000,
#    'zpid': 66672775},
#   {'address': {'city': 'Riverview',
#     'state': 'FL',
#     'streetAddress': '9810 Laurel Ledge Dr',
#     'zipcode': '33569'},
#    'currency': 'USD',
#    'homeStatus': 'OTHER',
#    'homeType': 'SINGLE_FAMILY',
#    'latitude': 27.856968,
#    'longitude': -82.305984,
#    'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/446704c859c61c97ef05e618ce411ce7-p_c.jpg'}],
#    'price': 380500,
#    'zpid': 66718693}],
#  'pageViewCount': 490,
#  'price': 480000,
#  'priceHistory': [{'attributeSource': {'infoString1': 'T3374663',
#     'infoString2': 'Stellar MLS / MFRMLS',
#     'infoString3': 'https://photos.zillowstatic.com/fp/e39375731b4bce0deb161dcc85f92017-zillow_web_logo_inf_11.jpg'},
#    'buyerAgent': None,
#    'date': '2022-05-20',
#    'event': 'Listed for sale',
#    'postingIsRental': False,
#    'price': 480000,
#    'priceChangeRate': 1.0253164556962,
#    'pricePerSquareFoot': 231,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'source': 'Stellar MLS / MFRMLS',
#    'time': 1653004800000},
#   {'attributeSource': {'infoString1': None,
#     'infoString2': 'Public Record',
#     'infoString3': None},
#    'buyerAgent': None,
#    'date': '2018-01-22',
#    'event': 'Sold',
#    'postingIsRental': False,
#    'price': 237000,
#    'priceChangeRate': -0.012088370154231,
#    'pricePerSquareFoot': 114,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'source': 'Public Record',
#    'time': 1516579200000},
#   {'attributeSource': {'infoString1': None,
#     'infoString2': 'HOMEXPRESS REALTY, INC.',
#     'infoString3': None},
#    'buyerAgent': None,
#    'date': '2017-12-12',
#    'event': 'Listing removed',
#    'postingIsRental': False,
#    'price': 239900,
#    'priceChangeRate': 0,
#    'pricePerSquareFoot': 115,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'source': 'HOMEXPRESS REALTY, INC.',
#    'time': 1513036800000},
#   {'attributeSource': {'infoString1': None,
#     'infoString2': 'HOMEXPRESS REALTY, INC.',
#     'infoString3': None},
#    'buyerAgent': None,
#    'date': '2017-12-08',
#    'event': 'Price change',
#    'postingIsRental': False,
#    'price': 239900,
#    'priceChangeRate': -0.02479674796748,
#    'pricePerSquareFoot': 115,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'source': 'HOMEXPRESS REALTY, INC.',
#    'time': 1512691200000},
#   {'attributeSource': {'infoString1': None,
#     'infoString2': 'HOMEXPRESS REALTY, INC.',
#     'infoString3': None},
#    'buyerAgent': None,
#    'date': '2017-11-14',
#    'event': 'Listed for sale',
#    'postingIsRental': False,
#    'price': 246000,
#    'priceChangeRate': -0.031496062992126,
#    'pricePerSquareFoot': 118,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'source': 'HOMEXPRESS REALTY, INC.',
#    'time': 1510617600000},
#   {'attributeSource': {'infoString1': None,
#     'infoString2': 'HOMEXPRESS REALTY, INC.',
#     'infoString3': None},
#    'buyerAgent': None,
#    'date': '2017-10-18',
#    'event': 'Pending sale',
#    'postingIsRental': False,
#    'price': 254000,
#    'priceChangeRate': 0,
#    'pricePerSquareFoot': 122,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'source': 'HOMEXPRESS REALTY, INC.',
#    'time': 1508284800000},
#   {'attributeSource': {'infoString1': None,
#     'infoString2': 'HOMEXPRESS REALTY, INC.',
#     'infoString3': None},
#    'buyerAgent': None,
#    'date': '2017-09-28',
#    'event': 'Price change',
#    'postingIsRental': False,
#    'price': 254000,
#    'priceChangeRate': -0.019305019305019,
#    'pricePerSquareFoot': 122,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'source': 'HOMEXPRESS REALTY, INC.',
#    'time': 1506556800000},
#   {'attributeSource': {'infoString1': None,
#     'infoString2': 'HOMEXPRESS REALTY, INC.',
#     'infoString3': None},
#    'buyerAgent': None,
#    'date': '2017-09-01',
#    'event': 'Listed for sale',
#    'postingIsRental': False,
#    'price': 259000,
#    'priceChangeRate': 0.43808995002776,
#    'pricePerSquareFoot': 125,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'source': 'HOMEXPRESS REALTY, INC.',
#    'time': 1504224000000},
#   {'attributeSource': {'infoString1': None,
#     'infoString2': 'Public Record',
#     'infoString3': None},
#    'buyerAgent': None,
#    'date': '2003-06-02',
#    'event': 'Sold',
#    'postingIsRental': False,
#    'price': 180100,
#    'priceChangeRate': 0,
#    'pricePerSquareFoot': 87,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'source': 'Public Record',
#    'time': 1054512000000}],
#  'propertyTaxRate': 1.06,
#  'propertyTypeDimension': 'Single Family',
#  'providerListingID': None,
#  'rentZestimate': 2408,
#  'resoFacts': {'aboveGradeFinishedArea': None,
#   'accessibilityFeatures': None,
#   'additionalParcelsDescription': None,
#   'allowedPets': None,
#   'appliances': ['Dishwasher',
#    'Disposal',
#    'Electric Water Heater',
#    'Microwave',
#    'Range',
#    'Refrigerator'],
#   'architecturalStyle': None,
#   'associationAmenities': None,
#   'associationFee': '$145 quarterly',
#   'associationFee2': None,
#   'associationFeeIncludes': None,
#   'associationName': None,
#   'associationName2': None,
#   'associationPhone': None,
#   'associationPhone2': None,
#   'atAGlanceFacts': [{'factLabel': 'Type',
#     'factValue': 'Single Family Residence'},
#    {'factLabel': 'Year Built', 'factValue': '2003'},
#    {'factLabel': 'Heating', 'factValue': 'Central'},
#    {'factLabel': 'Cooling', 'factValue': 'Central Air'},
#    {'factLabel': 'Parking', 'factValue': '2 Attached Garage spaces'},
#    {'factLabel': 'HOA', 'factValue': '$145 quarterly'},
#    {'factLabel': 'Lot', 'factValue': '6,534 sqft'},
#    {'factLabel': 'Days on Zillow', 'factValue': '3 Days'},
#    {'factLabel': 'Price/sqft', 'factValue': '$231'},
#    {'factLabel': "Buyer's Agent Fee", 'factValue': '3%-$295'},
#    {'factLabel': 'Offer Review Date', 'factValue': None}],
#   'attic': 'Living Room/Dining Room Combo, Master Bedroom Main Floor, Open Floorplan',
#   'availabilityDate': None,
#   'basement': None,
#   'basementYN': False,
#   'bathrooms': 2,
#   'bathroomsFull': 2,
#   'bathroomsHalf': 0,
#   'bathroomsOneQuarter': None,
#   'bathroomsPartial': None,
#   'bathroomsThreeQuarter': None,
#   'bedrooms': 4,
#   'belowGradeFinishedArea': None,
#   'bodyType': None,
#   'builderModel': None,
#   'builderName': None,
#   'buildingArea': '2,758',
#   'buildingAreaSource': None,
#   'buildingFeatures': None,
#   'buildingName': None,
#   'buyerAgencyCompensation': '3%-$295',
#   'buyerAgencyCompensationType': '%',
#   'canRaiseHorses': False,
#   'carportSpaces': None,
#   'cityRegion': 'Riverview',
#   'commonWalls': None,
#   'communityFeatures': None,
#   'constructionMaterials': ['Block'],
#   'cooling': ['Central Air'],
#   'coveredSpaces': 2,
#   'cropsIncludedYN': None,
#   'daysOnZillow': 3,
#   'depositsAndFees': None,
#   'developmentStatus': None,
#   'doorFeatures': None,
#   'electric': None,
#   'elementarySchool': None,
#   'elementarySchoolDistrict': None,
#   'elevation': None,
#   'elevationUnits': None,
#   'entryLevel': None,
#   'entryLocation': None,
#   'exclusions': None,
#   'exteriorFeatures': ['Fenced', 'Sidewalk', 'Sliding Doors'],
#   'fencing': 'Wood',
#   'fireplaceFeatures': None,
#   'fireplaces': None,
#   'flooring': ['Ceramic Tile', 'Vinyl'],
#   'foundationArea': None,
#   'foundationDetails': ['Slab'],
#   'frontageLength': None,
#   'frontageType': None,
#   'furnished': False,
#   'garageSpaces': 2,
#   'gas': None,
#   'greenBuildingVerificationType': None,
#   'greenEnergyEfficient': None,
#   'greenIndoorAirQuality': None,
#   'greenSustainability': None,
#   'greenWaterConservation': None,
#   'hasAdditionalParcels': False,
#   'hasAssociation': True,
#   'hasAttachedGarage': True,
#   'hasAttachedProperty': False,
#   'hasCarport': False,
#   'hasCooling': True,
#   'hasElectricOnProperty': True,
#   'hasFireplace': False,
#   'hasGarage': True,
#   'hasHeating': True,
#   'hasHomeWarranty': False,
#   'hasLandLease': False,
#   'hasOpenParking': True,
#   'hasPetsAllowed': True,
#   'hasPrivatePool': True,
#   'hasRentControl': None,
#   'hasSpa': False,
#   'hasView': True,
#   'hasWaterfrontView': None,
#   'heating': ['Central'],
#   'highSchool': None,
#   'highSchoolDistrict': None,
#   'hoaFee': '$145 quarterly',
#   'homeType': 'SingleFamily',
#   'horseAmenities': None,
#   'horseYN': None,
#   'inclusions': None,
#   'incomeIncludes': None,
#   'interiorFeatures': ['Living Room/Dining Room Combo', 'Open Floorplan'],
#   'irrigationWaterRightsAcres': None,
#   'irrigationWaterRightsYN': None,
#   'isNewConstruction': False,
#   'isSeniorCommunity': None,
#   'landLeaseAmount': None,
#   'landLeaseExpirationDate': None,
#   'laundryFeatures': ['Laundry Room'],
#   'leaseTerm': 'No Minimum',
#   'levels': 'One',
#   'listAOR': None,
#   'listingId': None,
#   'listingTerms': None,
#   'livingArea': '2,079 sqft',
#   'livingAreaRange': None,
#   'livingAreaRangeUnits': None,
#   'lotFeatures': None,
#   'lotSize': '6,534 sqft',
#   'lotSizeDimensions': '55 x 118',
#   'mainLevelBathrooms': None,
#   'mainLevelBedrooms': None,
#   'marketingType': None,
#   'middleOrJuniorSchool': None,
#   'middleOrJuniorSchoolDistrict': None,
#   'municipality': None,
#   'numberOfUnitsInCommunity': None,
#   'numberOfUnitsVacant': None,
#   'offerReviewDate': None,
#   'onMarketDate': 1653004800000,
#   'openParkingSpaces': None,
#   'otherEquipment': None,
#   'otherFacts': {},
#   'otherParking': None,
#   'otherStructures': None,
#   'ownership': 'Fee Simple',
#   'ownershipType': None,
#   'parcelNumber': 'U2130205XM00000600024.0',
#   'parking': 2,
#   'parkingFeatures': ['Garage Door Opener'],
#   'patioAndPorchFeatures': None,
#   'petsMaxWeight': None,
#   'poolFeatures': ['Gunite', 'In Ground'],
#   'pricePerSquareFoot': 231,
#   'propertyCondition': None,
#   'propertySubType': ['Single Family Residence'],
#   'roadSurfaceType': ['Paved'],
#   'roofType': 'Shingle',
#   'rooms': {},
#   'securityFeatures': None,
#   'sewer': ['Public Sewer'],
#   'spaFeatures': None,
#   'specialListingConditions': 'None',
#   'stories': None,
#   'storiesTotal': 1,
#   'structureType': None,
#   'subdivisionName': 'Boyette Farms Ph 2b1',
#   'taxAnnualAmount': 3768,
#   'tenantPays': None,
#   'topography': None,
#   'totalActualRent': 0,
#   'utilities': ['Cable Connected', 'Electricity Connected', 'Public'],
#   'vegetation': None,
#   'view': ['Pool'],
#   'virtualTour': 'https://www.propertypanorama.com/instaview/stellar/T3374663',
#   'virtualTourURLUnbranded': 'https://www.propertypanorama.com/instaview/stellar/T3374663',
#   'waterBodyName': None,
#   'waterSource': ['Public'],
#   'waterSources': None,
#   'waterView': None,
#   'waterViewYN': False,
#   'waterfrontFeatures': None,
#   'windowFeatures': ['Blinds'],
#   'woodedArea': None,
#   'yearBuilt': 2003,
#   'yearBuiltEffective': None,
#   'zoning': 'PD',
#   'zoningDescription': None},
#  'schools': [{'assigned': None,
#    'distance': 1.7,
#    'grades': 'PK-5',
#    'isAssigned': True,
#    'level': 'Primary',
#    'link': 'https://www.greatschools.org/school?id=01301&state=FL',
#    'name': 'Boyette Springs Elementary School',
#    'rating': 7,
#    'size': 861,
#    'studentsPerTeacher': 14,
#    'totalCount': 1,
#    'type': 'Public'},
#   {'assigned': None,
#    'distance': 0.9,
#    'grades': '6-8',
#    'isAssigned': True,
#    'level': 'Middle',
#    'link': 'https://www.greatschools.org/school?id=01475&state=FL',
#    'name': 'Rodgers Middle School',
#    'rating': 4,
#    'size': 749,
#    'studentsPerTeacher': 18,
#    'totalCount': 1,
#    'type': 'Public'},
#   {'assigned': None,
#    'distance': 0.5,
#    'grades': '9-12',
#    'isAssigned': True,
#    'level': 'High',
#    'link': 'https://www.greatschools.org/school?id=01473&state=FL',
#    'name': 'Riverview High School',
#    'rating': 5,
#    'size': 2576,
#    'studentsPerTeacher': 19,
#    'totalCount': 1,
#    'type': 'Public'}],
#  'solarPotential': {'buildFactor': 76.8,
#   'climateFactor': 6.89,
#   'electricityFactor': 3.5,
#   'solarFactor': 3.56,
#   'sunScore': 90.74},
#  'state': 'FL',
#  'stateId': 14,
#  'streetAddress': '11622 Pure Pebble Dr',
#  'taxHistory': [{'taxIncreaseRate': 0.029442947,
#    'taxPaid': 3678.56,
#    'time': 1590256690112,
#    'value': 197426,
#    'valueIncreaseRate': 0.02300155},
#   {'taxIncreaseRate': 0,
#    'taxPaid': 3573.35,
#    'time': 1558634290112,
#    'value': 192987,
#    'valueIncreaseRate': -0.021686563},
#   {'taxIncreaseRate': -0.16257913,
#    'taxPaid': 3573.35,
#    'time': 1527098290112,
#    'value': 197265,
#    'valueIncreaseRate': 0.18567917},
#   {'taxIncreaseRate': 0.09495664,
#    'taxPaid': 4267.09,
#    'time': 1495562290112,
#    'value': 166373,
#    'valueIncreaseRate': -0.009784725},
#   {'taxIncreaseRate': -0.013614871,
#    'taxPaid': 3897.04,
#    'time': 1464026290112,
#    'value': 168017,
#    'valueIncreaseRate': 0.099998035},
#   {'taxIncreaseRate': 0.134481,
#    'taxPaid': 3950.83,
#    'time': 1432403890112,
#    'value': 152743,
#    'valueIncreaseRate': 0.10000216},
#   {'taxIncreaseRate': 0,
#    'taxPaid': 3482.5,
#    'time': 1400867890112,
#    'value': 138857,
#    'valueIncreaseRate': 0.099996835},
#   {'taxIncreaseRate': 0.5024376,
#    'taxPaid': 3482.5,
#    'time': 1369331890112,
#    'value': 126234,
#    'valueIncreaseRate': 0.06190536},
#   {'taxIncreaseRate': 0,
#    'taxPaid': 2317.9,
#    'time': 1337795890112,
#    'value': 118875,
#    'valueIncreaseRate': 2.4279659},
#   {'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'time': 1053712690112,
#    'value': 34678,
#    'valueIncreaseRate': 0},
#   {'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'time': 1022176690112,
#    'value': 34678,
#    'valueIncreaseRate': 0}],
#  'timeOnZillow': '3 days',
#  'timeZone': 'America/New_York',
#  'url': '/homedetails/11622-Pure-Pebble-Dr-Riverview-FL-33569/66718658_zpid/',
#  'yearBuilt': 2003,
#  'zestimate': 443600,
#  'zestimateHighPercent': '5',
#  'zestimateLowPercent': '5',
#  'zipcode': '33569',
#  'zpid': 66718658}

# %%
# transform data to pandas dataframe
df_property_detail = pd.json_normalize(data=response.json())
print('Num of rows:', len(df_property_detail))
print('Num of cols:', len(df_property_detail.columns))
df_property_detail.head()
# Out:
# Num of rows: 1
# Num of cols: 259
#   listingProvider buildingPermits  propertyTaxRate  \
# 0            None            None             1.06
#
#                                   contact_recipients  longitude countyFIPS  \
# 0  [{'agent_reason': 1, 'zpro': None, 'recent_sal... -82.305725      12057
#
#    cityId timeOnZillow                                                url  \
# 0    6790       3 days  /homedetails/11622-Pure-Pebble-Dr-Riverview-FL...
#
#    zestimate                                             imgSrc      zpid  \
# 0     443600  https://photos.zillowstatic.com/fp/f42d9a19a27...  66718658
#
#   zipcode  livingAreaValue zestimateLowPercent  isListedByOwner  \
# 0   33569             2079                   5            False
#
#   propertyTypeDimension         streetAddress county  \
# 0         Single Family  11622 Pure Pebble Dr   None
#
#                                           taxHistory  stateId  countyId  \
# 0  [{'time': 1590256690112, 'valueIncreaseRate': ...       14      3165
#
#            timeZone       homeType livingAreaUnits comingSoonOnMarketDate  \
# 0  America/New_York  SINGLE_FAMILY            sqft                   None
#
#    livingArea  bathrooms  annualHomeownersInsurance state  rentZestimate  \
# 0        2079          2                       2016    FL           2408
#
#   building brokerId  yearBuilt                brokerageName    dateSold  \
# 0     None     None       2003  Keller Williams Tampa Prop.  2018-01-22
#
#     price  pageViewCount                                        description  \
# 0  480000            490  This 4 bedroom/2 bath pool home with a great y...
#
#   homeStatus homeFacts   latitude  datePosted  bedrooms  \
# 0   FOR_SALE      None  27.856653  2022-05-20         4
#
#                                          nearbyHomes  monthlyHoaFee  \
# 0  [{'miniCardPhotos': [{'url': 'https://photos.z...             48
#
#                                         priceHistory  favoriteCount  \
# 0  [{'priceChangeRate': 1.0253164556962, 'date': ...             18
#
#                                              schools zestimateHighPercent  \
# 0  [{'link': 'https://www.greatschools.org/school...                    5
#
#       mlsid       city providerListingID country currency  \
# 0  T3374663  Riverview              None     USA      USD
#
#   contingentListingType  solarPotential.sunScore  solarPotential.solarFactor  \
# 0                  None                    90.74                        3.56
#
#    solarPotential.buildFactor  solarPotential.climateFactor  \
# 0                        76.8                          6.89
#
#    solarPotential.electricityFactor  resoFacts.hasAttachedProperty  \
# 0                               3.5                          False
#
#   resoFacts.frontageType resoFacts.poolFeatures     resoFacts.flooring  \
# 0                   None    [Gunite, In Ground]  [Ceramic Tile, Vinyl]
#
#   resoFacts.foundationDetails resoFacts.accessibilityFeatures  \
# 0                      [Slab]                            None
#
#    resoFacts.hasGarage  resoFacts.hasPetsAllowed resoFacts.bodyType  \
# 0                 True                      True               None
#
#   resoFacts.topography resoFacts.landLeaseExpirationDate  \
# 0                 None                              None
#
#    resoFacts.hasAdditionalParcels  resoFacts.waterViewYN  \
# 0                           False                  False
#
#                             resoFacts.atAGlanceFacts  \
# 0  [{'factLabel': 'Type', 'factValue': 'Single Fa...
#
#   resoFacts.offerReviewDate resoFacts.aboveGradeFinishedArea resoFacts.view  \
# 0                      None                             None         [Pool]
#
#   resoFacts.buyerAgencyCompensationType resoFacts.carportSpaces  \
# 0                                     %                    None
#
#   resoFacts.cityRegion resoFacts.mainLevelBathrooms  resoFacts.hasPrivatePool  \
# 0            Riverview                         None                      True
#
#   resoFacts.associationFeeIncludes resoFacts.waterSource  \
# 0                             None              [Public]
#
#           resoFacts.exteriorFeatures  resoFacts.coveredSpaces  \
# 0  [Fenced, Sidewalk, Sliding Doors]                        2
#
#   resoFacts.inclusions  resoFacts.hasFireplace resoFacts.zoningDescription  \
# 0                 None                   False                        None
#
#    resoFacts.garageSpaces resoFacts.sewer resoFacts.elevationUnits  \
# 0                       2  [Public Sewer]                     None
#
#   resoFacts.exclusions resoFacts.mainLevelBedrooms  \
# 0                 None                        None
#
#   resoFacts.numberOfUnitsVacant resoFacts.hasWaterfrontView resoFacts.listAOR  \
# 0                          None                        None              None
#
#   resoFacts.lotSize resoFacts.entryLevel resoFacts.irrigationWaterRightsAcres  \
# 0        6,534 sqft                 None                                 None
#
#   resoFacts.greenWaterConservation resoFacts.stories resoFacts.livingArea  \
# 0                             None              None           2,079 sqft
#
#   resoFacts.numberOfUnitsInCommunity resoFacts.listingTerms  \
# 0                               None                   None
#
#   resoFacts.otherStructures resoFacts.associationFee resoFacts.marketingType  \
# 0                      None           $145 quarterly                    None
#
#   resoFacts.greenIndoorAirQuality resoFacts.greenSustainability  \
# 0                            None                          None
#
#    resoFacts.hasHomeWarranty resoFacts.associationPhone  \
# 0                      False                       None
#
#   resoFacts.greenBuildingVerificationType resoFacts.elementarySchool  \
# 0                                    None                       None
#
#    resoFacts.bedrooms resoFacts.architecturalStyle resoFacts.listingId  \
# 0                   4                         None                None
#
#   resoFacts.structureType                       resoFacts.interiorFeatures  \
# 0                    None  [Living Room/Dining Room Combo, Open Floorplan]
#
#   resoFacts.horseAmenities resoFacts.electric resoFacts.developmentStatus  \
# 0                     None               None                        None
#
#   resoFacts.lotFeatures resoFacts.roofType resoFacts.waterSources  \
# 0                  None            Shingle                   None
#
#   resoFacts.constructionMaterials resoFacts.fireplaceFeatures  \
# 0                         [Block]                        None
#
#   resoFacts.doorFeatures                               resoFacts.appliances  \
# 0                   None  [Dishwasher, Disposal, Electric Water Heater, ...
#
#    resoFacts.daysOnZillow resoFacts.bathroomsPartial  resoFacts.bathroomsHalf  \
# 0                       3                       None                        0
#
#   resoFacts.depositsAndFees  resoFacts.canRaiseHorses resoFacts.buildingName  \
# 0                      None                     False                   None
#
#    resoFacts.hasAssociation resoFacts.petsMaxWeight resoFacts.commonWalls  \
# 0                      True                    None                  None
#
#    resoFacts.totalActualRent resoFacts.additionalParcelsDescription  \
# 0                          0                                   None
#
#   resoFacts.associationName resoFacts.allowedPets resoFacts.communityFeatures  \
# 0                      None                  None                        None
#
#   resoFacts.tenantPays resoFacts.middleOrJuniorSchool  \
# 0                 None                           None
#
#   resoFacts.lotSizeDimensions resoFacts.roadSurfaceType  \
# 0                    55 x 118                   [Paved]
#
#    resoFacts.hasOpenParking  resoFacts.yearBuilt  \
# 0                      True                 2003
#
#   resoFacts.livingAreaRangeUnits resoFacts.irrigationWaterRightsYN  \
# 0                           None                              None
#
#    resoFacts.bathroomsFull resoFacts.horseYN resoFacts.incomeIncludes  \
# 0                        2              None                     None
#
#   resoFacts.highSchool resoFacts.leaseTerm resoFacts.elevation  \
# 0                 None          No Minimum                None
#
#   resoFacts.cropsIncludedYN  \
# 0                      None
#
#                                      resoFacts.attic  \
# 0  Living Room/Dining Room Combo, Master Bedroom ...
#
#   resoFacts.subdivisionName resoFacts.windowFeatures resoFacts.ownership  \
# 0      Boyette Farms Ph 2b1                 [Blinds]          Fee Simple
#
#   resoFacts.woodedArea resoFacts.middleOrJuniorSchoolDistrict  \
# 0                 None                                   None
#
#   resoFacts.associationPhone2 resoFacts.buyerAgencyCompensation  \
# 0                        None                           3%-$295
#
#   resoFacts.heating resoFacts.frontageLength  \
# 0         [Central]                     None
#
#                    resoFacts.virtualTourURLUnbranded  \
# 0  https://www.propertypanorama.com/instaview/ste...
#
#   resoFacts.associationAmenities  resoFacts.propertySubType  \
# 0                           None  [Single Family Residence]
#
#    resoFacts.hasCooling resoFacts.belowGradeFinishedArea  \
# 0                  True                             None
#
#    resoFacts.hasElectricOnProperty resoFacts.foundationArea resoFacts.zoning  \
# 0                             True                     None               PD
#
#   resoFacts.hoaFee resoFacts.livingAreaRange  resoFacts.basementYN  \
# 0   $145 quarterly                      None                 False
#
#   resoFacts.availabilityDate resoFacts.waterBodyName  \
# 0                       None                    None
#
#   resoFacts.waterfrontFeatures resoFacts.specialListingConditions  \
# 0                         None                               None
#
#   resoFacts.buildingAreaSource  resoFacts.taxAnnualAmount  resoFacts.parking  \
# 0                         None                       3768                  2
#
#    resoFacts.hasView                              resoFacts.virtualTour  \
# 0               True  https://www.propertypanorama.com/instaview/ste...
#
#   resoFacts.securityFeatures resoFacts.cooling resoFacts.entryLocation  \
# 0                       None     [Central Air]                    None
#
#   resoFacts.levels resoFacts.ownershipType resoFacts.basement  \
# 0              One                    None               None
#
#    resoFacts.onMarketDate resoFacts.waterView resoFacts.laundryFeatures  \
# 0           1653004800000                None            [Laundry Room]
#
#    resoFacts.hasAttachedGarage resoFacts.fencing resoFacts.spaFeatures  \
# 0                         True              Wood                  None
#
#    resoFacts.bathrooms resoFacts.homeType resoFacts.isSeniorCommunity  \
# 0                    2       SingleFamily                        None
#
#   resoFacts.municipality resoFacts.bathroomsThreeQuarter  resoFacts.hasSpa  \
# 0                   None                            None             False
#
#   resoFacts.otherParking resoFacts.associationFee2   resoFacts.parcelNumber  \
# 0                   None                      None  U2130205XM00000600024.0
#
#    resoFacts.hasHeating resoFacts.associationName2 resoFacts.hasRentControl  \
# 0                  True                       None                     None
#
#   resoFacts.elementarySchoolDistrict resoFacts.otherEquipment  \
# 0                               None                     None
#
#   resoFacts.parkingFeatures resoFacts.buildingArea  resoFacts.furnished  \
# 0      [Garage Door Opener]                  2,758                False
#
#   resoFacts.vegetation resoFacts.patioAndPorchFeatures  \
# 0                 None                            None
#
#   resoFacts.buildingFeatures resoFacts.builderName  \
# 0                       None                  None
#
#   resoFacts.highSchoolDistrict resoFacts.propertyCondition  \
# 0                         None                        None
#
#    resoFacts.storiesTotal resoFacts.yearBuiltEffective resoFacts.fireplaces  \
# 0                       1                         None                 None
#
#   resoFacts.bathroomsOneQuarter resoFacts.builderModel resoFacts.gas  \
# 0                          None                   None          None
#
#                                 resoFacts.utilities  \
# 0  [Cable Connected, Electricity Connected, Public]
#
#   resoFacts.greenEnergyEfficient resoFacts.landLeaseAmount  \
# 0                           None                      None
#
#    resoFacts.isNewConstruction  resoFacts.hasLandLease  \
# 0                        False                   False
#
#    resoFacts.pricePerSquareFoot  resoFacts.hasCarport  \
# 0                           231                 False
#
#   resoFacts.openParkingSpaces  mortgageRates.arm5Rate  \
# 0                        None                   4.452
#
#    mortgageRates.fifteenYearFixedRate  mortgageRates.thirtyYearFixedRate  \
# 0                               4.021                              4.882
#
#   address.city address.neighborhood address.state address.streetAddress  \
# 0    Riverview                 None            FL  11622 Pure Pebble Dr
#
#   address.zipcode  listed_by.agent_reason  listed_by.zpro  \
# 0           33569                       3            True
#
#    listed_by.recent_sales  listed_by.review_count listed_by.display_name  \
# 0                       0                       8       Melissa De Maria
#
#   listed_by.badge_type      listed_by.business_name  listed_by.rating_average  \
# 0        Listing Agent  Keller Williams Tampa Prop.                         5
#
#   listed_by.phone.prefix listed_by.phone.areacode listed_by.phone.number  \
# 0                    390                      813                   8675
#
#             listed_by.zuid                                listed_by.image_url
# 0  X1-ZUyb6yrkeebkzt_64j9u  https://photos.zillowstatic.com/h_n/ISnygmm26i...

# %%
# retrieve property detail elements
bedrooms = df_property_detail['bedrooms'].iloc[0]
bathrooms = df_property_detail['bathrooms'].iloc[0]
year_built = df_property_detail['yearBuilt'].iloc[0]
property_type = df_property_detail['homeType'].iloc[0]
living_area = df_property_detail['resoFacts.livingArea'].iloc[0]
lot_size = df_property_detail['resoFacts.lotSize'].iloc[0]
lot_dimensions = df_property_detail['resoFacts.lotSizeDimensions'].iloc[0]
zoning = df_property_detail['resoFacts.zoning'].iloc[0]
# estimates
zestimate = df_property_detail['zestimate'].iloc[0]
rent_zestimate = df_property_detail['rentZestimate'].iloc[0]

print('PROPERTY DETAILS FOR: ', property_address)
print('------------------------------------------------------------------')
print('  Bedrooms: {}'.format( bedrooms))
print('  Bathrooms: {}'.format( bathrooms))
print('  Year Built: {}'.format( year_built))
print('  Living Area: {}'.format( living_area))
print('  Lot Size: {}'.format( lot_size))
print('  Lot Dimensions: {}'.format( lot_dimensions))
print('  Zoning: {}'.format( zoning))
print('  Property Type: {}'.format( property_type))
print('  Zestimate: ${:,.0f}'.format( zestimate))
print('  Rent Zestimate: ${:,.0f}'.format( rent_zestimate))
# Out:
# PROPERTY DETAILS FOR:  11622 Pure Pebble Dr, RIVERVIEW, FL 33569
# ------------------------------------------------------------------
#   Bedrooms: 4
#   Bathrooms: 2
#   Year Built: 2003
#   Living Area: 2,079 sqft
#   Lot Size: 6,534 sqft
#   Lot Dimensions: 55 x 118
#   Zoning: PD
#   Property Type: SINGLE_FAMILY
#   Zestimate: $443,600
#   Rent Zestimate: $2,408

# %%
# download file
df_property_detail.to_csv('output.csv', index=False)
files.download('output.csv')

# %% [markdown]
# ### 2) List of Properties
# *   Upload csv file
#   * Check out [PropStream](https://trial.propstreampro.com/analyticsariel/) for on and off-market deals
# *   Get ZPID *(unique identifier for each property stored in the URL)*
# *   Get Property Details Data

# %%
# upload document
# Ariel's example - PropStream Woodbridge Tax Liens (sample of 5 properties)
uploaded = files.upload()
# Out:
#      <input type="file" id="files-edc48521-9bc5-441d-9829-9462ec1de000" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-edc48521-9bc5-441d-9829-9462ec1de000">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 202205 - Woodbridge Tax Liens Property Export All+Saved+Properties.csv to 202205 - Woodbridge Tax Liens Property Export All+Saved+Properties.csv

# %%
# get file name
file_name = list(uploaded.keys())[0]

# read file
df_upload = pd.read_csv(io.BytesIO(uploaded[file_name]))
print('Num of rows:', len(df_upload))
df_upload.head()
# Out:
# Num of rows: 5
#              Address  Unit #        City State   Zip     County  \
# 0      43 Martin Ter     NaN  Woodbridge    NJ  7095  Middlesex
# 1     704 Cricket Ln     NaN  Woodbridge    NJ  7095  Middlesex
# 2   258 Columbus Ave     NaN  Woodbridge    NJ  7095  Middlesex
# 3     164 Freeman St     NaN  Woodbridge    NJ  7095  Middlesex
# 4  615 Ridgewood Ave     NaN  Woodbridge    NJ  7095  Middlesex
#
#                                APN Owner Occupied Owner 1 First Name  \
# 0        25  00552- 102-00004-  01            Yes              Kevin
# 1  25  00252-0000-00100-0000-C0704            Yes               Mary
# 2        25  00263-  03-00015-  02             No            Eliezer
# 3        25  00570-0000-00013-  02            Yes              Bruce
# 4        25  00566-  03-00013-  04             No            Shirley
#
#   Owner 1 Last Name Owner 2 First Name Owner 2 Last Name  \
# 0            Monroe               Doug       Wynn-Monroe
# 1           Mcguinn                NaN               NaN
# 2         Placencia                NaN               NaN
# 3           Laraque                NaN               NaN
# 4          Gonzalez                NaN               NaN
#
#               Mailing Care of Name      Mailing Address  Mailing Unit #  \
# 0  Kevin Monroe & Doug Wynn-Monroe        43 Martin Ter             NaN
# 1                     Mary Mcguinn       704 Cricket Ln             NaN
# 2                Eliezer Placencia        438 Alpine St             NaN
# 3                    Bruce Laraque       164 Freeman St             NaN
# 4                 Shirley Gonzalez  301 Saint Marks Ave             NaN
#
#   Mailing City Mailing State  Mailing Zip  Mailing County  Do Not Mail  \
# 0   Woodbridge            NJ         7095             NaN          NaN
# 1   Woodbridge            NJ         7095             NaN          NaN
# 2  Perth Amboy            NJ         8861             NaN          NaN
# 3   Woodbridge            NJ         7095             NaN          NaN
# 4   Piscataway            NJ         8854             NaN          NaN
#
#                Property Type  Bedrooms  Total Bathrooms  Building Sqft  \
# 0  Single Family Residential         2                2          896.0
# 1  Condominium (Residential)         1                1            NaN
# 2  Single Family Residential         4                3          694.0
# 3  Single Family Residential         3                2         1432.0
# 4  Single Family Residential         3                2         1512.0
#
#    Lot Size Sqft  Effective Year Built  Total Assessed Value  \
# 0            NaN                  1931                 49400
# 1          463.0                  1981                 35000
# 2            NaN                  1935                 48100
# 3            NaN                  1916                 67300
# 4            NaN                  1958                 76100
#
#   Last Sale Recording Date  Last Sale Amount  Total Open Loans  \
# 0                 10/18/19            245000                 1
# 1                  9/22/00             67500                 2
# 2                 10/29/18            117000                 0
# 3                  10/4/05             80000                 1
# 4                  9/21/05            272000                 1
#
#    Est. Remaining balance of Open Loans  Est. Value  Est. Loan-to-Value  \
# 0                                234487      321626              72.907
# 1                                 37118      219756              16.891
# 2                                     0      312359               0.000
# 3                                169014      276184              61.196
# 4                                166658      438303              38.023
#
#    Est. Equity MLS Status  MLS Date  MLS Amount  Lien Amount  Marketing Lists  \
# 0        87139    REMOVED    2/5/21      245000       534.70                1
# 1       182638    REMOVED  10/28/21        1650     19010.24                1
# 2       312359    REMOVED    3/2/22      549999      3529.41                1
# 3       107170     ACTIVE    3/6/22      335000       267.35                1
# 4       271645    REMOVED   3/12/22      350000       385.43                1
#
#   Date Added to List Method of Add
# 0            3/30/22        Manual
# 1            3/30/22        Manual
# 2            3/30/22        Manual
# 3            3/30/22        Manual
# 4            3/30/22        Manual

# %%
# create empty list to store api response for property details
df_list = []
zpid_list = []

# iterate through dataframe
for index, row in df_upload.iterrows():
  # get property address attributes by column name
  street = row['Address']
  city = row['City']
  state = row['State']
  zip_code = "0" + str(row['Zip']) # fix issue with zip code

  # get zpid
  zpid = get_zpid(street=street, city=city, state=state, zip_code=zip_code)
  zpid_list.append(zpid)

  # wait 1 second to not overload Google Search
  time.sleep(1.5)

  # get property details
  # catch errors (possibly no zpid)
  try:
    response = get_property_detail(rapid_api_key, zpid)
    _df = pd.json_normalize(data=response.json())
    # append data to list of property details
    df_list.append(_df)
  except:
    print('Unable to retrieve data for : {0}, {1}, {2}, {3}'.format(street, city, state, zip_code))

# %%
# join property details data
df_prop_detail = pd.concat(df_list)
df_prop_detail.head()
# Out:
#   buildingPermits  propertyTaxRate  \
# 0            None             2.11
# 0            None             2.11
# 0            None             2.11
# 0            None             2.11
# 0            None             2.11
#
#                                   contact_recipients  longitude countyFIPS  \
# 0  [{'agent_reason': 1, 'zpro': None, 'recent_sal... -74.276540      34023
# 0  [{'agent_reason': 1, 'zpro': None, 'recent_sal... -74.285095      34023
# 0  [{'agent_reason': 1, 'zpro': None, 'recent_sal... -74.281750      34023
# 0  [{'agent_reason': 1, 'zpro': None, 'recent_sal... -74.281555      34023
# 0  [{'agent_reason': 1, 'zpro': None, 'recent_sal... -74.275190      34023
#
#    cityId timeOnZillow                                                url  \
# 0  826200     948 days  /homedetails/43-Martin-Ter-Woodbridge-NJ-07095...
# 0  826200      52 days  /homedetails/704-Cricket-Ln-Woodbridge-NJ-0709...
# 0  826200    1302 days  /homedetails/258-Columbus-Ave-Woodbridge-NJ-07...
# 0  826200      25 days  /homedetails/164-Freeman-St-Woodbridge-NJ-0709...
# 0  826200      40 days  /homedetails/615-Ridgewood-Ave-Woodbridge-NJ-0...
#
#    zestimate                                             imgSrc      zpid  \
# 0     331300  https://photos.zillowstatic.com/fp/c69f1a2113e...  39206632
# 0     204400  https://photos.zillowstatic.com/fp/e6dad479960...  39192163
# 0     560200  https://photos.zillowstatic.com/fp/daaccaefaaa...  39192601
# 0     404800  https://photos.zillowstatic.com/fp/2e466e729c4...  39207346
# 0     379500  https://photos.zillowstatic.com/fp/e9c57e94340...  39207264
#
#   zipcode livingAreaValue zestimateLowPercent  isListedByOwner  \
# 0   07095             896                   6            False
# 0   07095            None                   9            False
# 0   07095             694                   5            False
# 0   07095            1432                  10            False
# 0   07095            1512                   8            False
#
#   propertyTypeDimension      streetAddress county  \
# 0         Single Family      43 Martin Ter   None
# 0                 Condo     704 Cricket Ln   None
# 0         Single Family   258 Columbus Ave   None
# 0         Single Family     164 Freeman St   None
# 0          Multi Family  615 Ridgewood Ave   None
#
#                                           taxHistory  stateId  countyId  \
# 0  [{'time': 1621793915104, 'valueIncreaseRate': ...       40      2802
# 0  [{'time': 1621793917819, 'valueIncreaseRate': ...       40      2802
# 0  [{'time': 1621793920619, 'valueIncreaseRate': ...       40      2802
# 0  [{'time': 1621793923434, 'valueIncreaseRate': ...       40      2802
# 0  [{'time': 1621793926227, 'valueIncreaseRate': ...       40      2802
#
#            timeZone       homeType livingAreaUnits comingSoonOnMarketDate  \
# 0  America/New_York  SINGLE_FAMILY            sqft                   None
# 0  America/New_York          CONDO            None                   None
# 0  America/New_York  SINGLE_FAMILY            sqft                   None
# 0  America/New_York  SINGLE_FAMILY            sqft                   None
# 0  America/New_York   MULTI_FAMILY            sqft                   None
#
#   livingArea  bathrooms  annualHomeownersInsurance state  rentZestimate  \
# 0        896          2                       1029    NJ           2250
# 0       None          1                        575    NJ           1544
# 0        694          1                       2353    NJ           1855
# 0       1432          2                       1407    NJ           2600
# 0       1512          2                       1575    NJ           2598
#
#   building brokerId  yearBuilt               brokerageName    dateSold  \
# 0     None     None       1931                        None  2019-10-18
# 0     None     None       1981                        None  2022-04-01
# 0     None     None       1935                        None  2018-10-29
# 0     None     None       1916      RE/MAX FIRST REALTY II  2005-10-04
# 0     None     None       1958  BHHS NEW JERSEY PROPERTIES  2022-04-13
#
#     price  pageViewCount                                        description  \
# 0  245000              4  Commuters delight! Close to NYC transportation...
# 0  137000              5  Beautiful 1 br 1 bath in the desirable Wyndmoo...
# 0  560200             40  THIS 2 BEDROOM HOME IS IN NEED OF SOME TLC AND...
# 0  335000           2888  Easy to Show...Lovely 3 Bedroom, 2 Full Bath C...
# 0  375000             49  Location Location Location!! This multi family...
#
#       homeStatus homeFacts   latitude  datePosted  bedrooms  \
# 0           SOLD      None  40.560593                     2
# 0  RECENTLY_SOLD      None  40.544094                     1
# 0          OTHER      None  40.548843                     2
# 0       FOR_SALE      None  40.563320  2022-04-28         3
# 0  RECENTLY_SOLD      None  40.562374  2022-04-13         3
#
#                                          nearbyHomes monthlyHoaFee  \
# 0  [{'miniCardPhotos': [{'url': 'https://maps.goo...          None
# 0  [{'miniCardPhotos': [{'url': 'https://maps.goo...          None
# 0  [{'miniCardPhotos': [{'url': 'https://photos.z...          None
# 0  [{'miniCardPhotos': [{'url': 'https://maps.goo...          None
# 0  [{'miniCardPhotos': [{'url': 'https://maps.goo...          None
#
#                                         priceHistory  favoriteCount  \
# 0  [{'priceChangeRate': 0, 'date': '2019-10-18', ...              0
# 0  [{'priceChangeRate': 0.15367449537267, 'date':...              0
# 0  [{'priceChangeRate': 0, 'date': '2022-02-28', ...              0
# 0  [{'priceChangeRate': 0.20071684587814, 'date':...            103
# 0  [{'priceChangeRate': 0.071428571428571, 'date'...              1
#
#                                              schools zestimateHighPercent  \
# 0  [{'link': 'https://www.greatschools.org/school...                    6
# 0  [{'link': 'https://www.greatschools.org/school...                    9
# 0  [{'link': 'https://www.greatschools.org/school...                    5
# 0  [{'link': 'https://www.greatschools.org/school...                   10
# 0  [{'link': 'https://www.greatschools.org/school...                    8
#
#       mlsid        city providerListingID country currency  \
# 0      None  Woodbridge              None     USA      USD
# 0      None  Woodbridge              None     USA      USD
# 0      None  Woodbridge              None     USA      USD
# 0  2210505R  Woodbridge              None     USA      USD
# 0  2209161R  Woodbridge              None     USA      USD
#
#   contingentListingType listingProvider.enhancedVideoURL  \
# 0                  None                             None
# 0                  None                             None
# 0                  None                             None
# 0                  None                              NaN
# 0                  None                              NaN
#
#   listingProvider.showNoContactInfoMessage listingProvider.postingGroupName  \
# 0                                    False                             None
# 0                                    False                             None
# 0                                    False                             None
# 0                                      NaN                              NaN
# 0                                      NaN                              NaN
#
#   listingProvider.isZRMSourceText listingProvider.showLogos  \
# 0                            None                      None
# 0                            None                      None
# 0                            None                      None
# 0                             NaN                       NaN
# 0                             NaN                       NaN
#
#   listingProvider.disclaimerText listingProvider.sourceText  \
# 0                           None                       None
# 0                           None                       None
# 0                           None                       None
# 0                            NaN                        NaN
# 0                            NaN                        NaN
#
#   listingProvider.title listingProvider.postingWebsiteURL  \
# 0   Listing Provided by                              None
# 0   Listing Provided by                              None
# 0   Listing Provided by                              None
# 0                   NaN                               NaN
# 0                   NaN                               NaN
#
#   listingProvider.agentLicenseNumber listingProvider.postingWebsiteLinkText  \
# 0                               None                    See listing website
# 0                               None                    See listing website
# 0                               None                    See listing website
# 0                                NaN                                    NaN
# 0                                NaN                                    NaN
#
#   listingProvider.enhancedDescriptionText listingProvider.agentName  \
# 0                                    None                      None
# 0                                    None                      None
# 0                                    None                      None
# 0                                     NaN                       NaN
# 0                                     NaN                       NaN
#
#    solarPotential.sunScore  solarPotential.solarFactor  \
# 0                    91.61                         1.8
# 0                    79.61                         1.8
# 0                    79.61                         1.8
# 0                    91.61                         1.8
# 0                    82.01                         1.8
#
#    solarPotential.buildFactor  solarPotential.climateFactor  \
# 0                        80.0                          6.24
# 0                        68.0                          6.24
# 0                        68.0                          6.24
# 0                        80.0                          6.24
# 0                        70.4                          6.24
#
#    solarPotential.electricityFactor  resoFacts.hasAttachedProperty  \
# 0                              3.57                          False
# 0                              3.57                          False
# 0                              3.57                          False
# 0                              3.57                          False
# 0                              3.57                          False
#
#   resoFacts.frontageType resoFacts.poolFeatures        resoFacts.flooring  \
# 0                   None                   None  [Tile, Carpet, Hardwood]
# 0                   None                   None                       NaN
# 0                   None                   None                [Hardwood]
# 0                   None                   None                    [Wood]
# 0                   None                   None                      None
#
#   resoFacts.accessibilityFeatures  resoFacts.hasGarage  \
# 0                            None                False
# 0                            None                False
# 0                            None                False
# 0                            None                False
# 0                            None                False
#
#   resoFacts.hasPetsAllowed resoFacts.bodyType resoFacts.topography  \
# 0                     None               None                 None
# 0                     None               None                 None
# 0                     None               None                 None
# 0                     None               None                 None
# 0                     None               None                 None
#
#   resoFacts.landLeaseExpirationDate  resoFacts.hasAdditionalParcels  \
# 0                              None                           False
# 0                              None                           False
# 0                              None                           False
# 0                              None                           False
# 0                              None                           False
#
#   resoFacts.waterViewYN                           resoFacts.atAGlanceFacts  \
# 0                  None  [{'factLabel': 'Type', 'factValue': '1/2 Duple...
# 0                  None  [{'factLabel': 'Type', 'factValue': 'Condo'}, ...
# 0                  None  [{'factLabel': 'Type', 'factValue': 'SingleFam...
# 0                  None  [{'factLabel': 'Type', 'factValue': 'Single Fa...
# 0                  None  [{'factLabel': 'Type', 'factValue': 'Multi Fam...
#
#   resoFacts.offerReviewDate resoFacts.aboveGradeFinishedArea  \
# 0                      None                             None
# 0                      None                             None
# 0                      None                             None
# 0                      None                             None
# 0                      None                             None
#
#   resoFacts.buyerAgencyCompensationType  \
# 0                                  None
# 0                                  None
# 0                                  None
# 0                                  None
# 0                                  None
#
#                                      resoFacts.rooms resoFacts.carportSpaces  \
# 0  [{'level': None, 'dimensions': None, 'features...                    None
# 0                                                NaN                    None
# 0                                                NaN                    None
# 0  [{'level': None, 'dimensions': None, 'features...                       0
# 0                                                NaN                       0
#
#   resoFacts.cityRegion resoFacts.mainLevelBathrooms resoFacts.hasPrivatePool  \
# 0           Woodbridge                         None                    False
# 0           Woodbridge                         None                     None
# 0           Woodbridge                         None                     None
# 0           Woodbridge                         None                     None
# 0           Woodbridge                         None                     None
#
#   resoFacts.associationFeeIncludes resoFacts.waterSource  \
# 0                             None              [Public]
# 0                             None                  None
# 0                             None                  None
# 0                             None              [Public]
# 0                             None              [Public]
#
#   resoFacts.exteriorFeatures resoFacts.coveredSpaces resoFacts.inclusions  \
# 0             [Other, Vinyl]                       0                 None
# 0                        NaN                    None                 None
# 0                    [Vinyl]                    None                 None
# 0                     [Yard]                       0                 None
# 0                     [Yard]                       0                 None
#
#   resoFacts.hasFireplace resoFacts.zoningDescription resoFacts.garageSpaces  \
# 0                  False                         R-6                   None
# 0                   None                        None                   None
# 0                   None                        None                   None
# 0                   True                        None                      0
# 0                   None                        None                      0
#
#   resoFacts.sewer resoFacts.elevationUnits resoFacts.exclusions  \
# 0  [Public Sewer]                     None                 None
# 0            None                     None                 None
# 0            None                     None                 None
# 0  [Public Sewer]                     None                 None
# 0  [Public Sewer]                     None                 None
#
#   resoFacts.mainLevelBedrooms resoFacts.numberOfUnitsVacant  \
# 0                        None                          None
# 0                        None                          None
# 0                        None                          None
# 0                        None                          None
# 0                        None                          None
#
#   resoFacts.hasWaterfrontView resoFacts.listAOR resoFacts.lotSize  \
# 0                        None              None        2,500 sqft
# 0                        None              None              None
# 0                        None              None        3,998 sqft
# 0                        None              None        9,226 sqft
# 0                        None              None        7,200 sqft
#
#   resoFacts.entryLevel resoFacts.irrigationWaterRightsAcres  \
# 0                 None                                 None
# 0                 None                                 None
# 0                 None                                 None
# 0                 None                                 None
# 0                 None                                 None
#
#   resoFacts.greenWaterConservation resoFacts.stories resoFacts.livingArea  \
# 0                             None              None             896 sqft
# 0                             None              None                 None
# 0                             None              None             694 sqft
# 0                             None                 2           1,432 sqft
# 0                             None                 2           1,512 sqft
#
#   resoFacts.numberOfUnitsInCommunity resoFacts.listingTerms  \
# 0                               None                   None
# 0                               None                   None
# 0                               None                   None
# 0                               None                   None
# 0                               None                   None
#
#   resoFacts.otherStructures resoFacts.associationFee resoFacts.marketingType  \
# 0                 [Shed(s)]                     None                    None
# 0                      None                     None                    None
# 0                      None                     None                    None
# 0                      None                     None                    None
# 0                 [Shed(s)]                     None                    None
#
#   resoFacts.greenIndoorAirQuality resoFacts.greenSustainability  \
# 0                            None                          None
# 0                            None                          None
# 0                            None                          None
# 0                            None                          None
# 0                            None                          None
#
#    resoFacts.hasHomeWarranty resoFacts.associationPhone  \
# 0                      False                       None
# 0                      False                       None
# 0                      False                       None
# 0                      False                       None
# 0                      False                       None
#
#   resoFacts.greenBuildingVerificationType resoFacts.elementarySchool  \
# 0                                    None                       None
# 0                                    None                       None
# 0                                    None                       None
# 0                                    None                       None
# 0                                    None                       None
#
#    resoFacts.bedrooms resoFacts.architecturalStyle resoFacts.listingId  \
# 0                   2                     Colonial                None
# 0                   1                         None                None
# 0                   2                         None                None
# 0                   3                     Colonial                None
# 0                   3                         None                None
#
#   resoFacts.structureType                         resoFacts.interiorFeatures  \
# 0                Colonial                                               None
# 0                    None                                               None
# 0                Cape Cod                                               None
# 0                    None  [Entrance Foyer, Kitchen, Living Room, Other R...
# 0                    None  [Unit 1(1 Bedroom, 1 Bath), Unit 2(2 Bedrooms,...
#
#   resoFacts.horseAmenities resoFacts.electric resoFacts.developmentStatus  \
# 0                     None               None                        None
# 0                     None               None                        None
# 0                     None               None                        None
# 0                     None               None                        None
# 0                     None               None                        None
#
#                               resoFacts.lotFeatures resoFacts.roofType  \
# 0      [Sidewalk, Near Shopping, Near Train, Curbs]            Asphalt
# 0                                              None               None
# 0                                              None            Asphalt
# 0  [Near Shopping, Near Train, Near Public Transit]        See Remarks
# 0                [Near Shopping, Near Train, Level]            Asphalt
#
#   resoFacts.waterSources resoFacts.fireplaceFeatures resoFacts.doorFeatures  \
# 0                   None                        None                   None
# 0                   None                        None                   None
# 0                   None                        None                   None
# 0                   None              [Wood Burning]                   None
# 0                   None                        None                   None
#
#                                 resoFacts.appliances  resoFacts.daysOnZillow  \
# 0          [Dishwasher, Dryer, Refrigerator, Washer]                     948
# 0                                                NaN                      52
# 0                                                NaN                    1302
# 0  [Dishwasher, Dryer, Gas Range/Oven, Microwave,...                      25
# 0  [Water Heater(Gas), Water Heater, Unit 2(Range...                      40
#
#   resoFacts.bathroomsPartial  resoFacts.bathroomsHalf  \
# 0                       None                        0
# 0                       None                        0
# 0                       None                        0
# 0                       None                        0
# 0                       None                        0
#
#   resoFacts.depositsAndFees  resoFacts.canRaiseHorses resoFacts.buildingName  \
# 0                      None                     False                   None
# 0                      None                     False                   None
# 0                      None                     False                   None
# 0                      None                     False                   None
# 0                      None                     False                   None
#
#   resoFacts.hasAssociation resoFacts.petsMaxWeight resoFacts.commonWalls  \
# 0                     None                    None                  None
# 0                     True                    None                  None
# 0                     None                    None                  None
# 0                     None                    None                  None
# 0                     None                    None                  None
#
#   resoFacts.totalActualRent resoFacts.additionalParcelsDescription  \
# 0                      None                                   None
# 0                      None                                   None
# 0                      None                                   None
# 0                      None                                   None
# 0                      None                                   None
#
#   resoFacts.associationName resoFacts.allowedPets resoFacts.tenantPays  \
# 0                      None                  None                 None
# 0                      None                  None                 None
# 0                      None                  None                 None
# 0                      None                  None                 None
# 0                      None                  None                 None
#
#   resoFacts.middleOrJuniorSchool resoFacts.lotSizeDimensions  \
# 0                           None                        None
# 0                           None                        None
# 0                           None                        None
# 0                           None              205.00 x 45.00
# 0                           None               96.00 x 75.00
#
#   resoFacts.roadSurfaceType resoFacts.hasOpenParking  resoFacts.yearBuilt  \
# 0                      None                     None                 1931
# 0                      None                     None                 1981
# 0                      None                     None                 1935
# 0                      None                     True                 1916
# 0                      None                     None                 1958
#
#   resoFacts.livingAreaRangeUnits resoFacts.irrigationWaterRightsYN  \
# 0                           None                              None
# 0                           None                              None
# 0                           None                              None
# 0                           None                              None
# 0                           None                              None
#
#    resoFacts.bathroomsFull resoFacts.horseYN resoFacts.incomeIncludes  \
# 0                        2              None                     None
# 0                        0              None                     None
# 0                        1              None                     None
# 0                        2              None                     None
# 0                        0              None                     None
#
#   resoFacts.highSchool resoFacts.leaseTerm resoFacts.elevation  \
# 0                 None                None                None
# 0                 None                None                None
# 0                 None                None                None
# 0                 None                None                None
# 0                 None                None                None
#
#   resoFacts.cropsIncludedYN   resoFacts.attic resoFacts.subdivisionName  \
# 0                      None  Pull Down Stairs                      None
# 0                      None              None                      None
# 0                      None              None                      None
# 0                      None              None                      None
# 0                      None              None                      None
#
#   resoFacts.windowFeatures resoFacts.ownership resoFacts.woodedArea  \
# 0                     None                None                 None
# 0                     None                None                 None
# 0                     None                None                 None
# 0                     None          Fee Simple                 None
# 0                     None          Fee Simple                 None
#
#   resoFacts.middleOrJuniorSchoolDistrict resoFacts.associationPhone2  \
# 0                 Woodbridge Township SD                        None
# 0                                   None                        None
# 0                                   None                        None
# 0                                   None                        None
# 0                                   None                        None
#
#   resoFacts.buyerAgencyCompensation            resoFacts.heating  \
# 0                              None  [Forced air, Electric, Gas]
# 0                              None                          NaN
# 0                              None             [Baseboard, Gas]
# 0                              None        [Radiators-Hot Water]
# 0                              None            [Radiators-Steam]
#
#   resoFacts.frontageLength                  resoFacts.virtualTourURLUnbranded  \
# 0                     None                                               None
# 0                     None                                               None
# 0                     None                                               None
# 0                     None  https://www.propertypanorama.com/instaview/msx...
# 0                     None  https://www.propertypanorama.com/instaview/msx...
#
#   resoFacts.associationAmenities  resoFacts.propertySubType  \
# 0                           None               [1/2 Duplex]
# 0                           None                       None
# 0                           None                       None
# 0                           None  [Single Family Residence]
# 0                           None             [Multi Family]
#
#    resoFacts.hasCooling resoFacts.belowGradeFinishedArea  \
# 0                  True                             None
# 0                  True                             None
# 0                  True                             None
# 0                  True                             None
# 0                  True                             None
#
#   resoFacts.hasElectricOnProperty resoFacts.foundationArea resoFacts.zoning  \
# 0                            None                     None             None
# 0                            None                     None             None
# 0                            None                     None             None
# 0                            True                     None              R-6
# 0                            None                     None              R-6
#
#   resoFacts.hoaFee resoFacts.livingAreaRange  resoFacts.basementYN  \
# 0             None                      None                 False
# 0             None                      None                 False
# 0             None                      None                 False
# 0             None                      None                 False
# 0             None                      None                 False
#
#   resoFacts.availabilityDate resoFacts.waterBodyName  \
# 0              1565222400000                    None
# 0                       None                    None
# 0                       None                    None
# 0                       None                    None
# 0                       None                    None
#
#   resoFacts.waterfrontFeatures resoFacts.specialListingConditions  \
# 0                         None                               None
# 0                         None                               None
# 0                         None                               None
# 0                         None                               None
# 0                         None                               None
#
#   resoFacts.buildingAreaSource  resoFacts.taxAnnualAmount  resoFacts.parking  \
# 0                         None                       4356                  0
# 0                         None                       2910                  0
# 0                         None                       4242                  0
# 0                         None                       8256                  0
# 0                         None                       9336                  0
#
#    resoFacts.hasView                              resoFacts.virtualTour  \
# 0              False                                               None
# 0              False                                               None
# 0              False                                               None
# 0              False  https://www.propertypanorama.com/instaview/msx...
# 0              False  https://www.propertypanorama.com/instaview/msx...
#
#   resoFacts.securityFeatures     resoFacts.cooling resoFacts.entryLocation  \
# 0                       None             [Central]                    None
# 0                       None                [None]                    None
# 0                       None             [Central]                    None
# 0                       None      [Ceiling Fan(s)]                    None
# 0                       None  [A/C Window Unit(s)]                    None
#
#                                 resoFacts.otherFacts resoFacts.levels  \
# 0  [{'value': 'Wood, Carpet, Ceramic Tile', 'name...             None
# 0                                                NaN             None
# 0  [{'value': '1 Car Width, Dirt', 'name': 'Drive...             None
# 0                                                NaN              Two
# 0                                                NaN             None
#
#   resoFacts.ownershipType                                 resoFacts.basement  \
# 0                    None            Finished, Bath/Stubbed, Recreation Room
# 0                    None                                               None
# 0                    None                                               None
# 0                    None  Partially Finished, Full, Bath Full, Recreatio...
# 0                    None                                               None
#
#   resoFacts.onMarketDate resoFacts.waterView   resoFacts.laundryFeatures  \
# 0                   None                      [In Basement, Lower Level]
# 0                   None                                            None
# 0                   None                                            None
# 0          1646784000000                None                        None
# 0          1644624000000                None                        None
#
#   resoFacts.hasAttachedGarage resoFacts.fencing resoFacts.spaFeatures  \
# 0                        None            Fenced                  None
# 0                        None              None                  None
# 0                        None              None                  None
# 0                        None              None                  None
# 0                        None              None                  None
#
#    resoFacts.bathrooms resoFacts.homeType resoFacts.isSeniorCommunity  \
# 0                    2       SingleFamily                        None
# 0                    1              Condo                        None
# 0                    1       SingleFamily                        None
# 0                    2       SingleFamily                        None
# 0                    2        MultiFamily                        None
#
#   resoFacts.municipality resoFacts.bathroomsThreeQuarter  resoFacts.hasSpa  \
# 0                   None                               0             False
# 0                   None                               0             False
# 0                   None                               0             False
# 0                   None                            None             False
# 0                   None                            None             False
#
#   resoFacts.otherParking resoFacts.associationFee2     resoFacts.parcelNumber  \
# 0                   None                      None          25005521020000401
# 0                   None                      None  25002520000001000000C0704
# 0                   None                      None           2500263030001502
# 0                   None                      None         250057000000001302
# 0                   None                      None           2500566030001304
#
#    resoFacts.hasHeating resoFacts.associationName2 resoFacts.hasRentControl  \
# 0                  True                       None                     None
# 0                 False                       None                     None
# 0                  True                       None                     None
# 0                  True                       None                     None
# 0                  True                       None                     None
#
#   resoFacts.elementarySchoolDistrict resoFacts.otherEquipment  \
# 0             Woodbridge Township SD                     None
# 0                               None                     None
# 0                               None                     None
# 0                               None                     None
# 0                               None                     None
#
#   resoFacts.buildingArea  resoFacts.furnished resoFacts.vegetation  \
# 0                   None                False                 None
# 0                   None                False                 None
# 0                   None                False                 None
# 0                  1,432                False                 None
# 0                  1,512                False                 None
#
#   resoFacts.patioAndPorchFeatures resoFacts.buildingFeatures  \
# 0                   [Deck, Patio]                       None
# 0                            None                       None
# 0                            None                       None
# 0                [Deck, Enclosed]                       None
# 0                            None                       None
#
#   resoFacts.builderName resoFacts.highSchoolDistrict  \
# 0                  None       Woodbridge Township SD
# 0                  None                         None
# 0                  None                         None
# 0                  None                         None
# 0                  None                         None
#
#   resoFacts.propertyCondition resoFacts.storiesTotal  \
# 0                        None                      2
# 0                        None                   None
# 0                        None                   None
# 0                        None                      2
# 0                        None                      2
#
#   resoFacts.yearBuiltEffective resoFacts.fireplaces  \
# 0                         None                 None
# 0                         None                 None
# 0                         None                 None
# 0                         None                    1
# 0                         None                 None
#
#   resoFacts.bathroomsOneQuarter resoFacts.builderModel  resoFacts.gas  \
# 0                             0                   None  [Natural Gas]
# 0                             0                   None           None
# 0                             0                   None           None
# 0                          None                   None  [Natural Gas]
# 0                          None                   None  [Natural Gas]
#
#                               resoFacts.utilities  \
# 0  [Natural Gas Connected, Electricity Available]
# 0                                            None
# 0                                            None
# 0  [Electricity Connected, Natural Gas Connected]
# 0  [Underground Utilities, Natural Gas Connected]
#
#   resoFacts.greenEnergyEfficient resoFacts.landLeaseAmount  \
# 0                           None                      None
# 0                           None                      None
# 0                           None                      None
# 0                           None                      None
# 0                           None                      None
#
#   resoFacts.isNewConstruction  resoFacts.hasLandLease  \
# 0                        None                   False
# 0                        None                   False
# 0                        None                   False
# 0                        None                   False
# 0                        None                   False
#
#   resoFacts.pricePerSquareFoot resoFacts.hasCarport  \
# 0                          273                 None
# 0                         None                 None
# 0                          807                 None
# 0                          234                False
# 0                          248                False
#
#   resoFacts.openParkingSpaces  mortgageRates.arm5Rate  \
# 0                        None                   5.225
# 0                        None                   5.225
# 0                        None                   4.423
# 0                        None                   4.423
# 0                        None                   4.423
#
#    mortgageRates.fifteenYearFixedRate  mortgageRates.thirtyYearFixedRate  \
# 0                               4.622                              5.039
# 0                               4.622                              5.039
# 0                               4.036                              4.855
# 0                               4.036                              4.855
# 0                               4.036                              4.855
#
#   address.city address.neighborhood address.state address.streetAddress  \
# 0   Woodbridge                 None            NJ         43 Martin Ter
# 0   Woodbridge                 None            NJ        704 Cricket Ln
# 0   Woodbridge                 None            NJ      258 Columbus Ave
# 0   Woodbridge                 None            NJ        164 Freeman St
# 0   Woodbridge                 None            NJ     615 Ridgewood Ave
#
#   address.zipcode  listed_by.agent_reason  listed_by.zpro  \
# 0           07095                       3            True
# 0           07095                       3            True
# 0           07095                       3            True
# 0           07095                       3            True
# 0           07095                       3            True
#
#   listed_by.recent_sales listed_by.review_count listed_by.display_name  \
# 0                   None                   None                   None
# 0                   None                   None                   None
# 0                   None                   None                   None
# 0                      0                      0       Danielle Laraque
# 0                      0                      7         Teddy Gonzalez
#
#   listed_by.badge_type     listed_by.business_name listed_by.rating_average  \
# 0        Listing Agent                        None                     None
# 0        Listing Agent                        None                     None
# 0        Listing Agent                        None                     None
# 0        Listing Agent      RE/MAX FIRST REALTY II                        0
# 0        Listing Agent  BHHS NEW JERSEY PROPERTIES                        5
#
#   listed_by.phone           listed_by.zuid  \
# 0            None   X1-ZUz1ci99gqj409_uwi3
# 0            None   X1-ZUz1ci99gqj409_uwi3
# 0            None   X1-ZUz1ci99gqj409_uwi3
# 0             NaN  X1-ZUse8sd6fjuo7d_9skq8
# 0             NaN  X1-ZUzx3rcr7kbm6h_39zrd
#
#                                  listed_by.image_url  \
# 0  https://www.zillowstatic.com/static/images/nop...
# 0  https://www.zillowstatic.com/static/images/nop...
# 0  https://www.zillowstatic.com/static/images/nop...
# 0  https://photos.zillowstatic.com/h_n/ISrldaa8re...
# 0  https://photos.zillowstatic.com/h_n/ISfozrgsln...
#
#               resoFacts.parkingFeatures listingProvider  \
# 0                                   NaN             NaN
# 0                                [None]             NaN
# 0                   [Garage - Detached]             NaN
# 0  [1 Car Width, 2 Cars Deep, Driveway]            None
# 0                     [3-4 Car Parking]            None
#
#   resoFacts.communityFeatures listed_by.phone.prefix listed_by.phone.areacode  \
# 0                         NaN                    NaN                      NaN
# 0                         NaN                    NaN                      NaN
# 0                         NaN                    NaN                      NaN
# 0                        None                    359                      848
# 0                        None                    930                      908
#
#   listed_by.phone.number
# 0                    NaN
# 0                    NaN
# 0                    NaN
# 0                   5820
# 0                   2751

# %%
# join original dataset to property details
# create new column for zpid
df_upload['zpid'] = zpid_list

# confirm zpid is <str> type
df_upload['zpid'] = df_upload['zpid'].astype(str)
df_prop_detail['zpid'] = df_prop_detail['zpid'].astype(str)

# join on zpid
df_join = pd.merge(df_upload, df_prop_detail, how='left', on='zpid')
print('Num of columns:', len(df_join.columns))
df_join.head()
# Out:
# Num of columns: 313
#              Address  Unit #        City State   Zip     County  \
# 0      43 Martin Ter     NaN  Woodbridge    NJ  7095  Middlesex
# 1     704 Cricket Ln     NaN  Woodbridge    NJ  7095  Middlesex
# 2   258 Columbus Ave     NaN  Woodbridge    NJ  7095  Middlesex
# 3     164 Freeman St     NaN  Woodbridge    NJ  7095  Middlesex
# 4  615 Ridgewood Ave     NaN  Woodbridge    NJ  7095  Middlesex
#
#                                APN Owner Occupied Owner 1 First Name  \
# 0        25  00552- 102-00004-  01            Yes              Kevin
# 1  25  00252-0000-00100-0000-C0704            Yes               Mary
# 2        25  00263-  03-00015-  02             No            Eliezer
# 3        25  00570-0000-00013-  02            Yes              Bruce
# 4        25  00566-  03-00013-  04             No            Shirley
#
#   Owner 1 Last Name Owner 2 First Name Owner 2 Last Name  \
# 0            Monroe               Doug       Wynn-Monroe
# 1           Mcguinn                NaN               NaN
# 2         Placencia                NaN               NaN
# 3           Laraque                NaN               NaN
# 4          Gonzalez                NaN               NaN
#
#               Mailing Care of Name      Mailing Address  Mailing Unit #  \
# 0  Kevin Monroe & Doug Wynn-Monroe        43 Martin Ter             NaN
# 1                     Mary Mcguinn       704 Cricket Ln             NaN
# 2                Eliezer Placencia        438 Alpine St             NaN
# 3                    Bruce Laraque       164 Freeman St             NaN
# 4                 Shirley Gonzalez  301 Saint Marks Ave             NaN
#
#   Mailing City Mailing State  Mailing Zip  Mailing County  Do Not Mail  \
# 0   Woodbridge            NJ         7095             NaN          NaN
# 1   Woodbridge            NJ         7095             NaN          NaN
# 2  Perth Amboy            NJ         8861             NaN          NaN
# 3   Woodbridge            NJ         7095             NaN          NaN
# 4   Piscataway            NJ         8854             NaN          NaN
#
#                Property Type  Bedrooms  Total Bathrooms  Building Sqft  \
# 0  Single Family Residential         2                2          896.0
# 1  Condominium (Residential)         1                1            NaN
# 2  Single Family Residential         4                3          694.0
# 3  Single Family Residential         3                2         1432.0
# 4  Single Family Residential         3                2         1512.0
#
#    Lot Size Sqft  Effective Year Built  Total Assessed Value  \
# 0            NaN                  1931                 49400
# 1          463.0                  1981                 35000
# 2            NaN                  1935                 48100
# 3            NaN                  1916                 67300
# 4            NaN                  1958                 76100
#
#   Last Sale Recording Date  Last Sale Amount  Total Open Loans  \
# 0                 10/18/19            245000                 1
# 1                  9/22/00             67500                 2
# 2                 10/29/18            117000                 0
# 3                  10/4/05             80000                 1
# 4                  9/21/05            272000                 1
#
#    Est. Remaining balance of Open Loans  Est. Value  Est. Loan-to-Value  \
# 0                                234487      321626              72.907
# 1                                 37118      219756              16.891
# 2                                     0      312359               0.000
# 3                                169014      276184              61.196
# 4                                166658      438303              38.023
#
#    Est. Equity MLS Status  MLS Date  MLS Amount  Lien Amount  Marketing Lists  \
# 0        87139    REMOVED    2/5/21      245000       534.70                1
# 1       182638    REMOVED  10/28/21        1650     19010.24                1
# 2       312359    REMOVED    3/2/22      549999      3529.41                1
# 3       107170     ACTIVE    3/6/22      335000       267.35                1
# 4       271645    REMOVED   3/12/22      350000       385.43                1
#
#   Date Added to List Method of Add      zpid buildingPermits  propertyTaxRate  \
# 0            3/30/22        Manual  39206632            None             2.11
# 1            3/30/22        Manual  39192163            None             2.11
# 2            3/30/22        Manual  39192601            None             2.11
# 3            3/30/22        Manual  39207346            None             2.11
# 4            3/30/22        Manual  39207264            None             2.11
#
#                                   contact_recipients  longitude countyFIPS  \
# 0  [{'agent_reason': 1, 'zpro': None, 'recent_sal... -74.276540      34023
# 1  [{'agent_reason': 1, 'zpro': None, 'recent_sal... -74.285095      34023
# 2  [{'agent_reason': 1, 'zpro': None, 'recent_sal... -74.281750      34023
# 3  [{'agent_reason': 1, 'zpro': None, 'recent_sal... -74.281555      34023
# 4  [{'agent_reason': 1, 'zpro': None, 'recent_sal... -74.275190      34023
#
#    cityId timeOnZillow                                                url  \
# 0  826200     948 days  /homedetails/43-Martin-Ter-Woodbridge-NJ-07095...
# 1  826200      52 days  /homedetails/704-Cricket-Ln-Woodbridge-NJ-0709...
# 2  826200    1302 days  /homedetails/258-Columbus-Ave-Woodbridge-NJ-07...
# 3  826200      25 days  /homedetails/164-Freeman-St-Woodbridge-NJ-0709...
# 4  826200      40 days  /homedetails/615-Ridgewood-Ave-Woodbridge-NJ-0...
#
#    zestimate                                             imgSrc zipcode  \
# 0     331300  https://photos.zillowstatic.com/fp/c69f1a2113e...   07095
# 1     204400  https://photos.zillowstatic.com/fp/e6dad479960...   07095
# 2     560200  https://photos.zillowstatic.com/fp/daaccaefaaa...   07095
# 3     404800  https://photos.zillowstatic.com/fp/2e466e729c4...   07095
# 4     379500  https://photos.zillowstatic.com/fp/e9c57e94340...   07095
#
#   livingAreaValue zestimateLowPercent  isListedByOwner propertyTypeDimension  \
# 0             896                   6            False         Single Family
# 1            None                   9            False                 Condo
# 2             694                   5            False         Single Family
# 3            1432                  10            False         Single Family
# 4            1512                   8            False          Multi Family
#
#        streetAddress county  \
# 0      43 Martin Ter   None
# 1     704 Cricket Ln   None
# 2   258 Columbus Ave   None
# 3     164 Freeman St   None
# 4  615 Ridgewood Ave   None
#
#                                           taxHistory  stateId  countyId  \
# 0  [{'time': 1621793915104, 'valueIncreaseRate': ...       40      2802
# 1  [{'time': 1621793917819, 'valueIncreaseRate': ...       40      2802
# 2  [{'time': 1621793920619, 'valueIncreaseRate': ...       40      2802
# 3  [{'time': 1621793923434, 'valueIncreaseRate': ...       40      2802
# 4  [{'time': 1621793926227, 'valueIncreaseRate': ...       40      2802
#
#            timeZone       homeType livingAreaUnits comingSoonOnMarketDate  \
# 0  America/New_York  SINGLE_FAMILY            sqft                   None
# 1  America/New_York          CONDO            None                   None
# 2  America/New_York  SINGLE_FAMILY            sqft                   None
# 3  America/New_York  SINGLE_FAMILY            sqft                   None
# 4  America/New_York   MULTI_FAMILY            sqft                   None
#
#   livingArea  bathrooms  annualHomeownersInsurance state  rentZestimate  \
# 0        896          2                       1029    NJ           2250
# 1       None          1                        575    NJ           1544
# 2        694          1                       2353    NJ           1855
# 3       1432          2                       1407    NJ           2600
# 4       1512          2                       1575    NJ           2598
#
#   building brokerId  yearBuilt               brokerageName    dateSold  \
# 0     None     None       1931                        None  2019-10-18
# 1     None     None       1981                        None  2022-04-01
# 2     None     None       1935                        None  2018-10-29
# 3     None     None       1916      RE/MAX FIRST REALTY II  2005-10-04
# 4     None     None       1958  BHHS NEW JERSEY PROPERTIES  2022-04-13
#
#     price  pageViewCount                                        description  \
# 0  245000              4  Commuters delight! Close to NYC transportation...
# 1  137000              5  Beautiful 1 br 1 bath in the desirable Wyndmoo...
# 2  560200             40  THIS 2 BEDROOM HOME IS IN NEED OF SOME TLC AND...
# 3  335000           2888  Easy to Show...Lovely 3 Bedroom, 2 Full Bath C...
# 4  375000             49  Location Location Location!! This multi family...
#
#       homeStatus homeFacts   latitude  datePosted  bedrooms  \
# 0           SOLD      None  40.560593                     2
# 1  RECENTLY_SOLD      None  40.544094                     1
# 2          OTHER      None  40.548843                     2
# 3       FOR_SALE      None  40.563320  2022-04-28         3
# 4  RECENTLY_SOLD      None  40.562374  2022-04-13         3
#
#                                          nearbyHomes monthlyHoaFee  \
# 0  [{'miniCardPhotos': [{'url': 'https://maps.goo...          None
# 1  [{'miniCardPhotos': [{'url': 'https://maps.goo...          None
# 2  [{'miniCardPhotos': [{'url': 'https://photos.z...          None
# 3  [{'miniCardPhotos': [{'url': 'https://maps.goo...          None
# 4  [{'miniCardPhotos': [{'url': 'https://maps.goo...          None
#
#                                         priceHistory  favoriteCount  \
# 0  [{'priceChangeRate': 0, 'date': '2019-10-18', ...              0
# 1  [{'priceChangeRate': 0.15367449537267, 'date':...              0
# 2  [{'priceChangeRate': 0, 'date': '2022-02-28', ...              0
# 3  [{'priceChangeRate': 0.20071684587814, 'date':...            103
# 4  [{'priceChangeRate': 0.071428571428571, 'date'...              1
#
#                                              schools zestimateHighPercent  \
# 0  [{'link': 'https://www.greatschools.org/school...                    6
# 1  [{'link': 'https://www.greatschools.org/school...                    9
# 2  [{'link': 'https://www.greatschools.org/school...                    5
# 3  [{'link': 'https://www.greatschools.org/school...                   10
# 4  [{'link': 'https://www.greatschools.org/school...                    8
#
#       mlsid        city providerListingID country currency  \
# 0      None  Woodbridge              None     USA      USD
# 1      None  Woodbridge              None     USA      USD
# 2      None  Woodbridge              None     USA      USD
# 3  2210505R  Woodbridge              None     USA      USD
# 4  2209161R  Woodbridge              None     USA      USD
#
#   contingentListingType listingProvider.enhancedVideoURL  \
# 0                  None                             None
# 1                  None                             None
# 2                  None                             None
# 3                  None                              NaN
# 4                  None                              NaN
#
#   listingProvider.showNoContactInfoMessage listingProvider.postingGroupName  \
# 0                                    False                             None
# 1                                    False                             None
# 2                                    False                             None
# 3                                      NaN                              NaN
# 4                                      NaN                              NaN
#
#   listingProvider.isZRMSourceText listingProvider.showLogos  \
# 0                            None                      None
# 1                            None                      None
# 2                            None                      None
# 3                             NaN                       NaN
# 4                             NaN                       NaN
#
#   listingProvider.disclaimerText listingProvider.sourceText  \
# 0                           None                       None
# 1                           None                       None
# 2                           None                       None
# 3                            NaN                        NaN
# 4                            NaN                        NaN
#
#   listingProvider.title listingProvider.postingWebsiteURL  \
# 0   Listing Provided by                              None
# 1   Listing Provided by                              None
# 2   Listing Provided by                              None
# 3                   NaN                               NaN
# 4                   NaN                               NaN
#
#   listingProvider.agentLicenseNumber listingProvider.postingWebsiteLinkText  \
# 0                               None                    See listing website
# 1                               None                    See listing website
# 2                               None                    See listing website
# 3                                NaN                                    NaN
# 4                                NaN                                    NaN
#
#   listingProvider.enhancedDescriptionText listingProvider.agentName  \
# 0                                    None                      None
# 1                                    None                      None
# 2                                    None                      None
# 3                                     NaN                       NaN
# 4                                     NaN                       NaN
#
#    solarPotential.sunScore  solarPotential.solarFactor  \
# 0                    91.61                         1.8
# 1                    79.61                         1.8
# 2                    79.61                         1.8
# 3                    91.61                         1.8
# 4                    82.01                         1.8
#
#    solarPotential.buildFactor  solarPotential.climateFactor  \
# 0                        80.0                          6.24
# 1                        68.0                          6.24
# 2                        68.0                          6.24
# 3                        80.0                          6.24
# 4                        70.4                          6.24
#
#    solarPotential.electricityFactor  resoFacts.hasAttachedProperty  \
# 0                              3.57                          False
# 1                              3.57                          False
# 2                              3.57                          False
# 3                              3.57                          False
# 4                              3.57                          False
#
#   resoFacts.frontageType resoFacts.poolFeatures        resoFacts.flooring  \
# 0                   None                   None  [Tile, Carpet, Hardwood]
# 1                   None                   None                       NaN
# 2                   None                   None                [Hardwood]
# 3                   None                   None                    [Wood]
# 4                   None                   None                      None
#
#   resoFacts.accessibilityFeatures  resoFacts.hasGarage  \
# 0                            None                False
# 1                            None                False
# 2                            None                False
# 3                            None                False
# 4                            None                False
#
#   resoFacts.hasPetsAllowed resoFacts.bodyType resoFacts.topography  \
# 0                     None               None                 None
# 1                     None               None                 None
# 2                     None               None                 None
# 3                     None               None                 None
# 4                     None               None                 None
#
#   resoFacts.landLeaseExpirationDate  resoFacts.hasAdditionalParcels  \
# 0                              None                           False
# 1                              None                           False
# 2                              None                           False
# 3                              None                           False
# 4                              None                           False
#
#   resoFacts.waterViewYN                           resoFacts.atAGlanceFacts  \
# 0                  None  [{'factLabel': 'Type', 'factValue': '1/2 Duple...
# 1                  None  [{'factLabel': 'Type', 'factValue': 'Condo'}, ...
# 2                  None  [{'factLabel': 'Type', 'factValue': 'SingleFam...
# 3                  None  [{'factLabel': 'Type', 'factValue': 'Single Fa...
# 4                  None  [{'factLabel': 'Type', 'factValue': 'Multi Fam...
#
#   resoFacts.offerReviewDate resoFacts.aboveGradeFinishedArea  \
# 0                      None                             None
# 1                      None                             None
# 2                      None                             None
# 3                      None                             None
# 4                      None                             None
#
#   resoFacts.buyerAgencyCompensationType  \
# 0                                  None
# 1                                  None
# 2                                  None
# 3                                  None
# 4                                  None
#
#                                      resoFacts.rooms resoFacts.carportSpaces  \
# 0  [{'level': None, 'dimensions': None, 'features...                    None
# 1                                                NaN                    None
# 2                                                NaN                    None
# 3  [{'level': None, 'dimensions': None, 'features...                       0
# 4                                                NaN                       0
#
#   resoFacts.cityRegion resoFacts.mainLevelBathrooms resoFacts.hasPrivatePool  \
# 0           Woodbridge                         None                    False
# 1           Woodbridge                         None                     None
# 2           Woodbridge                         None                     None
# 3           Woodbridge                         None                     None
# 4           Woodbridge                         None                     None
#
#   resoFacts.associationFeeIncludes resoFacts.waterSource  \
# 0                             None              [Public]
# 1                             None                  None
# 2                             None                  None
# 3                             None              [Public]
# 4                             None              [Public]
#
#   resoFacts.exteriorFeatures resoFacts.coveredSpaces resoFacts.inclusions  \
# 0             [Other, Vinyl]                       0                 None
# 1                        NaN                    None                 None
# 2                    [Vinyl]                    None                 None
# 3                     [Yard]                       0                 None
# 4                     [Yard]                       0                 None
#
#   resoFacts.hasFireplace resoFacts.zoningDescription resoFacts.garageSpaces  \
# 0                  False                         R-6                   None
# 1                   None                        None                   None
# 2                   None                        None                   None
# 3                   True                        None                      0
# 4                   None                        None                      0
#
#   resoFacts.sewer resoFacts.elevationUnits resoFacts.exclusions  \
# 0  [Public Sewer]                     None                 None
# 1            None                     None                 None
# 2            None                     None                 None
# 3  [Public Sewer]                     None                 None
# 4  [Public Sewer]                     None                 None
#
#   resoFacts.mainLevelBedrooms resoFacts.numberOfUnitsVacant  \
# 0                        None                          None
# 1                        None                          None
# 2                        None                          None
# 3                        None                          None
# 4                        None                          None
#
#   resoFacts.hasWaterfrontView resoFacts.listAOR resoFacts.lotSize  \
# 0                        None              None        2,500 sqft
# 1                        None              None              None
# 2                        None              None        3,998 sqft
# 3                        None              None        9,226 sqft
# 4                        None              None        7,200 sqft
#
#   resoFacts.entryLevel resoFacts.irrigationWaterRightsAcres  \
# 0                 None                                 None
# 1                 None                                 None
# 2                 None                                 None
# 3                 None                                 None
# 4                 None                                 None
#
#   resoFacts.greenWaterConservation resoFacts.stories resoFacts.livingArea  \
# 0                             None              None             896 sqft
# 1                             None              None                 None
# 2                             None              None             694 sqft
# 3                             None                 2           1,432 sqft
# 4                             None                 2           1,512 sqft
#
#   resoFacts.numberOfUnitsInCommunity resoFacts.listingTerms  \
# 0                               None                   None
# 1                               None                   None
# 2                               None                   None
# 3                               None                   None
# 4                               None                   None
#
#   resoFacts.otherStructures resoFacts.associationFee resoFacts.marketingType  \
# 0                 [Shed(s)]                     None                    None
# 1                      None                     None                    None
# 2                      None                     None                    None
# 3                      None                     None                    None
# 4                 [Shed(s)]                     None                    None
#
#   resoFacts.greenIndoorAirQuality resoFacts.greenSustainability  \
# 0                            None                          None
# 1                            None                          None
# 2                            None                          None
# 3                            None                          None
# 4                            None                          None
#
#    resoFacts.hasHomeWarranty resoFacts.associationPhone  \
# 0                      False                       None
# 1                      False                       None
# 2                      False                       None
# 3                      False                       None
# 4                      False                       None
#
#   resoFacts.greenBuildingVerificationType resoFacts.elementarySchool  \
# 0                                    None                       None
# 1                                    None                       None
# 2                                    None                       None
# 3                                    None                       None
# 4                                    None                       None
#
#    resoFacts.bedrooms resoFacts.architecturalStyle resoFacts.listingId  \
# 0                   2                     Colonial                None
# 1                   1                         None                None
# 2                   2                         None                None
# 3                   3                     Colonial                None
# 4                   3                         None                None
#
#   resoFacts.structureType                         resoFacts.interiorFeatures  \
# 0                Colonial                                               None
# 1                    None                                               None
# 2                Cape Cod                                               None
# 3                    None  [Entrance Foyer, Kitchen, Living Room, Other R...
# 4                    None  [Unit 1(1 Bedroom, 1 Bath), Unit 2(2 Bedrooms,...
#
#   resoFacts.horseAmenities resoFacts.electric resoFacts.developmentStatus  \
# 0                     None               None                        None
# 1                     None               None                        None
# 2                     None               None                        None
# 3                     None               None                        None
# 4                     None               None                        None
#
#                               resoFacts.lotFeatures resoFacts.roofType  \
# 0      [Sidewalk, Near Shopping, Near Train, Curbs]            Asphalt
# 1                                              None               None
# 2                                              None            Asphalt
# 3  [Near Shopping, Near Train, Near Public Transit]        See Remarks
# 4                [Near Shopping, Near Train, Level]            Asphalt
#
#   resoFacts.waterSources resoFacts.fireplaceFeatures resoFacts.doorFeatures  \
# 0                   None                        None                   None
# 1                   None                        None                   None
# 2                   None                        None                   None
# 3                   None              [Wood Burning]                   None
# 4                   None                        None                   None
#
#                                 resoFacts.appliances  resoFacts.daysOnZillow  \
# 0          [Dishwasher, Dryer, Refrigerator, Washer]                     948
# 1                                                NaN                      52
# 2                                                NaN                    1302
# 3  [Dishwasher, Dryer, Gas Range/Oven, Microwave,...                      25
# 4  [Water Heater(Gas), Water Heater, Unit 2(Range...                      40
#
#   resoFacts.bathroomsPartial  resoFacts.bathroomsHalf  \
# 0                       None                        0
# 1                       None                        0
# 2                       None                        0
# 3                       None                        0
# 4                       None                        0
#
#   resoFacts.depositsAndFees  resoFacts.canRaiseHorses resoFacts.buildingName  \
# 0                      None                     False                   None
# 1                      None                     False                   None
# 2                      None                     False                   None
# 3                      None                     False                   None
# 4                      None                     False                   None
#
#   resoFacts.hasAssociation resoFacts.petsMaxWeight resoFacts.commonWalls  \
# 0                     None                    None                  None
# 1                     True                    None                  None
# 2                     None                    None                  None
# 3                     None                    None                  None
# 4                     None                    None                  None
#
#   resoFacts.totalActualRent resoFacts.additionalParcelsDescription  \
# 0                      None                                   None
# 1                      None                                   None
# 2                      None                                   None
# 3                      None                                   None
# 4                      None                                   None
#
#   resoFacts.associationName resoFacts.allowedPets resoFacts.tenantPays  \
# 0                      None                  None                 None
# 1                      None                  None                 None
# 2                      None                  None                 None
# 3                      None                  None                 None
# 4                      None                  None                 None
#
#   resoFacts.middleOrJuniorSchool resoFacts.lotSizeDimensions  \
# 0                           None                        None
# 1                           None                        None
# 2                           None                        None
# 3                           None              205.00 x 45.00
# 4                           None               96.00 x 75.00
#
#   resoFacts.roadSurfaceType resoFacts.hasOpenParking  resoFacts.yearBuilt  \
# 0                      None                     None                 1931
# 1                      None                     None                 1981
# 2                      None                     None                 1935
# 3                      None                     True                 1916
# 4                      None                     None                 1958
#
#   resoFacts.livingAreaRangeUnits resoFacts.irrigationWaterRightsYN  \
# 0                           None                              None
# 1                           None                              None
# 2                           None                              None
# 3                           None                              None
# 4                           None                              None
#
#    resoFacts.bathroomsFull resoFacts.horseYN resoFacts.incomeIncludes  \
# 0                        2              None                     None
# 1                        0              None                     None
# 2                        1              None                     None
# 3                        2              None                     None
# 4                        0              None                     None
#
#   resoFacts.highSchool resoFacts.leaseTerm resoFacts.elevation  \
# 0                 None                None                None
# 1                 None                None                None
# 2                 None                None                None
# 3                 None                None                None
# 4                 None                None                None
#
#   resoFacts.cropsIncludedYN   resoFacts.attic resoFacts.subdivisionName  \
# 0                      None  Pull Down Stairs                      None
# 1                      None              None                      None
# 2                      None              None                      None
# 3                      None              None                      None
# 4                      None              None                      None
#
#   resoFacts.windowFeatures resoFacts.ownership resoFacts.woodedArea  \
# 0                     None                None                 None
# 1                     None                None                 None
# 2                     None                None                 None
# 3                     None          Fee Simple                 None
# 4                     None          Fee Simple                 None
#
#   resoFacts.middleOrJuniorSchoolDistrict resoFacts.associationPhone2  \
# 0                 Woodbridge Township SD                        None
# 1                                   None                        None
# 2                                   None                        None
# 3                                   None                        None
# 4                                   None                        None
#
#   resoFacts.buyerAgencyCompensation            resoFacts.heating  \
# 0                              None  [Forced air, Electric, Gas]
# 1                              None                          NaN
# 2                              None             [Baseboard, Gas]
# 3                              None        [Radiators-Hot Water]
# 4                              None            [Radiators-Steam]
#
#   resoFacts.frontageLength                  resoFacts.virtualTourURLUnbranded  \
# 0                     None                                               None
# 1                     None                                               None
# 2                     None                                               None
# 3                     None  https://www.propertypanorama.com/instaview/msx...
# 4                     None  https://www.propertypanorama.com/instaview/msx...
#
#   resoFacts.associationAmenities  resoFacts.propertySubType  \
# 0                           None               [1/2 Duplex]
# 1                           None                       None
# 2                           None                       None
# 3                           None  [Single Family Residence]
# 4                           None             [Multi Family]
#
#    resoFacts.hasCooling resoFacts.belowGradeFinishedArea  \
# 0                  True                             None
# 1                  True                             None
# 2                  True                             None
# 3                  True                             None
# 4                  True                             None
#
#   resoFacts.hasElectricOnProperty resoFacts.foundationArea resoFacts.zoning  \
# 0                            None                     None             None
# 1                            None                     None             None
# 2                            None                     None             None
# 3                            True                     None              R-6
# 4                            None                     None              R-6
#
#   resoFacts.hoaFee resoFacts.livingAreaRange  resoFacts.basementYN  \
# 0             None                      None                 False
# 1             None                      None                 False
# 2             None                      None                 False
# 3             None                      None                 False
# 4             None                      None                 False
#
#   resoFacts.availabilityDate resoFacts.waterBodyName  \
# 0              1565222400000                    None
# 1                       None                    None
# 2                       None                    None
# 3                       None                    None
# 4                       None                    None
#
#   resoFacts.waterfrontFeatures resoFacts.specialListingConditions  \
# 0                         None                               None
# 1                         None                               None
# 2                         None                               None
# 3                         None                               None
# 4                         None                               None
#
#   resoFacts.buildingAreaSource  resoFacts.taxAnnualAmount  resoFacts.parking  \
# 0                         None                       4356                  0
# 1                         None                       2910                  0
# 2                         None                       4242                  0
# 3                         None                       8256                  0
# 4                         None                       9336                  0
#
#    resoFacts.hasView                              resoFacts.virtualTour  \
# 0              False                                               None
# 1              False                                               None
# 2              False                                               None
# 3              False  https://www.propertypanorama.com/instaview/msx...
# 4              False  https://www.propertypanorama.com/instaview/msx...
#
#   resoFacts.securityFeatures     resoFacts.cooling resoFacts.entryLocation  \
# 0                       None             [Central]                    None
# 1                       None                [None]                    None
# 2                       None             [Central]                    None
# 3                       None      [Ceiling Fan(s)]                    None
# 4                       None  [A/C Window Unit(s)]                    None
#
#                                 resoFacts.otherFacts resoFacts.levels  \
# 0  [{'value': 'Wood, Carpet, Ceramic Tile', 'name...             None
# 1                                                NaN             None
# 2  [{'value': '1 Car Width, Dirt', 'name': 'Drive...             None
# 3                                                NaN              Two
# 4                                                NaN             None
#
#   resoFacts.ownershipType                                 resoFacts.basement  \
# 0                    None            Finished, Bath/Stubbed, Recreation Room
# 1                    None                                               None
# 2                    None                                               None
# 3                    None  Partially Finished, Full, Bath Full, Recreatio...
# 4                    None                                               None
#
#   resoFacts.onMarketDate resoFacts.waterView   resoFacts.laundryFeatures  \
# 0                   None                      [In Basement, Lower Level]
# 1                   None                                            None
# 2                   None                                            None
# 3          1646784000000                None                        None
# 4          1644624000000                None                        None
#
#   resoFacts.hasAttachedGarage resoFacts.fencing resoFacts.spaFeatures  \
# 0                        None            Fenced                  None
# 1                        None              None                  None
# 2                        None              None                  None
# 3                        None              None                  None
# 4                        None              None                  None
#
#    resoFacts.bathrooms resoFacts.homeType resoFacts.isSeniorCommunity  \
# 0                    2       SingleFamily                        None
# 1                    1              Condo                        None
# 2                    1       SingleFamily                        None
# 3                    2       SingleFamily                        None
# 4                    2        MultiFamily                        None
#
#   resoFacts.municipality resoFacts.bathroomsThreeQuarter  resoFacts.hasSpa  \
# 0                   None                               0             False
# 1                   None                               0             False
# 2                   None                               0             False
# 3                   None                            None             False
# 4                   None                            None             False
#
#   resoFacts.otherParking resoFacts.associationFee2     resoFacts.parcelNumber  \
# 0                   None                      None          25005521020000401
# 1                   None                      None  25002520000001000000C0704
# 2                   None                      None           2500263030001502
# 3                   None                      None         250057000000001302
# 4                   None                      None           2500566030001304
#
#    resoFacts.hasHeating resoFacts.associationName2 resoFacts.hasRentControl  \
# 0                  True                       None                     None
# 1                 False                       None                     None
# 2                  True                       None                     None
# 3                  True                       None                     None
# 4                  True                       None                     None
#
#   resoFacts.elementarySchoolDistrict resoFacts.otherEquipment  \
# 0             Woodbridge Township SD                     None
# 1                               None                     None
# 2                               None                     None
# 3                               None                     None
# 4                               None                     None
#
#   resoFacts.buildingArea  resoFacts.furnished resoFacts.vegetation  \
# 0                   None                False                 None
# 1                   None                False                 None
# 2                   None                False                 None
# 3                  1,432                False                 None
# 4                  1,512                False                 None
#
#   resoFacts.patioAndPorchFeatures resoFacts.buildingFeatures  \
# 0                   [Deck, Patio]                       None
# 1                            None                       None
# 2                            None                       None
# 3                [Deck, Enclosed]                       None
# 4                            None                       None
#
#   resoFacts.builderName resoFacts.highSchoolDistrict  \
# 0                  None       Woodbridge Township SD
# 1                  None                         None
# 2                  None                         None
# 3                  None                         None
# 4                  None                         None
#
#   resoFacts.propertyCondition resoFacts.storiesTotal  \
# 0                        None                      2
# 1                        None                   None
# 2                        None                   None
# 3                        None                      2
# 4                        None                      2
#
#   resoFacts.yearBuiltEffective resoFacts.fireplaces  \
# 0                         None                 None
# 1                         None                 None
# 2                         None                 None
# 3                         None                    1
# 4                         None                 None
#
#   resoFacts.bathroomsOneQuarter resoFacts.builderModel  resoFacts.gas  \
# 0                             0                   None  [Natural Gas]
# 1                             0                   None           None
# 2                             0                   None           None
# 3                          None                   None  [Natural Gas]
# 4                          None                   None  [Natural Gas]
#
#                               resoFacts.utilities  \
# 0  [Natural Gas Connected, Electricity Available]
# 1                                            None
# 2                                            None
# 3  [Electricity Connected, Natural Gas Connected]
# 4  [Underground Utilities, Natural Gas Connected]
#
#   resoFacts.greenEnergyEfficient resoFacts.landLeaseAmount  \
# 0                           None                      None
# 1                           None                      None
# 2                           None                      None
# 3                           None                      None
# 4                           None                      None
#
#   resoFacts.isNewConstruction  resoFacts.hasLandLease  \
# 0                        None                   False
# 1                        None                   False
# 2                        None                   False
# 3                        None                   False
# 4                        None                   False
#
#   resoFacts.pricePerSquareFoot resoFacts.hasCarport  \
# 0                          273                 None
# 1                         None                 None
# 2                          807                 None
# 3                          234                False
# 4                          248                False
#
#   resoFacts.openParkingSpaces  mortgageRates.arm5Rate  \
# 0                        None                   5.225
# 1                        None                   5.225
# 2                        None                   4.423
# 3                        None                   4.423
# 4                        None                   4.423
#
#    mortgageRates.fifteenYearFixedRate  mortgageRates.thirtyYearFixedRate  \
# 0                               4.622                              5.039
# 1                               4.622                              5.039
# 2                               4.036                              4.855
# 3                               4.036                              4.855
# 4                               4.036                              4.855
#
#   address.city address.neighborhood address.state address.streetAddress  \
# 0   Woodbridge                 None            NJ         43 Martin Ter
# 1   Woodbridge                 None            NJ        704 Cricket Ln
# 2   Woodbridge                 None            NJ      258 Columbus Ave
# 3   Woodbridge                 None            NJ        164 Freeman St
# 4   Woodbridge                 None            NJ     615 Ridgewood Ave
#
#   address.zipcode  listed_by.agent_reason  listed_by.zpro  \
# 0           07095                       3            True
# 1           07095                       3            True
# 2           07095                       3            True
# 3           07095                       3            True
# 4           07095                       3            True
#
#   listed_by.recent_sales listed_by.review_count listed_by.display_name  \
# 0                   None                   None                   None
# 1                   None                   None                   None
# 2                   None                   None                   None
# 3                      0                      0       Danielle Laraque
# 4                      0                      7         Teddy Gonzalez
#
#   listed_by.badge_type     listed_by.business_name listed_by.rating_average  \
# 0        Listing Agent                        None                     None
# 1        Listing Agent                        None                     None
# 2        Listing Agent                        None                     None
# 3        Listing Agent      RE/MAX FIRST REALTY II                        0
# 4        Listing Agent  BHHS NEW JERSEY PROPERTIES                        5
#
#   listed_by.phone           listed_by.zuid  \
# 0            None   X1-ZUz1ci99gqj409_uwi3
# 1            None   X1-ZUz1ci99gqj409_uwi3
# 2            None   X1-ZUz1ci99gqj409_uwi3
# 3             NaN  X1-ZUse8sd6fjuo7d_9skq8
# 4             NaN  X1-ZUzx3rcr7kbm6h_39zrd
#
#                                  listed_by.image_url  \
# 0  https://www.zillowstatic.com/static/images/nop...
# 1  https://www.zillowstatic.com/static/images/nop...
# 2  https://www.zillowstatic.com/static/images/nop...
# 3  https://photos.zillowstatic.com/h_n/ISrldaa8re...
# 4  https://photos.zillowstatic.com/h_n/ISfozrgsln...
#
#               resoFacts.parkingFeatures listingProvider  \
# 0                                   NaN             NaN
# 1                                [None]             NaN
# 2                   [Garage - Detached]             NaN
# 3  [1 Car Width, 2 Cars Deep, Driveway]            None
# 4                     [3-4 Car Parking]            None
#
#   resoFacts.communityFeatures listed_by.phone.prefix listed_by.phone.areacode  \
# 0                         NaN                    NaN                      NaN
# 1                         NaN                    NaN                      NaN
# 2                         NaN                    NaN                      NaN
# 3                        None                    359                      848
# 4                        None                    930                      908
#
#   listed_by.phone.number
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                   5820
# 4                   2751

# %%
# reduce number of columns in join
df_mod_output = pd.merge(
    df_upload, 
    df_prop_detail[['zpid', 'zestimate', 'rentZestimate']], 
    how='left', 
    on='zpid')
print('Num of columns:', len(df_mod_output.columns))
df_mod_output.head()
# Out:
# Num of columns: 44
#              Address  Unit #        City State   Zip     County  \
# 0      43 Martin Ter     NaN  Woodbridge    NJ  7095  Middlesex
# 1     704 Cricket Ln     NaN  Woodbridge    NJ  7095  Middlesex
# 2   258 Columbus Ave     NaN  Woodbridge    NJ  7095  Middlesex
# 3     164 Freeman St     NaN  Woodbridge    NJ  7095  Middlesex
# 4  615 Ridgewood Ave     NaN  Woodbridge    NJ  7095  Middlesex
#
#                                APN Owner Occupied Owner 1 First Name  \
# 0        25  00552- 102-00004-  01            Yes              Kevin
# 1  25  00252-0000-00100-0000-C0704            Yes               Mary
# 2        25  00263-  03-00015-  02             No            Eliezer
# 3        25  00570-0000-00013-  02            Yes              Bruce
# 4        25  00566-  03-00013-  04             No            Shirley
#
#   Owner 1 Last Name Owner 2 First Name Owner 2 Last Name  \
# 0            Monroe               Doug       Wynn-Monroe
# 1           Mcguinn                NaN               NaN
# 2         Placencia                NaN               NaN
# 3           Laraque                NaN               NaN
# 4          Gonzalez                NaN               NaN
#
#               Mailing Care of Name      Mailing Address  Mailing Unit #  \
# 0  Kevin Monroe & Doug Wynn-Monroe        43 Martin Ter             NaN
# 1                     Mary Mcguinn       704 Cricket Ln             NaN
# 2                Eliezer Placencia        438 Alpine St             NaN
# 3                    Bruce Laraque       164 Freeman St             NaN
# 4                 Shirley Gonzalez  301 Saint Marks Ave             NaN
#
#   Mailing City Mailing State  Mailing Zip  Mailing County  Do Not Mail  \
# 0   Woodbridge            NJ         7095             NaN          NaN
# 1   Woodbridge            NJ         7095             NaN          NaN
# 2  Perth Amboy            NJ         8861             NaN          NaN
# 3   Woodbridge            NJ         7095             NaN          NaN
# 4   Piscataway            NJ         8854             NaN          NaN
#
#                Property Type  Bedrooms  Total Bathrooms  Building Sqft  \
# 0  Single Family Residential         2                2          896.0
# 1  Condominium (Residential)         1                1            NaN
# 2  Single Family Residential         4                3          694.0
# 3  Single Family Residential         3                2         1432.0
# 4  Single Family Residential         3                2         1512.0
#
#    Lot Size Sqft  Effective Year Built  Total Assessed Value  \
# 0            NaN                  1931                 49400
# 1          463.0                  1981                 35000
# 2            NaN                  1935                 48100
# 3            NaN                  1916                 67300
# 4            NaN                  1958                 76100
#
#   Last Sale Recording Date  Last Sale Amount  Total Open Loans  \
# 0                 10/18/19            245000                 1
# 1                  9/22/00             67500                 2
# 2                 10/29/18            117000                 0
# 3                  10/4/05             80000                 1
# 4                  9/21/05            272000                 1
#
#    Est. Remaining balance of Open Loans  Est. Value  Est. Loan-to-Value  \
# 0                                234487      321626              72.907
# 1                                 37118      219756              16.891
# 2                                     0      312359               0.000
# 3                                169014      276184              61.196
# 4                                166658      438303              38.023
#
#    Est. Equity MLS Status  MLS Date  MLS Amount  Lien Amount  Marketing Lists  \
# 0        87139    REMOVED    2/5/21      245000       534.70                1
# 1       182638    REMOVED  10/28/21        1650     19010.24                1
# 2       312359    REMOVED    3/2/22      549999      3529.41                1
# 3       107170     ACTIVE    3/6/22      335000       267.35                1
# 4       271645    REMOVED   3/12/22      350000       385.43                1
#
#   Date Added to List Method of Add      zpid  zestimate  rentZestimate
# 0            3/30/22        Manual  39206632     331300           2250
# 1            3/30/22        Manual  39192163     204400           1544
# 2            3/30/22        Manual  39192601     560200           1855
# 3            3/30/22        Manual  39207346     404800           2600
# 4            3/30/22        Manual  39207264     379500           2598

# %%
# download file
df_mod_output.to_csv('output2.csv', index=False)
files.download('output2.csv')

# %%
# view zestimate
fig = px.box(df_mod_output, y="zestimate")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="773d823b-3bdc-4940-bd9e-cdc299d1a0d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("773d823b-3bdc-4940-bd9e-cdc299d1a0d3")) {                    Plotly.newPlot(                        "773d823b-3bdc-4940-bd9e-cdc299d1a0d3",                        [{"alignmentgroup":"True","hovertemplate":"zestimate=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[331300,204400,560200,404800,379500],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorba ...

# %% [markdown]
# ## <font color="blue">Automation</font>

# %% [markdown]
# ### 1) Property Bulk Upload Tool (by AnalyticsAriel)
# Check out my video below for a <B>NO CODE SOLUTION</B> on how to get Zillow property data for ANY spreadsheet.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('9m7Q_EfhSmk')

# %% [markdown]
# ### 2) Zapier Integration
# Check out my video below for an <B>Automation Workflow</B> on how to get Zillow property data for new addresses added to a Google Spreadsheet (subscriptions start at $19/mo).

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('WumrvKboDxo')

# %% [markdown]
# ### 3) Zoho Integration
# Check out my video below on how to get Zillow property data for ZOHO CRM.

# %%
from IPython.display import YouTubeVideo
# YouTubeVideo('Dh09SWvCuiM') Coming Soon!

# %% [markdown]
# # End Notebook
