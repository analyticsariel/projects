# %% [markdown]
# <a href="https://colab.research.google.com/github/analyticsariel/projects/blob/master/Estated_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Estated Property Data
#
# ## Overview
# | Detail Tag            | Information                                                                                        |
# |-----------------------|----------------------------------------------------------------------------------------------------|
# | Originally Created By | Ariel Herrera arielherrera@analyticsariel.com |
# | External References   | API |
# | Input Datasets        | Source name |
# | Output Datasets       | Source name |
# | Input Data Source     | Pandas DataFrame |
# | Output Data Source    | Pandas DataFrame |
#
# ## History
# | Date         | Developed By  | Reason                                                |
# |--------------|---------------|-------------------------------------------------------|
# | 24th Jan 2022 | Ariel Herrera | Create notebook. |
#
# ## Getting Started
# 1. Copy this notebook -> File -> Save a Copy in Drive
# 2. Directions
#
# ## Useful Resources
# - [Google Colab Cheat Sheet](https://towardsdatascience.com/cheat-sheet-for-google-colab-63853778c093)
# - [Estated Data Dictionary](https://estated.com/developers/docs/v4/property/bulk)
# - [Estated Data Schema](https://estated.com/developers/docs/v4/property/schema)
# - [How to convert JSON into a Pandas DataFrame](https://towardsdatascience.com/how-to-convert-json-into-a-pandas-dataframe-100b2ae1e0d8)
# - [Convert CURL request to Python](https://curlconverter.com/#)

# %% [markdown]
# ## Install Packages

# %% [markdown]
# ## Imports

# %%
from google.colab import drive, files # google colab specific
import requests
import pandas as pd
import os
import warnings

# %% [markdown]
# ## Functions

# %%
def get_estated_detail(api_key, 
                       street_address, 
                       city, 
                       state, 
                       zip_code):
  # sample API get request
  base_url = 'https://apis.estated.com/v4/property'

  params = (
      ('token', estated_api_key),
      ('street_address', street_address),
      ('city', city),
      ('state', state),
      ('zip_code', zip_code),
  )

  response = requests.get(base_url, params=params)
  return response

# %% [markdown]
# ## Locals & Constants

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# set working directory
os.chdir('/content/drive/MyDrive/Colab Data/')
dir = os.getcwd()
print('Current working directory:', dir)

# remove pandas warnings
warnings.filterwarnings('ignore')
# Out:
# Current working directory: /content/drive/MyDrive/Colab Data

# %% [markdown]
# ## Data

# %%
# read in api keys
df_api_keys = pd.read_csv(dir + '/input/api_keys.csv')
# extract api key
estated_api_key = df_api_keys.loc[df_api_keys['API'] == 'estated']['KEY'].iloc[0]

# %% [markdown]
# ## Transformations

# %% [markdown]
# ### <font color="green">Sample API Request - Single Address</font>

# %%
# sample API get request
base_url = 'https://apis.estated.com/v4/property'

params = (
    ('token', estated_api_key),
    ('street_address', '151 Battle Green Dr'),
    ('city', 'Rochester'),
    ('state', 'NY'),
    ('zip_code', '14624'),
)

response = requests.get(base_url, params=params)
print(response.text)
# Out:
# {"data":{"metadata":{"publishing_date":"2021-02-01"},"address":{"street_number":"151","street_pre_direction":null,"street_name":"BATTLE GREEN","street_suffix":"DR","street_post_direction":null,"unit_type":null,"unit_number":null,"formatted_street_address":"151 BATTLE GREEN DR","city":"ROCHESTER","state":"NY","zip_code":"14624","zip_plus_four_code":"4969","carrier_code":"C006","latitude":43.108222,"longitude":-77.704543,"geocoding_accuracy":"PARCEL CENTROID","census_tract":"360550145.043011"},"parcel":{"apn_original":"262200 147.09-2-6","apn_unformatted":"2622001470926","apn_previous":null,"fips_code":"36055","frontage_ft":75.0,"depth_ft":125.0,"area_sq_ft":9583,"area_acres":0.22,"county_name":"MONROE","county_land_use_code":"210","county_land_use_description":"1-FAMILY YEAR-ROUND RESIDENCE","standardized_land_use_category":"RESIDENTIAL","standardized_land_use_type":"SINGLE FAMILY RESIDENTIAL","location_descriptions":[],"zoning":"02 - SINGLE RESIDENCE","building_count":null,"tax_account_number":"COM-0003926","legal_description":"LOT 27 3000 ACRE TRACT LEXINGTON SUB SEC 12 L-1205 245-51","lot_code":null,"lot_number":"6","subdivision":null,"municipality":"CHILI","section_township_range":null},"boundary":{"wkt":"MULTIPOLYGON(((-77.70481631402163 43.10823905468868,-77.70466049568529 43.10840154509526,-77.70426873391489 43.10820366906415,-77.70442375814986 43.10803832241072,-77.70481631402163 43.10823905468868)))","geojson":{"type":"MultiPolygon","coordinates":[[[[-77.70481631402163,43.10823905468868],[-77.70466049568529,43.10840154509526],[-77.70426873391489,43.10820366906415],[-77.70442375814986,43.10803832241072],[-77.70481631402163,43.10823905468868]]]]}},"structure":{"year_built":1989,"effective_year_built":null,"stories":"2+B","rooms_count":null,"beds_count":4,"baths":2.0,"partial_baths_count":1,"units_count":null,"parking_type":"ATTACHED GARAGE","parking_spaces_count":2,"pool_type":null,"architecture_type":"COLONIAL","construction_type":null,"exterior_wall_type":"ALUMINUM OR VINYL SIDING","foundation_type":null,"roof_material_type":null,"roof_style_type":null,"heating_type":"FORCED AIR UNIT","heating_fuel_type":"GAS","air_conditioning_type":"CENTRAL","fireplaces":"1","basement_type":"FULL BASEMENT","quality":"C","condition":"GOOD","flooring_types":[],"plumbing_fixtures_count":null,"interior_wall_type":null,"water_type":"MUNICIPAL","sewer_type":"MUNICIPAL","total_area_sq_ft":1975,"other_areas":[{"type":"1ST FLOOR","sq_ft":"912"},{"type":"2ND FLOOR","sq_ft":"1063"},{"type":"GARAGE","sq_ft":"400"},{"type":"COVERED PORCH","sq_ft":"592"}],"other_rooms":["RECREATION ROOM"],"other_features":[],"other_improvements":[{"type":"SHED","sq_ft":"10X12"}],"amenities":[]},"valuation":{"value":249000,"high":273900,"low":224100,"forecast_standard_deviation":10,"date":"2022-01-06"},"taxes":[{"year":2021,"amount":8868,"exemptions":[],"rate_code_area":"262601"}],"assessments":[{"year":2020,"land_value":31400,"improvement_value":158300,"total_value":189700},{"year":2019,"land_value":31400,"improvement_value":158300,"total_value":189700},{"year":2018,"land_value":31400,"improvement_value":127900,"total_value":159300}],"market_assessments":[{"year":2020,"land_value":32708,"improvement_value":164896,"total_value":197604}],"owner":{"name":"KRISTIN N RIMES","second_name":null,"unit_type":null,"unit_number":null,"formatted_street_address":"151 BATTLE GREEN DR","city":"ROCHESTER","state":"NY","zip_code":"14624","zip_plus_four_code":"4969","owner_occupied":"YES"},"deeds":[{"document_type":"WARRANTY DEED","recording_date":"2018-07-03","original_contract_date":"2018-06-28","deed_book":"12048","deed_page":"266","document_id":"201807030288","sale_price":199000,"sale_price_description":"FULL AMOUNT COMPUTED FROM TRANSFER TAX OR EXCISE TAX","transfer_tax":796.0,"distressed_sale":false,"real_estate_owned":"NO","seller_first_name":"NICHOLAS M","seller_last_name":"BELLUCCIO","seller2_first_name":null,"seller2_last_name":null,"seller_address":null,"seller_unit_numb ...

# %%
# transform to json response
response_json = response.json()
response_json
# Out:
# {'data': {'address': {'carrier_code': 'C006',
#    'census_tract': '360550145.043011',
#    'city': 'ROCHESTER',
#    'formatted_street_address': '151 BATTLE GREEN DR',
#    'geocoding_accuracy': 'PARCEL CENTROID',
#    'latitude': 43.108222,
#    'longitude': -77.704543,
#    'state': 'NY',
#    'street_name': 'BATTLE GREEN',
#    'street_number': '151',
#    'street_post_direction': None,
#    'street_pre_direction': None,
#    'street_suffix': 'DR',
#    'unit_number': None,
#    'unit_type': None,
#    'zip_code': '14624',
#    'zip_plus_four_code': '4969'},
#   'assessments': [{'improvement_value': 158300,
#     'land_value': 31400,
#     'total_value': 189700,
#     'year': 2020},
#    {'improvement_value': 158300,
#     'land_value': 31400,
#     'total_value': 189700,
#     'year': 2019},
#    {'improvement_value': 127900,
#     'land_value': 31400,
#     'total_value': 159300,
#     'year': 2018}],
#   'boundary': {'geojson': {'coordinates': [[[[-77.70481631402163,
#         43.10823905468868],
#        [-77.70466049568529, 43.10840154509526],
#        [-77.70426873391489, 43.10820366906415],
#        [-77.70442375814986, 43.10803832241072],
#        [-77.70481631402163, 43.10823905468868]]]],
#     'type': 'MultiPolygon'},
#    'wkt': 'MULTIPOLYGON(((-77.70481631402163 43.10823905468868,-77.70466049568529 43.10840154509526,-77.70426873391489 43.10820366906415,-77.70442375814986 43.10803832241072,-77.70481631402163 43.10823905468868)))'},
#   'deeds': [{'buyer2_first_name': None,
#     'buyer2_last_name': None,
#     'buyer_address': '151 BATTLE GREEN DR',
#     'buyer_city': 'ROCHESTER',
#     'buyer_first_name': 'KRISTIN',
#     'buyer_last_name': 'RIMES',
#     'buyer_state': 'NY',
#     'buyer_unit_number': None,
#     'buyer_unit_type': None,
#     'buyer_zip_code': '14624',
#     'buyer_zip_plus_four_code': '4969',
#     'deed_book': '12048',
#     'deed_page': '266',
#     'distressed_sale': False,
#     'document_id': '201807030288',
#     'document_type': 'WARRANTY DEED',
#     'lender_name': None,
#     'lender_type': None,
#     'loan_amount': None,
#     'loan_due_date': None,
#     'loan_finance_type': None,
#     'loan_interest_rate': None,
#     'loan_type': None,
#     'original_contract_date': '2018-06-28',
#     'real_estate_owned': 'NO',
#     'recording_date': '2018-07-03',
#     'sale_price': 199000,
#     'sale_price_description': 'FULL AMOUNT COMPUTED FROM TRANSFER TAX OR EXCISE TAX',
#     'seller2_first_name': None,
#     'seller2_last_name': None,
#     'seller_address': None,
#     'seller_city': None,
#     'seller_first_name': 'NICHOLAS M',
#     'seller_last_name': 'BELLUCCIO',
#     'seller_state': None,
#     'seller_unit_number': None,
#     'seller_zip_code': None,
#     'seller_zip_plus_four_code': None,
#     'transfer_tax': 796.0},
#    {'buyer2_first_name': None,
#     'buyer2_last_name': None,
#     'buyer_address': '151 BATTLE GREEN DR',
#     'buyer_city': 'ROCHESTER',
#     'buyer_first_name': 'NICHOLAS M',
#     'buyer_last_name': 'BELLUCCIO',
#     'buyer_state': 'NY',
#     'buyer_unit_number': None,
#     'buyer_unit_type': None,
#     'buyer_zip_code': '14624',
#     'buyer_zip_plus_four_code': '4969',
#     'deed_book': '11870',
#     'deed_page': '262',
#     'distressed_sale': False,
#     'document_id': '201706060753',
#     'document_type': 'WARRANTY DEED',
#     'lender_name': None,
#     'lender_type': None,
#     'loan_amount': None,
#     'loan_due_date': None,
#     'loan_finance_type': None,
#     'loan_interest_rate': None,
#     'loan_type': None,
#     'original_contract_date': '2017-04-04',
#     'real_estate_owned': 'NO',
#     'recording_date': '2017-06-06',
#     'sale_price': 168750,
#     'sale_price_description': 'SALES PRICE OR TRANSFER TAX ROUNDED BY COUNTY PRIOR TO COMPUTATION',
#     'seller2_first_name': None,
#     'seller2_last_name': None,
#     'seller_address': '151 BATTLE GREEN DR',
#     'seller_city': 'ROCHESTER',
#     'seller_first_name': 'CHRISTOPHER M',
#     'seller_last_name': 'CROWLEY',
#     'seller_state': 'NY',
#     'seller_unit_number': None,
#     'seller_zip_code': '14624',
#     'seller_zip_plus_four_code': '4969',
#     'transfer_tax': 675.0},
#    {'buyer2_first_name': None,
#     'buyer2_last_name': None,
#     'buyer_address': '1854 CONCORDIA LAKE CIR',
#     'buyer_city': 'CAPE CORAL',
#     'buyer_first_name': 'CHRISTOPHER M',
#     'buyer_last_name': 'CROWLEY',
#     'buyer_state': 'FL',
#     'buyer_unit_number': '808',
#     'buyer_unit_type': 'UNIT',
#     'buyer_zip_code': '33909',
#     'buyer_zip_plus_four_code': '9075',
#     'deed_book': '11701',
#     'deed_page': '490',
#     'distressed_sale': False,
#     'document_id': '201605250391',
#     'document_type': 'WARRANTY DEED',
#     'lender_name': None,
#     'lender_type': None,
#     'loan_amount': None,
#     'loan_due_date': None,
#     'loan_finance_type': None,
#     'loan_interest_rate': None,
#     'loan_type': None,
#     'original_contract_date': '2016-05-17',
#     'real_estate_owned': 'NO',
#     'recording_date': '2016-05-25',
#     'sale_price': 160750,
#     'sale_price_description': 'SALES PRICE OR TRANSFER TAX ROUNDED BY COUNTY PRIOR TO COMPUTATION',
#     'seller2_first_name': None,
#     'seller2_last_name': 'LOCKER FAMILY DYNASTY TRUST',
#     'seller_address': '4571 RTE 89',
#     'seller_city': 'SENECA FALLS',
#     'seller_first_name': 'ELMAR',
#     'seller_last_name': 'LOCKER',
#     'seller_state': 'NY',
#     'seller_unit_number': None,
#     'seller_zip_code': '13148',
#     'seller_zip_plus_four_code': None,
#     'transfer_tax': 643.0},
#    {'buyer2_first_name': 'ROBERT D',
#     'buyer2_last_name': 'SCOLARO',
#     'buyer_address': '4571 RT 89',
#     'buyer_city': 'SENECA FALLS',
#     'buyer_first_name': 'ELMAR',
#     'buyer_last_name': 'LOCKER',
#     'buyer_state': 'NY',
#     'buyer_unit_number': None,
#     'buyer_unit_type': None,
#     'buyer_zip_code': '13149',
#     'buyer_zip_plus_four_code': '0000',
#     'deed_book': '11315',
#     'deed_page': '315',
#     'distressed_sale': False,
#     'document_id': '201310110734',
#     'document_type': 'WARRANTY DEED',
#     'lender_name': None,
#     'lender_type': None,
#     'loan_amount': None,
#     'loan_due_date': None,
#     'loan_finance_type': None,
#     'loan_interest_rate': None,
#     'loan_type': None,
#     'original_contract_date': '2013-10-07',
#     'real_estate_owned': 'NO',
#     'recording_date': '2013-10-11',
#     'sale_price': 155000,
#     'sale_price_description': 'FULL AMOUNT STATED ON DOCUMENT',
#     'seller2_first_name': None,
#     'seller2_last_name': None,
#     'seller_address': '151 BATTLE GREEN DR',
#     'seller_city': 'ROCHESTER',
#     'seller_first_name': 'SONIA M',
#     'seller_last_name': 'PALERMO',
#     'seller_state': 'NY',
#     'seller_unit_number': None,
#     'seller_zip_code': '14624',
#     'seller_zip_plus_four_code': '4969',
#     'transfer_tax': 620.0},
#    {'buyer2_first_name': None,
#     'buyer2_last_name': None,
#     'buyer_address': '151 BATTLE GREEN DR',
#     'buyer_city': 'ROCHESTER',
#     'buyer_first_name': 'SONIA M',
#     'buyer_last_name': 'PALERMO',
#     'buyer_state': 'NY',
#     'buyer_unit_number': None,
#     'buyer_unit_type': None,
#     'buyer_zip_code': '14624',
#     'buyer_zip_plus_four_code': '4969',
#     'deed_book': '10926',
#     'deed_page': '081',
#     'distressed_sale': False,
#     'document_id': '201009270868',
#     'document_type': 'INTRAFAMILY TRANSFER AND DISSOLUTION',
#     'lender_name': 'RBS CITIZENS NA',
#     'lender_type': 'BANK',
#     'loan_amount': 110000,
#     'loan_due_date': '2040-10-01',
#     'loan_finance_type': None,
#     'loan_interest_rate': None,
#     'loan_type': 'NEW CONVENTIONAL',
#     'original_contract_date': '2010-09-16',
#     'real_estate_owned': 'NO',
#     'recording_date': '2010-09-27',
#     'sale_price': None,
#     'sale_price_description': 'NON-ARMS LENGTH TRANSACTION',
#     'seller2_first_name': 'SONIA M',
#     'seller2_last_name': 'PALERMO',
#     'seller_address': '151 BATTLE GREEN DR',
#     'seller_city': 'ROCHESTER',
#     'seller_first_name': 'CHRISTOPHER M',
#     'seller_last_name': 'PALERMO',
#     'seller_state': 'NY',
#     'seller_unit_number': None,
#     'seller_zip_code': '14624',
#     'seller_zip_plus_four_code': '4969',
#     'transfer_tax': None}],
#   'market_assessments': [{'improvement_value': 164896,
#     'land_value': 32708,
#     'total_value': 197604,
#     'year': 2020}],
#   'metadata': {'publishing_date': '2021-02-01'},
#   'owner': {'city': 'ROCHESTER',
#    'formatted_street_address': '151 BATTLE GREEN DR',
#    'name': 'KRISTIN N RIMES',
#    'owner_occupied': 'YES',
#    'second_name': None,
#    'state': 'NY',
#    'unit_number': None,
#    'unit_type': None,
#    'zip_code': '14624',
#    'zip_plus_four_code': '4969'},
#   'parcel': {'apn_original': '262200 147.09-2-6',
#    'apn_previous': None,
#    'apn_unformatted': '2622001470926',
#    'area_acres': 0.22,
#    'area_sq_ft': 9583,
#    'building_count': None,
#    'county_land_use_code': '210',
#    'county_land_use_description': '1-FAMILY YEAR-ROUND RESIDENCE',
#    'county_name': 'MONROE',
#    'depth_ft': 125.0,
#    'fips_code': '36055',
#    'frontage_ft': 75.0,
#    'legal_description': 'LOT 27 3000 ACRE TRACT LEXINGTON SUB SEC 12 L-1205 245-51',
#    'location_descriptions': [],
#    'lot_code': None,
#    'lot_number': '6',
#    'municipality': 'CHILI',
#    'section_township_range': None,
#    'standardized_land_use_category': 'RESIDENTIAL',
#    'standardized_land_use_type': 'SINGLE FAMILY RESIDENTIAL',
#    'subdivision': None,
#    'tax_account_number': 'COM-0003926',
#    'zoning': '02 - SINGLE RESIDENCE'},
#   'structure': {'air_conditioning_type': 'CENTRAL',
#    'amenities': [],
#    'architecture_type': 'COLONIAL',
#    'basement_type': 'FULL BASEMENT',
#    'baths': 2.0,
#    'beds_count': 4,
#    'condition': 'GOOD',
#    'construction_type': None,
#    'effective_year_built': None,
#    'exterior_wall_type': 'ALUMINUM OR VINYL SIDING',
#    'fireplaces': '1',
#    'flooring_types': [],
#    'foundation_type': None,
#    'heating_fuel_type': 'GAS',
#    'heating_type': 'FORCED AIR UNIT',
#    'interior_wall_type': None,
#    'other_areas': [{'sq_ft': '912', 'type': '1ST FLOOR'},
#     {'sq_ft': '1063', 'type': '2ND FLOOR'},
#     {'sq_ft': '400', 'type': 'GARAGE'},
#     {'sq_ft': '592', 'type': 'COVERED PORCH'}],
#    'other_features': [],
#    'other_improvements': [{'sq_ft': '10X12', 'type': 'SHED'}],
#    'other_rooms': ['RECREATION ROOM'],
#    'parking_spaces_count': 2,
#    'parking_type': 'ATTACHED GARAGE',
#    'partial_baths_count': 1,
#    'plumbing_fixtures_count': None,
#    'pool_type': None,
#    'quality': 'C',
#    'roof_material_type': None,
#    'roof_style_type': None,
#    'rooms_count': None,
#    'sewer_type': 'MUNICIPAL',
#    'stories': '2+B',
#    'total_area_sq_ft': 1975,
#    'units_count': None,
#    'water_type': 'MUNICIPAL',
#    'year_built': 1989},
#   'taxes': [{'amount': 8868,
#     'exemptions': [],
#     'rate_code_area': '262601',
#     'year': 2021}],
#   'valuation': {'date': '2022-01-06',
#    'forecast_standard_deviation': 10,
#    'high': 273900,
#    'low': 224100,
#    'value': 249000}},
#  'metadata': {'timestamp': '2022-01-26T22:18:28.289771Z',
#   'version': '0.10.0-2.23.3'},
#  'warnings': []}

# %%
response_json['data'].keys()
# Out:
# dict_keys(['metadata', 'address', 'parcel', 'boundary', 'structure', 'valuation', 'taxes', 'assessments', 'market_assessments', 'owner', 'deeds'])

# %%
# normalize into a tabular format
df = pd.json_normalize(
    data=response_json['data']
    )
df.head()
# Out:
#                                                taxes  ... owner.owner_occupied
# 0  [{'year': 2021, 'amount': 8868, 'exemptions': ...  ...                  YES
#
# [1 rows x 98 columns]

# %%
# download
df.to_csv('estated_output.csv', index=False)
files.download('estated_output.csv')

# %% [markdown]
# ### <font color="green">Sub Tables</font>

# %%
# select keys to view sub tables
print('Keys available under <data>: {}', response_json['data'].keys())
deeds_dict = response_json['data']['deeds']
deeds_dict
# Out:
# Keys available under <data>: {} dict_keys(['metadata', 'address', 'parcel', 'boundary', 'structure', 'valuation', 'taxes', 'assessments', 'market_assessments', 'owner', 'deeds'])
# [{'buyer2_first_name': None,
#   'buyer2_last_name': None,
#   'buyer_address': '151 BATTLE GREEN DR',
#   'buyer_city': 'ROCHESTER',
#   'buyer_first_name': 'KRISTIN',
#   'buyer_last_name': 'RIMES',
#   'buyer_state': 'NY',
#   'buyer_unit_number': None,
#   'buyer_unit_type': None,
#   'buyer_zip_code': '14624',
#   'buyer_zip_plus_four_code': '4969',
#   'deed_book': '12048',
#   'deed_page': '266',
#   'distressed_sale': False,
#   'document_id': '201807030288',
#   'document_type': 'WARRANTY DEED',
#   'lender_name': None,
#   'lender_type': None,
#   'loan_amount': None,
#   'loan_due_date': None,
#   'loan_finance_type': None,
#   'loan_interest_rate': None,
#   'loan_type': None,
#   'original_contract_date': '2018-06-28',
#   'real_estate_owned': 'NO',
#   'recording_date': '2018-07-03',
#   'sale_price': 199000,
#   'sale_price_description': 'FULL AMOUNT COMPUTED FROM TRANSFER TAX OR EXCISE TAX',
#   'seller2_first_name': None,
#   'seller2_last_name': None,
#   'seller_address': None,
#   'seller_city': None,
#   'seller_first_name': 'NICHOLAS M',
#   'seller_last_name': 'BELLUCCIO',
#   'seller_state': None,
#   'seller_unit_number': None,
#   'seller_zip_code': None,
#   'seller_zip_plus_four_code': None,
#   'transfer_tax': 796.0},
#  {'buyer2_first_name': None,
#   'buyer2_last_name': None,
#   'buyer_address': '151 BATTLE GREEN DR',
#   'buyer_city': 'ROCHESTER',
#   'buyer_first_name': 'NICHOLAS M',
#   'buyer_last_name': 'BELLUCCIO',
#   'buyer_state': 'NY',
#   'buyer_unit_number': None,
#   'buyer_unit_type': None,
#   'buyer_zip_code': '14624',
#   'buyer_zip_plus_four_code': '4969',
#   'deed_book': '11870',
#   'deed_page': '262',
#   'distressed_sale': False,
#   'document_id': '201706060753',
#   'document_type': 'WARRANTY DEED',
#   'lender_name': None,
#   'lender_type': None,
#   'loan_amount': None,
#   'loan_due_date': None,
#   'loan_finance_type': None,
#   'loan_interest_rate': None,
#   'loan_type': None,
#   'original_contract_date': '2017-04-04',
#   'real_estate_owned': 'NO',
#   'recording_date': '2017-06-06',
#   'sale_price': 168750,
#   'sale_price_description': 'SALES PRICE OR TRANSFER TAX ROUNDED BY COUNTY PRIOR TO COMPUTATION',
#   'seller2_first_name': None,
#   'seller2_last_name': None,
#   'seller_address': '151 BATTLE GREEN DR',
#   'seller_city': 'ROCHESTER',
#   'seller_first_name': 'CHRISTOPHER M',
#   'seller_last_name': 'CROWLEY',
#   'seller_state': 'NY',
#   'seller_unit_number': None,
#   'seller_zip_code': '14624',
#   'seller_zip_plus_four_code': '4969',
#   'transfer_tax': 675.0},
#  {'buyer2_first_name': None,
#   'buyer2_last_name': None,
#   'buyer_address': '1854 CONCORDIA LAKE CIR',
#   'buyer_city': 'CAPE CORAL',
#   'buyer_first_name': 'CHRISTOPHER M',
#   'buyer_last_name': 'CROWLEY',
#   'buyer_state': 'FL',
#   'buyer_unit_number': '808',
#   'buyer_unit_type': 'UNIT',
#   'buyer_zip_code': '33909',
#   'buyer_zip_plus_four_code': '9075',
#   'deed_book': '11701',
#   'deed_page': '490',
#   'distressed_sale': False,
#   'document_id': '201605250391',
#   'document_type': 'WARRANTY DEED',
#   'lender_name': None,
#   'lender_type': None,
#   'loan_amount': None,
#   'loan_due_date': None,
#   'loan_finance_type': None,
#   'loan_interest_rate': None,
#   'loan_type': None,
#   'original_contract_date': '2016-05-17',
#   'real_estate_owned': 'NO',
#   'recording_date': '2016-05-25',
#   'sale_price': 160750,
#   'sale_price_description': 'SALES PRICE OR TRANSFER TAX ROUNDED BY COUNTY PRIOR TO COMPUTATION',
#   'seller2_first_name': None,
#   'seller2_last_name': 'LOCKER FAMILY DYNASTY TRUST',
#   'seller_address': '4571 RTE 89',
#   'seller_city': 'SENECA FALLS',
#   'seller_first_name': 'ELMAR',
#   'seller_last_name': 'LOCKER',
#   'seller_state': 'NY',
#   'seller_unit_number': None,
#   'seller_zip_code': '13148',
#   'seller_zip_plus_four_code': None,
#   'transfer_tax': 643.0},
#  {'buyer2_first_name': 'ROBERT D',
#   'buyer2_last_name': 'SCOLARO',
#   'buyer_address': '4571 RT 89',
#   'buyer_city': 'SENECA FALLS',
#   'buyer_first_name': 'ELMAR',
#   'buyer_last_name': 'LOCKER',
#   'buyer_state': 'NY',
#   'buyer_unit_number': None,
#   'buyer_unit_type': None,
#   'buyer_zip_code': '13149',
#   'buyer_zip_plus_four_code': '0000',
#   'deed_book': '11315',
#   'deed_page': '315',
#   'distressed_sale': False,
#   'document_id': '201310110734',
#   'document_type': 'WARRANTY DEED',
#   'lender_name': None,
#   'lender_type': None,
#   'loan_amount': None,
#   'loan_due_date': None,
#   'loan_finance_type': None,
#   'loan_interest_rate': None,
#   'loan_type': None,
#   'original_contract_date': '2013-10-07',
#   'real_estate_owned': 'NO',
#   'recording_date': '2013-10-11',
#   'sale_price': 155000,
#   'sale_price_description': 'FULL AMOUNT STATED ON DOCUMENT',
#   'seller2_first_name': None,
#   'seller2_last_name': None,
#   'seller_address': '151 BATTLE GREEN DR',
#   'seller_city': 'ROCHESTER',
#   'seller_first_name': 'SONIA M',
#   'seller_last_name': 'PALERMO',
#   'seller_state': 'NY',
#   'seller_unit_number': None,
#   'seller_zip_code': '14624',
#   'seller_zip_plus_four_code': '4969',
#   'transfer_tax': 620.0},
#  {'buyer2_first_name': None,
#   'buyer2_last_name': None,
#   'buyer_address': '151 BATTLE GREEN DR',
#   'buyer_city': 'ROCHESTER',
#   'buyer_first_name': 'SONIA M',
#   'buyer_last_name': 'PALERMO',
#   'buyer_state': 'NY',
#   'buyer_unit_number': None,
#   'buyer_unit_type': None,
#   'buyer_zip_code': '14624',
#   'buyer_zip_plus_four_code': '4969',
#   'deed_book': '10926',
#   'deed_page': '081',
#   'distressed_sale': False,
#   'document_id': '201009270868',
#   'document_type': 'INTRAFAMILY TRANSFER AND DISSOLUTION',
#   'lender_name': 'RBS CITIZENS NA',
#   'lender_type': 'BANK',
#   'loan_amount': 110000,
#   'loan_due_date': '2040-10-01',
#   'loan_finance_type': None,
#   'loan_interest_rate': None,
#   'loan_type': 'NEW CONVENTIONAL',
#   'original_contract_date': '2010-09-16',
#   'real_estate_owned': 'NO',
#   'recording_date': '2010-09-27',
#   'sale_price': None,
#   'sale_price_description': 'NON-ARMS LENGTH TRANSACTION',
#   'seller2_first_name': 'SONIA M',
#   'seller2_last_name': 'PALERMO',
#   'seller_address': '151 BATTLE GREEN DR',
#   'seller_city': 'ROCHESTER',
#   'seller_first_name': 'CHRISTOPHER M',
#   'seller_last_name': 'PALERMO',
#   'seller_state': 'NY',
#   'seller_unit_number': None,
#   'seller_zip_code': '14624',
#   'seller_zip_plus_four_code': '4969',
#   'transfer_tax': None}]

# %%
# view sub tables
df_deeds = pd.DataFrame(deeds_dict)
df_deeds
# Out:
#                           document_type  ... loan_interest_rate
# 0                         WARRANTY DEED  ...               None
# 1                         WARRANTY DEED  ...               None
# 2                         WARRANTY DEED  ...               None
# 3                         WARRANTY DEED  ...               None
# 4  INTRAFAMILY TRANSFER AND DISSOLUTION  ...               None
#
# [5 rows x 39 columns]

# %% [markdown]
# ### <font color="green">Case Study: Find Potential Investments</font>

# %%
# create a dataframe
d = {'address': ['9210 Horizon Dr, Spring Hill, FL 34608', '11230 Holbrook St, Spring Hill, FL 34609']}
_df_addresses = pd.DataFrame(data=d)
_df_addresses
# Out:
#                                     address
# 0    9210 Horizon Dr, Spring Hill, FL 34608
# 1  11230 Holbrook St, Spring Hill, FL 34609

# %%
# split dataframe into sub address elements
df_addresses = _df_addresses.copy()
df_addresses['street'] = df_addresses.apply(lambda x: x['address'].split(',')[0], axis=1)
df_addresses['city'] = df_addresses.apply(lambda x: x['address'].split(',')[1].strip(), axis=1)
df_addresses['state'] = df_addresses.apply(lambda x: x['address'].split(',')[2].split()[0], axis=1)
df_addresses['zip_code'] = df_addresses.apply(lambda x: x['address'].split(',')[2].split()[1], axis=1)
df_addresses
# Out:
#                                     address             street  ... state zip_code
# 0    9210 Horizon Dr, Spring Hill, FL 34608    9210 Horizon Dr  ...    FL    34608
# 1  11230 Holbrook St, Spring Hill, FL 34609  11230 Holbrook St  ...    FL    34609
#
# [2 rows x 5 columns]

# %%
# get estated property detail per address

response_list = []
# iterate through rows in the dataframe (table)
for index, row in df_addresses.iterrows():
  # get parameters
  address = row['address']
  street = row['street']
  city = row['city']
  state = row['state']
  zip_code = row['zip_code']
  # get api response
  print('Getting data for address: {0}'.format(address))
  response = get_estated_detail(estated_api_key, 
                        street, 
                        city, 
                        state, 
                        zip_code)
  # append to list
  response_list.append(response)
# Out:
# Getting data for address: 9210 Horizon Dr, Spring Hill, FL 34608
# Getting data for address: 11230 Holbrook St, Spring Hill, FL 34609

# %%
print('Num of responses:', len(response_list))
print('Data keys:', response_list[1].json()['data'])
response_list[1].json()['data']['structure']
# Out:
# Num of responses: 2
# Data keys: {'metadata': {'publishing_date': '2021-11-01'}, 'address': {'street_number': '11230', 'street_pre_direction': None, 'street_name': 'HOLBROOK', 'street_suffix': 'ST', 'street_post_direction': None, 'unit_type': None, 'unit_number': None, 'formatted_street_address': '11230 HOLBROOK ST', 'city': 'SPRING HILL', 'state': 'FL', 'zip_code': '34609', 'zip_plus_four_code': '3843', 'carrier_code': 'R029', 'latitude': 28.465462, 'longitude': -82.536269, 'geocoding_accuracy': 'PARCEL CENTROID', 'census_tract': '120530411.062047'}, 'parcel': {'apn_original': 'R32-323-17-5090-0492-0070', 'apn_unformatted': 'R3232317509004920070', 'apn_previous': None, 'fips_code': '12053', 'frontage_ft': None, 'depth_ft': None, 'area_sq_ft': 12188, 'area_acres': 0.28, 'county_name': 'HERNANDO', 'county_land_use_code': '01', 'county_land_use_description': 'SINGLE FAMILY RESIDENCE', 'standardized_land_use_category': 'RESIDENTIAL', 'standardized_land_use_type': 'SINGLE FAMILY RESIDENTIAL', 'location_descriptions': [], 'zoning': None, 'building_count': None, 'tax_account_number': None, 'legal_description': 'BLK 492 LOT 7 SPRING HILL UNIT 9', 'lot_code': None, 'lot_number': '7', 'subdivision': 'SPRING HILL', 'municipality': None, 'section_township_range': 'SEC 32 TWN 23S RNG 17E'}, 'boundary': {'wkt': 'MULTIPOLYGON(((-82.53650545006644 28.465504112324993,-82.5364940115893 28.465512063231188,-82.53647986885085 28.465523117697785,-82.53646611192147 28.46553417396302,-82.53645274979453 28.46554556927265,-82.53643987599946 28.465557655261648,-82.53642748873756 28.465570081194357,-82.53641558800894 28.465582504429108,-82.5364040757874 28.465595613846574,-82.53639315711848 28.46560906230843,-82.53638271958681 28.465622855210654,-82.53637186207175 28.46563626140437,-82.53635924997934 28.46565561031821,-82.5360293597671 28.465485702303397,-82.53610366894912 28.465370582786193,-82.53622934380911 28.46527657575342,-82.53626064111563 28.465253074669704,-82.53650545006644 28.465504112324993)))', 'geojson': {'type': 'MultiPolygon', 'coordinates': [[[[-82.53650545006644, 28.465504112324993], [-82.5364940115893, 28.465512063231188], [-82.53647986885085, 28.465523117697785], [-82.53646611192147, 28.46553417396302], [-82.53645274979453, 28.46554556927265], [-82.53643987599946, 28.465557655261648], [-82.53642748873756, 28.465570081194357], [-82.53641558800894, 28.465582504429108], [-82.5364040757874, 28.465595613846574], [-82.53639315711848, 28.46560906230843], [-82.53638271958681, 28.465622855210654], [-82.53637186207175, 28.46563626140437], [-82.53635924997934, 28.46565561031821], [-82.5360293597671, 28.465485702303397], [-82.53610366894912, 28.465370582786193], [-82.53622934380911, 28.46527657575342], [-82.53626064111563, 28.465253074669704], [-82.53650545006644, 28.465504112324993]]]]}}, 'structure': {'year_built': 1983, 'effective_year_built': 1989, 'stories': '1', 'rooms_count': 5, 'beds_count': 3, 'baths': 2.0, 'partial_baths_count': None, 'units_count': None, 'parking_type': 'GARAGE', 'parking_spaces_count': 2, 'pool_type': 'YES', 'architecture_type': None, 'construction_type': 'WOOD', 'exterior_wall_type': 'STUCCO', 'foundation_type': 'CONCRETE', 'roof_material_type': 'COMPOSITION SHINGLE', 'roof_style_type': 'GABLE OR HIP', 'heating_type': 'YES', 'heating_fuel_type': None, 'air_conditioning_type': 'YES', 'fireplaces': None, 'basement_type': None, 'quality': None, 'condition': 'AVERAGE', 'flooring_types': ['COMBINATION'], 'plumbing_fixtures_count': 6, 'interior_wall_type': 'GYPSUM BOARD', 'water_type': None, 'sewer_type': None, 'total_area_sq_ft': 1820, 'other_areas': [{'type': 'BASE AREA', 'sq_ft': '1820'}, {'type': 'ENCLOSED PORCH', 'sq_ft': '176'}, {'type': 'COVERED PORCH', 'sq_ft': '280'}, {'type': 'MEZZANINE', 'sq_ft': '483'}, {'type': 'ENCLOSED PORCH', 'sq_ft': '88'}, {'type': 'COVERED PORCH', 'sq_ft': '30'}, {'type': 'COVERED PORCH', 'sq_ft': '16'}], 'other_rooms': [], 'other_features': [{'type': 'SCREENED ENCLOSURE', 'sq_ft': '589'}, {'type': 'CONCRETE ...
# {'air_conditioning_type': 'YES',
#  'amenities': [],
#  'architecture_type': None,
#  'basement_type': None,
#  'baths': 2.0,
#  'beds_count': 3,
#  'condition': 'AVERAGE',
#  'construction_type': 'WOOD',
#  'effective_year_built': 1989,
#  'exterior_wall_type': 'STUCCO',
#  'fireplaces': None,
#  'flooring_types': ['COMBINATION'],
#  'foundation_type': 'CONCRETE',
#  'heating_fuel_type': None,
#  'heating_type': 'YES',
#  'interior_wall_type': 'GYPSUM BOARD',
#  'other_areas': [{'sq_ft': '1820', 'type': 'BASE AREA'},
#   {'sq_ft': '176', 'type': 'ENCLOSED PORCH'},
#   {'sq_ft': '280', 'type': 'COVERED PORCH'},
#   {'sq_ft': '483', 'type': 'MEZZANINE'},
#   {'sq_ft': '88', 'type': 'ENCLOSED PORCH'},
#   {'sq_ft': '30', 'type': 'COVERED PORCH'},
#   {'sq_ft': '16', 'type': 'COVERED PORCH'}],
#  'other_features': [{'sq_ft': '589', 'type': 'SCREENED ENCLOSURE'},
#   {'sq_ft': '934', 'type': 'CONCRETE PAVING'}],
#  'other_improvements': [{'sq_ft': '288', 'type': 'POOL SIZE'}],
#  'other_rooms': [],
#  'parking_spaces_count': 2,
#  'parking_type': 'GARAGE',
#  'partial_baths_count': None,
#  'plumbing_fixtures_count': 6,
#  'pool_type': 'YES',
#  'quality': None,
#  'roof_material_type': 'COMPOSITION SHINGLE',
#  'roof_style_type': 'GABLE OR HIP',
#  'rooms_count': 5,
#  'sewer_type': None,
#  'stories': '1',
#  'total_area_sq_ft': 1820,
#  'units_count': None,
#  'water_type': None,
#  'year_built': 1983}

# %%
# Python code to merge dict using a single
# expression
def Merge(dict1, dict2, dict3):
    res = {**dict1, **dict2, **dict3}
    return res

structure_data_list = [Merge(resp.json()['data']['address'], resp.json()['data']['valuation'], resp.json()['data']['structure']) for resp in response_list]
pd.DataFrame(structure_data_list)
# Out:
#   street_number  ... amenities
# 0          9210  ...        []
# 1         11230  ...        []
#
# [2 rows x 57 columns]

# %% [markdown]
# # End Notebook
