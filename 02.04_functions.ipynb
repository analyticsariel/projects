# %% [markdown]
# <a href="https://colab.research.google.com/github/analyticsariel/projects/blob/master/02.04_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Functions
#
# ## Overview
# | Detail Tag            | Information                                                                                        |
# |-----------------------|----------------------------------------------------------------------------------------------------|
# | Created By | Ariel Herrera arielherrera@analyticsariel.com |
#
# ## History
# | Date         | Developed By  | Reason                                                |
# |--------------|---------------|-------------------------------------------------------|
# | 1st Sep 2022 | Ariel Herrera | Create notebook. |
#
# ## Getting Started
# 1. Copy this notebook -> File -> Save a Copy in Drive
#
# ## Useful Resources
# - [Course Contents](https://colab.research.google.com/drive/12K0Ow9Y8v3-a1xuWMc52aPFgaLl-h9vx)
# - [Google Colab Cheat Sheet](https://towardsdatascience.com/cheat-sheet-for-google-colab-63853778c093)
# - [Format Currency](https://stackabuse.com/format-number-as-currency-string-in-python/)
# - [Functions](https://www.w3schools.com/python/python_functions.asp)

# %% [markdown]
# ## <font color="blue">What are Functions?</font>
# A function is a block of code which only runs when it is called.
#
# You can pass data, known as parameters, into a function.
#
# A function can return data as a result.
#
# **We will be using functions A LOT!**

# %% [markdown]
# ### <font color="green">1. Increase Rent Percentage</font>

# %%
# calculate rent increase

# %%
rent_income_list = [1300, 1450, 900, 1500]

inc = .05 # increase prct
# create for loop

# %% [markdown]
# ### <font color="green">2. Credit Check</font>

# %%
# create function to check credit check with 3 parameters

# %%
# applicant with good credit score

# %%
# applicant with low credit score and bandwidth

# %%
# applicant with low credit score and NO bandwidth (hard limit)

# %% [markdown]
# ### <font color="green">3. Monthly Mortgage</font>

# %%
# Get the monthly mortgage payment from mortgage details

# %%
# purchase_price = 300000
# downpayment = 0.20
# principal = purchase_price * (1 - downpayment)
# print('Principal: ${:,.2f}'.format(principal))

# %%
# call function to get monthly mortgage payment

# %% [markdown]
# ## Recap
# We covered Functions for:
# 1. Increase Rent Percentage
# 2. Credit Check
# 3. Monthly Mortgage
#
# Let's explore list comprehensions in the following lessons!

# %% [markdown]
# ## Need more help?
# Check out the video below for an in-depth view of functions

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('NSbOtYzIQI0')

# %% [markdown]
# # End Notebook
