# %% [markdown]
# <a href="https://colab.research.google.com/github/analyticsariel/projects/blob/master/Redfin_Market_Data_Zip_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Redfin Market Data - Zip Code
#
# ## Overview
# | Detail Tag            | Information                                                                                        |
# |-----------------------|----------------------------------------------------------------------------------------------------|
# | Originally Created By | Ariel Herrera arielherrera@analyticsariel.com |
# | External References   | API |
# | Input Datasets        | Source name |
# | Output Datasets       | Source name |
# | Input Data Source     | Pandas DataFrame |
# | Output Data Source    | Pandas DataFrame |
#
# ## History
# | Date         | Developed By  | Reason                                                |
# |--------------|---------------|-------------------------------------------------------|
# | 1st Jun 2021 | Ariel Herrera | Create notebook. |
#
# ## Getting Started
# 1. Copy this notebook -> File -> Save a Copy in Drive
# 2. Directions
#
# ## Useful Resources
# - [Google Colab Cheat Sheet](https://towardsdatascience.com/cheat-sheet-for-google-colab-63853778c093)

# %% [markdown]
# ## <font color="blue">Install Packages</font>

# %% [markdown]
# ## <font color="blue">Imports</font>

# %%
from google.colab import drive, files # specific to Google Colab
from datetime import datetime
import pandas as pd
import time
import warnings

pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')

# %% [markdown]
# ## <font color="blue">Functions</font>

# %% [markdown]
# ## <font color="blue">Locals & Constants</font>

# %% [markdown]
# ## <font color="blue">Data</font>

# %%
# url link from - https://www.redfin.com/news/data-center/
url = 'https://redfin-public-data.s3.us-west-2.amazonaws.com/redfin_market_tracker/zip_code_market_tracker.tsv000.gz'

# start time to read file
startTime = time.time()
df = pd.read_csv(url, compression='gzip', sep='\t', on_bad_lines='skip')
# end time 
executionTime = (time.time() - startTime)
print('Execution time in minutes: ' + str(round(executionTime / 60, 2)))
print('Num of rows:', len(df))
print('Num of cols:', len(df.columns))
df.head()
# Out:
# Execution time in minutes: 2.29
# Num of rows: 5884029
# Num of cols: 58
#   period_begin  period_end  period_duration region_type  region_type_id  \
# 0   2013-02-01  2013-04-30               90    zip code               2
# 1   2015-09-01  2015-11-30               90    zip code               2
# 2   2016-01-01  2016-03-31               90    zip code               2
# 3   2017-04-01  2017-06-30               90    zip code               2
# 4   2015-01-01  2015-03-31               90    zip code               2
#
#    table_id is_seasonally_adjusted           region  city          state  \
# 0     10714                      f  Zip Code: 26757   NaN  West Virginia
# 1     35915                      f  Zip Code: 84093   NaN           Utah
# 2     34773                      f  Zip Code: 80238   NaN       Colorado
# 3      1373                      f  Zip Code: 04210   NaN          Maine
# 4     23258                      f  Zip Code: 54603   NaN      Wisconsin
#
#   state_code              property_type  property_type_id  median_sale_price  \
# 0         WV  Single Family Residential                 6            95000.0
# 1         UT                  Townhouse                13           299270.0
# 2         CO                  Townhouse                13           431250.0
# 3         ME                Condo/Co-op                 3           180000.0
# 4         WI                Condo/Co-op                 3           195000.0
#
#    median_sale_price_mom  median_sale_price_yoy  median_list_price  \
# 0               0.032609              -0.208333           135000.0
# 1              -0.077749               0.088255           295000.0
# 2               0.140873               0.051913           415422.5
# 3              -0.088608              -0.100000           117400.0
# 4                    NaN                    NaN           199800.0
#
#    median_list_price_mom  median_list_price_yoy  median_ppsf  median_ppsf_mom  \
# 0               0.040864              -0.068323    83.333333         0.218966
# 1               0.000000                    NaN   118.406430         0.069277
# 2               0.000120               0.118513   201.993317        -0.113819
# 3              -0.190345              -0.079216   112.781955        -0.063703
# 4                    NaN                    NaN   165.254237              NaN
#
#    median_ppsf_yoy  median_list_ppsf  median_list_ppsf_mom  \
# 0        -0.136719        110.644861              0.165324
# 1        -0.039831        120.010225             -0.040325
# 2         0.249501        225.313886              0.000000
# 3         0.221940         91.640723             -0.159899
# 4              NaN        145.475728                   NaN
#
#    median_list_ppsf_yoy  homes_sold  homes_sold_mom  homes_sold_yoy  \
# 0              0.181424        25.0        0.315789        0.470588
# 1                   NaN         4.0        1.000000        3.000000
# 2              0.305622         6.0        0.200000       -0.250000
# 3             -0.017776         7.0        0.750000        0.400000
# 4                   NaN         1.0             NaN             NaN
#
#    pending_sales  pending_sales_mom  pending_sales_yoy  new_listings  \
# 0            2.0          -0.333333                0.0          17.0
# 1            NaN                NaN                NaN           NaN
# 2            6.0           0.200000                0.5          20.0
# 3            4.0           0.000000                1.0          10.0
# 4            1.0                NaN                NaN           4.0
#
#    new_listings_mom  new_listings_yoy  inventory  inventory_mom  \
# 0         -0.392857         -0.638298       54.0      -0.129032
# 1               NaN               NaN        NaN            NaN
# 2          0.428571          1.222222        7.0       0.000000
# 3          0.111111          0.000000        3.0      -0.500000
# 4               NaN               NaN        4.0            NaN
#
#    inventory_yoy  months_of_supply  months_of_supply_mom  \
# 0      -0.325000               NaN                   NaN
# 1            NaN               NaN                   NaN
# 2       1.333333               NaN                   NaN
# 3      -0.571429               NaN                   NaN
# 4            NaN               NaN                   NaN
#
#    months_of_supply_yoy  median_dom  median_dom_mom  median_dom_yoy  \
# 0                   NaN       105.0            -9.0           -19.0
# 1                   NaN        40.5             3.5          -177.5
# 2                   NaN         5.0             0.0           -17.5
# 3                   NaN        19.0             9.0             6.0
# 4                   NaN       333.0             NaN             NaN
#
#    avg_sale_to_list  avg_sale_to_list_mom  avg_sale_to_list_yoy  \
# 0          0.957351             -0.003772              0.028875
# 1          0.977453             -0.024910             -0.013896
# 2          1.009202              0.009876              0.020281
# 3          0.949244             -0.004520             -0.008079
# 4          0.975488                   NaN                   NaN
#
#    sold_above_list  sold_above_list_mom  sold_above_list_yoy  price_drops  \
# 0         0.160000             0.054737             0.160000          NaN
# 1         0.250000            -0.250000             0.250000          NaN
# 2         0.500000             0.300000             0.250000          NaN
# 3         0.142857             0.142857             0.142857          NaN
# 4         0.000000                  NaN                  NaN          NaN
#
#    price_drops_mom  price_drops_yoy  off_market_in_two_weeks  \
# 0              NaN              NaN                 0.000000
# 1              NaN              NaN                      NaN
# 2              NaN              NaN                 0.666667
# 3              NaN              NaN                 0.750000
# 4              NaN              NaN                 1.000000
#
#    off_market_in_two_weeks_mom  off_market_in_two_weeks_yoy  \
# 0                     0.000000                     0.000000
# 1                          NaN                          NaN
# 2                     0.266667                    -0.083333
# 3                     0.750000                     0.250000
# 4                          NaN                          NaN
#
#   parent_metro_region  parent_metro_region_metro_code         last_updated
# 0      Winchester, VA                           49020  2022-06-12 14:28:57
# 1  Salt Lake City, UT                           41620  2022-06-12 14:28:57
# 2          Denver, CO                           19740  2022-06-12 14:28:57
# 3        Lewiston, ME                           30340  2022-06-12 14:28:57
# 4       La Crosse, WI                           29100  2022-06-12 14:28:57

# %% [markdown]
# ## <font color="blue">Transformations</font>

# %%
# filter on state code
state_code = 'FL'
df_filter = df.loc[df['state_code'] == state_code]
print('Num of rows:', len(df_filter))
df_filter.head(1)
# Out:
# Num of rows: 386584
#   period_begin  period_end  period_duration region_type  region_type_id  \
# 5   2019-01-01  2019-03-31               90    zip code               2
#
#    table_id is_seasonally_adjusted           region  city    state state_code  \
# 5     14776                      f  Zip Code: 34994   NaN  Florida         FL
#
#   property_type  property_type_id  median_sale_price  median_sale_price_mom  \
# 5   Condo/Co-op                 3           115500.0              -0.017021
#
#    median_sale_price_yoy  median_list_price  median_list_price_mom  \
# 5              -0.024905           129500.0               0.027778
#
#    median_list_price_yoy  median_ppsf  median_ppsf_mom  median_ppsf_yoy  \
# 5              -0.007663   111.434109        -0.038593         0.018897
#
#    median_list_ppsf  median_list_ppsf_mom  median_list_ppsf_yoy  homes_sold  \
# 5             125.0              0.001278             -0.020153        64.0
#
#    homes_sold_mom  homes_sold_yoy  pending_sales  pending_sales_mom  \
# 5        0.103448       -0.157895           20.0           0.052632
#
#    pending_sales_yoy  new_listings  new_listings_mom  new_listings_yoy  \
# 5          -0.354839          93.0         -0.010638         -0.311111
#
#    inventory  inventory_mom  inventory_yoy  months_of_supply  \
# 5       84.0      -0.096774      -0.333333               NaN
#
#    months_of_supply_mom  months_of_supply_yoy  median_dom  median_dom_mom  \
# 5                   NaN                   NaN        50.0            -3.0
#
#    median_dom_yoy  avg_sale_to_list  avg_sale_to_list_mom  \
# 5            -9.5          0.943252             -0.000173
#
#    avg_sale_to_list_yoy  sold_above_list  sold_above_list_mom  \
# 5             -0.005195          0.09375             0.007543
#
#    sold_above_list_yoy  price_drops  price_drops_mom  price_drops_yoy  \
# 5             0.054276          NaN              NaN              NaN
#
#    off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 5                      0.1                    -0.005263
#
#    off_market_in_two_weeks_yoy parent_metro_region  \
# 5                    -0.254839  Port St. Lucie, FL
#
#    parent_metro_region_metro_code         last_updated
# 5                           38940  2022-06-12 14:28:57

# %%
df_filter.describe()
# Out:
#        period_duration  region_type_id       table_id  city  property_type_id  \
# count         386584.0        386584.0  386584.000000   0.0     386584.000000
# mean              90.0             2.0   14401.738595   NaN          4.522937
# std                0.0             0.0    2932.434518   NaN          4.678744
# min               90.0             2.0   13309.000000   NaN         -1.000000
# 25%               90.0             2.0   13789.000000   NaN         -1.000000
# 50%               90.0             2.0   14107.000000   NaN          4.000000
# 75%               90.0             2.0   14457.000000   NaN          6.000000
# max               90.0             2.0   41994.000000   NaN         13.000000
#
#        median_sale_price  median_sale_price_mom  median_sale_price_yoy  \
# count       3.865840e+05          375070.000000          354181.000000
# mean        2.485784e+05               0.028650               0.223037
# std         2.755073e+05               0.951993              26.950052
# min         1.000000e+00              -0.999977              -0.999846
# 25%         1.290000e+05              -0.021739               0.006944
# 50%         1.981500e+05               0.000000               0.104938
# 75%         2.950000e+05               0.043478               0.236667
# max         1.550000e+07             499.500000           15999.000000
#
#        median_list_price  median_list_price_mom  median_list_price_yoy  \
# count       3.695950e+05          357695.000000          341551.000000
# mean        2.769843e+05               0.033566               0.160217
# std         3.352239e+05               1.339819               1.485152
# min         5.500000e+02              -0.997876              -0.996839
# 25%         1.430000e+05              -0.024081               0.002466
# 50%         2.180000e+05               0.000334               0.095248
# 75%         3.200000e+05               0.044544               0.217239
# max         4.506500e+07             309.537304             365.666667
#
#          median_ppsf  median_ppsf_mom  median_ppsf_yoy  median_list_ppsf  \
# count  386395.000000    374896.000000    354017.000000     369525.000000
# mean      148.259141         0.030682         0.207479        164.909370
# std       259.905190         2.450966        20.047660        854.991414
# min         0.000751        -0.999977        -0.999895          0.379310
# 25%        88.902488        -0.011790         0.025857         98.524268
# 50%       125.874126         0.002891         0.098984        135.819747
# 75%       175.362459         0.032692         0.206923        189.221550
# max    110000.000000       750.167760     11531.467532     481981.823877
#
#        median_list_ppsf_mom  median_list_ppsf_yoy     homes_sold  \
# count         357635.000000         341497.000000  386584.000000
# mean               0.115408              0.164534      61.708069
# std               51.770820             15.321325      78.563830
# min               -0.999916             -0.999956       1.000000
# 25%               -0.012506              0.024943       5.000000
# 50%                0.004334              0.090763      28.000000
# 75%                0.032156              0.188895      93.000000
# max            30918.478629           8892.526139     917.000000
#
#        homes_sold_mom  homes_sold_yoy  pending_sales  pending_sales_mom  \
# count   375070.000000   354181.000000  316374.000000      287859.000000
# mean         0.050315        0.270425      18.340205           0.180661
# std          0.378792        3.095896      21.476741           0.806736
# min         -0.909091       -0.985714       1.000000          -0.960784
# 25%         -0.092308       -0.138889       3.000000          -0.239437
# 50%          0.000000        0.030675      10.000000           0.000000
# 75%          0.115942        0.295455      26.000000           0.333333
# max         31.500000      388.000000     280.000000          24.500000
#
#        pending_sales_yoy   new_listings  new_listings_mom  new_listings_yoy  \
# count      279464.000000  356849.000000     344684.000000     323062.000000
# mean            0.392120      76.121275          0.039112          0.178116
# std             1.400496      91.512000          0.338705          1.092806
# min            -0.978261       1.000000         -0.962963         -0.965517
# 25%            -0.166667       8.000000         -0.096774         -0.141732
# 50%             0.090909      38.000000          0.000000          0.018750
# 75%             0.562500     117.000000          0.111111          0.250000
# max           121.000000     949.000000         24.000000         91.000000
#
#            inventory  inventory_mom  inventory_yoy  months_of_supply  \
# count  353000.000000  341523.000000  321726.000000               0.0
# mean       82.882167       0.023553       0.027931               NaN
# std       113.389546       0.312170       0.765429               NaN
# min         1.000000      -0.958333      -0.982143               NaN
# 25%         9.000000      -0.083333      -0.272727               NaN
# 50%        39.000000       0.000000      -0.070175               NaN
# 75%       117.000000       0.072165       0.133758               NaN
# max      1797.000000      22.000000      52.000000               NaN
#
#        months_of_supply_mom  months_of_supply_yoy     median_dom  \
# count                   0.0                   0.0  376605.000000
# mean                    NaN                   NaN      94.903525
# std                     NaN                   NaN     195.004104
# min                     NaN                   NaN       1.000000
# 25%                     NaN                   NaN      39.000000
# 50%                     NaN                   NaN      64.500000
# 75%                     NaN                   NaN     102.000000
# max                     NaN                   NaN    8220.000000
#
#        median_dom_mom  median_dom_yoy  avg_sale_to_list  avg_sale_to_list_mom  \
# count   364695.000000   338237.000000     386238.000000         374724.000000
# mean        -0.954071      -13.199811          0.962556              0.000457
# std        125.340271      209.017558          0.043712              0.025909
# min      -7264.000000    -8152.000000          0.500000             -1.065897
# 25%         -7.000000      -30.500000          0.948438             -0.004195
# 50%          0.000000       -8.000000          0.966644              0.000000
# 75%          5.500000       10.000000          0.981624              0.005213
# max       8099.000000     8094.000000          1.963333              0.991597
#
#        avg_sale_to_list_yoy  sold_above_list  sold_above_list_mom  \
# count         353807.000000    386584.000000        375070.000000
# mean               0.004886         0.153578             0.001984
# std                0.047809         0.176456             0.102426
# min               -0.965909         0.000000            -1.000000
# 25%               -0.007514         0.000000            -0.015315
# 50%                0.004130         0.115385             0.000000
# 75%                0.017783         0.214286             0.019715
# max                1.033554         1.000000             1.000000
#
#        sold_above_list_yoy  price_drops  price_drops_mom  price_drops_yoy  \
# count        354181.000000          0.0              0.0              0.0
# mean              0.017541          NaN              NaN              NaN
# std               0.191574          NaN              NaN              NaN
# min              -1.000000          NaN              NaN              NaN
# 25%              -0.038503          NaN              NaN              NaN
# 50%               0.000000          NaN              NaN              NaN
# 75%               0.068182          NaN              NaN              NaN
# max               1.000000          NaN              NaN              NaN
#
#        off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# count            316374.000000                287859.000000
# mean                  0.289652                     0.003040
# std                   0.271135                     0.265677
# min                   0.000000                    -1.500000
# 25%                   0.000000                    -0.094118
# 50%                   0.250000                     0.000000
# 75%                   0.453125                     0.100000
# max                   2.000000                     1.500000
#
#        off_market_in_two_weeks_yoy  parent_metro_region_metro_code
# count                279464.000000                   386584.000000
# mean                      0.039075                    34960.707820
# std                       0.274532                     9082.778223
# min                      -1.250000                    11580.000000
# 25%                      -0.068421                    27260.000000
# 50%                       0.001201                    36740.000000
# 75%                       0.159091                    45220.000000
# max                       1.000000                    48424.000000

# %% [markdown]
# ### Sample Dataset

# %%
"""
PROBLEM - Data takes a long time to load in Tableau
RESOLUTION - Sample a subset of zip codes
"""
# get zip code county data
geo_data_url = 'https://raw.githubusercontent.com/scpike/us-state-county-zip/master/geo-data.csv'
df_geo = pd.read_csv(geo_data_url)
print('Num of rows:', len(df_geo))
print('Num of columns:', len(df_geo.columns))
df_geo.head()
# Out:
# Num of rows: 33103
# Num of columns: 6
#    state_fips    state state_abbr zipcode      county        city
# 0           1  Alabama         AL   35004   St. Clair       Acmar
# 1           1  Alabama         AL   35005   Jefferson  Adamsville
# 2           1  Alabama         AL   35006   Jefferson       Adger
# 3           1  Alabama         AL   35007      Shelby    Keystone
# 4           1  Alabama         AL   35010  Tallapoosa    New site

# %%
from IPython.display import Image, display
display(Image('https://www.fdottampabay.com/assets/images/d7-service-area-map-new.png'))

# %%
# filter on single county
df_geo_county = df_geo.loc[(df_geo['state_abbr'] == 'FL') &
                           (df_geo['county'].isin(['Hillsborough', 'Pinellas', 'Pasco', 'Hernando', 'Citris']))]
# create feature to check if zip code is valid
df_geo_county['valid_zip_code'] = df_geo_county.apply(lambda x: x['zipcode'].isnumeric(), axis=1)
print('Dataset:')
print(df_geo_county.groupby(['valid_zip_code', 'county'])['zipcode'].count())
print(' ')
print('Invalid zip codes:', df_geo_county.loc[df_geo_county['valid_zip_code'] == False]['zipcode'].unique())
# Out:
# Dataset:
# valid_zip_code  county
# False           Hernando         1
#                 Hillsborough     2
#                 Pasco            1
#                 Pinellas         1
# True            Hernando         9
#                 Hillsborough    45
#                 Pasco           19
#                 Pinellas        46
# Name: zipcode, dtype: int64
#
# Invalid zip codes: ['335HH' '336HH' '337HH' '346HH' '346XX']

# %%
# filter on only valid zip codes
df_geo_county_valid = df_geo_county.loc[df_geo_county['valid_zip_code'] == True]
print('Num of VALID zip codes:', len(df_geo_county_valid))
df_geo_county_valid.head(1)
# Out:
# Num of VALID zip codes: 119
#       state_fips    state state_abbr zipcode        county     city  \
# 5129          12  Florida         FL   33510  Hillsborough  Brandon
#
#       valid_zip_code
# 5129            True

# %%
# get zip code from region field
df_filter['zipcode'] = df_filter.apply(lambda x: x['region'].split(':')[1].strip(), axis=1)
# merge market data and geo zip codes
df_merge = pd.merge(
    df_filter,
    df_geo_county_valid[['zipcode', 'city', 'county']],
    how='inner', # only return zip codes from BOTH tables
    on=['zipcode'] # field to join on
)
print('Num of rows:', len(df_merge))
df_merge.head()
# Out:
# Num of rows: 56173
#   period_begin  period_end  period_duration region_type  region_type_id  \
# 0   2016-05-01  2016-07-31               90    zip code               2
# 1   2017-08-01  2017-10-31               90    zip code               2
# 2   2021-02-01  2021-04-30               90    zip code               2
# 3   2015-02-01  2015-04-30               90    zip code               2
# 4   2020-08-01  2020-10-31               90    zip code               2
#
#    table_id is_seasonally_adjusted           region  city_x    state  \
# 0     14383                      f  Zip Code: 33781     NaN  Florida
# 1     14383                      f  Zip Code: 33781     NaN  Florida
# 2     14383                      f  Zip Code: 33781     NaN  Florida
# 3     14383                      f  Zip Code: 33781     NaN  Florida
# 4     14383                      f  Zip Code: 33781     NaN  Florida
#
#   state_code              property_type  property_type_id  median_sale_price  \
# 0         FL  Single Family Residential                 6           138000.0
# 1         FL                  Townhouse                13           185100.0
# 2         FL                Condo/Co-op                 3            84850.0
# 3         FL                Condo/Co-op                 3            34900.0
# 4         FL                  Townhouse                13           228750.0
#
#    median_sale_price_mom  median_sale_price_yoy  median_list_price  \
# 0               0.061538               0.205240           159900.0
# 1              -0.002425               0.088824           204900.0
# 2              -0.030286               0.022289            87500.0
# 3              -0.008523              -0.002857            39900.0
# 4               0.063953               0.063953           239000.0
#
#    median_list_price_mom  median_list_price_yoy  median_ppsf  median_ppsf_mom  \
# 0               0.066711               0.391645   115.571776         0.001622
# 1              -0.000488               0.122740   127.400000         0.009324
# 2               0.029412               0.535088   101.066561        -0.156275
# 3               0.081301               0.453552    32.461677         0.022727
# 4              -0.004167               0.059867   158.379671         0.024006
#
#    median_ppsf_yoy  median_list_ppsf  median_list_ppsf_mom  \
# 0         0.272115        132.211538              0.051082
# 1         0.063131        134.325190              0.002698
# 2         0.101004         94.691943             -0.122395
# 3        -0.054554         35.978359              0.078378
# 4         0.049524        163.120567              0.006917
#
#    median_list_ppsf_yoy  homes_sold  homes_sold_mom  homes_sold_yoy  \
# 0              0.287100        97.0       -0.058252        0.077778
# 1              0.045160        23.0        0.150000        0.095238
# 2              0.238886         8.0        0.142857        0.600000
# 3             -0.124478         7.0        0.750000        0.000000
# 4              0.072695        12.0       -0.368421       -0.076923
#
#    pending_sales  pending_sales_mom  pending_sales_yoy  new_listings  \
# 0           21.0          -0.363636          -0.045455         101.0
# 1            9.0           0.500000           0.000000          18.0
# 2            2.0           1.000000          -0.333333           9.0
# 3            2.0          -0.333333           0.000000           9.0
# 4            3.0          -0.500000           0.000000          17.0
#
#    new_listings_mom  new_listings_yoy  inventory  inventory_mom  \
# 0         -0.073394          0.041237       82.0       0.078947
# 1         -0.142857         -0.280000       10.0       0.000000
# 2          0.000000          0.285714        5.0      -0.166667
# 3         -0.307692          0.500000       11.0      -0.153846
# 4         -0.105263          0.062500        8.0       0.333333
#
#    inventory_yoy  months_of_supply  months_of_supply_mom  \
# 0      -0.068182               NaN                   NaN
# 1      -0.333333               NaN                   NaN
# 2       0.250000               NaN                   NaN
# 3      -0.083333               NaN                   NaN
# 4       0.142857               NaN                   NaN
#
#    months_of_supply_yoy  median_dom  median_dom_mom  median_dom_yoy  \
# 0                   NaN        48.0            -2.0            -2.0
# 1                   NaN        23.0             0.0           -27.0
# 2                   NaN        13.0           -35.0           -51.5
# 3                   NaN        52.0            19.0          -172.0
# 4                   NaN        19.0             0.0             5.0
#
#    avg_sale_to_list  avg_sale_to_list_mom  avg_sale_to_list_yoy  \
# 0          0.993254              0.005869              0.008949
# 1          0.973702              0.007817             -0.009215
# 2          0.986780             -0.004834             -0.000821
# 3          0.933755              0.009664             -0.053506
# 4          0.986936              0.005513              0.021330
#
#    sold_above_list  sold_above_list_mom  sold_above_list_yoy  price_drops  \
# 0         0.329897             0.009509             0.041008          NaN
# 1         0.173913             0.073913             0.078675          NaN
# 2         0.250000            -0.035714             0.250000          NaN
# 3         0.000000             0.000000            -0.142857          NaN
# 4         0.166667             0.061404             0.166667          NaN
#
#    price_drops_mom  price_drops_yoy  off_market_in_two_weeks  \
# 0              NaN              NaN                 0.428571
# 1              NaN              NaN                 0.444444
# 2              NaN              NaN                 1.000000
# 3              NaN              NaN                 0.500000
# 4              NaN              NaN                 0.666667
#
#    off_market_in_two_weeks_mom  off_market_in_two_weeks_yoy  \
# 0                     0.125541                     0.201299
# 1                     0.111111                     0.111111
# 2                     0.000000                     1.000000
# 3                     0.166667                     0.000000
# 4                     0.000000                    -0.333333
#
#   parent_metro_region  parent_metro_region_metro_code         last_updated  \
# 0           Tampa, FL                           45300  2022-06-12 14:28:57
# 1           Tampa, FL                           45300  2022-06-12 14:28:57
# 2           Tampa, FL                           45300  2022-06-12 14:28:57
# 3           Tampa, FL                           45300  2022-06-12 14:28:57
# 4           Tampa, FL                           45300  2022-06-12 14:28:57
#
#   zipcode            city_y    county
# 0   33781  Saint petersburg  Pinellas
# 1   33781  Saint petersburg  Pinellas
# 2   33781  Saint petersburg  Pinellas
# 3   33781  Saint petersburg  Pinellas
# 4   33781  Saint petersburg  Pinellas

# %% [markdown]
# ### View Bad Data from Redfin

# %%
# choose a specific zip code / property type and view MoM change
# TODO: Future auto loop through each MoM column and recalulate
df_merge.loc[(df_merge['zipcode'] == '33510') & 
             (df_merge['property_type'] == 'Single Family Residential')]\
  .sort_values(by=['period_begin']).tail(2)\
  [['period_begin', 'median_dom', 'median_dom_mom', 'median_dom_yoy']]
# Out:
#       period_begin  median_dom  median_dom_mom  median_dom_yoy
# 46424   2022-02-01         6.0            -1.0             0.0
# 46786   2022-03-01         7.0             1.0             2.5

# %%
# test to correct the error
df_test = df_merge.copy()
df_test['median_dom_mom_correction'] = df_test.sort_values(by=['period_begin'])['median_dom'].pct_change()
df_test.loc[(df_test['zipcode'] == '33510') & 
             (df_test['property_type'] == 'Single Family Residential')]\
  .sort_values(by=['period_begin']).tail(2)\
  [['period_begin', 'median_dom', 'median_dom_mom', 'median_dom_yoy', 'median_dom_mom_correction']]
# Out:
#       period_begin  median_dom  median_dom_mom  median_dom_yoy  \
# 46424   2022-02-01         6.0            -1.0             0.0
# 46786   2022-03-01         7.0             1.0             2.5
#
#        median_dom_mom_correction
# 46424                   0.000000
# 46786                   0.166667

# %% [markdown]
# ### Add Features

# %%
# add features
df_features = df_merge.copy()
print('Max begin date:', df_features['period_begin'].max())
print('Max end date:', df_features['period_end'].max())
max_end_date = df_features['period_end'].max()

# 1) flag for most recent date
df_features['latest_period'] = df_features.apply(
    lambda x: True if x['period_end'] == max_end_date else False, axis=1)

# 2) remove Redfin city and keep Geo city
df_features = df_features.drop(columns=['city_x'])
df_features = df_features.rename(columns={'city_y': 'city'})

# 3) fix median days on market (bad data)
df_features['median_dom_mom'] = df_features.sort_values(by=['period_begin'])['median_dom'].pct_change()

# view first 5 rows
df_features.head()
# Out:
# Max begin date: 2022-03-01
# Max end date: 2022-05-31
#   period_begin  period_end  period_duration region_type  region_type_id  \
# 0   2016-05-01  2016-07-31               90    zip code               2
# 1   2017-08-01  2017-10-31               90    zip code               2
# 2   2021-02-01  2021-04-30               90    zip code               2
# 3   2015-02-01  2015-04-30               90    zip code               2
# 4   2020-08-01  2020-10-31               90    zip code               2
#
#    table_id is_seasonally_adjusted           region    state state_code  \
# 0     14383                      f  Zip Code: 33781  Florida         FL
# 1     14383                      f  Zip Code: 33781  Florida         FL
# 2     14383                      f  Zip Code: 33781  Florida         FL
# 3     14383                      f  Zip Code: 33781  Florida         FL
# 4     14383                      f  Zip Code: 33781  Florida         FL
#
#                property_type  property_type_id  median_sale_price  \
# 0  Single Family Residential                 6           138000.0
# 1                  Townhouse                13           185100.0
# 2                Condo/Co-op                 3            84850.0
# 3                Condo/Co-op                 3            34900.0
# 4                  Townhouse                13           228750.0
#
#    median_sale_price_mom  median_sale_price_yoy  median_list_price  \
# 0               0.061538               0.205240           159900.0
# 1              -0.002425               0.088824           204900.0
# 2              -0.030286               0.022289            87500.0
# 3              -0.008523              -0.002857            39900.0
# 4               0.063953               0.063953           239000.0
#
#    median_list_price_mom  median_list_price_yoy  median_ppsf  median_ppsf_mom  \
# 0               0.066711               0.391645   115.571776         0.001622
# 1              -0.000488               0.122740   127.400000         0.009324
# 2               0.029412               0.535088   101.066561        -0.156275
# 3               0.081301               0.453552    32.461677         0.022727
# 4              -0.004167               0.059867   158.379671         0.024006
#
#    median_ppsf_yoy  median_list_ppsf  median_list_ppsf_mom  \
# 0         0.272115        132.211538              0.051082
# 1         0.063131        134.325190              0.002698
# 2         0.101004         94.691943             -0.122395
# 3        -0.054554         35.978359              0.078378
# 4         0.049524        163.120567              0.006917
#
#    median_list_ppsf_yoy  homes_sold  homes_sold_mom  homes_sold_yoy  \
# 0              0.287100        97.0       -0.058252        0.077778
# 1              0.045160        23.0        0.150000        0.095238
# 2              0.238886         8.0        0.142857        0.600000
# 3             -0.124478         7.0        0.750000        0.000000
# 4              0.072695        12.0       -0.368421       -0.076923
#
#    pending_sales  pending_sales_mom  pending_sales_yoy  new_listings  \
# 0           21.0          -0.363636          -0.045455         101.0
# 1            9.0           0.500000           0.000000          18.0
# 2            2.0           1.000000          -0.333333           9.0
# 3            2.0          -0.333333           0.000000           9.0
# 4            3.0          -0.500000           0.000000          17.0
#
#    new_listings_mom  new_listings_yoy  inventory  inventory_mom  \
# 0         -0.073394          0.041237       82.0       0.078947
# 1         -0.142857         -0.280000       10.0       0.000000
# 2          0.000000          0.285714        5.0      -0.166667
# 3         -0.307692          0.500000       11.0      -0.153846
# 4         -0.105263          0.062500        8.0       0.333333
#
#    inventory_yoy  months_of_supply  months_of_supply_mom  \
# 0      -0.068182               NaN                   NaN
# 1      -0.333333               NaN                   NaN
# 2       0.250000               NaN                   NaN
# 3      -0.083333               NaN                   NaN
# 4       0.142857               NaN                   NaN
#
#    months_of_supply_yoy  median_dom  median_dom_mom  median_dom_yoy  \
# 0                   NaN        48.0       -0.150442            -2.0
# 1                   NaN        23.0       -0.417722           -27.0
# 2                   NaN        13.0        1.600000           -51.5
# 3                   NaN        52.0        0.238095          -172.0
# 4                   NaN        19.0        1.375000             5.0
#
#    avg_sale_to_list  avg_sale_to_list_mom  avg_sale_to_list_yoy  \
# 0          0.993254              0.005869              0.008949
# 1          0.973702              0.007817             -0.009215
# 2          0.986780             -0.004834             -0.000821
# 3          0.933755              0.009664             -0.053506
# 4          0.986936              0.005513              0.021330
#
#    sold_above_list  sold_above_list_mom  sold_above_list_yoy  price_drops  \
# 0         0.329897             0.009509             0.041008          NaN
# 1         0.173913             0.073913             0.078675          NaN
# 2         0.250000            -0.035714             0.250000          NaN
# 3         0.000000             0.000000            -0.142857          NaN
# 4         0.166667             0.061404             0.166667          NaN
#
#    price_drops_mom  price_drops_yoy  off_market_in_two_weeks  \
# 0              NaN              NaN                 0.428571
# 1              NaN              NaN                 0.444444
# 2              NaN              NaN                 1.000000
# 3              NaN              NaN                 0.500000
# 4              NaN              NaN                 0.666667
#
#    off_market_in_two_weeks_mom  off_market_in_two_weeks_yoy  \
# 0                     0.125541                     0.201299
# 1                     0.111111                     0.111111
# 2                     0.000000                     1.000000
# 3                     0.166667                     0.000000
# 4                     0.000000                    -0.333333
#
#   parent_metro_region  parent_metro_region_metro_code         last_updated  \
# 0           Tampa, FL                           45300  2022-06-12 14:28:57
# 1           Tampa, FL                           45300  2022-06-12 14:28:57
# 2           Tampa, FL                           45300  2022-06-12 14:28:57
# 3           Tampa, FL                           45300  2022-06-12 14:28:57
# 4           Tampa, FL                           45300  2022-06-12 14:28:57
#
#   zipcode              city    county  latest_period
# 0   33781  Saint petersburg  Pinellas          False
# 1   33781  Saint petersburg  Pinellas          False
# 2   33781  Saint petersburg  Pinellas          False
# 3   33781  Saint petersburg  Pinellas          False
# 4   33781  Saint petersburg  Pinellas          False

# %% [markdown]
# ## <font color="blue">Output</font>

# %%
date_str = datetime.today().strftime('%Y-%m')
print('Current year/month:', date_str)
# Out:
# Current year/month: 2022-06

# %%
# download file
df_features.to_csv('zip_realtor_{0}_{1}.csv'.format(state_code, date_str), index=False)
files.download('zip_realtor_{0}_{1}.csv'.format(state_code, date_str))

# %% [markdown]
# # End Notebook
